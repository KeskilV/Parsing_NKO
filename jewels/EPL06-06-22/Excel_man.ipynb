# %%
import pandas as pd

# %%
import re

# %%
import os

# %%
raw = pd.read_excel('ЭПЛ_парсинг_ман_05-06-2022.xlsx', header=None, sheet_name = 2 )

# %%
raw
# Out:
#                                                       0      1       2      3  \
# 0     https://epldiamond.ru/product/koltso-iz-belogo...    NaN     NaN    NaN
# 1                                                   NaN    NaN     NaN    NaN
# 2                 КОЛЬЦО ИЗ БЕЛОГО ЗОЛОТА С БРИЛЛИАНТОМ    NaN     NaN    NaN
# 3        Артикул: э09к041642 / Штрих код: 2050006033685    NaN     NaN    NaN
# 4                                       Цена: 138 860 ₽    NaN     NaN    NaN
# ...                                                 ...    ...     ...    ...
# 1382                                     ХАРАКТЕРИСТИКИ    NaN     NaN    NaN
# 1383  Тип металла: Белое золото, Вес: 1.78 грамм, Ра...    NaN     NaN    NaN
# 1384                                                NaN    NaN     NaN    NaN
# 1385                                            Вставка  Форма  Кол-во    Вес
# 1386                                          Бриллиант   Кр57       1  0.173
#
#          4        5        6
# ...

# %%
raw.loc[403:405]
# Out:
#              0     1    2     3                    4    5    6
# 403  Бриллиант  Кр57    1  0.43  2022-01-06 00:00:00    7    А
# 404        NaN   NaN  NaN   NaN                  NaN  NaN  NaN
# 405        NaN   NaN  NaN   NaN                  NaN  NaN  NaN

# %%
pd.read_excel?
