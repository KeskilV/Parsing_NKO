# %%
import numpy as np
import pandas as pd
import re
import os

# %%
import matplotlib.pyplot as plt

# %%
#from mpl_toolkits.mplot3d import Axes3D

# %%
# %matplotlib notebook
#%matplotlib inline

# %% [markdown]
# ###  FILENAME -->

# %%
files = os.listdir('.')
[nf for nf in enumerate(files)]
# Out:
# [(0, '.DS_Store'),
#  (1, '.git'),
#  (2, '.idea'),
#  (3, '.ipynb_checkpoints'),
#  (4, 'env'),
#  (5, 'for_parsing_func.ipynb'),
#  (6, 'jewels'),
#  (7, 'Parsing.html'),
#  (8, 'ParsingMiuz.ipynb'),
#  (9, 'ParsingNKObyAita.ipynb'),
#  (10, 'requiremnts.txt'),
#  (11, 'rusprice'),
#  (12, 'Untitled.ipynb'),
#  (13, 'visio_matplotlib.ipynb')]

# %%
path = files[6]
files1 = os.listdir(path)
[nf for nf in enumerate(files1)]
# Out:
# [(0, '.DS_Store'), (1, 'kdm'), (2, 'miuz')]

# %%
path1 = files1[1]
path2 = path+'/'+path1
files2 = os.listdir(path2)
[nf for nf in enumerate(files2)]
# Out:
# [(0, '_АНАЛИЗ_брилл_суммированы__объединенная_по_jewelsartemeva16112021.xlsx')]

# %%
path2+'/'+files2[0]
# Out:
# 'jewels/kdm/_АНАЛИЗ_брилл_суммированы__объединенная_по_jewelsartemeva16112021.xlsx'

# %%
filenamemiuz = 'jewels/miuz/_брилл_суммированы_mius161121_0-3178.xlsx'

# %%
filenamekdm =  'jewels/kdm/_АНАЛИЗ_брилл_суммированы__объединенная_по_jewelsartemeva16112021.xlsx'

# %% [markdown]
# ###  -- FILENAME;

# %% [markdown]
# ### MIUZ -->

# %%
raw = pd.read_excel(filenamemiuz,sheet_name=0)#[['price','weight','prcost']]

# %%
data = raw.loc[raw.price<400000,['price','weight','prcost']]

# %%
data.loc[data.prcost > 1400]
# Out:
#       price  weight   prcost  goldcarat
# 610  303396    4.44  1585.46         14
# 652  349500    2.56  1680.00         14

# %%
raw.loc[raw.prcost > 1400]
# Out:
#       Unnamed: 0  index_row                                        h1  \
# 1              1          4                      Кольцо c бриллиантом
# 15            15         56     Кольцо c бриллиантом R01-ALR52-070-G1
# 108          108        300         Кольцо c бриллиантом R01-89-34873
# 116          116        325     Кольцо c бриллиантами R4193-17310-WGW
# 162          162        439        Кольцо c бриллиантом R4154-BVP-148
# 193          193        507     Кольцо c бриллиантами R4193-17312-WGW
# 196          196        511    Кольцо c бриллиантами R4212-HY2845-150
# 210          210        534   Кольцо c бриллиантами R01-SL135-050-165
# 222          222        568     Кольцо c бриллиантом R01-ALR40-090-G2
# 366          366        947  Кольцо c бриллиантами R4212-SA2280R-100A
# 549          549       1426     Кольцо c бриллиантом R01-ALR01-090-G2
# 587          587       1523     Кольцо c бриллиантом R01-ALR40-070-G1
# 602          602       1561       Кольцо c бриллиантами R2022-SA2283R
# 610          610       1572        Кольцо c бриллиантами R01-89-34848
# 652          652       1679     Кольцо c бриллиантом R01-SOL01-070-G2
# 685          685       1761     Кольцо c бриллиантом R01-SOL53-050-G1
# 708          708       1841       Кольцо c бриллиантами R2022-SA2289R
# 803          803       2081        Кольцо c бриллиантами R01-89-34903
# 804          804       2082  Кольцо c бриллиантами R4212-R93998B-8X6A
# 906          906       2302      Кольцо c бриллиантами R4049-MAR83262
# 1128        1128       2814     Кольцо c бриллиантами R4193-17313-WGW
# 1130        1130       2823     Кольцо c бриллиантом R01-ALR01-090-G1
# 1241        1241       3097     Кольцо c бриллиантом R01-ALR37-090-G2
#
#                                                     art    price        gold  \
# 1     [<span itemprop="name">Артикул R01-ALR52-090-G...  1051194  Золото 585
# 15    [<span itemprop="name">Артикул R01-ALR52-070-G...   629994  Золото 585
# 108   [<span itemprop="name">Артикул R01-89-34873</s...   522596  Золото 585
# 116   [<span itemprop="name">Артикул R4193-17310-WGW...   537000  Золото 750
# 162   [<span itemprop="name">Артикул R4154-BVP-148</...   639960  Золото 750
# 193   [<span itemprop="name">Артикул R4193-17312-WGW...   507000  Золото 750
# 196   [<span itemprop="name">Артикул R4212-HY2845-15...   899940  Золото 750
# 210   [<span itemprop="name">Артикул R01-SL135-050-1...   583745  Золото 585
# 222   [<span itemprop="name">Артикул R01-ALR40-090-G...   576294  Золото 585
# 366   [<span itemprop="name">Артикул R4212-SA2280R-1...   929940  Золото 750
# 549   [<span itemprop="name">Артикул R01-ALR01-090-G...   587394  Золото 585
# 587   [<span itemprop="name">Артикул R01-ALR40-070-G...   642594  Золото 585
# 602   [<span itemprop="name">Артикул R2022-SA2283R</...   931494  Золото 585
# 610   [<span itemprop="name">Артикул R01-89-34848</s...   303396  Золото 585
# 652   [<span itemprop="name">Артикул R01-SOL01-070-G...   349500  Золото 585
# 685   [<span itemprop="name">Артикул R01-SOL53-050-G...   459745  Золото 585
# 708   [<span itemprop="name">Артикул R2022-SA2289R</...   952194  Золото 585
# 803   [<span itemprop="name">Артикул R01-89-34903</s...   857596  Золото 585
# 804   [<span itemprop="name">Артикул R4212-R93998B-8...   689940  Золото 750
# 906   [<span itemprop="name">Артикул R4049-MAR83262<...   528123  Золото 750
# 1128  [<span itemprop="name">Артикул R4193-17313-WGW...   747000  Золото 750
# 1130  [<span itemprop="name">Артикул R01-ALR01-090-G...   835494  Золото 585
# 1241  [<span itemprop="name">Артикул R01-ALR37-090-G...   635994  Золото 585
#
#       weight                                               gems  \
# 1        NaN  1  Бриллиант огранки "Круглая" граней - 57, ти...
# 15      2.79  1  Бриллиант огранки "Круглая" граней - 57, ти...
# 108     3.30  1  Бриллиант огранки "Круглая" граней - 89, ти...
# 116     9.61  93  Бриллианта огранки "Круглая" граней - 57, ...
# 162     3.05  1  Бриллиант огранки "Радиант", тип огранки A,...
# 193    10.32  24  Бриллианта огранки "Круглая" граней - 57, ...
# 196     3.80  2  Бриллианта огранки "Круглая" граней - 57, т...
# 210     3.98  20  Бриллиантов огранки "Круглая" граней - 57,...
# 222     2.39  1  Бриллиант огранки "Круглая" граней - 57, ти...
# 366     3.60  60  Бриллиантов огранки "Круглая" граней - 57,...
# 549     2.85  1  Бриллиант огранки "Круглая" граней - 57, ти...
# 587     2.62  1  Бриллиант огранки "Круглая" граней - 57, ти...
# 602     5.42  18  Бриллиантов огранки "Круглая" граней - 57,...
# 610     4.44  38  Бриллиантов огранки "Круглая" граней - 57,...
# 652     2.56  1  Бриллиант огранки "Круглая" граней - 57, ти...
# 685     3.36  1  Бриллиант огранки "Круглая" граней - 57, ти...
# 708     4.53  25  Бриллиантов огранки "Изумруд" граней - 65,...
# 803     3.52  14  Бриллиантов огранки "Круглая" граней - 57,...
# 804     6.51  110  Бриллиантов огранки "Круглая" граней - 57...
# 906    22.94  264  Бриллианта огранки "Круглая" граней - 57,...
# 1128   16.14  279  Бриллиантов огранки "Круглая" граней - 57...
# 1130    2.78  1  Бриллиант огранки "Круглая" граней - 57, ти...
# 1241    2.98  1  Бриллиант огранки "Круглая" граней - 57, ти...
#
#                                                     url  \
# 1       https://miuz.ru/catalog/rings/R01-ALR52-090-G1/
# 15      https://miuz.ru/catalog/rings/R01-ALR52-070-G1/
# 108         https://miuz.ru/catalog/rings/R01-89-34873/
# 116      https://miuz.ru/catalog/rings/R4193-17310-WGW/
# 162        https://miuz.ru/catalog/rings/R4154-BVP-148/
# 193      https://miuz.ru/catalog/rings/R4193-17312-WGW/
# 196     https://miuz.ru/catalog/rings/R4212-HY2845-150/
# 210    https://miuz.ru/catalog/rings/R01-SL135-050-165/
# 222     https://miuz.ru/catalog/rings/R01-ALR40-090-G2/
# 366   https://miuz.ru/catalog/rings/R4212-SA2280R-100A/
# 549     https://miuz.ru/catalog/rings/R01-ALR01-090-G2/
# 587     https://miuz.ru/catalog/rings/R01-ALR40-070-G1/
# 602        https://miuz.ru/catalog/rings/R2022-SA2283R/
# 610         https://miuz.ru/catalog/rings/R01-89-34848/
# 652     https://miuz.ru/catalog/rings/R01-SOL01-070-G2/
# 685     https://miuz.ru/catalog/rings/R01-SOL53-050-G1/
# 708        https://miuz.ru/catalog/rings/R2022-SA2289R/
# 803         https://miuz.ru/catalog/rings/R01-89-34903/
# 804   https://miuz.ru/catalog/rings/R4212-R93998B-8X6A/
# 906       https://miuz.ru/catalog/rings/R4049-MAR83262/
# 1128     https://miuz.ru/catalog/rings/R4193-17313-WGW/
# 1130    https://miuz.ru/catalog/rings/R01-ALR01-090-G1/
# 1241    https://miuz.ru/catalog/rings/R01-ALR37-090-G2/
#
#                                           vstavki_list1  ШТУК  КАРАТ   prcost
# 1     ['1  Бриллиант огранки "Круглая" граней - 57, ...     1  0.900  4275.00
# 15    ['1  Бриллиант огранки "Круглая" граней - 57, ...     1  0.700  2268.00
# 108   ['1  Бриллиант огранки "Круглая" граней - 89, ...     1  1.020  2570.40
# 116   ['93  Бриллианта огранки "Круглая" граней - 57...   113  1.640  2003.05
# 162   ['1  Бриллиант огранки "Радиант", тип огранки ...     1  1.010  1472.58
# 193   ['24  Бриллианта огранки "Круглая" граней - 57...   223  1.750  1523.40
# 196   ['2  Бриллианта огранки "Круглая" граней - 57,...     3  0.990  1549.31
# 210   ['20  Бриллиантов огранки "Круглая" граней - 5...    21  2.120  1722.50
# 222   ['1  Бриллиант огранки "Круглая" граней - 57, ...     1  0.900  2088.00
# 366   ['60  Бриллиантов огранки "Круглая" граней - 5...    65  1.470  1498.02
# 549   ['1  Бриллиант огранки "Круглая" граней - 57, ...     1  0.910  2830.10
# 587   ['1  Бриллиант огранки "Круглая" граней - 57, ...     1  0.700  2520.00
# 602   ['18  Бриллиантов огранки "Круглая" граней - 5...    18  3.619  2135.21
# 610   ['38  Бриллиантов огранки "Круглая" граней - 5...    49  1.350  1585.46
# 652   ['1  Бриллиант огранки "Круглая" граней - 57, ...     1  0.700  1680.00
# 685   ['1  Бриллиант огранки "Круглая" граней - 57, ...     1  0.550  1413.50
# 708   ['25  Бриллиантов огранки "Изумруд" граней - 6...    25  4.110  1471.38
# 803   ['14  Бриллиантов огранки "Круглая" граней - 5...    15  1.270  4864.40
# 804   ['110  Бриллиантов огранки "Круглая" граней - ...   117  2.010  1804.96
# 906   ['264  Бриллианта огранки "Круглая" граней - 5...   534  6.800  1641.26
# 1128  ['279  Бриллиантов огранки "Круглая" граней - ...   339  2.690  2377.00
# 1130  ['1  Бриллиант огранки "Круглая" граней - 57, ...     1  0.900  3960.00
# 1241  ['1  Бриллиант огранки "Круглая" граней - 57, ...     1  0.910  3094.00

# %%
len(raw.loc[raw.gold.str.contains('585'),'gold'])+len(raw.loc[raw.gold.str.contains('750'),'gold'])
# Out:
# 1247

# %%
data['goldcarat'] = raw.gold.apply(lambda x: 14 if re.search(r'585',x) else 18 if re.search(r'750',x) else 9 if re.search(r'375',x) else 0)

# %%
data.loc[data.goldcarat == 14]
# Out:
#        price  weight  prcost  goldcarat
# 0     153610    6.72  183.80         14
# 2     153610    6.72  183.80         14
# 3      37934    3.68   71.80         14
# 4     101940    4.69  117.00         14
# 5      39873    4.92   72.93         14
# ...      ...     ...     ...        ...
# 1269   13497    1.09   22.40         14
# 1270   36196    2.86   36.66         14
# 1271   23397    1.77   18.40         14
# 1272   16495    1.39   18.00         14
# 1273  115300    3.67  292.84         14
#
# [1119 rows x 4 columns]

# %%
data.loc[data.goldcarat == 18]
# Out:
#        price  weight  prcost  goldcarat
# 11     30248    2.85   62.40         18
# 25    239400    5.13  224.61         18
# 37    334452    5.52  376.08         18
# 70    395400    5.62  437.00         18
# 71     83247    3.93  269.50         18
# ...      ...     ...     ...        ...
# 1150  105373    9.54  136.20         18
# 1162  372500   20.17  676.80         18
# 1222  127873    6.25  371.80         18
# 1234  191400    3.18  242.72         18
# 1254   73498    3.91  216.80         18
#
# [77 rows x 4 columns]

# %% [markdown]
# ###  -- MIUZ;

# %% [markdown]
# ### KDM -->

# %%
rawkdm = pd.read_excel(filenamekdm,sheet_name=0)#[['price','weight','prcost']]

# %%
rawkdm.columns
# Out:
# Index(['Unnamed: 0', 'index_row', 'пп', 'id7c', 'Изделие', 'Артикул',
#        'Unnamed: 5', 'НоменГр', 'Проба', 'Цвет металла', 'Кол', 'Вес', 'Закуп',
#        'Розн', 'Вставки', 'Размер', 'РазмернаяГруппаЦК', 'ЦветЦК', 'ЧистотаЦК',
#        'Дизайн', 'Поставщик', 'Договор', 'ТН', 'filname', 'checklog',
#        'vs_dict', 'gem', 'ШТУК', 'КАРАТ', 'prcost', 'Unnamed: 30',
#        'Unnamed: 31', 'ошибка ', 'наценка0'],
#       dtype='object')

# %%
datakdm = rawkdm[['Изделие','Проба','gem','Вес', 'Розн','prcost',]].loc[(~rawkdm.prcost.isna())&(rawkdm.Розн<400000)]

# %%
bool('str cvfd  kml87743mn 984 vfvf 585 kkj n '.find('585'))
# Out:
# True

# %%
bool(re.search(r'585','str cvfd  kml87743mn 984 vfvf 5 85 kkj n '))
# Out:
# False

# %%
# Data of MIUZ
data.prcost.sort_values()
# Out:
# 0          1.60
# 2          1.60
# 3          1.90
# 4          1.90
# 5          1.90
#          ...
# 1269    1238.95
# 1270    1356.30
# 1271    1585.46
# 1272    1680.00
# 1273    4850.00
# Name: prcost, Length: 1223, dtype: float64

# %%
#data.drop(index = data.loc[data.prcost == 4850].index, inplace=True)
data.loc[data.prcost > 1400]
# Out:
#       price  weight   prcost  goldcarat
# 610  303396    4.44  1585.46         14
# 652  349500    2.56  1680.00         14

# %%
raw.loc[(raw.prcost > 1400)&(raw.price < 400000)]
# Out:
#      Unnamed: 0  index_row                                     h1  \
# 610         610       1572     Кольцо c бриллиантами R01-89-34848
# 652         652       1679  Кольцо c бриллиантом R01-SOL01-070-G2
#
#                                                    art   price        gold  \
# 610  [<span itemprop="name">Артикул R01-89-34848</s...  303396  Золото 585
# 652  [<span itemprop="name">Артикул R01-SOL01-070-G...  349500  Золото 585
#
#      weight                                               gems  \
# 610    4.44  38  Бриллиантов огранки "Круглая" граней - 57,...
# 652    2.56  1  Бриллиант огранки "Круглая" граней - 57, ти...
#
#                                                  url  \
# 610      https://miuz.ru/catalog/rings/R01-89-34848/
# 652  https://miuz.ru/catalog/rings/R01-SOL01-070-G2/
#
#                                          vstavki_list1  ШТУК  КАРАТ   prcost
# 610  ['38  Бриллиантов огранки "Круглая" граней - 5...    49   1.35  1585.46
# 652  ['1  Бриллиант огранки "Круглая" граней - 57, ...     1   0.70  1680.00

# %%
ax = plt.axes(projection='3d')
#ax.scatter3D(data.weight,data.prcost,data.price/1000,s=1,c=data.goldcarat)
ax.scatter3D(datakdm.Вес,datakdm.prcost,datakdm.Розн/1000,s=1,c=datakdm.Проба.apply(lambda x: '#1f77b4' if x == 585 else '#bcbd22'))
ax.set_xlabel('вес изделия, \n грамм')
ax.set_ylabel('прейск ст-ть \n брилл, долл')
ax.set_zlabel('ст-ть изделия,\n тыс.руб')
ax.view_init(0,0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# colors default: cycler('color', ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'])).

# %%
datakdm.Проба.apply(lambda x: 0 if x == 585 else -1)
# Out:
# 97      0
# 98      0
# 99      0
# 100     0
# 101     0
#        ..
# 3622   -1
# 3623   -1
# 3624   -1
# 3625   -1
# 3626   -1
# Name: Проба, Length: 595, dtype: int64

# %%
ax.plot_surface(data.weight,data.prcost,data.price/1000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-b02fcce9f261> in <module>()
# ----> 1 ax.plot_surface(data.weight,data.prcost,data.price/1000)
#
# ~/anaconda3/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot_surface(self, X, Y, Z, *args, **kwargs)
#    1620
#    1621         if Z.ndim != 2:
# -> 1622             raise ValueError("Argument Z must be 2-dimensional.")
#    1623         # TODO: Support masked arrays
#    1624         X, Y, Z = np.broadcast_arrays(X, Y, Z)
#
# ValueError: Argument Z must be 2-dimensional.

# %%
ax.scatter3D?

# %%
#fig = plt.figure(figsize=(5,5))

#ax_3d = Axes3D(fig)

# %%
type(ax)
# Out:
# matplotlib.axes._subplots.Axes3DSubplot

# %%
x = np.linspace(0,100,11)

# %%
y = abs(50*np.cos(x))

# %%
y
# Out:
# array([50.        , 41.95357645, 20.40410309,  7.71257249, 33.34690308,
#        48.24830142, 47.62064902, 31.66596015,  5.51936219, 22.40368081,
#        43.11594361])

# %%
type(ax_3d)
# Out:
# NoneType

# %%
f = ax_3d

# %%
# %matplotlib inline

# %%
f = plt.figure(figsize=(7,7))
f.add_axes([0,0,1,1])

# %%
plt.show()

# %%
plt.axes?

# %%
fig = plt.figure(figsize=(7,4))

# %%
ax_3d = f.add_subplot(projection = '3D')

# %%
plt.show()

# %%
ff = plt.figure()
ff.add_axes([0,0,100,100])

# %%
ff.show()
# Out:
# /Users/mac1/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
