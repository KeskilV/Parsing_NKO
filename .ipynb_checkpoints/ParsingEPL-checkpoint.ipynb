# %%
from bs4 import BeautifulSoup
import requests
from requests import Request, Session
import pandas as pd

# %%
import re

# %%
import json

# %%
#BeautifulSoup(json.__doc__, 'lxml')

# %%
def mysoup(urls):
    response = requests.get(urls)
    return BeautifulSoup(response.text, 'lxml')

# %%
def mysoup(urls):
    header = {
  'accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
  'accept-encoding':'gzip, deflate, br',
  'accept-language':'ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7',
  'cache-control':'no-cache',
  'dnt': '1',
  'pragma': 'no-cache',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-site': 'none',
  'sec-fetch-user': '?1',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36'}

    response = requests.get(urls, headers = header)
    print('', response)
    return BeautifulSoup(response.text, 'lxml')

# %%
def getlinks(urls):
    quotes = mysoup(urls).find_all('div', class_="product")
    res = [q.find("a").get("href") for q in quotes]
    print(len(res), 'links is ready ' , res[0], '...', res[-1])
    return res

# %%
def get_info_from_card(urls):
    card = mysoup(urls)
    return card.select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)')

# %%
header = {
  'accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
  'accept-encoding':'gzip, deflate, br',
  'accept-language':'ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7',
  'cache-control':'no-cache',
  'dnt': '1',
  'pragma': 'no-cache',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-site': 'none',
  'sec-fetch-user': '?1',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36'}

# %%
response = requests.get('https://epldiamond.ru/catalog/diamond-earrings/585/?PAGEN_2=1')
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     440             try:
# --> 441                 cnx.do_handshake()
#     442             except OpenSSL.SSL.WantReadError:
#
# ~/anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1805         result = _lib.SSL_do_handshake(self._ssl)
# -> 1806         self._raise_ssl_error(self._ssl, result)
#    1807
#
# ~/anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1545         else:
# -> 1546             _raise_current_error()
#    1547
#
# ~/anaconda3/lib/python3.6/site-packages/OpenSSL/_util.py in exception_from_error_queue(exception_type)
#      53
# ---> 54     raise exception_type(errors)
#      55
#
# Error: [('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')]
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     325             server_hostname=hostname,
# --> 326             ssl_context=context)
#     327
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     328     if HAS_SNI:  # Platform-specific: OpenSSL with enabled SNI
# --> 329         return context.wrap_socket(sock, server_hostname=server_hostname)
#     330
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     447             except OpenSSL.SSL.Error as e:
# --> 448                 raise ssl.SSLError('bad handshake: %r' % e)
#     449             break
#
# SSLError: ("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPSConnectionPool(host='epldiamond.ru', port=443): Max retries exceeded with url: /catalog/diamond-earrings/585/?PAGEN_2=1 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-17-b4719465e3c9> in <module>()
# ----> 1 response = requests.get('https://epldiamond.ru/catalog/diamond-earrings/585/?PAGEN_2=1')
#
# ~/anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~/anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     504             if isinstance(e.reason, _SSLError):
#     505                 # This branch is for urllib3 v1.22 and later.
# --> 506                 raise SSLError(e, request=request)
#     507
#     508             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='epldiamond.ru', port=443): Max retries exceeded with url: /catalog/diamond-earrings/585/?PAGEN_2=1 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))

# %% [markdown]
# ## Сбор ссылок на карточки

# %%
#url = 'https://epldiamond.ru/catalog/diamond-rings/?utm_source=samolet-yandex&utm_medium=cpc&utm_campaign=%D0%98%D0%B7%D0%B4%D0%B5%D0%BB%D0%B8%D1%8F+%D1%81+%D0%B1%D1%80%D0%B8%D0%BB%D0%BB%D0%B8%D0%B0%D0%BD%D1%82%D0%B0%D0%BC%D0%B8+%2F+%D0%A0%D0%A1%D0%AF+%2F+%D0%9C%D0%B8%D0%BB%D0%BB%D0%B8%D0%BE%D0%BD%D0%BD%D0%B8%D0%BA%D0%B8&utm_content=cid%7C47794255%7Cgid%7C4031655955%7Caid%7C8315568285%7Cadp%7Cno%7Cdvc%7Cmobile%7Cpid%7C18983667016%7Crid%7C%7Cdid%7C18983667016%7Cpos%7Cnone0%7Cadn%7Ccontext%7Ccrid%7C0%7C&utm_term=%D0%BA%D1%83%D0%BF%D0%B8%D1%82%D1%8C+%D0%BA%D0%BE%D0%BB%D1%8C%D1%86%D0%BE+%D1%81+%D0%B1%D1%80%D0%B8%D0%BB%D0%BB%D0%B8%D0%B0%D0%BD%D1%82%D0%BE%D0%BC+%D0%B4%D0%BE%D1%80%D0%BE%D0%B3%D0%BE&roistat=direct44_context_8315568285_%D0%BA%D1%83%D0%BF%D0%B8%D1%82%D1%8C+%D0%BA%D0%BE%D0%BB%D1%8C%D1%86%D0%BE+%D1%81+%D0%B1%D1%80%D0%B8%D0%BB%D0%BB%D0%B8%D0%B0%D0%BD%D1%82%D0%BE%D0%BC+%D0%B4%D0%BE%D1%80%D0%BE%D0%B3%D0%BE&roistat_referrer=mamba.ru&roistat_pos=none_0&yclid=2091523364497194038&PAGEN_2=1'

# %%
url = 'https://epldiamond.ru/catalog/diamond-earrings/585/?PAGEN_2=2'

# %%
links = []

# %%
url[:-1]
# Out:
# 'https://epldiamond.ru/catalog/diamond-earrings/585/?PAGEN_2='

# %%
bs = mysoup(url)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     440             try:
# --> 441                 cnx.do_handshake()
#     442             except OpenSSL.SSL.WantReadError:
#
# ~/anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1805         result = _lib.SSL_do_handshake(self._ssl)
# -> 1806         self._raise_ssl_error(self._ssl, result)
#    1807
#
# ~/anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1545         else:
# -> 1546             _raise_current_error()
#    1547
#
# ~/anaconda3/lib/python3.6/site-packages/OpenSSL/_util.py in exception_from_error_queue(exception_type)
#      53
# ---> 54     raise exception_type(errors)
#      55
#
# Error: [('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')]
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     325             server_hostname=hostname,
# --> 326             ssl_context=context)
#     327
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     328     if HAS_SNI:  # Platform-specific: OpenSSL with enabled SNI
# --> 329         return context.wrap_socket(sock, server_hostname=server_hostname)
#     330
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     447             except OpenSSL.SSL.Error as e:
# --> 448                 raise ssl.SSLError('bad handshake: %r' % e)
#     449             break
#
# SSLError: ("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPSConnectionPool(host='epldiamond.ru', port=443): Max retries exceeded with url: /catalog/diamond-earrings/585/?PAGEN_2=2 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-11-b70c69e950bc> in <module>()
# ----> 1 bs = mysoup(url)
#
# <ipython-input-5-535a5f6a9436> in mysoup(urls)
#      13   'user-agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36'}
#      14
# ---> 15     response = requests.get(urls, headers = header)
#      16     print('', response)
#      17     return BeautifulSoup(response.text, 'lxml')
#
# ~/anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~/anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     504             if isinstance(e.reason, _SSLError):
#     505                 # This branch is for urllib3 v1.22 and later.
# --> 506                 raise SSLError(e, request=request)
#     507
#     508             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='epldiamond.ru', port=443): Max retries exceeded with url: /catalog/diamond-earrings/585/?PAGEN_2=2 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))

# %%
for i in range(1,45):
    bs = mysoup(url[:-1]+str(i))
    quotes = bs.find_all('a', class_="b-product-card__title")
    links.extend(['https:'+ q.get("href") for q in quotes])
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     440             try:
# --> 441                 cnx.do_handshake()
#     442             except OpenSSL.SSL.WantReadError:
#
# ~/anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1805         result = _lib.SSL_do_handshake(self._ssl)
# -> 1806         self._raise_ssl_error(self._ssl, result)
#    1807
#
# ~/anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1545         else:
# -> 1546             _raise_current_error()
#    1547
#
# ~/anaconda3/lib/python3.6/site-packages/OpenSSL/_util.py in exception_from_error_queue(exception_type)
#      53
# ---> 54     raise exception_type(errors)
#      55
#
# Error: [('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')]
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     325             server_hostname=hostname,
# --> 326             ssl_context=context)
#     327
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     328     if HAS_SNI:  # Platform-specific: OpenSSL with enabled SNI
# --> 329         return context.wrap_socket(sock, server_hostname=server_hostname)
#     330
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     447             except OpenSSL.SSL.Error as e:
# --> 448                 raise ssl.SSLError('bad handshake: %r' % e)
#     449             break
#
# SSLError: ("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPSConnectionPool(host='epldiamond.ru', port=443): Max retries exceeded with url: /catalog/diamond-earrings/585/?PAGEN_2=1 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-12-affbf2438b4f> in <module>()
#       1 for i in range(1,45):
# ----> 2     bs = mysoup(url[:-1]+str(i))
#       3     quotes = bs.find_all('a', class_="b-product-card__title")
#       4     links.extend(['https:'+ q.get("href") for q in quotes])
#
# <ipython-input-5-535a5f6a9436> in mysoup(urls)
#      13   'user-agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36'}
#      14
# ---> 15     response = requests.get(urls, headers = header)
#      16     print('', response)
#      17     return BeautifulSoup(response.text, 'lxml')
#
# ~/anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~/anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     504             if isinstance(e.reason, _SSLError):
#     505                 # This branch is for urllib3 v1.22 and later.
# --> 506                 raise SSLError(e, request=request)
#     507
#     508             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='epldiamond.ru', port=443): Max retries exceeded with url: /catalog/diamond-earrings/585/?PAGEN_2=1 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))

# %%
url[:-1]+str(i)
# Out:
# 'https://epldiamond.ru/catalog/diamond-earrings/585/?PAGEN_2=44'

# %%
l1
# Out:
# ['//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0938kts02220460/?4423573',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts02220753/?4410605',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0942kts10211001/?4408067',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0927kts11210461/?4408045',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts12210506-pink/?4344469',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts11210955-blue/?4350269',
#  '//epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0606kts10210371/?4302649',
#  '//epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts09210001/?4259787',
#  '//epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e0301kts07200363/?4118515',
#  '//epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-s-brilliantami-e0201kts05210375/?4245169',
#  '//epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts03210507/?4302231',
#  '//epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-s-brilliantom-e0201kts04202996/?4445051',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts06200002/?4352457',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts02220939/?4411855',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0912kts08190200-pink/?4176737',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0912kts09190150-pink/?4176735',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts04210651-blue/?4351249',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts04175100-blue/?4343751',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts01190400-pink/?4341475',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts04201507-pink/?4349905',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts04201511-pink/?4351381',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts04201506-pink/?4349879',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts07166700-pink/?4349523',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts07160700-blue/?4350323',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts04181600-pink/?4323473',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts08151700-pink/?4349513',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts06210022-pink/?4338029',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts06165300-pink/?4346147',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts01144400-blue/?4349509',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts04190300-blue/?4333761']

# %%
len(set(links))
# Out:
# 1239

# %%
links[1292]
# Out:
# 'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts09152700/?1940591'

# %%
import os

# %%
os.listdir('jewels')
# Out:
# ['.DS_Store',
#  'AnaliticRep031221 - Jupyter Notebook.html',
#  'AnaliticRep031221 - Jupyter Notebook_files',
#  'AnaliticRep061221-KDM1C8 - Jupyter Notebook.html',
#  'AnaliticRep061221-KDM1C8 - Jupyter Notebook_files',
#  'egelge',
#  'epl',
#  'kdm',
#  'kdm_1c8',
#  'kierge',
#  'miuz',
#  'muiz04-2022']

# %%
os.makedirs('jewels/epl')

# %%
dlinks = {0:(links,url,url)}

# %%
dlinks[1] = (links,url,url)

# %%
dlinks[0]
# Out:
# (['https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts03220603/?4610199',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts03220911/?4610147',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts03220907/?4610139',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts03220906/?4610135',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts03220604/?4610213',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts05210957/?4603285',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts03220751/?4603325',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0606kts05151200/?4610181',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts02220355/?4410743',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts12210507-pink/?4344465',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts11081300-pink/?4350493',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0609kts04211041/?4350007',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts03210513/?4323509',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts08151900/?4135069',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0337kts12200462/?4446887',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts10210009/?4609983',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0940kts12210407/?4424677',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0943kts01220457/?4418513',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0609kts12154200/?4446035',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0608kts10200467/?4393323',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0628kts12210403/?4359371',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0609kts11210371/?4320585',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts01210112/?4125979',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0609kts11102400/?4609419',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts07167100/?4433659',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0938kts03220451/?4424581',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts09210661/?4423463',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts11210652-pink/?4351175',
#   'https://epldiamond.ru/product/koltso-iz-kombinirovannogo-zolota-585-s-brilliantami-e1001kts09210658/?4609973',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0936kts08184700/?4424619',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts03220603/?4610199',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts03220911/?4610147',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts03220907/?4610139',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts03220906/?4610135',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts03220604/?4610213',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts05210957/?4603285',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts03220751/?4603325',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0606kts05151200/?4610181',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts02220355/?4410743',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts12210507-pink/?4344465',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts11081300-pink/?4350493',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0609kts04211041/?4350007',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts03210513/?4323509',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts08151900/?4135069',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0337kts12200462/?4446887',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts10210009/?4609983',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0940kts12210407/?4424677',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0943kts01220457/?4418513',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0609kts12154200/?4446035',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0608kts10200467/?4393323',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0628kts12210403/?4359371',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0609kts11210371/?4320585',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts01210112/?4125979',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0609kts11102400/?4609419',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts07167100/?4433659',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0938kts03220451/?4424581',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts09210661/?4423463',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts11210652-pink/?4351175',
#   'https://epldiamond.ru/product/koltso-iz-kombinirovannogo-zolota-585-s-brilliantami-e1001kts09210658/?4609973',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0936kts08184700/?4424619',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0938kts02220460/?4423573',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts02220753/?4410605',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0942kts10211001/?4408067',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0927kts11210461/?4408045',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts12210506-pink/?4344469',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts11210955-blue/?4350269',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0606kts10210371/?4302649',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts09210001/?4259787',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e0301kts07200363/?4118515',
#   'https://epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-s-brilliantami-e0201kts05210375/?4245169',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts03210507/?4302231',
#   'https://epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-s-brilliantom-e0201kts04202996/?4445051',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts06200002/?4352457',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts02220939/?4411855',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0912kts08190200-pink/?4176737',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0912kts09190150-pink/?4176735',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts04210651-blue/?4351249',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts04175100-blue/?4343751',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts01190400-pink/?4341475',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts04201507-pink/?4349905',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts04201511-pink/?4351381',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts04201506-pink/?4349879',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts07166700-pink/?4349523',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts07160700-blue/?4350323',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts04181600-pink/?4323473',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts08151700-pink/?4349513',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts06210022-pink/?4338029',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts06165300-pink/?4346147',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts01144400-blue/?4349509',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts04190300-blue/?4333761',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts07210307/?4341277',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts04211033-blue/?4288027',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e0301kts04203092/?3591537',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0940kts02220413/?4410741',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0940kts02220411/?4410733',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e0301kts02220753/?4610107',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0943kts02220455/?4408027',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0963kts01220468/?4408007',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts11210869/?4406071',
#   'https://epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-s-brilliantami-e0201kts04193800/?4444683',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts02220938/?4400685',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0605kts11210464/?4405605',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts11210660/?4400373',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts01220203/?4400647',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0933kts12210414/?4362215',
#   'https://epldiamond.ru/product/koltso-iz-kombinirovannogo-zolota-585-s-brilliantami-e1001kts11210503/?4333579',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts06210022/?4349493',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts05210375/?4136619',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e0301kts04202996/?3783607',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts01220883/?4446039',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0976kts01220467/?4396055',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts08151700/?4445529',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts11210956-pink/?4351171',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts06165200-blue/?4290327',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0937kts07210487/?4384031',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0938kts05210473/?4383981',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts09150600/?4410491',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts10210306-blue/?4291029',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e1401kts05160600/?4269585',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts12210653/?4383955',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts07210126/?4422887',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0928kts12210414/?4362207',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts08210006/?4445547',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts04190300/?4410503',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts10210360/?4262951',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0989kts12210414/?4351343',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0938kts11210458/?4344425',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts04181600/?4603039',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0940kts10210358/?4308595',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0939kts09200474/?4125521',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0953kts06210408/?4396077',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts04201511-white/?4393057',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts04201506-white/?4393055',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts01144400-white/?4385821',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts10210120/?4366301',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts04201506/?4410495',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts01144400/?4445525',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts11210918/?4368419',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts10210907/?4372117',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts11210115/?4366313',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0933kts11210404/?4344967',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts10210373/?4333649',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0943kts06210354/?4308533',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0938kts07210404/?4346069',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts11210956-blue/?4333743',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts11210914/?4363455',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts10210901/?4362351',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0606kts11210371/?4323577',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts08210354/?4383653',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts10210902/?4350343',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts09210102/?4347505',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts12200951/?4312377',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0937kts04210463/?4154883',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0940kts04201497/?4118579',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0906kts04202357/?3793687',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts06170800/?4346835',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0633kts12210403/?4366075',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts08211058/?4333555',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0951kts11210402/?4323799',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts09210127/?4450441',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0943kts11210405/?4301385',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0943kts07210411/?4609527',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0943kts10200406/?4410353',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts10210903/?4336743',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0943kts11210378/?4344139',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0943kts04210360/?3745285',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts07210011/?4223195',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts03210913/?3764279',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts09200302/?3714431',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts01210301/?3585471',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0605kts04164200/?3075231',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts06165300/?4410485',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts08210003/?4246827',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0607kts03142000/?3053499',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0942kts11210407/?4308071',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e1101kts08200117/?3615431',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts06165300-white/?4383593',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts10210128/?4315469',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0940kts04201479/?3672775',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts06210107/?4315675',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts06210951/?4423037',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts08210005/?4307719',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0938kts05210461/?4118639',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0940kts06210424/?4201691',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0605kts10200375/?4404007',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts06200005/?4358719',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e1101kts04200800/?1564119',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0626kts06210352/?4115315',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0943kts04210407/?4163103',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts08210005/?4298485',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts10210003/?4285731',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts07210304/?4272019',
#   'https://epldiamond.ru/product/koltso-iz-kombinirovannogo-zolota-585-s-brilliantami-e1001kts04200715/?4111975',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0989kts11210404/?4393011',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts10210002/?4318281',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts05210957/?4236145',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts09210608/?4284119',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts04210378/?4294209',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts05210907/?4275963',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts10210003/?4285733',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0936kts05210472/?4385793',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0943kts09210461/?4269453',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts07210304/?4609635',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts04210362/?4251973',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts04210379/?4450381',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e0301kts10210204/?4274273',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e0301kts10210207/?4286533',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts09210908/?4257421',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts04210363/?4377951',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts07210118/?4332767',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts08210551/?4332793',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts07210306/?4609647',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0693kts08210106/?4605529',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts07210110/?4328933',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0906kts05210409/?4130895',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e0301kts07200752/?4450077',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts09210551/?4269507',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0912kts09190160-blue/?4286941',
#   'https://epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-s-brilliantami-e0201kts06184900/?4433011',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e0301kts08210868/?4299297',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0940kts08210351/?4322803',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts09200956/?4111003',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts10210203/?4371663',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts10210207/?4445419',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts10210204/?4286479',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts08210009/?4262933',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts04210657/?4360061',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0906kts09169300/?4157777',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts08210009/?4365961',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts09211003-blue/?4256767',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts09210907/?4256707',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts09210001/?4253085',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts11200503/?4251955',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts07210111/?4308455',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts08210008/?4250143',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts04210659/?4609421',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0620kts07200402/?4382251',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e0301kts04200870/?4211157',
#   'https://epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-s-brilliantami-e0201kts04200771/?4247399',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts07210009/?4243429',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0936kts07210379/?4229833',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0942kts06210471/?4176665',
#   'https://epldiamond.ru/product/koltso-iz-kombinirovannogo-zolota-585-s-brilliantami-e1001kts07210377/?4138755',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts11195540/?4603217',
#   'https://epldiamond.ru/product/koltso-iz-kombinirovannogo-zolota-585-s-brilliantom-e1001kts08200117/?3381781',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0609kts02203590/?4246003',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts08210903/?4243473',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0601kts06210103/?4211523',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts08191300-white/?4367987',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts08210305/?4270033',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0605kts09210405/?4432945',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts06210117/?4422755',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts06165200-white/?3666493',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0942kts03210411/?4138633',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0942kts02210403/?4163073',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0912kts07190190/?4602635',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts09210853/?4295031',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts07210011/?4275687',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0610kts07210362/?4235109',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts08210003/?4247669',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts01208580/?4377543',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e0301kts06200857/?4438835',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts12200014/?3591491',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts07200901/?4328369',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0908kts07210457/?4134587',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0633kts04190300/?4163147',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts10200951/?4357049',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0605kts07200402/?4229839',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901ka09210653/?4341199',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts05210201/?4602917',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts07210009/?4246679',
#   'https://epldiamond.ru/product/koltso-iz-kombinirovannogo-zolota-585-s-brilliantami-e1001kts06210602/?4221101',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0940kts05210472/?4210357',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0936kts05210471/?4210275',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts06210022/?4234757',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0942kts09210401/?4241471',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0943kts09210404/?4445393',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts09210852/?4221535',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0607kts11102400/?4251853',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e0301kts05210201/?4395349',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0943kts05210464/?4221073',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts01210119/?4189077',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts06182400/?3639785',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0936kts05210458/?4138629',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0942kts05210472/?4383539',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0951kts05210464/?4212501',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts07210307/?4268989',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e0301kts06200856/?4422809',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0942kts12200412/?4267147',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts09200305/?4307195',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts08210868/?4422861',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0611kts04201896/?4262757',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts04211033/?4609471',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0601kts06184300/?3049905',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0608kts10200468/?4422659',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0601kts02210503/?4258993',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0640kts02203570/?4170087',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e0301kts05200688/?4371545',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e0301kts06200855/?4609395',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts03210902/?4183369',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts04140400/?4225669',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts07210651/?4379175',
#   'https://epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-s-brilliantami-e0201kts03210352/?4126095',
#   'https://epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-s-brilliantami-e0201kts08200360/?3817401',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts01210119/?4157537',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts07210306/?4286397',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts04211033-white/?4378565',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0937kts08210406/?4273851',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts06210651/?4316735',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts06210653/?4609557',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts06210654/?4326829',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts08210857/?4349359',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts07211014/?4177933',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e0305kts10200467/?4177911',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts04211024/?4609543',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts05210910/?4183655',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts09200956/?4438825',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0305kts05103500/?4177677',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts04082400/?4392061',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts08210552/?4392927',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0601kts02210502/?4167423',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0601kts08197540/?4173353',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts07210606/?4445319',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0603kts10191120/?4609537',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts09190350-blue/?4290123',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts08200360/?3817525',
#   'https://epldiamond.ru/product/koltso-iz-kombinirovannogo-zolota-585-s-brilliantami-e1001kts08200366/?3644791',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts06210115/?4432901',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0942kts06210470/?4177811',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts08151900-blue/?3064299',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0601kts04201013/?4271931',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0942kts07210478/?4138803',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0942kts07210464/?4138799',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts03210352/?4134517',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e1101kts11190180/?3672551',
#   'https://epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-e0200kts01210551/?4165547',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0611kts09200455/?4371579',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-e0300kts01210551/?4161735',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts06210951/?4422757',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts06210504/?4159063',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts09200956-pink/?4118535',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0612kts01158900-ell/?3666775',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e09k041908-blue/?1284623',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts06210021/?4122293',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts07210303/?4270593',
#   'https://epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-s-brilliantami-e0201kts01210119/?4161775',
#   'https://epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-s-brilliantami-e0201kts03210112/?4161757',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts07210865/?4215483',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0936kts06210466/?4160333',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts03210356/?3715125',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0611kts04200688/?4157639',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0607kts04200688/?4157631',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts06210952/?4312763',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts03210108/?4445229',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts06210866/?4138811',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts09200956-blue/?4118531',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0912kts01137300-pink/?3690713',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts07070100-pink/?3358297',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts06210904/?4371569',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0942kts06210466/?4134643',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0942kts05210473/?4193727',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0942kts07210456/?4127777',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts06210021/?4307443',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts03210507/?4314973',
#   'https://epldiamond.ru/product/koltso-iz-kombinirovannogo-zolota-585-s-brilliantami-e1001kts11190180/?4213805',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts09190050/?4134409',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts07210601/?4328731',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e1401kts05210554/?4322657',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e1401kts05210555/?4118665',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0605kts06210352/?4432725',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts01210501/?4322699',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0943kts06210422/?4316711',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts05210375/?4122169',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0608kts03142100/?4122049',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts06210504/?4298069',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0912kts07190200-blue/?4333763',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0912kts08190410-blue/?4328767',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts12162900-blue/?3775623',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0312kts12162900-blue/?3731565',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0912kts01137300-blue/?4322553',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0612kts02159400-blue/?3672829',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts08151900-ell/?3064303',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts07070100-blue/?3604849',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts09183400-blue/?3064273',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts07153600-blue/?3064235',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts03183700-blue/?3060285',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0912kts06160900-blue/?3040773',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0912kts12150900-blue/?3000921',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0912kts07190190-blue/?3804025',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0912kts11102400-blue/?4138005',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0912k-0719019-blue/?1301025',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0912k-0719020-blue/?1312477',
#   'https://epldiamond.ru/product/koltso-iz-kombinirovannogo-zolota-585-s-brilliantami-e1045kts04210365/?4122375',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts06210907/?4395379',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts01210501/?4298035',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts08200915/?4348395',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts10166200/?4118799',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts11190030/?3804693',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0942kts05210484/?4126009',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0942kts05210485/?4126007',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts11191290/?4267137',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts01210112/?4609485',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts03210518/?4209989',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts04210019/?4361725',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0609kts03210455/?4198195',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts04210378/?4346661',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts03210910/?4190935',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts05210901/?4175079',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts06211001/?4383767',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0940kts04202357/?4298057',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts04203084/?4118935',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts07200354/?4450197',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts08200360/?3302163',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts03200903/?4299179',
#   'https://epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-s-brilliantom-e0201kts09152400/?3612437',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0605kts05151500/?3017723',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0938kts03210458/?4125819',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0936kts04200993/?4235793',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts07191000/?4375875',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-e0300kts05210601/?3801463',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts03210518/?4322587',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0611kts04200675/?3325749',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e0301kts04203084/?4450183',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0938kts06210403/?4139493',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts11191270/?4311159',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts04211034-white/?3775659',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts12200951/?4409833',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts05210552/?4212391',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts05210701/?4256385',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0610kts10200383/?4410379',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0605kts12192040/?3116389',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0942kts06165200/?4605191',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts06200904/?4327983',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0306kts09169300/?3050025',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0912kts09190130/?4170263',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts04201507/?4115353',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0606kts04203001/?3091519',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0912kts08190420/?4605271',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts04202741/?4395225',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts11190170/?3811511',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts03210356/?4231445',
#   'https://epldiamond.ru/product/koltso-iz-kombinirovannogo-zolota-585-s-brilliantami-e1001kts11200377/?4262641',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts11190030/?3805137',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts09162600/?4311119',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts11190170/?4445057',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts05200683/?4377843',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-e0300kts08152900/?3804461',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts07156100/?4373101',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0905kts05103500/?3798961',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts04210657/?4609423',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts04210651/?4360053',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts04210653/?4113743',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0602kts04210462/?3785957',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0943kts04210415/?4290383',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts12140600/?3789373',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts03210352/?3729477',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0607kts09152400/?3358903',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0938kts04210469/?4125843',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0942kts02210351/?4383389',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e0301kts05200692/?4432519',
# ...
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts04164800/?3388533',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts02159700/?4295681',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e0301kts04160500/?4116577',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts08151900/?4289621',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts12153700/?4262061',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0606kts09152400/?3088517',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e0301kts04091200/?4398011',
#   'https://epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-s-brilliantami-e0201kts08151700/?4372735',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts05185300/?3785375',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e0301kts03153900/?4072571',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0601kts02193800/?3114685',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts05102300/?3018045',
#   'https://epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-s-brilliantami-e0201kts09160400/?3645243',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0601kts02182400/?4072777',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts04160100/?4176175',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts11102400/?3589725',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts02150900/?4132171',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts02167200/?3296647',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts05102000/?3825117',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts07151600/?4602531',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts02159400/?3042105',
#   'https://epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-s-brilliantami-e0201kts02163300/?3725261',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts02163500/?3202639',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts06163900/?3014167',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts05152000/?4162385',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts08110300/?4445965',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts04200870/?2088037',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts11175700/?3820451',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0601kts12191020/?4132063',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts04162900/?4450063',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0601kts04200718/?4602491',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts08161200/?4605047',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts01162900/?1927765',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts11180500/?4437071',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts04091200/?3646159',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts12153500/?3815209',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts04160200/?4327141',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts10170700/?4014063',
#   'https://epldiamond.ru/product/koltso-iz-kombinirovannogo-zolota-585-s-brilliantami-e1001kts02203610/?4225793',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts08161100/?3918983',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0601kts04200717/?3664203',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts04181800/?4132157',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0601kts02193900/?4439145',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts08151700/?4182387',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts07153300/?4166705',
#   'https://epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-s-brilliantami-e0201kts02159700/?3118907',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts11161100/?4223619',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0601kts10153700/?4289511',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts04151900/?4197959',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts02185300/?4328153',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts10130200/?4293941',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts06200907/?3359231',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts04203126/?4609143',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts08200912/?3747391',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e0301kts11200201/?4166907',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0601kts09190440/?4431865',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts04203146/?3651531',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts03200902/?4422171',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0605kts10153700/?4229335',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0601kts11191270/?4118887',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0942kts01210406/?4155525',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts12200555/?4376311',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-e0900kts01210551/?3675379',
#   'https://epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-s-brilliantami-e0201kts12200014/?4219213',
#   'https://epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-s-brilliantom-e0201kts10200131/?4602807',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e0301kts10200131/?4111803',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts10200131/?4450219',
#   'https://epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-s-brilliantom-e0201kts04203137/?3963151',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e0301kts04203137/?3103717',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-e0900kts10160600/?4404159',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts04203092/?4443421',
#   'https://epldiamond.ru/product/koltso-iz-kombinirovannogo-zolota-585-s-brilliantom-e1006kts12193580/?1855145',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0606kts05151500/?3054061',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0605kts02167200/?3273563',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0605kts03152300/?4020773',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0606kts12154300/?2981249',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0942kts03111100/?3714065',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0942kts09200473/?3587671',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0601kts03153900/?2905963',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts04190200/?3080459',
#   'https://epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-s-brilliantami-e0201kts10101500/?2852161',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts06181200/?4450215',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0607kts01158900/?3054331',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0605kts12154200/?3052049',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0606kts12154200/?3384499',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0937kts12200420/?4132683',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0943kts12200422/?4328505',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts10200952/?4331149',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0605kts01178400/?4314761',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts08200358/?3110857',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0908kts11102400/?4609185',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts11200503/?4320541',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts11174400/?4332515',
#   'https://epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-e0200kts09173300/?4201183',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts09200112/?4122135',
#   'https://epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-s-brilliantami-e0201kts03180300/?4197083',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts04203137/?4602523',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-e0300kts01172200/?3048007',
#   'https://epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-e0200kts01172200/?3257215',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts04202076/?2690991',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0943kts11200422/?4158835',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0936kts10200417/?4163017',
#   'https://epldiamond.ru/product/koltso-iz-kombinirovannogo-zolota-585-s-brilliantami-e1001kts04201998/?4608927',
#   'https://epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-s-brilliantom-e0201kts10200128/?3333149',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts10200128/?3394547',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0608kts04164200/?4608983',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e0301kts10200128/?3317545',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts06200855/?4444901',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-e0900kts01172200/?3724193',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-e0900kts05166300/?4137657',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0606kts05152200/?3095417',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts11134300/?3815549',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0605kts04200126/?3081899',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0605kts04200688/?3332771',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts11200601/?4292319',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0607kts03142100/?3785759',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0605kts05103500/?3059401',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0608kts11102400/?4444691',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-e0300kts01161000/?4320723',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts04152600/?4231385',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0601kts02152000/?3074909',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts08200111/?3269339',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts08200111/?3269287',
#   'https://epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-s-brilliantami-e0201kts08200105/?4388853',
#   'https://epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e0301kts03154100/?4132471',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0606kts03142100/?3274541',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts06200110/?3604905',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0611kts04200039/?4450169',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts09200304/?3713609',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0608kts02134400/?4290021',
#   'https://epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantom-e0608kts01178400/?4602643',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0942kts09200451/?4082919',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts03081600/?3590575',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts04152600/?3779343',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts03154100/?4158647',
#   'https://epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-s-brilliantami-e0201kts03081600/?4445223',
#   'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts02121700/?4393199',
#   ...],
#  'https://epldiamond.ru/catalog/diamond-rings/?utm_source=samolet-yandex&utm_medium=cpc&utm_campaign=%D0%98%D0%B7%D0%B4%D0%B5%D0%BB%D0%B8%D1%8F+%D1%81+%D0%B1%D1%80%D0%B8%D0%BB%D0%BB%D0%B8%D0%B0%D0%BD%D1%82%D0%B0%D0%BC%D0%B8+%2F+%D0%A0%D0%A1%D0%AF+%2F+%D0%9C%D0%B8%D0%BB%D0%BB%D0%B8%D0%BE%D0%BD%D0%BD%D0%B8%D0%BA%D0%B8&utm_content=cid%7C47794255%7Cgid%7C4031655955%7Caid%7C8315568285%7Cadp%7Cno%7Cdvc%7Cmobile%7Cpid%7C18983667016%7Crid%7C%7Cdid%7C18983667016%7Cpos%7Cnone0%7Cadn%7Ccontext%7Ccrid%7C0%7C&utm_term=%D0%BA%D1%83%D0%BF%D0%B8%D1%82%D1%8C+%D0%BA%D0%BE%D0%BB%D1%8C%D1%86%D0%BE+%D1%81+%D0%B1%D1%80%D0%B8%D0%BB%D0%BB%D0%B8%D0%B0%D0%BD%D1%82%D0%BE%D0%BC+%D0%B4%D0%BE%D1%80%D0%BE%D0%B3%D0%BE&roistat=direct44_context_8315568285_%D0%BA%D1%83%D0%BF%D0%B8%D1%82%D1%8C+%D0%BA%D0%BE%D0%BB%D1%8C%D1%86%D0%BE+%D1%81+%D0%B1%D1%80%D0%B8%D0%BB%D0%BB%D0%B8%D0%B0%D0%BD%D1%82%D0%BE%D0%BC+%D0%B4%D0%BE%D1%80%D0%BE%D0%B3%D0%BE&roistat_referrer=mamba.ru&roistat_pos=none_0&yclid=2091523364497194038&PAGEN_2=1',
#  'https://epldiamond.ru/catalog/diamond-rings/?utm_source=samolet-yandex&utm_medium=cpc&utm_campaign=%D0%98%D0%B7%D0%B4%D0%B5%D0%BB%D0%B8%D1%8F+%D1%81+%D0%B1%D1%80%D0%B8%D0%BB%D0%BB%D0%B8%D0%B0%D0%BD%D1%82%D0%B0%D0%BC%D0%B8+%2F+%D0%A0%D0%A1%D0%AF+%2F+%D0%9C%D0%B8%D0%BB%D0%BB%D0%B8%D0%BE%D0%BD%D0%BD%D0%B8%D0%BA%D0%B8&utm_content=cid%7C47794255%7Cgid%7C4031655955%7Caid%7C8315568285%7Cadp%7Cno%7Cdvc%7Cmobile%7Cpid%7C18983667016%7Crid%7C%7Cdid%7C18983667016%7Cpos%7Cnone0%7Cadn%7Ccontext%7Ccrid%7C0%7C&utm_term=%D0%BA%D1%83%D0%BF%D0%B8%D1%82%D1%8C+%D0%BA%D0%BE%D0%BB%D1%8C%D1%86%D0%BE+%D1%81+%D0%B1%D1%80%D0%B8%D0%BB%D0%BB%D0%B8%D0%B0%D0%BD%D1%82%D0%BE%D0%BC+%D0%B4%D0%BE%D1%80%D0%BE%D0%B3%D0%BE&roistat=direct44_context_8315568285_%D0%BA%D1%83%D0%BF%D0%B8%D1%82%D1%8C+%D0%BA%D0%BE%D0%BB%D1%8C%D1%86%D0%BE+%D1%81+%D0%B1%D1%80%D0%B8%D0%BB%D0%BB%D0%B8%D0%B0%D0%BD%D1%82%D0%BE%D0%BC+%D0%B4%D0%BE%D1%80%D0%BE%D0%B3%D0%BE&roistat_referrer=mamba.ru&roistat_pos=none_0&yclid=2091523364497194038&PAGEN_2=1')

# %%
with open('jewels/epl'+'/links01.json', 'w') as writefile:
    json.dump(dlinks, writefile)

# %%
https://epldiamond.ru/catalog/diamond-earrings/585/

# %% [markdown]
# ## Обработка карточки

# %%
with open('jewels/epl'+'/links.json', 'r') as writefile:
    dlinks0 = json.load(writefile)

# %%
dlinks0['0'][0][0]
# Out:
# 'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts03220603/?4610199'

# %% [markdown]
# ### Пошагово, ручная обработка карточки

# %%
dlinks[0][0][0]
# Out:
# 'https://epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts03220603/?4610199'

# %%
card = mysoup(dlinks[0][0][0])
# Out:
#  <Response [200]>

# %%
#title
card.find('h1',class_="b-card-page__title").text
# Out:
# 'Кольцо из белого золота с бриллиантами'

# %%
<h1 class="b-card-page__title" itemprop="name">Серьги из белого золота с бриллиантами и рубинами</h1>

# %%
#art
card.find('span',class_="b-prod-info__vendor-code-value").text#replace(r'\\n/','')
# Out:
# 'э0901кц03220603                                                \n/\n'

# %%
<span class="b-prod-info__vendor-code-value"><span>э0939сг01220463                                                </span>
                                                                                                <i>/</i>
                                                                                        </span>

# %%
#kod
card.find('span',class_="b-prod-info__bar-code-value").text
# Out:
# '7000001358226'

# %%
<span class="b-prod-info__bar-code-value">7000001339867</span>

# %%
card.find_all('table',class_="b-adaptiveV1-table js-adaptiveV1-table")#.text.replace(" ",''))
# Out:
# [<table class="b-adaptiveV1-table js-adaptiveV1-table">
#  <thead>
#  <tr>
#  <th>Вставка</th>
#  <th>Форма</th>
#  <th>Кол-во</th>
#  <th>Вес</th>
#  <th>Цвет</th>
#  <th>Чистота</th>
#  <th>Огранка</th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td data-label="Вставка">Бриллиант</td>
#  <td data-label="Форма">Кр57</td>
#  <td data-label="Кол-во">20</td>
#  <td data-label="Вес">0.402</td>
#  <td data-label="Цвет">3</td>
#  <td data-label="Чистота">6</td>
#  <td data-label="Огранка"> </td>
#  </tr>
#  </tbody>
#  </table>]

# %%
data-id

# %%
b-adaptiveV1-table js-adaptiveV1-table

# %%
card.text
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\nКольцо из белого золота с бриллиантами – купить в Москве по цене  97 938 руб. в интернет-магазине ЭПЛ Даймонд\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\nУточняется наличие украшений. Пожалуйста подождите..\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nЯкутск\n\nСалоны и пункты выдачи\n\n\n\n\n\n\n\n\n\n\n\n8 800 333 67 37\n\n\nОбратный звонок\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nВход в личный кабинет\n\n\n\n\n\n\nВход\n\nЗабыли пароль?\n\n\r\n\t\tНажимая на кнопку «войти», вы подтверждаете свое согласие с политикой конфиденциальности и даете\r\n\t\tсогласие на обработку персональных данных\r\n\t\n\n\n\n\n\n\n\n← Вернуться \n\nВосстановить пароль\n\nВосстановить\nНажимая на кнопку «войти», вы подтверждаете свое согласие с политикой конфиденциальности и даете согласие на обработку персональных данных\n\n\n\n← Вернуться \n\n\nРегистрация\n\n\n\n\n\n\nРегистрация\nНажимая на кнопку «войти», вы подтверждаете свое согласие с политикой конфиденциальности и даете согласие на обработку персональных данных\n\n\n\n\n\n← Вернуться \n\nКод подтверждения\n\nПодтвердить\n\n\n\n\n\n← Вернуться \n\nЗавершение регистрации\n\n\nПодтвердить\n\n \n\n\n\n\n\n\nУкрашения в корзине\n\nНет товаров\n\n\n\n\n\n\n\n\n\n\n\nЗАКАЗАТЬ ОБРАТНЫЙ ЗВОНОК\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n \n\n\n\n\n\r\n            ПЕРЕЗВОНИТЕ МНЕ\r\n        \nНажимая на кнопку «перезвоните мне», вы подтверждаете свое согласие с политикой конфиденциальности и даете согласие на обработку персональных данных\n\n\n\n\n\nСпасибо за ваше обращение. Наш менеджер свяжется с Вами в ближайшее время!\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\r\n                    Якутск                \n\n\n\n\n\n\nВаш город:\nЯкутск\nизменить\n\n\n\n\n\n\n\n\n\n\n\n\r\n                        Сменить\r\n                    \n\n\nОпределить мой город автоматически\n\n\n\n\nСАЛОНЫ ЭПЛ И ПУНКТЫ ВЫДАЧИ\n\n\n\n\nСписком\n\n\n\n\nНа карте\n\n\n\n\n\n\nПоказывать только салоны\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nНазад к списку\n\nНичего не найдено :(\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nЮвелирные изделия\n\n\n\n\n\n\n\nКольца\n\n\n\nКлассика\n\n\nПомолвочные\n\n\nОбручальные\n\n\nМужские кольца\n\n\nБез бриллианта\n\n\n\n\nВсе кольца\n\n\n\n\n\nСерьги\n\n\n\nКлассика\n\n\nСерьги-конго(кольца)\n\n\nПусеты (гвоздики)\n\n\n\n\nВсе серьги\n\n\n\n\n\nПодвески\n\n\n\nКлассика\n\n\nСердечки\n\n\nКрестики\n\n\nДетские\n\n\n\n\nВсе подвески\n\n\n\n\n\nДругие украшения\r\n                                                            \n\n\nКолье\n\nБраслеты\n\nБроши\n\nЗапонки\n\nЗажимы\n\nЦепи\n\nКасты\n\nСувениры\n\n\n\n\n\n\n\n\n\n\n\nБриллианты\n\n\n\n\n\n\n\n\r\n                                                                            ФОРМА ОГРАНКИ:\r\n                                                                        \n\n \n\n\n\n\n\n \n\n\n\n\n\n \n\n\nВсе бриллианты\n\n\n\n\n\n\r\n                                                                            БРИЛЛИАНТЫ:\r\n                                                                        \n\n\nАбсолютно бесцветные\n\nБелые бриллианты\n\nБесцветные\n\nКоньячные\n\nКрупные бриллианты\n\nПылающий лед / Firing Ice\n\n\n\n\n\n\n\nЧИСТОТА:\r\n                                                                \n\n\nИдеально чистые\n\nЧистые\n\nС вкраплениями\n\n\n\n\n\n\n\n\n\n\n\n\nКоллекции\n\n\n\n\n\n\nКоллекция Blossom\n\n\nКоллекция Мой первый бриллиант\n\n\nКоллекция Must Have\n\n\nКоллекция основная\n\n\nКоллекция свадьба и помолвка\n\n\nКоллекция эксклюзивная\n\n\nКоллекция WOW COLLECTION\n\n\nКоллекция Серебряная\n\n\nКоллекция EPL Grace\n\n\nКоллекция -70%\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSale\n\n\nEPL Bio\n\n\nЗвезды выбирают\n\n\n\n\n\n\nЗвёзды выбирают украшения ЭПЛ\n\n ...

# %%
<tr class="table-row " onclick="if (!window.__cfRLUnblockHandlers) return false; clickTableOffer(this);" data-id="4450663">
									<td class="table-cell">5.086</td>
																		<td class="table-cell">
													 7000001339867												</td>
									<td class="table-cell">
																									 1 050 084 <span class="rub">₽</span>																								</td>
									<td class="table-cell cell-delivery">уточняйте у оператора</td>
								</tr>

# %%
<div class="b-card-page__price-line mt-20">
                                                            Цена:
                            
                                                            <span class="text-gray">
                                    <span class="text-through">3 500 280</span> ₽
                                </span>
                            						</div>

# %%
<span class="text-through">3 500 280</span>

# %%
card.find_all('span',class_="b-card-page__price-line")
# Out:
# []

# %%
<div class="b-card-page__price-line">
								Со скидкой: <span>1 050 084</span>
								<span>₽ (-70%)</span>
							</div>

# %%
card.find_all('span',"store-replace")
# Out:
# []

# %%
<span class="store-replace">
                                        Москва,
                                                                                    ТГ «Модный сезон»,
                                                                                ул. Охотный Ряд, д. 2, 1 этаж, метро «Театральная»
                                                                                </span>

# %%
session = requests.Session()
response = session.get('https://kierge.com/zhenskie/tproduct/195388121-518721987481-koltso')
response
# Out:
# <Response [403]>

# %%
session.headers =  {
  'accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
  'accept-encoding':'gzip, deflate, br',
  'accept-language':'ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7',
  'cache-control':'no-cache',
  'dnt': '1',
  'pragma': 'no-cache',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-site': 'none',
  'sec-fetch-user': '?1',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36'}

# %%
response = session.get('https://kierge.com/zhenskie/tproduct/195388121-518721987481-koltso')
response
# Out:
# <Response [200]>

# %%
url =  f'https://kierge.com/zhenskie/tproduct/195388121-518721987481-koltso'
json_url =  f'https://kierge.com/zhenskie/tproduct/195388121-518721987481-koltso'
header = {
  'accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
  'accept-encoding':'gzip, deflate, br',
  'accept-language':'ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7',
  'cache-control':'no-cache',
  'dnt': '1',
  'pragma': 'no-cache',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-site': 'none',
  'sec-fetch-user': '?1',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36'}

session = requests.Session()
session.headers = header
r = session.get(url)
if r.status_code == 200:
  json_r = session.get(json_url)
  if json_r.status_code == 200:
    print(json_r.text)
  else:
    print(json_r.status_code)

# %%
card = BeautifulSoup(json_r.text, 'lxml')

# %%
card.find_all('div',"js-store-prod-all-text")[0].text.strip()

# %%
file = open("jewels/kierge/Женские украшения_21-04-2022_кольца.html", "r")

# %%
file
# Out:
# <_io.TextIOWrapper name='jewels/kierge/Женские украшения_21-04-2022_кольца.html' mode='r' encoding='cp1251'>

# %%
with open ("jewels/kierge/Женские украшения_21-04-2022_кольца.html",'r',encoding='utf-8') as f:
    html = BeautifulSoup(f.read(), 'lxml')

# %%
<div class="t-store__card__wrap_all " style="background-color:#222222;box-shadow: 0px 0px 3px 0px rgba(0, 0, 0, 0.3);">    <a href="https://kierge.com/zhenskie/tproduct/195388121-486904972136-koltso">        <div class="t-store__card__imgwrapper " style="padding-bottom:83.33333333333333%;">        <div class="js-product-img t-store__card__bgimg t-bgimg loaded" data-original="https://static.tildacdn.com/tild3062-3235-4165-a537-336462306165/27-min.jpg" style="background-image: url(&quot;https://thumb.tildacdn.com/tild3062-3235-4165-a537-336462306165/-/cover/280x233/center/center/-/format/webp/27-min.jpg&quot;);" bgimgfield="st_gallery__486904972136:::0"></div>    </div>    </a>    <div class="t-store__card__wrap_txt-and-btns" style="height: 120px;">        <div class="store__card__wrap_txt-and-opts">            <a href="https://kierge.com/zhenskie/tproduct/195388121-486904972136-koltso">                        <div class="t-store__card__textwrapper">            <div class="js-store-prod-name js-product-name t-store__card__title t-name t-name_md" style="color:#ffffff;font-weight:700;" field="st_title__486904972136" data-redactor-toolbar="no">Кольцо</div><div class="t-store__card__sku t-descr t-descr_xxs" style="display:none;color:#ffffff;">Артикул: <span class="js-store-prod-sku js-product-sku" field="st_sku__486904972136" data-redactor-toolbar="no">8989000475952</span></div><div class="js-store-price-wrapper t-store__card__price-wrapper">    <div class="t-store__card__price t-store__card__price-item t-name t-name_xs" style="color:#ffffff;font-size:20px;font-weight:400;"><div class="js-product-price js-store-prod-price-val t-store__card__price-value notranslate" translate="no" field="st_price__486904972136" data-redactor-toolbar="no" data-product-price-def="27903" data-product-price-def-str="27903">27 903</div><div class="t-store__card__price-currency">р.</div></div>    <div class="t-store__card__price_old t-store__card__price-item t-name t-name_xs" style="display: none;color:#bdbdbd;font-size:20px;font-weight:400;"><div class="js-store-prod-price-old-val t-store__card__price-value notranslate" translate="no" field="st_priceold__486904972136" data-redactor-toolbar="no"></div><div class="t-store__card__price-currency">р.</div></div>    </div>        </div>            </a>            <div class="js-product-controls-wrapper t-store__card__prod-controls-wrapper" style="display:none;"></div>        </div>            </div></div>

# %% [markdown]
# ## epl

# %%
response = session.get('https://epldiamond.ru/catalog/diamond-rings/?utm_source=samolet-yandex&utm_medium=cpc&utm_campaign=%D0%98%D0%B7%D0%B4%D0%B5%D0%BB%D0%B8%D1%8F+%D1%81+%D0%B1%D1%80%D0%B8%D0%BB%D0%BB%D0%B8%D0%B0%D0%BD%D1%82%D0%B0%D0%BC%D0%B8+%2F+%D0%A0%D0%A1%D0%AF+%2F+%D0%9C%D0%B8%D0%BB%D0%BB%D0%B8%D0%BE%D0%BD%D0%BD%D0%B8%D0%BA%D0%B8&utm_content=cid%7C47794255%7Cgid%7C4031655955%7Caid%7C8315568285%7Cadp%7Cno%7Cdvc%7Cmobile%7Cpid%7C18983667016%7Crid%7C%7Cdid%7C18983667016%7Cpos%7Cnone0%7Cadn%7Ccontext%7Ccrid%7C0%7C&utm_term=%D0%BA%D1%83%D0%BF%D0%B8%D1%82%D1%8C+%D0%BA%D0%BE%D0%BB%D1%8C%D1%86%D0%BE+%D1%81+%D0%B1%D1%80%D0%B8%D0%BB%D0%BB%D0%B8%D0%B0%D0%BD%D1%82%D0%BE%D0%BC+%D0%B4%D0%BE%D1%80%D0%BE%D0%B3%D0%BE&roistat=direct44_context_8315568285_%D0%BA%D1%83%D0%BF%D0%B8%D1%82%D1%8C+%D0%BA%D0%BE%D0%BB%D1%8C%D1%86%D0%BE+%D1%81+%D0%B1%D1%80%D0%B8%D0%BB%D0%BB%D0%B8%D0%B0%D0%BD%D1%82%D0%BE%D0%BC+%D0%B4%D0%BE%D1%80%D0%BE%D0%B3%D0%BE&roistat_referrer=mamba.ru&roistat_pos=none_0&yclid=2091523364497194038&PAGEN_2=3')

# %%
response
# Out:
# <Response [200]>

# %%
html = BeautifulSoup(response.text,'lxml')

# %%
#rec195388121 > div.t778 > div > div.js-store-grid-cont.t-store__grid-cont.t-container.t-store__mobile-two-columns.t-store__grid-cont_mobile-grid > div:nth-child(1) > div > a

# %%
#quotes = html.select('rec195388121 > div.t778 > div > div.js-store-grid-cont.t-store__grid-cont.t-container.t-store__mobile-two-columns.t-store__grid-cont_mobile-grid > div:nth-child(1) > div > a')
quotes = html.find_all('div', class_="t-store__card__wrap_all ")
quotes

#[q.get("data-original") for q in quotes]
# Out:
# []

# %%
#quotes = html.select('rec195388121 > div.t778 > div > div.js-store-grid-cont.t-store__grid-cont.t-container.t-store__mobile-two-columns.t-store__grid-cont_mobile-grid > div:nth-child(1) > div > a')
quotes = html.find_all('a', class_="b-product-card__title")
quotes

[q.get("href") for q in quotes]
# Out:
# ['//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0940kts02220413/?4410741',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0940kts02220411/?4410733',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0943kts02220455/?4408027',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0963kts01220468/?4408007',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts11210869/?4406071',
#  '//epldiamond.ru/product/koltso-iz-krasnogo-zolota-585-s-brilliantami-e0201kts04193800/?4444683',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts02220938/?4400685',
#  '//epldiamond.ru/product/koltso-iz-serebra-925-s-brilliantami-e0605kts11210464/?4405605',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts11210660/?4400373',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts01220203/?4400647',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0933kts12210414/?4362215',
#  '//epldiamond.ru/product/koltso-iz-kombinirovannogo-zolota-585-s-brilliantami-e1001kts11210503/?4333579',
#  '//epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts06210022/?4349493',
#  '//epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantami-e0301kts05210375/?4136619',
#  '//epldiamond.ru/product/koltso-iz-zheltogo-zolota-585-s-brilliantom-e0301kts04202996/?3783607',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantom-e0901kts01220883/?4446039',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0976kts01220467/?4396055',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts08151700/?4445529',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts11210956-pink/?4351171',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts06165200-blue/?4290327',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0937kts07210487/?4384031',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0938kts05210473/?4383981',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts09150600/?4410491',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts10210306-blue/?4291029',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e1401kts05160600/?4269585',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts12210653/?4383955',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0901kts07210126/?4422887',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0928kts12210414/?4362207',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts08210006/?4445547',
#  '//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0912kts04190300/?4410503']

# %%
<a class="b-product-card__title" href="//epldiamond.ru/product/koltso-iz-belogo-zolota-585-s-brilliantami-e0943kts02220455/?4408027">
									<span itemprop="name">
																			Кольцо из белого золота с бриллиантами и топазом																		</span>
								</a>

# %%
html
# Out:
# <!--[if lt IE 11]>
# <style>.header, .content, .footer, .head-nav{display: none}#old-browser-warning{margin-left:auto; margin-right: auto;text-align: center; margin-top: 60px; margin-bottom: 60px; border: 2px dashed #888; max-width: 600px;}#old-browser-warning h4{margin-top: 14px; margin-bottom: 14px;}#old-browser-warning a{display: block;}</style>
# <p id="old-browser-warning">
# 	<p>Ваш браузер не поддерживается!</p>
# 	<p>Пожалуйста, скачайте более современный браузер на Ваш выбор</p><a href="https://www.google.ru/chrome/browser/desktop/index.html" target="_blank">Google Chrome</a><a href="//epldiamond.ru/catalog/diamond-rings/http://getfirefox.com" target="_blank">FireFox</a><a href="//epldiamond.ru/catalog/diamond-rings/http://www.opera.com/download/" target="_blank">Opera</a><a href="//epldiamond.ru/catalog/diamond-rings/http://www.microsoft.com/windows/downloads/ie/getitnow.mspx" target="_blank">Internet Explorer EDGE</a>
# 	<p>Спасибо!</p>
# </div><![endif]--><!DOCTYPE html>
# <html class="no-js" lang="ru">
# <head>
# <!-- Yandex.Metrika counter -->
# <script type="c9c85dae9ae649b1e52c1077-text/javascript">
#             (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
#                 m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
#             (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
#             ym(24555296, "init", {
#                 clickmap:true,
#                 trackLinks:true,
#                 accurateTrackBounce:true,
#                 webvisor:true,
#                 ecommerce:"dataLayer"
#             });
#         </script>
# <noscript><div><img alt="" src="https://mc.yandex.ru/watch/24555296" style="position:absolute; left:-9999px;"/></div></noscript>
# <!-- /Yandex.Metrika counter -->
# <!-- Google Tag Manager -->
# <script data-skip-moving="true" id="google-tm-all-salons" type="c9c85dae9ae649b1e52c1077-text/javascript">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                 new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                 j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.id='google-tm-all-salons-3';j.src=
#                 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#             })(window,document,'script','dataLayer','GTM-TBJJS2S');</script>
# <!-- End Google Tag Manager -->
# <script type="c9c85dae9ae649b1e52c1077-text/javascript">
#             const backend = {
#                 userIp: '77.242.1.44',
#             };
#         </script>
# <meta charset="utf-8"/>
# <meta content="width=device-width, height=device-height, initial-scale=1.0, user-scalable=no, maximum-scale=1.0" name="viewport"/>
# <title>Кольца с бриллиантами – купить в Москве по недорогой цене в интернет-магазине ЭПЛ Даймонд – Якутские бриллианты - Страница 3</title>
# <!-- Twitter microformat -->
# <link href="//epldiamond.ru/favicon.ico" rel="icon"/>
# <meta content="#000" name="theme-color"/>
# <meta content="app-id=1502967424" name="apple-itunes-app"/>
# <script type="c9c85dae9ae649b1e52c1077-text/javascript">
# 		if(/MSIE \d|Trident.*rv:/.test(navigator.userAgent)){document.write('<script src="/local/templates/design2019/js/svgxuse.js"><\/script>');}
# 	</script>
# <meta content="index, follow" name="robots"/>
# <meta content=" " name="description"/>
# <link href="//epldiamond.ru/bitrix/js/main/core/css/core_popup.css?151043587114934" rel="stylesheet" type="text/css"/>
# <link data-template-style="true" href="//epldiamond.ru/local/templates/design2019/styles/libraries.css?155611409846598" rel="stylesheet" type="text/css"/>
# <link data-template-style="true" href="//epldiamond.ru/css/suggestions.min.css?16346492972091" rel="stylesheet" type="text/css"/>
# <link data-template-style="true" href="//epldiamond.ru/local/templates/design2019/styles/common.css?164491976164131" rel="stylesheet" type="text/css"/>
# <link data-template-style="true" href="//epldiamond.ru/local/templates/design2019/styles/custom.css?161857572122670" rel="stylesheet" type="text/css"/>
# <link data-template-style="true" href="//epldiamond.ru/local/templates/design2019/styles/easyautocomplete/easy-autocomplete.min.css?16449394148315" rel="stylesheet" type="text/css"/>
# <link data-template-style="true" href="//epldiamond.ru/local/templates/design2019/styles/easyautocomplete/easy-autocomplete.themes.min.css?16449197615277" rel="stylesheet" type="text/css"/>
# <link data-template-style="true" href="//epldiamond.ru/bitrix/js/main/core/css/core.css?14338648383963" rel="stylesheet" type="text/css"/>
# <link data-template-style="true" href="//epldiamond.ru/local/templates/design2019/components/custom/main.register/.default/style.css?1644316745118" rel="stylesheet" type="text/css"/>
# <link data-template-style="true" href="//epldiamond.ru/local/templates/design2019/components/altasib/geobase.select.city/design2019/custom.css?155499314814140" rel="stylesheet" type="text/css"/>
# <link data-template-style="true" href="//epldiamond.ru/local/templates/design2019/components/altasib/geobase.select.city/design2019/style.css?16371458501777" rel="stylesheet" type="text/css"/>
# <link data-template-style="true" href="//epldiamond.ru/local/include/languages/styles.css?16330098023825" rel="stylesheet" type="text/css"/>
# <script type="c9c85dae9ae649b1e52c1077-text/javascript">if(!window.BX)window.BX={};if(!window.BX.message)window.BX.message=function(mess){if(typeof mess=='object') for(var i in mess) BX.message[i]=mess[i]; return true;};</script>
# <script type="c9c85dae9ae649b1e52c1077-text/javascript">(window.BX||top.BX).message({'JS_CORE_LOADING':'Загрузка...','JS_CORE_NO_DATA':'- Нет данных -','JS_CORE_WINDOW_CLOSE':'Закрыть','JS_CORE_WINDOW_EXPAND':'Развернуть','JS_CORE_WINDOW_NARROW':'Свернуть в окно','JS_CORE_WINDOW_SAVE':'Сохранить','JS_CORE_WINDOW_CANCEL':'Отменить','JS_CORE_WINDOW_CONTINUE':'Продолжить','JS_CORE_H':'ч','JS_CORE_M':'м','JS_CORE_S':'с','JSADM_AI_HIDE_EXTRA':'Скрыть лишние','JSADM_AI_ALL_NOTIF':'Показать все','JSADM_AUTH_REQ':'Требуется авторизация!','JS_CORE_WINDOW_AUTH':'Войти','JS_CORE_IMAGE_FULL':'Полный размер'});</script>
# <script type="c9c85dae9ae649b1e52c1077-text/javascript">(window.BX||top.BX).message({'LANGUAGE_ID':'ru','FORMAT_DATE':'DD.MM.YYYY','FORMAT_DATETIME':'DD.MM.YYYY HH:MI:SS','COOKIE_PREFIX':'BITRIX_SM','SERVER_TZ_OFFSET':'10800','SITE_ID':'s1','SITE_DIR':'/','USER_ID':'','SERVER_TIME':'1650615578','USER_TZ_OFFSET':'0','USER_TZ_AUTO':'Y','bitrix_sessid':'d7254082a78feb2da557ff104266c61e'});</script>
# <script src="/bitrix/js/main/core/core.js?1522845624124374" type="c9c85dae9ae649b1e52c1077-text/javascript"></script>
# <script src="/bitrix/js/main/core/core_ajax.js?152284562440156" type="c9c85dae9ae649b1e52c1077-text/javascript"></script>
# <script src="https://www.google.com/recaptcha/api.js?onload=multipleReCaptchaHandler&amp;render=explicit" type="c9c85dae9ae649b1e52c1077-text/javascript"></script>
# <script src="/bitrix/js/main/core/core_fx.js?151043575316888" type="c9c85dae9ae649b1e52c1077-text/javascript"></script>
# <script src="/bitrix/js/main/core/core_popup.js?151043587459673" type="c9c85dae9ae649b1e52c1077-text/javascript"></script>
# <link href="https://epldiamond.ru/catalog/diamond-rings/?PAGEN_2=3" rel="canonical"/>
# <script src="/local/templates/design2019/js/libraries.js?1598430630347792" type="c9c85dae9ae649b1e52c1077-text/javascript"></script>
# <script src="/js/jquery.suggestions.min.js?163464929782758" type="c9c85dae9ae649b1e52c1077-text/javascript"></script>
# <script src="/local/templates/design2019/js/jquery.easy-autocomplete.min.js?164491976115207" type="c9c85dae9ae649b1e52c1077-text/javascript"></script>
# <script src="/js/mobile-detect.min.js?163586243039587" type="c9c85dae9ae649b1e52c1077-text/javascript"></script>
# <script src="/local/templates/design2019/js/bundle.js?1648540438157476" type="c9c85dae9ae649b1e52c1077-text/javascript"></script>
# <script src="/js/jquery.form.min.js?159802584715250" type="c9c85dae9ae649b1e52c1077-text/javascript"></script>
# <script src="/local/templates/design2019/js/custom.js?164862874325896" type="c9c85dae9ae649b1e52c1077-text/javascript"></script>
# <script src="/local/templates/.default/js/analytics-sender.js?155618667023833" type="c9c85dae9ae649b1e52c1077-text/javascript"></script>
# <script src="/local/templates/design2019/components/custom/main.register/.default/script.js?1644316745276" type="c9c85dae9ae649b1e52c1077-text/javascript"></script>
# <script src="/local/templates/design2019/components/altasib/geobase.select.city/design2019/custom.js?162549984931755" type="c9c85dae9ae649b1e52c1077-text/javascript"></script>
# <script src="/local/components/elastic/catalog.smart.filter/templates/.default/script.js?164622600621337" type="c9c85dae9ae649b1e52c1077-text/javascript"></script>
# <script src="/js/jquery.cookie.js?1541517437973" type="c9c85dae9ae649b1e52c1077-text/javascript"></script>
# <script type="c9c85dae9ae649b1e52c1077-text/javascript">var _ba = _ba || []; _ba.push(["aid", "72dc2239e86ac08db38a56683f909562"]); _ba.push(["host", "epldiamond.ru"]); (function() {var ba = document.createElement("script"); ba.type = "text/javascript"; ba.async = true;ba.src = (document.location.protocol == "https:" ? "https://" : "http://") + "bitrix.info/ba.js";var s = document.getElementsByTagName("script")[0];s.parentNode.insertBefore(ba, s);})();</script>
# <!-- 🡇🡇🡇 полифилл intersection-observer -->
# <script type="c9c85dae9ae649b1e52c1077-text/javascript">if(!('IntersectionObserver' in window)){document.write('<script src="/local/templates/design2019/js/intersection-observer.js"><\/script>');}</script><!-- -->
# <!-- 🡇🡇🡇 полифилл promise -->
# <script type="c9c85dae9ae649b1e52c1077-text/javascript">if(!('Promise' in window)){document.write('<script src="/local/templates/design2019/js/promise-polyfill.js"><\/script>');}</script><!-- -->
# <!-- BEGIN JIVOSITE CODE {literal} -->
# <script type="c9c85dae9ae649b1e52c1077-text/javascript">
#     window.widget_id = '9gCixsG0KS';
#     window.jivoChatLoaded = false;
#     var jivoChatAnswerTime = 120;
#     var jivoContactInfo;
#     var jivoMessages = [];
#     var jivoChatReloaded = false;
#     var jivochat = function () {
#         if (window.jivoChatLoaded)
#             return;
#
#         window.jivoChatLoaded = true;
#         var d = document;
#         var w = window;
#
#         function l() {
#             var s = document.createElement('script');
#             s.type = 'text/javascript';
#             s.async = true;
#             s.src = '//code.jivosite.com/script/widget/' + window.widget_id;
#             var ss = document.getElementsByTagName('script')[0];
#             ss.parentNode.insertBefore(s, ss);
#             // jivoLoaded();
#         }
#
#         if (d.readyState == 'complete') {
#             l();
#         } else {
#             if (w.attachEvent) {
#                 w.attachEvent('onload', l);
#             } else {
#                 w.addEventListener('load', l, false);
#             }
#         }
#     };
#
#     jivochat();
#
#     var defaultWidget = '9gCixsG0KS';
#     var jivoFirstOpen = true;
#     function jivo_onOpen() {
#         if (jivoFirstOpen) {
#             jivoFirstOpen = false;
#             //Получаем кнопку отправки в живочате
#             var jivoSendButton = $('jdiv')
#                 .filter(function() {
#                     return $(this).get(0).className.match(/sendButton.*/);
#                 });
#
#             if (jivoSendButton.length) {
#                 jivoSendButton.click(function () {
#                     jivoMessages.push($('#jcont textarea').val());
#                 });
#             }
#         }
#
#
#         if (jivoChatReloaded) {
#             jivoChatReloaded = false;
#
#             $.each(jivoMessages, function (index, value) {
#                 jivo_api.sendMessage(value);
#             });
#
#             if (jivoContactInfo)
#                 jivo_api.setContactInfo(jivoContactInfo);
#         }
#     }
#
#     function jivo_onIntroduction(){
#         console.log('jivo_onIntroduction');
#         jivoContactInfo = jivo_api.getContactInfo();
#         var contact = jivoContactInfo;
#         var gid = getCookie('_ga');
#         var gidArr = gid.split('.');
#         gid = gidArr[2] + '.' + gidArr[3];
#         contact['gid'] = gid;
#         contact['sn'] = '';
#         contact['sn_type'] = '';
#         var httpRequest = new XMLHttpRequest();
#         // httpRequest.onreadystatechange = function (data) {console.log('cInfo')};
#         // httpRequest.open('POST', "/api/crm/webhook/js_webhook_jivochat.php");
#         // httpRequest.setRequestHeader('Content-Type', 'application/json');
#         // httpRequest.send(JSON.stringify(contact));
#     }
#
#     var inactiveTimer;
#     var inactiveTimerId;
#
#     var reloadJivoChat = function(){
#         window.jivo_destroy();
#         window.jivoChatLoaded = false;
#         window.widget_id = defaultWidget;
#         jivochat();
#         Hlp.setCookie('setJivochatDefaultWidget', 1, {domain: '.epldiamond.ru'});
#         jivoChatReloaded = true;
#     };
#
#     function jivo_onAccept() {
#         clearTimeout(inactiveTimerId);
#         console.log('jivo_onAccept');
#         Hlp.setCookie('jivochatAccepted', 1, {domain: '.epldiamond.ru'});
#     }
#
#     function jivo_onMessageSent() {
#         console.log('jivo_onMessageSent');
#         jivoChatAnswerTime += 20;
#     }
#
#     // function jivoLoaded() {
#     //     if (window.widget_id === defaultWidget ||  Hlp.getCookie('jivochatAccepted')) {
#     //         return;
#     //     }
#     //     inactiveTimer = parseInt(Hlp.getCookie('inactiveTimerJivochat'));
#     //     if (!inactiveTimer) {
#     //         inactiveTimer = (+ new Date());
#     //         Hlp.setCookie('inactiveTimerJivochat', inactiveTimer, {domain: '.epldiamond.ru'});
#     //     }
#     //
#     //     inactiveTimerId = setInterval(function () {
#     //         var secondsAfterFirstMessage = ((+ new Date()) - inactiveTimer) / 1000;
#     //         if (secondsAfterFirstMessage > jivoChatAnswerTime) {
#     //             clearTimeout(inactiveTimerId);
#     //             reloadJivoChat();
#     //         }
#     //     }, 1000);
#     // }
#
#
#
#     </script>
# <!-- {/literal} END JIVOSITE CODE -->
# <script type="c9c85dae9ae649b1e52c1077-text/javascript">
#     window.GTMId = '';
#     window.GAId = 'UA-33918303-1';
#     window.isSalonGTM = '';
#     window.GTMLoaded = false;
#     window.GALoaded = false;
#
#     var GTMStart = function () {
#         if (window.GTMLoaded)
#             return;
#
#         window.GTMLoaded = true;
#
#         var d = document;
#         var w = window;
#
#         function loadGTMCode()
#         {
#             if(!window.GTMId)
#                 return;
#
#             var script = document.createElement('script');
#             script.id = 'google-tm-load-script';
#             var GTMCodeStr = "(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':";
#             GTMCodeStr += "new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],";
#             GTMCodeStr += "j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.id='google-tm-script';j.src=";
#             GTMCodeStr += "'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);";
#             GTMCodeStr += "})(window,document,'script','dataLayer','"+window.GTMId+"');";
#             script.innerHTML = GTMCodeStr;
#
#             var ss = document.getElementsByTagName('script')[0];
#             ss.parentNode.insertBefore(script, ss);
#
#             var script2 = document.createElement('noscript');
#             script2.id = 'google-tm-load-script-2';
#             var GTMCodeStr2 = '<iframe src="https://www.googletagmanager.com/ns.html?id='+window.GTMId+'" height="0" width="0" style="display:none;visibility:hidden"></iframe>';
#             script2.innerHTML = GTMCodeStr2;
#             document.body.append(script2);
#         }
#
#         if (d.readyState == 'complete') {
#             loadGTMCode();
#         } else {
#             if (w.attachEvent) {
#                 w.attachEvent('onload', loadGTMCode);
#             } else {
#                 w.addEventListener('load', loadGTMCode, false);
#             }
#         }
#     };
#
#     var GAStart = function () {
#         if (window.GALoaded)
#             return;
#
#         window.GALoaded = true;
#
#         var d = document;
#         var w = window;
#
#         function loadGACode()
#         {
#             var scriptGA1 = document.createElement('script');
#             scriptGA1.id = 'google-analytics-load-script';
#             scriptGA1.async = false;
#             //scriptGA1.src = "https://www.googletagmanager.com/gtag/js?id=G-8GXKCBFLD8";
#             scriptGA1.src = "https://www.googletagmanager.com/gtag/js?id="+window.GAId;
#
#             var scriptGa2 = document.createElement('script');
#             scriptGa2.id = 'google-analytics-load-script-2';
#             GAScript2CodeStr = 'window.dataLayer = window.dataLayer || [];';
#             GAScript2CodeStr += 'function gtag(){dataLayer.push(arguments);}';
#             GAScript2CodeStr += "gtag('js', new Date());";
#             GAScript2CodeStr += "gtag('config', '"+window.GAId+"');";
#
#             scriptGa2.innerHTML = GAScript2CodeStr;
#
#             // scriptGA1.after(scriptGa2);
#             var ss = document.getElementsByTagName('script')[0];
#             ss.parentNode.insertBefore(scriptGA1, ss);
#             ss.parentNode.insertBefore(scriptGa2, ss);
#
#             if(!isSalonGTM)
#             {
#                 var scriptGA3 = document.createElement('script');
#                 scriptGA3.id = 'gtag-load-script';
#                 scriptGA3.async = false;
#                 scriptGA3.src = "https://www.googletagmanager.com/gtag/js?id=AW-356701103";
#
#                 var scriptGa4 = document.createElement('script');
#                 scriptGa4.id = 'gtag-load-script-2';
#                 GtagScript2CodeStr = 'window.dataLayer = window.dataLayer || [];';
#                 GtagScript2CodeStr += 'function gtag(){dataLayer.push(arguments);}';
#                 GtagScript2CodeStr += "gtag('js', new Date());";
#                 GtagScript2CodeStr += "gtag('config', 'AW-356701103');";
#
#                 scriptGa4.innerHTML = GtagScript2CodeStr;
#
#                 var ss = document.getElementsByTagName('script')[0];
#                 ss.parentNode.insertBefore(scriptGA3, ss);
#                 ss.parentNode.insertBefore(scriptGa4, ss);
#
#                 var scriptGA3 = document.createElement('script');
#                 scriptGA3.id = 'gtag-load-script-3';
#                 scriptGA3.async = false;
#                 scriptGA3.src = "https://www.googletagmanager.com/gtag/js?id=G-41WYEX3D4V";
#
#                 var scriptGa4 = document.createElement('script');
#                 scriptGa4.id = 'gtag-load-script-4';
#                 GtagScript2CodeStr = 'window.dataLayer = window.dataLayer || [];';
#                 GtagScript2CodeStr += 'function gtag(){dataLayer.push(arguments);}';
#                 GtagScript2CodeStr += "gtag('js', new Date());";
#                 GtagScript2CodeStr += "gtag('config', 'G-41WYEX3D4V');";
#
#                 scriptGa4.innerHTML = GtagScript2CodeStr;
#
#                 var ss = document.getElementsByTagName('script')[0];
#                 ss.parentNode.insertBefore(scriptGA3, ss);
#                 ss.parentNode.insertBefore(scriptGa4, ss);
#             }
#         }
#
#         if (d.readyState == 'complete') {
#             loadGACode();
#         } else {
#             if (w.attachEvent) {
#                 w.attachEvent('onload', loadGACode);
#             } else {
#                 w.addEventListener('load', loadGACode, false);
#             }
#         }
#     };
#
#     GTMStart();
#     GAStart();
#
#     function gtm_destroy() {
#         $('script#google-tm-script').remove();
#         $('script#google-tm-load-script').remove();
#         $('noscript#google-tm-load-script-2').remove();
#     }
#
#     function ga_destroy() {
#         $('script#google-analytics-load-script').remove();
#         $('script#google-analytics-load-script-2').remove();
#     }
#
#     function sendGaEvent(categoryName, eventName)
#     {
#         ga('allSalonsGTMCode.send', 'event', categoryName, eventName);
#         if(window.GAId && window.GAId != 'UA-33918303-1')
#         {
#             ga('salonsGTMCode.send', 'event', categoryName, eventName);
#         }
#     }
# </script>
# <script type="c9c85dae9ae649b1e52c1077-text/javascript">
#     window.ymCode = '';
#     window.YMLoaded = false;
#
#     var YMStart = function () {
#         if (window.YMLoaded || !window.ymCode)
#             return;
#
#         window.YMLoaded = true;
#
#         var d = document;
#         var w = window;
#
#         function loadYMCode()
#         {
#             var scriptYM = document.createElement('script');
#             scriptYM.id = 'yandex-metrika-script-1';
#             scriptYM.async = false;
#             YMScriptStr = '(function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};';
#             YMScriptStr += 'm[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})';
#             YMScriptStr += '(window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");';
#             YMScriptStr += 'ym('+window.ymCode+', "init", {';
#             YMScriptStr += 'clickmap:true,';
#             YMScriptStr += 'trackLinks:true,';
#             YMScriptStr += 'accurateTrackBounce:true,';
#             YMScriptStr += 'webvisor:true,';
#             YMScriptStr += 'ecommerce:"dataLayer"';
#             YMScriptStr += '});';
#             scriptYM.innerHTML = YMScriptStr;
#
#             var scriptYM2 = document.createElement('noscript');
#             scriptYM2.id = 'yandex-metrika-script-2';
#             scriptYM2Str = '<div><img src="https://mc.yandex.ru/watch/'+window.ymCode+'" style="position:absolute; left:-9999px;" alt="" /></div>';
#
#             scriptYM2.innerHTML = scriptYM2Str;
#             var ss = document.getElementsByTagName('script')[0];
#             ss.parentNode.insertBefore(scriptYM, ss);
#             ss.parentNode.insertBefore(scriptYM2, ss);
#
#             setTimeout(function(){
#                 if (location.href.indexOf('/personal/order/make/?ORDER_ID=') != -1) {
#                     sendGaEvent('переход на страницу', 'Страница заказ оформлен');
#                     sendYMEvent('Страница заказ оформлен');
#                 }
#             }, 1000);
#         }
#
#         if (d.readyState == 'complete') {
#             loadYMCode();
#         } else {
#             if (w.attachEvent) {
#                 w.attachEvent('onload', loadYMCode);
#             } else {
#                 w.addEventListener('load', loadYMCode, false);
#             }
#         }
#     };
#
#     YMStart();
#
#     function ym_destroy() {
#         $('script#yandex-metrika-script-1').remove();
#         $('script#yandex-metrika-script-2').remove();
#     }
#
#     function sendYMEvent(eventName)
#     {
#         ym(24555296, 'reachGoal', eventName)
#         if(window.ymCode)
#         {
#             ym(window.ymCode, 'reachGoal', eventName);
#         }
#     }
# </script> <!-- сервис "где слон"-->
# <script type="c9c85dae9ae649b1e52c1077-text/javascript">
#         if(!window.gdeslon_q||window.gdeslon_q instanceof Array){var hasPerformance="undefined"!==typeof performance&&"function"===typeof performance.now;var perf=hasPerformance?performance.now():null;var oldQueue=window.gdeslon_q||[];window.gdeslon_q=function(){var _exceptions=[],_state={},appendScript=function(url){var gss=document.createElement("script");gss.type="text/javascript";gss.async=true;gss.src=url;var s=document.getElementsByTagName("script")[0];s.parentNode.insertBefore(gss,s)},serializeObject=function(obj){return Object.keys(obj).map(function(key){return encodeURIComponent(key)+"="+encodeURIComponent(obj[key])}).join("&")},deserializeObject=function(str,pairsSeparator,keyValueSeparator){var result={},pairs,pair,key,value,i,l;if(!keyValueSeparator){keyValueSeparator="="}if(!str){return result}pairs=str.split(pairsSeparator);for(i=0,l=pairs.length;i<l;i++){pair=pairs[i].replace(/^\s+|\s+$/g,"").split(keyValueSeparator);try{key=decodeURIComponent(pair[0]);value=decodeURIComponent(pair[1]);result[key]=value}catch(e){console.log(e.message)}}return result},location=function(){return document.location}(),domain=function(){var domain=location.hostname||location.host.split(":")[0];var domainParts=domain.split(".");var l=domainParts.length;if(l>1){domain=domainParts[l-2]+"."+domainParts[l-1]}return domain}(),queryParams=function(){return deserializeObject(location.search.slice(1),"&")}(),cookieTtl=function(){var cookieTtl=parseInt(queryParams._gs_cttl,10);if(!cookieTtl||isNaN(cookieTtl)){cookieTtl=180}return cookieTtl}(),writeCookie=function(name,value,ttlSeconds){if(!(name&&value)){return}value=encodeURIComponent(value);var ttl=ttlSeconds||cookieTtl*24*60*60;var date=new Date;date.setTime(date.getTime()+ttl*1e3);var expires="; expires="+date.toUTCString();var domainParam="domain="+domain+"; ";document.cookie=name+"="+value+expires+"; "+domainParam+"path=/;"},cookies=function(key){return deserializeObject(document.cookie,";")[key]},token=function(){return cookies("gdeslon.ru.__arc_token")},affiliate_id=function(){return cookies("gdeslon.ru.__arc_aid")},track_domain=function(){return cookies("gdeslon.ru.__arc_domain")||"gdeslon.ru"},pixel_domain=function(){return cookies("gdeslon.ru.__arc_gsp_domain")||"gdeslon.ru"},gs_uid=function(){return cookies("gdeslon.ru.user_id")},processor=function(){_state.pushStartedAt=Date.now();var pixel=[];var track=[];if(arguments.length===0){return}var obj=arguments[0];var shouldInvokeTrack=false;Object.keys(obj).forEach(function(key){var val=obj[key];var same="";switch(key){case"page_type":pixel.mode=val;break;case"merchant_id":pixel.mid=val;track.merchant_id=val;break;case"category_id":pixel.cat_id=val;track.cat_id=val;break;case"products":if(!val||val.constructor!==Array)break;same=val.map(function(l){var repeats=[];for(var i=0;i<parseFloat(l.quantity);i++){repeats.push(l.id+":"+parseFloat(l.price))}return repeats.join(",")});pixel.codes=same;track.codes=same;break;case"user_id":pixel.muid=val;track.muid=val;break;default:pixel[key]=val;track[key]=val;break}});if(obj.page_type==="thanks"){if(obj.hasOwnProperty("deduplication")){if(Object.prototype.toString.call(obj.deduplication)==="[object String]"){var trueArr=["gdeslon_cpa","gdeslon","gde slon","","undefined","null","true","1"];shouldInvokeTrack=trueArr.indexOf(obj.deduplication.toLowerCase())>-1}else{shouldInvokeTrack=true}}else{shouldInvokeTrack=true}}pixel.perf=parseInt(perf,10);track.perf=pixel.perf;pixel.gs_uid=gs_uid();track.gs_uid=pixel.gs_uid;pixel._t=Date.now();track._t=Date.now();pixel.source=window.location.href;var url="//"+pixel_domain()+"/gsp.js?"+serializeObject(pixel);appendScript(url);if(shouldInvokeTrack){_state.shouldInvokeTrack=true;track.affiliate_id=affiliate_id();track.token=token();url="//"+track_domain()+"/purchase.js?"+serializeObject(track);appendScript(url)}else{_state.shouldInvokeTrack=false}_state.pushFinishedAt=Date.now()},_push=function(){try{return processor.apply(null,arguments)}catch(c){_exceptions.pu ...
#     </script>
# <!-- End сервис "где слон" -->
# </head>
# <body class="">
# <!-- Google Tag Manager (noscript) -->
# <noscript id="google-tm-all-salons-2"><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TBJJS2S" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div class="overlay-filter-load-cards" id="overlay-filter-load-cards">
# <div class="overlay-filter-load-cards__info">
# <div class="overlay-filter-load-cards__loader">
# <svg>
# <use xlink:href="/local/templates/design2019/svg/svg-sprite.svg#svg-diamond-circle"></use>
# </svg>
# </div>
# <div class="mt-10 fs-17">Уточняется наличие украшений. Пожалуйста подождите..</div>
# </div>
# </div>
# <div class="l-wrapper">
# <header class="l-header b-header js-header">
# <div class="l-container b-header__row">
# <div class="b-header__left">
# <button class="b-header__mobile-nav-btn js-header__mobile-nav-btn">
# <svg class="b-header__mobile-nav-btn-svg" data-cf-modified-c9c85dae9ae649b1e52c1077-="" onclick="if (!window.__cfRLUnblockHandlers) return false; this.classList.toggle('is-active')" viewbox="0 0 100 100">
# <path class="line top" d="m 30,33 h 40 c 3.722839,0 7.5,3.126468 7.5,8.578427 0,5.451959 -2.727029,8.421573 -7.5,8.421573 h -20"></path>
# <path class="line middle" d="m 30,50 h 40"></path>
# <path class="line bottom" d="m 70,67 h -40 c 0,0 -7.5,-0.802118 -7.5,-8.365747 0,-7.563629 7.5,-8.634253 7.5,-8.634253 h 20"></path>
# </svg>
# </button>
# <div class="b-header__inf-b is-show-md js-header-popup-btn" data-popup="salons">
# <div class="b-header__inf-b__icon">
# <svg class="b-header__inf-b__svg-icon">
# <use xlink:href="/local/templates/design2019/svg/svg-sprite.svg#svg-location2"></use>
# </svg>
# </div>
# <div class="b-header__inf-b__info">
# <div class="b-header__inf-b__title">Якутск</div>
# <div class="b-header__inf-b__subtitle">
# <button class="b-header__inf-b__link">Салоны и пункты выдачи</button>
# </div>
# </div>
# </div>
# <div class="b-header__inf-b is-show-sm js-header-popup-btn" data-popup="backcall">
# <div class="b-header__inf-b__icon">
# <svg class="b-header__inf-b__svg-icon">
# <use xlink:href="/local/templates/design2019/svg/svg-sprite.svg#svg-phone"></use>
# </svg>
# </div>
# <div class="b-header__inf-b__info">
# <div class="b-header__inf-b__title">
# <div class="b-header__inf-b__phone" href="tel:
# +78003336737"><span class="call_phone_1 js-new-replace-phone">8 800 333 67 37</span></div>
# </div>
# <div class="b-header__inf-b__subtitle">
# <button class="b-header__inf-b__link">Обратный звонок</button>
# </div>
# </div>
# </div>
# </div>
# <div class="b-header__logo"><a class="b-header__logo-link" href="//epldiamond.ru/">
# <svg class="b-header__logo-svg">
# <use xlink:href="/local/templates/design2019/svg/svg-sprite.svg#svg-logo"></use>
# </svg></a></div>
# <div class="b-header__right">
# <ul class="reset b-header__btns-list">
# <li class="b-header__btns-item is-hidden-sm">
# <button class="b-header__btns-btn js-header-popup-btn" data-popup="search">
# <svg class="b-header__btns-svg" height="20" width="20">
# <use xlink:href="/local/templates/design2019/svg/svg-sprite.svg#svg-search"></use>
# </svg>
# </button>
# </li>
# <li class="b-header__btns-item is-hidden-sm">
# <button class="b-header__btns-btn js-header-popup-btn" data-popup="user">
# <svg class="b-header__btns-svg" height="20" width="21">
# <use xlink:href="/local/templates/design2019/svg/svg-sprite.svg#svg-user"></use>
# </svg>
# </button>
# </li>
# <li class="b-header__btns-item">
# <button class="b-header__btns-btn js-header-popup-btn" data-popup="basket" id="js-basket-open-button">
# <svg class="b-header__basket-svg">
# <use xlink:href="/local/templates/design2019/svg/svg-sprite.svg#svg-cart"></use>
# </svg><span class="b-header__basket-value js_basket_count"></span>
# </button>
# </li>
# </ul>
# </div>
# </div>
# <div class="b-header-popups js-header-popups">
# <div class="b-header-popup b-header-popup_overflow_visible b-header-popup__search js-header-popup" data-popup="search">
# <div class="l-container b-header-popup__inner">
# <button class="epl-icon-close-black b-header-popup__btn-close js-header-popup__btn-close"></button>
# <style>
#     .b-header-popup__search-submit{height:40px;width:40px;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-ms-flex-pack:center;justify-content:center}
#     .b-header-popup__search-submit > svg{fill:#000}
#     .b-header-popup__search-submit:hover{opacity:.8}
#     .b-header-popup__search-input{height:40px;border:0;font-size:18px;background-color:inherit;width:100%;color:#000;padding:4px 20px 4px 0;white-space:nowrap;overflow:hidden;-o-text-overflow:ellipsis;text-overflow:ellipsis;letter-spacing:1px}
#     .b-header-popup__search-input::-webkit-input-placeholder{color:#222;font-size:15px;font-style:italic}
#     .b-header-popup__search-input:-ms-input-placeholder{color:#222;font-size:15px;font-style:italic}
#     .b-header-popup__search-input::-ms-input-placeholder{color:#222;font-size:15px;font-style:italic}
#     .b-header-popup__search-input::placeholder{color:#222;font-size:15px;font-style:italic}
#     .b-header-popup__search-panel{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;max-width:600px;position:relative}
#     .b-header-popup__search-panel:after{content:'';height:1px;bottom:-1px;width:100%;left:0;background-color:#000;position:absolute;-webkit-transition:width .3s;-o-transition:width .3s;transition:width .3s}
#
# </style>
# <form action="/search/" class="b-header-popup__search-panel" method="GET">
# <input class="b-header-popup__search-input" id="headerSearchFormInput" name="q" placeholder="Поиск по названию, артикулу, цвету и т.д." type="text"/>
# <button class="b-header-popup__search-submit" type="submit">
# <svg class="b-header-popup__search-svg" height="25" width="25">
# <use xlink:href="/local/templates/design2019/svg/svg-sprite.svg#svg-search"></use>
# </svg>
# </button>
# </form>
# </div>
# </div>
# <div class="b-header-popup b-header-popup__user js-header-popup" data-popup="user">
# <div class="l-container b-header-popup__inner">
# <button class="epl-icon-close-black b-header-popup__btn-close js-header-popup__btn-close"></button>
# <div class="b-header-popup__user-forms js-header-popup__user-forms">
# <form action="/catalog/diamond-rings/?utm_source=samolet-yandex&amp;utm_medium=cpc&amp;utm_campaign=%D0%98%D0%B7%D0%B4%D0%B5%D0%BB%D0%B8%D1%8F+%D1%81+%D0%B1%D1%80%D0%B8%D0%BB%D0%BB%D0%B8%D0%B0%D0%BD%D1%82%D0%B0%D0%BC%D0%B8+%2F+%D0%A0%D0%A1%D0%AF+%2F+%D0%9C%D0%B8%D0%BB%D0%BB%D0%B8%D0%BE%D0%BD%D0%BD%D0%B8%D0%BA%D0%B8&amp;utm_content=cid%7C47794255%7Cgid%7C4031655955%7Caid%7C8315568285%7Cadp%7Cno%7Cdvc%7Cmobile%7Cpid%7C18983667016%7Crid%7C%7Cdid%7C18983667016%7Cpos%7Cnone0%7Cadn%7Ccontext%7Ccrid%7C0%7C&amp;utm_term=%D0%BA%D1%83%D0%BF%D0%B8%D1%82%D1%8C+%D0%BA%D0%BE%D0%BB%D1%8C%D1%86%D0%BE+%D1%81+%D0%B1%D1%80%D0%B8%D0%BB%D0%BB%D0%B8%D0%B0%D0%BD%D1%82%D0%BE%D0%BC+%D0%B4%D0%BE%D1%80%D0%BE%D0%B3%D0%BE&amp;roistat=direct44_context_8315568285_%D0%BA%D1%83%D0%BF%D0%B8%D1%82%D1%8C+%D0%BA%D0%BE%D0%BB%D1%8C%D1%86%D0%BE+%D1%81+%D0%B1%D1%80%D0%B8%D0%BB%D0%BB%D0%B8%D0%B0%D0%BD%D1%82%D0%BE%D0%BC+%D0%B4%D0%BE%D1%80%D0%BE%D0%B3%D0%BE&amp;roistat_referrer=mamba.ru&amp;roistat_pos=none_0&amp;yclid=2091523364497194038&amp;PAGEN_2=3" class="b-basis-form is-visible" data-form="login" id="auth-form" method="post" name="system_auth_form6zOYVN">
# <input name="AUTH_FORM" type="hidden" value="Y"/>
# <input name="TYPE" type="hidden" value="AUTH"/>
# <div class="reset b-basis-form__title">Вход в личный кабинет</div>
# <div class="b-international-tel js-international-tel">
# <button class="b-international-tel__btn"></button>
# <input class="b-basis-form__input" name="PERSONAL_PHONE" placeholder="Телефон" required="" type="text" value=""/>
# </div>
# <p class="captcha-error_message" id="authRecaptchaErrorMessage"></p>
# <div class="g-recaptcha mt-10" data-sitekey="6LdW_IsUAAAAABjLM719qhywDttw0Os9_OEpzGuQ" id="authReCaptcha"></div>
# <button class="b-btn b-btn-v1 b-basis-form__btn" type="submit">Вход</button>
# <div class="b-basis-form__choice-form-mbtns">
# <button class="js-user-fmBtns" data-btn="recovery-password">Забыли пароль?</button>
# </div>
# <div class="b-basis-form__agreement">
# 		Нажимая на кнопку «войти», вы подтверждаете свое согласие с политикой конфиденциальности и даете
# 		<a href="//epldiamond.ru/konfidencialnost/" target="_blank">согласие </a>на обработку персональных данных
# 	</div>
# </form>
# <script type="c9c85dae9ae649b1e52c1077-text/javascript">
#     const recaptchaPublicKey = '6LdW_IsUAAAAABjLM719qhywDttw0Os9_OEpzGuQ';
# </script>
# <form action="/catalog/diamond-rings/?utm_source=samolet-yandex&amp;amp;utm_medium=cpc&amp;amp;utm_campaign=%D0%98%D0%B7%D0%B4%D0%B5%D0%BB%D0%B8%D1%8F+%D1%81+%D0%B1%D1%80%D0%B8%D0%BB%D0%BB%D0%B8%D0%B0%D0%BD%D1%82%D0%B0%D0%BC%D0%B8+%2F+%D0%A0%D0%A1%D0%AF+%2F+%D0%9C%D0%B8%D0%BB%D0%BB%D0%B8%D0%BE%D0%BD%D0%BD%D0%B8%D0%BA%D0%B8&amp;amp;utm_content=cid%7C47794255%7Cgid%7C4031655955%7Caid%7C8315568285%7Cadp%7Cno%7Cdvc%7Cmobile%7Cpid%7C18983667016%7Crid%7C%7Cdid%7C18983667016%7Cpos%7Cnone0%7Cadn%7Ccontext%7Ccrid%7C0%7C&amp;amp;utm_term=%D0%BA%D1%83%D0%BF%D0%B8%D1%82%D1%8C+%D0%BA%D0%BE%D0%BB%D1%8C%D1%86%D0%BE+%D1%81+%D0%B1%D1%80%D0%B8%D0%BB%D0%BB%D0%B8%D0%B0%D0%BD%D1%82%D0%BE%D0%BC+%D0%B4%D0%BE%D1%80%D0%BE%D0%B3%D0%BE&amp;amp;roistat=direct44_context_8315568285_%D0%BA%D1%83%D0%BF%D0%B8%D1%82%D1%8C+%D0%BA%D0%BE%D0%BB%D1%8C%D1%86%D0%BE+%D1%81+%D0%B1%D1%80%D0%B8%D0%BB%D0%BB%D0%B8%D0%B0%D0%BD%D1%82%D0%BE%D0%BC+%D0%B4%D0%BE%D1%80%D0%BE%D0%B3%D0%BE&amp;amp;roistat_referrer=mamba.ru&amp;amp;roistat_pos=none_0&amp;amp;yclid=2091523364497194038&amp;amp;PAGEN_2=3" class="b-basis-form" data-form="recovery-password" method="post" name="bform">
# <input name="backurl" type="hidden" value="/catalog/diamond-rings/?utm_source=samolet-yandex&amp;utm_medium=cpc&amp;utm_campaign=%D0%98%D0%B7%D0%B4%D0%B5%D0%BB%D0%B8%D1%8F+%D1%81+%D0%B1%D1%80%D0%B8%D0%BB%D0%BB%D0%B8%D0%B0%D0%BD%D1%82%D0%B0%D0%BC%D0%B8+%2F+%D0%A0%D0%A1%D0%AF+%2F+%D0%9C%D0%B8%D0%BB%D0%BB%D0%B8%D0%BE%D0%BD%D0%BD%D0%B8%D0%BA%D0%B8&amp;utm_content=cid%7C47794255%7Cgid%7C4031655955%7Caid%7C8315568285%7Cadp%7Cno%7Cdvc%7Cmobile%7Cpid%7C18983667016%7Crid%7C%7Cdid%7C18983667016%7Cpos%7Cnone0%7Cadn%7Ccontext%7Ccrid%7C0%7C&amp;utm_term=%D0%BA%D1%83%D0%BF%D0%B8%D1%82%D1%8C+%D0%BA%D0%BE%D0%BB%D1%8C%D1%86%D0%BE+%D1%81+%D0%B1%D1%80%D0%B8%D0%BB%D0%BB%D0%B8%D0%B0%D0%BD%D1%82%D0%BE%D0%BC+%D0%B4%D0%BE%D1%80%D0%BE%D0%B3%D0%BE&amp;roistat=direct44_context_8315568285_%D0%BA%D1%83%D0%BF%D0%B8%D1%82%D1%8C+%D0%BA%D0%BE%D0%BB%D1%8C%D1%86%D0%BE+%D1%81+%D0%B1%D1%80%D0%B8%D0%BB%D0%BB%D0%B8%D0%B0%D0%BD%D1%82%D0%BE%D0%BC+%D0%B4%D0%BE%D1%80%D0%BE%D0%B3%D0%BE&amp;roistat_referrer=mamba.ru&amp;roistat_pos=none_0&amp;yclid=2091523364497194038&amp;PAGEN_2=3"/>
# <input name="AUTH_FORM" type="hidden" value="Y"/>
# <input name="TYPE" type="hidden" value="SEND_PWD"/>
# <div class="b-basis-form__choice-form-mbtns">
# <button class="js-user-fmBtns" data-btn="login">← Вернуться </button>
# </div>
# <div class="reset b-basis-form__title">Восстановить пароль</div>
# <input class="b-basis-form__input" name="USER_LOGIN" placeholder="Ваш email" type="email" value=""/>
# <button class="b-btn b-btn-v1 b-basis-form__btn" type="submit">Восстановить</button>
# <div class="b-basis-form__agreement">Нажимая на кнопку «войти», вы подтверждаете свое согласие с политикой конфиденциальности и даете <a href="//epldiamond.ru/konfidencialnost/" target="_blank">согласие </a>на обработку персональных данных</div>
# </form>
# <form action="/catalog/diamond-rings/?utm_source=samolet-yandex&amp;utm_medium=cpc&amp;utm_campaign=%D0%98%D0%B7%D0%B4%D0%B5%D0%BB%D0%B8%D1%8F+%D1%81+%D0%B1%D1%80%D0%B8%D0%BB%D0%BB%D0%B8%D0%B0%D0%BD%D1%82%D0%B0%D0%BC%D0%B8+%2F+%D0%A0%D0%A1%D0%AF+%2F+%D0%9C%D0%B8%D0%BB%D0%BB%D0%B8%D0%BE%D0%BD%D0%BD%D0%B8%D0%BA%D0%B8&amp;utm_content=cid%7C47794255%7Cgid%7C4031655955%7Caid%7C8315568285%7Cadp%7Cno%7Cdvc%7Cmobile%7Cpid%7C18983667016%7Crid%7C%7Cdid%7C18983667016%7Cpos%7Cnone0%7Cadn%7Ccontext%7Ccrid%7C0%7C&amp;utm_term=%D0%BA%D1%83%D0%BF%D0%B8%D1%82%D1%8C+%D0%BA%D0%BE%D0%BB%D1%8C%D1%86%D0%BE+%D1%81+%D0%B1%D1%80%D0%B8%D0%BB%D0%BB%D0%B8%D0%B0%D0%BD%D1%82%D0%BE%D0%BC+%D0%B4%D0%BE%D1%80%D0%BE%D0%B3%D0%BE&amp;roistat=direct44_context_8315568285_%D0%BA%D1%83%D0%BF%D0%B8%D1%82%D1%8C+%D0%BA%D0%BE%D0%BB%D1%8C%D1%86%D0%BE+%D1%81+%D0%B1%D1%80%D0%B8%D0%BB%D0%BB%D0%B8%D0%B0%D0%BD%D1%82%D0%BE%D0%BC+%D0%B4%D0%BE%D1%80%D0%BE%D0%B3%D0%BE&amp;roistat_referrer=mamba.ru&amp;roistat_pos=none_0&amp;yclid=2091523364497194038&amp;PAGEN_2=3" class="b-basis-form" data-form="registration" id="registration-form" method="post" name="regform">
# <div class="b-basis-form__choice-form-mbtns">
# <button class="js-user-fmBtns" data-btn="login">← Вернуться </button>
# </div>
# <input name="REGISTER_FORM" type="hidden" value="Y"/>
# <div class="reset b-basis-form__title">Регистрация</div>
# <div class="b-international-tel js-international-tel">
# <button class="b-international-tel__btn"></button>
# <input class="b-basis-form__input" name="PERSONAL_PHONE" placeholder="Телефон" required="" type="text" value=""/>
# </div>
# <p class="captcha-error_message" id="registerRecaptchaErrorMessage"></p>
# <div class="g-recaptcha mt-10" data-sitekey="6LdW_IsUAAAAABjLM719qhywDttw0Os9_OEpzGuQ" id="registerReCaptcha"></div>
# <button class="b-btn b-btn-v1 b-basis-form__btn" type="submit">Регистрация</button>
# <div class="b-basis-form__agreement">Нажимая на кнопку «войти», вы подтверждаете свое согласие с политикой конфиденциальности и даете <a href="//epldiamond.ru/konfidencialnost/" target="_blank">согласие </a>на обработку персональных данных</div>
# </form>
# <form action="" autocomplete="off" class="b-basis-form" data-form="confirm-code" id="confirmation-code" method="post" name="bform">
# <input class="phone-field" name="PHONE" type="hidden" value=""/>
# <input name="CONFIRM_FORM" type="hidden" value="Y"/>
# <div class="b-basis-form__choice-form-mbtns">
# <button class="js-user-fmBtns" data-btn="login" type="button">← Вернуться </button>
# </div>
# <div class="reset b-basis-form__title">Код подтверждения</div>
# <input autocomplete="off" class="b-basis-form__input" name="CONFIRM_CODE" placeholder="Код подтверждение" type="text" value=""/>
# <button class="b-btn b-btn-v1 b-basis-form__btn" type="submit">Подтвердить</button>
# </form>
# <form action="" class="b-basis-form" data-form="finish-register" id="finish-register" method="post" name="bform">
# <input name="FINISH_REGISTER_FORM" type="hidden" value="Y"/>
# <input class="phone-field" name="PHONE" type="hidden" value=""/>
# <div class="b-basis-form__choice-form-mbtns">
# <button class="js-user-fmBtns" data-btn="login">← Вернуться </button>
# </div>
# <div class="reset b-basis-form__title">Завершение регистрации</div>
# <input class="b-basis-form__input" name="NAME" placeholder="Имя" required="" type="text" value=""/>
# <input class="b-basis-form__input" name="EMAIL" placeholder="Email" required="" type="email" value=""/>
# <button class="b-btn b-btn-v1 b-basis-form__btn" type="submit">Подтвердить</button>
# </form>
# </div> </div>
# </div>
# <div class="b-header-popup b-header-popup__basket js-header-popup" data-popup="basket" id="mini-basket"><style>
#     .b-mini-basket{width:100%;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-orient:vertical;-webkit-box-direction:normal;-ms-flex-direction:column;flex-direction:column}
#     .b-mini-basket__title{font-size:18px;text-align:center;font-family:Lazurski,sans-serif;text-transform:uppercase;color:#000;letter-spacing:.36px;font-weight:700;margin-bottom:4px;margin-top:7px}
#     .b-mini-basket__product-list-wrap{-webkit-box-flex:1;-ms-flex-positive:1;flex-grow:1}
#     @media screen and (min-width: 1024px) {
#         .b-mini-basket__product-list-wrap{max-height:334px;overflow-y:auto}
#     }
#     .b-mini-basket__product-list{padding-right:10px}
#     .b-mini-basket__product-row{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-ms-flex-pack:justify;justify-content:space-between;border-bottom:1px solid #e6e6e6}
#     .b-mini-basket__bottom-info{margin-top:15px;padding-right:17px}
#     .b-mini-basket__bottom-info-row{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-ms-flex-pack:justify;justify-content:space-between;color:#606060}
#     .b-mini-basket__bottom-info-row + .b-mini-basket__bottom-info-row{margin-top:5px}
#     .b-mini-basket__bottom-info-row.is-total{color:#000;font-weight:700}
#     .b-mini-basket__product-photo{padding:9px 10px 9px 0}
#     .b-mini-basket__product-img{vertical-align:middle;width:80px;max-width:80px}
#     .b-mini-basket__product-info{padding:0 10px;margin:0;color:#000;text-decoration:none;margin-right:auto}
#     .b-mini-basket__product-info:hover{text-decoration:underline}
#     .b-mini-basket__product-price{padding:9px 0 9px 10px;text-align:right;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-align:end;-ms-flex-align:end;align-items:flex-end;-webkit-box-orient:vertical;-webkit-box-direction:normal;-ms-flex-direction:column;flex-direction:column}
#     .b-mini-basket__product-price-value{white-space:nowrap;margin:0}
#     .b-mini-basket__product-delete{font-size:10px;color:#606060;display:inline-block}
#     .b-mini-basket__product-delete:hover{text-decoration:underline}
#     .b-mini-basket__bottom-row{
#         display: flex;
#         margin: 20px -5px 0;
#     }
#     @media (max-width: 575px) {
#         .b-mini-basket__bottom-row{
#             flex-wrap: wrap;
#         }
#     }
#     .b-mini-basket__btn-to-issue, .b-mini-basket__btn-to-basket{
#         font-size: 11px;
#         padding: 0 15px;
#         height: 35px;
#         margin: 5px;
#     }
#     .b-mini-basket__btn-to-basket {
#         /* width: 100%; */
#         flex-grow: 1;
#         max-width: 300px;
#         opacity: .9;
#     }
#     .b-mini-basket__btn-to-issue{
#         /* width: 100%; */
#         flex-grow: 1;
#         max-width: 300px;
#     }
# </style>
# <script type="c9c85dae9ae649b1e52c1077-text/javascript">
# 	$(function () {
# 		$('#mini-basket').find('.js-delete-product').click(function () {
# 			var $this = $(this);
# 			var $bMiniBasketProductRow = $this.closest('.b-mini-basket__product-row');
# 			var $jsBasketItem = $('.js-basket-item[data-id="' + $bMiniBasketProductRow.attr('data-id') + '"]');
#
# 			$.ajax({
# 				type: "POST",
# 				url:  "/ajax/remove_product.php",
# 				data: {
# 					BASKET_ID: $(this).attr('data-id')
# 				},
# 				success: function(html){
# 					$("#mini-basket").html(html);
# 					$("#mini-basket").find('.js-header-popup__btn-close').click(function () {
# 						App.header.closePopup();
# 					});
#
# 					window.dataLayer.push({
# 						'event': 'gtm-ee-event',
# 						'gtm-ee-event-category': 'Enhanced Ecommerce',
# 						'gtm-ee-event-action': 'Removing a Product from a Shopping Cart',
# 						'ecommerce': {
# 							'currencyCode': 'RUB',
# 							'remove': {
# 								'actionField': {
# 									'list': 'RegularOrder'
# 								},
# 								'products': [{
# 									'name': $jsBasketItem.attr('data-name'),  // название товара
# 									'id': $jsBasketItem.attr('data-product-id'),  // id товара
# 									'price': $jsBasketItem.attr('data-price'), //  цена товара
# 									'brand': 'EPL', // бренд
# 									//'category': 'Серьги', // категория товара
# 									'variant': $jsBasketItem.attr('data-sku'),
# 									'quantity': 1 // количество удаленных товаров
# 								}]
# 							}
# 						}
# 					});
#
# 				},
# 				error: function(html){
#
# 				}
# 			});
# 		});
# 		$(".js_favorite_count").text();
# 		$(".js_basket_count").text();
# 	});
#
# </script>
# <div class="l-container b-header-popup__inner">
# <button class="epl-icon-close-black b-header-popup__btn-close js-header-popup__btn-close"></button>
# <div class="b-mini-basket">
# <div class="reset b-mini-basket__title">Украшения в корзине</div>
# <div class="b-mini-basket__product-list-wrap is-css-scroll">
# <p>Нет товаров</p>
# </div>
# </div>
# </div>
# <div class="js-basket-info" style="display:none">
# </div>
# </div>
# <div class="b-header-popup b-header-popup__backcall js-header-popup" data-popup="backcall">
# <div class="l-container b-header-popup__inner"><style>
#     .b-basis-form .b-basis-form__input[name=form_text_1] {
#         margin-bottom: 10px;
#     }
#     .b-header-popup__backcall-form-success{opacity:0;visibility:hidden;-webkit-transition:visibility .2s,opacity .2s;-o-transition:visibility .2s,opacity .2s;transition:visibility .2s,opacity .2s;position:absolute;top:0;left:0;width:100%;height:100%}
#     .b-header-popup__backcall-form-success h5{font-weight:400;font-size:14px}
#     .b-header-popup__backcall-form-success.is-visible{opacity:1;visibility:visible;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-ms-flex-pack:center;justify-content:center;-webkit-box-orient:vertical;-webkit-box-direction:normal;-ms-flex-direction:column;flex-direction:column;background-color:#fff;text-align:center;font-size:14px}
#     .b-header-popup__backcall-form-success > svg{width:90px;height:90px}
#
# </style>
# ...
# </p>
# <p>
#
# </p>
# <p>
#     3.3.2.     Сайт осуществляет сбор статистики об IP-адресах своих посетителей. Данная информация используется с целью предотвращения, выявления и решения технических проблем.
# </p>
# <p>
#
# </p>
# <p>
#     3.4.       Любая иная персональная информация неоговоренная выше (история посещения, используемые браузеры, операционные системы и т.д.) подлежит надежному хранению и нераспространению, за исключением случаев, предусмотренных в п.п. 5.2. и 5.3. настоящей Политики конфиденциальности.
# </p>
# <p align="center">
#
# </p>
# <p align="center">
# <b>4.            ЦЕЛИ СБОРА ПЕРСОНАЛЬНОЙ ИНФОРМАЦИИ ПОЛЬЗОВАТЕЛЯ </b>
# </p>
# <b> </b>
# <p>
#
# </p>
# <p>
#     4.1.       Персональные данные Пользователя Администрация может использовать в целях:
# </p>
# <p>
#     4.1.1.     Идентификации Пользователя, зарегистрированного на сайте для его дальнейшей авторизации, оформления заказа и других действий.
# </p>
# <p>
#     4.1.2.     Предоставления Пользователю доступа к персонализированным данным сайта.
# </p>
# <p>
#     4.1.3.     Установления с Пользователем обратной связи, включая направление уведомлений, запросов, касающихся использования сайта, оказания услуг и обработки запросов и заявок от Пользователя.
# </p>
# <p>
#     4.1.4.     Определения места нахождения Пользователя для обеспечения безопасности, предотвращения мошенничества.
# </p>
# <p>
#     4.1.5.     Подтверждения достоверности и полноты персональных данных, предоставленных Пользователем.
# </p>
# <p>
#     4.1.6.     Создания учетной записи для использования частей сайта, если Пользователь дал согласие на создание учетной записи.
# </p>
# <p>
#     4.1.7.     Уведомления Пользователя по электронной почте.
# </p>
# <p>
#     4.1.8.     Предоставления Пользователю эффективной технической поддержки при возникновении проблем, связанных с использованием сайта.
# </p>
# <p>
#     4.1.9.     Предоставления Пользователю с его согласия специальных предложений, информации о ценах, новостной рассылки и иных сведений от имени сайта.
# </p>
# <p>
#     4.1.10. Осуществления рекламной деятельности с согласия Пользователя.
# </p>
# <p>
#
# </p>
# <p align="center">
# <b>5.            СПОСОБЫ И СРОКИ ОБРАБОТКИ ПЕРСОНАЛЬНОЙ ИНФОРМАЦИИ</b>
# </p>
# <p>
#
# </p>
# <p>
#     5.1.       Обработка персональных данных Пользователя осуществляется без ограничения срока, любым законным способом, в том числе в информационных системах персональных данных с использованием средств автоматизации или без использования таких средств.
# </p>
# <p>
#
# </p>
# <p>
#     5.2.       Пользователь соглашается с тем, что Администрация вправе передавать персональные данные третьим лицам, в частности, курьерским службам, организациями почтовой связи (в том числе электронной), операторам электросвязи, исключительно в целях выполнения заказа Пользователя, оформленного на сайте, включая доставку Товара, документации или e-mail сообщений.
# </p>
# <p>
#
# </p>
# <p>
#     5.3.       Персональные данные Пользователя могут быть переданы уполномоченным органам государственной власти Российской Федерации только по основаниям и в порядке, установленным законодательством Российской Федерации.
# </p>
# <p>
#
# </p>
# <p>
#     5.4.       При утрате или разглашении персональных данных Администрация вправе не информировать Пользователя об утрате или разглашении персональных данных.
# </p>
# <p>
#
# </p>
# <p>
#     5.5.       Администрация принимает необходимые организационные и технические меры для защиты персональной информации Пользователя от неправомерного или случайного доступа, уничтожения, изменения, блокирования, копирования, распространения, а также от иных неправомерных действий третьих лиц.
# </p>
# <p>
#
# </p>
# <p>
#     5.6.       Администрация совместно с Пользователем принимает все необходимые меры по предотвращению убытков или иных отрицательных последствий, вызванных утратой или разглашением персональных данных Пользователя.
# </p>
# <p>
#
# </p>
# <p align="center">
# <b>6.            ПРАВА И ОБЯЗАННОСТИ СТОРОН </b>
# </p>
# <b> </b>
# <p>
#
# </p>
# <p>
# <b>6.1.       Пользователь вправе: </b>
# </p>
# <b> </b>
# <p>
#
# </p>
# <p>
#     6.1.1.     Принимать свободное решение о предоставлении своих персональных данных, необходимых для использования сайта, и давать согласие на их обработку.
# </p>
# <p>
#
# </p>
# <p>
#     6.1.2.     Обновить, дополнить предоставленную информацию о персональных данных в случае изменения данной информации.
# </p>
# <p>
#
# </p>
# <p>
#     6.1.3.     Пользователь имеет право на получение у Администрации информации, касающейся обработки его персональных данных, если такое право не ограничено в соответствии с федеральными законами. Пользователь вправе требовать от Администрации уточнения его персональных данных, их блокирования или уничтожения в случае, если персональные данные являются неполными, устаревшими, неточными, незаконно полученными или не являются необходимыми для заявленной цели обработки, а также принимать предусмотренные законом меры по защите своих прав.
# </p>
# <p>
#
# </p>
# <p>
# <b>6.2.       Администрация обязана: </b>
# </p>
# <b> </b>
# <p>
#
# </p>
# <p>
#     6.2.1.     Использовать полученную информацию исключительно для целей, указанных в п. 4 настоящей Политики конфиденциальности.
# </p>
# <p>
#
# </p>
# <p>
#     6.2.2.     Обеспечить хранение конфиденциальной информации в тайне, не разглашать без предварительного письменного разрешения Пользователя, а также не осуществлять продажу, обмен, опубликование, либо разглашение иными возможными способами переданных персональных данных Пользователя, за исключением п.п. 5.2 и 5.3. настоящей Политики Конфиденциальности.
# </p>
# <p>
#
# </p>
# <p>
#     6.2.3.     Принимать меры предосторожности для защиты конфиденциальности персональных данных Пользователя согласно порядку, обычно используемого для защиты такого рода информации в существующем деловом обороте.
# </p>
# <p>
#
# </p>
# <p>
#     6.2.4.     Осуществить блокирование персональных данных, относящихся к соответствующему Пользователю, с момента обращения или запроса Пользователя, или его законного представителя либо уполномоченного органа по защите прав субъектов персональных данных на период проверки, в случае выявления недостоверных персональных данных или неправомерных действий.
# </p>
# <p>
#
# </p>
# <p align="center">
# <b>7.            ОТВЕТСТВЕННОСТЬ СТОРОН </b>
# </p>
# <b> </b>
# <p>
#
# </p>
# <p>
#     7.1.       Администрация, не исполнившая свои обязательства, несёт ответственность за убытки, понесённые Пользователем в связи с неправомерным использованием персональных данных, в соответствии с законодательством Российской Федерации, за исключением случаев, предусмотренных п.п. 5.2., 5.3. и 7.2. настоящей Политики Конфиденциальности.
# </p>
# <p>
#
# </p>
# <p>
#     7.2.       В случае утраты или разглашения Конфиденциальной информации Администрация не несёт ответственность, если данная конфиденциальная информация:
# </p>
# <p>
#     7.2.1.     Стала публичным достоянием до её утраты или разглашения.
# </p>
# <p>
#     7.2.2.     Была получена от третьей стороны до момента её получения Администрацией Ресурса.
# </p>
# <p>
#     7.2.3.     Была разглашена с согласия Пользователя.
# </p>
# <p>
#
# </p>
# <p>
#     7.3.       Пользователь несет полную ответственность за соблюдение требований законодательства РФ, в том числе законов о рекламе, о защите авторских и смежных прав, об охране товарных знаков и знаков обслуживания, но, не ограничиваясь перечисленным, включая полную ответственность за содержание и форму материалов.
# </p>
# <p>
#
# </p>
# <p>
#     7.4.       Пользователь признает, что ответственность за любую информацию (в том числе, но, не ограничиваясь: файлы с данными, тексты и т. д.), к которой он может иметь доступ как к части сайта, несет лицо, предоставившее такую информацию.
# </p>
# <p>
#
# </p>
# <p>
#     7.5.       Пользователь соглашается, что информация, предоставленная ему как часть сайта, может являться объектом интеллектуальной собственности, права на который защищены и принадлежат другим Пользователям, партнерам или рекламодателям, которые размещают такую информацию на сайте. Пользователь не вправе вносить изменения, передавать в аренду, передавать на условиях займа, продавать, распространять или создавать производные работы на основе такого Содержания (полностью или в части), за исключением случаев, когда такие действия были письменно прямо разрешены собственниками такого Содержания в соответствии с условиями отдельного соглашения.
# </p>
# <p>
#
# </p>
# <p>
#     7.6.       В отношении текстовых материалов (статей, публикаций, находящихся в свободном публичном доступе на сайте) допускается их распространение при условии, что будет дана ссылка на Сайт.
# </p>
# <p>
#
# </p>
# <p>
#     7.7.       Администрация не несет ответственности перед Пользователем за любой убыток или ущерб, понесенный Пользователем в результате удаления, сбоя или невозможности сохранения какого-либо Содержания и иных коммуникационных данных, содержащихся на сайте или передаваемых через него.
# </p>
# <p>
#
# </p>
# <p>
#     7.8.       Администрация не несет ответственности за любые прямые или косвенные убытки, произошедшие из-за:
# </p>
# <p>
#     - использования либо невозможности использования сайта, либо отдельных сервисов;
# </p>
# <p>
#     - несанкционированного доступа к коммуникациям Пользователя;
# </p>
# <p>
#     - заявления или поведение любого третьего лица на сайте.
# </p>
# <p>
#
# </p>
# <p>
#     7.9.       Администрация не несет ответственность за какую-либо информацию, размещенную пользователем на сайте, включая, но, не ограничиваясь: информацию, защищенную авторским правом, без прямого согласия владельца авторского права.
# </p>
# <p>
#
# </p>
# <p align="center">
# <b>8.            РАЗРЕШЕНИЕ СПОРОВ </b>
# </p>
# <b> </b>
# <p>
#
# </p>
# <p>
#     8.1.       До обращения в суд с иском по спорам, возникающим из отношений между Пользователем и Администрацией, обязательным является предъявление претензии (письменного предложения или предложения в электронном виде о добровольном урегулировании спора).
# </p>
# <p>
#
# </p>
# <p>
#     8.2.       Получатель претензии в течение 30 календарных дней со дня получения претензии, письменно или в электронном виде уведомляет заявителя претензии о результатах рассмотрения претензии.
# </p>
# <p>
#
# </p>
# <p>
#     8.3.       При не достижении соглашения спор будет передан на рассмотрение Арбитражного суда г. Москва. Если спор не будет подведомствен арбитражным судам, такой спор подлежит рассмотрению в Замоскворецком районном суде города Москвы.
# </p>
# <p>
#
# </p>
# <p>
#     8.4.       К настоящей Политике конфиденциальности и отношениям между Пользователем и Администрацией применяется действующее законодательство Российской Федерации.
# </p>
# <p>
#
# </p>
# <p align="center">
# <b>9.            ДОПОЛНИТЕЛЬНЫЕ УСЛОВИЯ </b>
# </p>
# <b> </b>
# <p>
#
# </p>
# <p>
#     9.1.       Администрация вправе вносить изменения в настоящую Политику конфиденциальности без согласия Пользователя.
# </p>
# <p>
#
# </p>
# <p>
#     9.2.       Новая Политика конфиденциальности вступает в силу с момента ее размещения на сайте, если иное не предусмотрено новой редакцией Политики конфиденциальности.
# </p>
# <p>
#
# </p>
# <p>
#     9.3.       Все предложения или вопросы касательно настоящей Политики конфиденциальности следует сообщать по адресу: <a href="/cdn-cgi/l/email-protection#fef38d96918ebe9b8e929a979f9391909ad09d9193"><span class="__cf_email__" data-cfemail="295a414659694c59454d40484446474d074a4644">[email protected]</span></a>.
# </p>
# <p>
#
# </p>
# <p>
#     9.4. Действующая Политика конфиденциальности размещена на странице по адресу http://
# </p>
# <p>
#
# </p>
# <p>
#     Обновлено: 19 Октября 2018 года
# </p>
# <p>
#
# </p>
# <p>
#     г. Москва,
# </p>
# <p>
#
# </p>
# <p>
#     ООО «СТОЛИЦА ДАЙМОНД»
# </p>
# <p>
#
# </p>
# <p align="center">
# </p>
# <br/> </div>
# </div>
# </div>
# </div>
# </div>
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script type="c9c85dae9ae649b1e52c1077-text/javascript">/* window.jQuery || document.write('<script src="https://ajax.googleapis.com/ajax/libs/jquery/3.3.1/jquery.min.js"><\/script>') */</script>
# <!-- <script async="async" src="https://api-maps.yandex.ru/2.1/?lang=ru_RU"></script> -->
# <script type="c9c85dae9ae649b1e52c1077-text/javascript">
#
# 	try {
# 		//установка admitad_uid в куки
# 		var admitad_reg = new RegExp("admitad_uid=([^&]+)");
# 		var admitad_uid = window.location.href.match(admitad_reg);
# 		if (admitad_uid && admitad_uid.length >= 2) {
# 			var date = new Date(Date.now() + 7776000e3);
# 			date = date.toUTCString();
# 			document.cookie = "_aid=" + admitad_uid[1] + "; path=/; domain=epldiamond.ru; expires=" + date;
# 			document.cookie = "_aid=" + admitad_uid[1] + "; path=/; domain=.epldiamond.ru; expires=" + date;
# 			console.log("cookie", "_aid=" + admitad_uid[1] + "; path=/; domain=epldiamond.ru; expires=" + date);
# 		}
# 	} catch (ex) {}
# </script>
# <!--ROISTAT BEGIN-->
# <!--<script>-->
# <!--    (function(w, d, s, h, id) {-->
# <!--        w.roistatProjectId = id; w.roistatHost = h;-->
# <!--        var p = d.location.protocol == "https:" ? "https://" : "http://";-->
# <!--        var u = /^.*roistat_visit=[^;]+(.*)?$/.test(d.cookie) ? "/dist/module.js" : "/api/site/1.0/"+id+"/init";-->
# <!--        var js = d.createElement(s); js.charset="UTF-8"; js.async = 1; js.src = p+h+u; var js2 = d.getElementsByTagName(s)[0]; js2.parentNode.insertBefore(js, js2);-->
# <!--    })(window, document, 'script', 'cloud.roistat.com', 'a80243001fc88df14a8ce24a725e8e4c');-->
# <!--</script>-->
# <!-- BEGIN JIVOSITE INTEGRATION WITH ROISTAT-->
# <script type="c9c85dae9ae649b1e52c1077-text/javascript">
#     var getCookie = window.getCookie = function (name) {
#         var matches = document.cookie.match(new RegExp("(?:^|; )" + name.replace(/([\.$?*|{}\(\)\[\]\\\/\+^])/g, '\\$1') + "=([^;]*)"));
#         return matches ? decodeURIComponent(matches[1]) : undefined;
#     };
#     function jivo_onLoadCallback() {
#         jivo_api.setUserToken(getCookie('roistat_visit'));
#     }
#
#     if (typeof altasib_geobase == "undefined") {
#         altasib_geobase = {};
#         altasib_geobase.bitrix_sessid = 'd7254082a78feb2da557ff104266c61e';
#         Hlp.setCookie('altasib_bitrix_sessid', 1, {domain: '.epldiamond.ru'});
#     } else if(typeof altasib_geobase.bitrix_sessid == "undefined") {
#         altasib_geobase.bitrix_sessid = 'd7254082a78feb2da557ff104266c61e';
#         Hlp.setCookie('altasib_bitrix_sessid', 1, {domain: '.epldiamond.ru'});
#     }
# </script>
# <!-- END JIVOSITE INTEGRATION WITH ROISTAT -->
# <!--ROISTAT END-->
# <div class="modal modal-greeting" id="modal-greeting" style="display:none">
# <a href="//epldiamond.ru/catalog/sale/">
# <div class="modal-greeting__banner"><!-- при необходимости сделать ссылкой --></div>
# </a>
# <div class="modal-greeting__end-timer">
# <div class="modal-greeting__end-timer-square">
# <span class="modal-greeting__end-time-value js-end-time-days"></span>
# <span class="modal-greeting__end-time-smtext">Дни</span>
# </div>
# <span class="sep">:</span>
# <div class="modal-greeting__end-timer-square">
# <span class="modal-greeting__end-time-value js-end-time-hours"></span>
# <span class="modal-greeting__end-time-smtext">Часы</span>
# </div>
# <span class="sep">:</span>
# <div class="modal-greeting__end-timer-square">
# <span class="modal-greeting__end-time-value js-end-time-minutes"></span>
# <span class="modal-greeting__end-time-smtext">Мин</span>
# </div>
# <span class="sep">:</span>
# <div class="modal-greeting__end-timer-square">
# <span class="modal-greeting__end-time-value js-end-time-seconds"></span>
# <span class="modal-greeting__end-time-smtext">Сек</span>
# </div>
# </div>
# </div>
# <script type="c9c85dae9ae649b1e52c1077-text/javascript">
#     setTimeout(function(){
#         ga('create', 'UA-33918303-1', 'auto', 'allSalonsGTMCode');
#         if(window.GAId && window.GAId != 'UA-33918303-1')
#         {
#             ga('create', window.GAId, 'auto', 'salonsGTMCode');
#         }
#     }, 1000);
# </script><script data-cf-settings="c9c85dae9ae649b1e52c1077-|49" defer="" src="/cdn-cgi/scripts/7d0fa10a/cloudflare-static/rocket-loader.min.js"></script></header></div></body>
# </html>

# %%
<div class="js-product-img t-store__card__bgimg t-bgimg loaded" data-original="https://static.tildacdn.com/tild3964-3932-4639-a536-653231343765/8-min.jpg" style="background-image: url(&quot;https://thumb.tildacdn.com/tild3964-3932-4639-a536-653231343765/-/cover/280x233/center/center/-/format/webp/8-min.jpg&quot;);" bgimgfield="st_gallery__117902233653:::0"></div>

# %%
<div class="t-store__card__wrap_all " style="background-color:#222222;box-shadow: 0px 0px 3px 0px rgba(0, 0, 0, 0.3);">    <a href="https://kierge.com/zhenskie/tproduct/195388121-117902233653-koltso">        <div class="t-store__card__imgwrapper " style="padding-bottom:83.33333333333333%;">        <div class="js-product-img t-store__card__bgimg t-bgimg loaded" data-original="https://static.tildacdn.com/tild3964-3932-4639-a536-653231343765/8-min.jpg" style="background-image: url(&quot;https://thumb.tildacdn.com/tild3964-3932-4639-a536-653231343765/-/cover/280x233/center/center/-/format/webp/8-min.jpg&quot;);" bgimgfield="st_gallery__117902233653:::0"></div>    </div>    </a>    <div class="t-store__card__wrap_txt-and-btns" style="height: 143px;">        <div class="store__card__wrap_txt-and-opts">            <a href="https://kierge.com/zhenskie/tproduct/195388121-117902233653-koltso">                        <div class="t-store__card__textwrapper">            <div class="js-store-prod-name js-product-name t-store__card__title t-name t-name_md" style="color:#ffffff;font-weight:700;" field="st_title__117902233653" data-redactor-toolbar="no">Кольцо</div><div class="t-store__card__sku t-descr t-descr_xxs" style="display:none;color:#ffffff;">Артикул: <span class="js-store-prod-sku js-product-sku" field="st_sku__117902233653" data-redactor-toolbar="no">2000000509006</span></div><div class="js-store-price-wrapper t-store__card__price-wrapper">    <div class="t-store__card__price t-store__card__price-item t-name t-name_xs" style="color:#ffffff;font-size:20px;font-weight:400;"><div class="js-product-price js-store-prod-price-val t-store__card__price-value notranslate" translate="no" field="st_price__117902233653" data-redactor-toolbar="no" data-product-price-def="7936" data-product-price-def-str="7936">7 936</div><div class="t-store__card__price-currency">р.</div></div>    <div class="t-store__card__price_old t-store__card__price-item t-name t-name_xs" style="display: none;color:#bdbdbd;font-size:20px;font-weight:400;"><div class="js-store-prod-price-old-val t-store__card__price-value notranslate" translate="no" field="st_priceold__117902233653" data-redactor-toolbar="no"></div><div class="t-store__card__price-currency">р.</div></div>    </div>        </div>            </a>            <div class="js-product-controls-wrapper t-store__card__prod-controls-wrapper" style="display:none;"></div>        </div>            </div></div>

# %%
#jlook.find_all('span',"woocommerce-Price-amount amount")
#jlook = mysoup('https://egelge.com/catalog/zolotye-sergi-s-brilliantami-811/')

# %%
domain+links[73]

# %%
#цена без скидки
jlook.find_all('span',"woocommerce-Price-amount amount")[0].text

# %%
#цена со скидкой
jlook.find_all('span',"woocommerce-Price-amount amount")[1].text

# %%
#наименование
jlook.find_all('h1',"product_title entry-title")[0].text

# %%
#наименование
jlook.find('h1',"product_title entry-title").text

# %%
#Артикул:
jlook.find_all('p',"reference")[0].text

# %%
#Акция:
jlook.find_all('div',"col")[0].text.strip()

# %%
#Описание:
jlook.find_all('div',"tab-pane fade show active")[0].text.strip()

# %% [markdown]
# ## Сборка цикла по карточкам

# %%
data = pd.DataFrame(columns=['h1','art','price','disc_price','action','describe','char','Бренд','Страна производства','Материал','Вставка','Средний вес','url'])

# %%
'Бренд - ЭГЭЛГЭ',
 'Страна производства - Россия',
 'Материал - красное золото 585 пробы',
 'Вставка - 1 Бр Кр 57 0,013Ct 3/6А ,1 Бр Кр 57 0,005Ct 3/6А ,1 Бр Кр 57 0,009Ct 3/6А',
 'Средний вес - 1,1 гр']

# %%
data

# %%
len(data)

# %%
#20-04-2022
for i in range(18,len(links)):
    try:
        urlcard = domain +links[i]
        
        response = requests.get(urlcard)
        card = BeautifulSoup(response.text, 'lxml')
        row = len(data)+1
        data.loc[row,'url'] = urlcard
        data.loc[row,'h1'] = card.find('h1',"product_title entry-title").text#.strip()
        data.loc[row,'art'] = card.find_all('p',"reference")[0].text
        data.loc[row,'price'] = card.find_all('span',"woocommerce-Price-amount amount")[0].text
        data.loc[row,'disc_price'] = card.find_all('span',"woocommerce-Price-amount amount")[1].text
        data.loc[row,'action'] = card.find_all('div',"col")[0].text.strip()
        data.loc[row,'describe'] = card.find_all('div',"tab-pane fade show active")[0].text.strip()
        #data.loc[row,'char'] = card.find_all('div',"tab-pane fade")[1].find('ul')
        
        ch = [x.text.replace('\xa0',' ') for x in card.find_all(
                "div","tab-pane fade")[1].find('ul').find_all('li')]
        if len(ch) == 5:
            data.loc[row,['Бренд','Страна производства','Материал','Вставка','Средний вес']] = ch 
        elif len(ch) == 4:
            data.loc[row,['Бренд','Страна производства','Материал','Средний вес']]  = ch
        else:
            print('ch is not 5 or 4')
    except (AttributeError,TypeError) as e:
        print('error',e, urlcard)
    except (IndexError,ValueError) as e:
        print('index value error len of = ', e, urlcard)
    print(i, urlcard)

# %% [markdown]
# ## Обработка датафрейма

# %%
data

# %%
data.price = data.price.apply(lambda x: x.replace('р.','').replace(' ','')).astype('float')

# %%
data.disc_price = data.disc_price.apply(lambda x: x.replace('р.','').replace(' ','')).astype('float')

# %%
todelete = ['Бренд','Страна производства','Материал','Вставка','Средний вес']

# %%
for xxx in todelete:
    data[xxx] = data[xxx].apply(lambda xx: str(xx).replace(xxx+' - ',''))

# %%
data['Средний вес'] = data['Средний вес'].apply(lambda x: x.replace('гр','').replace(',','.')).astype('float')

# %% [markdown]
# ## Запись в файл

# %%
import os

# %%
import datetime

# %%
datetime.datetime.now().strftime('%d-%m-%Y')

# %%
os.listdir('jewels/egelge/')

# %%
resdir = 'jewels/egelge/'

# %%
data.to_excel(resdir+'эгэлгеЭг_'+str(len(data))+datetime.datetime.now().strftime('%d-%m-%Y')+ '.xlsx')

# %% [markdown]
# ## dump

# %%
xxx = todelete[0]

# %%
xxx

# %%
data[xxx] = data[xxx].apply(lambda xx: str(xx).replace(xxx+' - ',''))

# %%
urlcard

# %%
len(data)

# %%
data.loc()

# %%
#data.drop(0,inplace=True)

# %% [markdown]
# https://egelge.com/catalog/zolotoe-kolco-s-brilliantami-716/

# %%
response = requests.get( 'https://egelge.com/catalog/zolotoe-kolco-s-brilliantami-716/')
response

# %%
response.text

# %%
card = BeautifulSoup(response.text, 'lxml')

# %%
<div class="tab-pane fade active show" id="pills-profile" role="tabpanel" aria-labelledby="pills-profile-tab"><ul>
	<li>Бренд - ЭГЭЛГЭ</li>
	<li>Страна производства - Россия</li>
	<li>Материал - красное золото 585 пробы</li>
	<li>Вставка -&nbsp;20 Бр Кр 17 0,043Ct 2/3А ,1 Хромдиопсид круг 5,00 0,512Ct</li>
	<li>Средний вес - 3,5 гр</li>
</ul>
</div>

# %%
[x.text.replace('\xa0',' ') for x in card.find_all("div","tab-pane fade")[1].find('ul').find_all('li')]

# %%
data.loc[1000,['Бренд','Страна производства','Материал','Вставка','Средний вес']] = [
    x.text.replace('\xa0',' ') for x in card.find_all(
        "div","tab-pane fade")[1].find('ul').find_all('li')]

# %%
card.select('ul')

# %%
#pills-profile > ul > li:nth-child(1)

# %%
<div class="tab-pane fade show active" id="pills-home" role="tabpanel" aria-labelledby="pills-home-tab" itemprop="description" content="Кольцо из коллекции " Европейская="" классика".="" Изготовлено="" из="" красного="" золота="" 585="" пробы.="" Вставки="" -="" 3="" Бриллианта="" круглой="" огранки="" 57="" граней,="" общим="" весом="" 0.03="" карат,="" группа="" цвета="" 3,="" чистоты="" 6,="" качество="" А.="" Вес="" изделия="" 1,1="" грамм.="" "="">Кольцо из коллекции "Европейская классика". Изготовлено из красного золота 585 пробы. Вставки - 3 Бриллианта круглой огранки 57 граней, общим весом 0.03 карат, группа цвета - 3, группа чистоты - 6, качество огранки - А. Вес изделия 1,1 грамм.

# %%
<div class="col" style="color: #7A1C6C">

# %%
<p class="reference"><b>Артикул:</b> п06110-10-2010</p>

# %%
<h1 class="product_title entry-title" itemprop="name" content="Золотое кольцо с бриллиантами">Золотое кольцо с бриллиантами</h1>

# %%
<span class="woocommerce-Price-amount amount">16 151 р.</span>

# %%
links

# %%
#drop duplicates subset keep
links = list(set(links))

# %%
links[10]

# %%
#del after

# %%
jlook = mysoup('https://miuz.ru/catalog/rings/R2022-MSR501/')

# %%
jgems = jlook.select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)')

# %%
type(jgems)

# %%
#def main():

urls = f'https://egelge.com/catalog/ukrasheniya-164/?mat%5B%5D=175&type%5B%5D=%D0%9A%D0%BE%D0%BB%D1%8C%D1%86%D0%BE&order=prices+asc'
domain = f'https://egelge.com'



quotes = mysoup(urls).find_all('div', class_="dici-thumb-wrapper")
res.extend([q.find("a").get("href") for q in quotes])

















#for i in range(1,100):
#    pages = f'page={i}/'
#links += getlinks(urls)

# %%
jlook.find_all('div','detail__item-option')[0].text

# %%
<div class="detail__item-option"><span>Камни:</span>
                    28  Бриллиантов огранки "Круглая" граней - 57, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/cutForm/'); event.stopPropagation();">тип огранки</span> A, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/razmer-tsvet-ves/'); event.stopPropagation();">цвет</span> 3, <span class="href" onclick="event.preventDefault(); window.open('/guide/quality/chistota-brillianta/'); event.stopPropagation();">чистота</span> 6, 0.21 карат;<br>4  Бриллианта огранки "Круглая" граней - 57, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/cutForm/'); event.stopPropagation();">тип огранки</span> A, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/razmer-tsvet-ves/'); event.stopPropagation();">цвет</span> 3, <span class="href" onclick="event.preventDefault(); window.open('/guide/quality/chistota-brillianta/'); event.stopPropagation();">чистота</span> 6, 0.023 карат;<br>12  Бриллиантов огранки "Круглая" граней - 57, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/cutForm/'); event.stopPropagation();">тип огранки</span> A, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/razmer-tsvet-ves/'); event.stopPropagation();">цвет</span> 3, <span class="href" onclick="event.preventDefault(); window.open('/guide/quality/chistota-brillianta/'); event.stopPropagation();">чистота</span> 6, 0.105 карат;<br>12  Бриллиантов огранки "Круглая" граней - 57, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/cutForm/'); event.stopPropagation();">тип огранки</span> A, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/razmer-tsvet-ves/'); event.stopPropagation();">цвет</span> 3, <span class="href" onclick="event.preventDefault(); window.open('/guide/quality/chistota-brillianta/'); event.stopPropagation();">чистота</span> 6, 0.114 карат;<br>4  Бриллианта огранки "Круглая" граней - 57, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/cutForm/'); event.stopPropagation();">тип огранки</span> A, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/razmer-tsvet-ves/'); event.stopPropagation();">цвет</span> 3, <span class="href" onclick="event.preventDefault(); window.open('/guide/quality/chistota-brillianta/'); event.stopPropagation();">чистота</span> 6, 0.084 карат;<br>2  Бриллианта огранки "Багет" граней - 25, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/cutForm/'); event.stopPropagation();">тип огранки</span> A, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/razmer-tsvet-ves/'); event.stopPropagation();">цвет</span> 3, <span class="href" onclick="event.preventDefault(); window.open('/guide/quality/chistota-brillianta/'); event.stopPropagation();">чистота</span> 5, 0.068 карат;<br>2  Бриллианта огранки "Багет" граней - 25, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/cutForm/'); event.stopPropagation();">тип огранки</span> A, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/razmer-tsvet-ves/'); event.stopPropagation();">цвет</span> 3, <span class="href" onclick="event.preventDefault(); window.open('/guide/quality/chistota-brillianta/'); event.stopPropagation();">чистота</span> 5, 0.067 карат;<br>3  Бриллианта огранки "Багет" граней - 25, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/cutForm/'); event.stopPropagation();">тип огранки</span> A, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/razmer-tsvet-ves/'); event.stopPropagation();">цвет</span> 3, <span class="href" onclick="event.preventDefault(); window.open('/guide/quality/chistota-brillianta/'); event.stopPropagation();">чистота</span> 5, 0.325 карат;<br>                </div>

# %%
re.findall(r'<div class="detail__item-option"><span>Камни:</span>[\w\W]+?\s*</div>',str(jlook))[0]

# %%
re.search(r'Камни:\s+([\w\W]+)', str(div_gems[0].text.strip()))[1]

# %%
jgems[0].text

# %%
data = pd.DataFrame(columns=['h1','art','price','gold','weight','gems','url'])

# %%
 pd.options.display.max_colwidth = 200

# %%
urlcard = domain +links[0]
urlcard

# %%
data

# %%
#отладка ручной прогон

# %%
#urlcard = 'https://miuz.ru/catalog/rings/R01-ALR52-090-G1/'

# %%
card = mysoup(urlcard)

# %%
card

# %%
re.findall(r'<div class="detail__item-option"><span>Камни:</span>([\w\W]+?)\s*</div>',str(card))

# %%
row = len(data)

# %%
data.loc[row,'url'] = urlcard

# %%
data.loc[row,'h1'] = card.find("h1").text.strip()

# %%
data.loc[row,'art'] = card.select('body > div.grid > div > div > div.shops__breadcrumbs.catalog_breadcrumbs > div > div:nth-child(4) > span > span')

# %%
card.select('body > div.grid > div > div > div.shops__breadcrumbs.catalog_breadcrumbs > div > div:nth-child(4) > span > span')

# %%
data.loc[row,'price'] = float(''.join(re.findall(r'\d+', card.find('div',"detail__item-price-new").text)))

# %%
data.loc[row,'gold'] = re.findall(r"(Золото\s+\d+)",str(card))[0]

# %%
div_gems = card.select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)')

# %%
div_gems = card.find_all('div','detail__item-option')[3]

# %%
card.find_all('div','detail__item-option')[1].text

# %%
len(card.find_all('div','detail__item-option'))

# %%
len(jlook.find_all('div','detail__item-option'))

# %%
jlook.find_all('div','detail__item-option')[].text

# %%
str(card)

# %%
re.search(r'Камни:\s+([\w\W]+)', str(div_gems.text.strip()))

# %%
 str(div_gems.text.strip())

# %%
data.loc[row,'gems'] = re.search(r'Камни:\s+([\w\W]+)', str(div_gems.text.strip()))[1]

# %%
data.loc[row,'weight'] = float(re.findall(r"(?:Вес:\n)\s+(\d+.\d+)",
                                          card.find_all('div','detail__item-option')[1].text)[0])

# %%
card.find_all('div','detail__item-option')[1].text

# %%
re.findall(r"(?:Вес:\n)\s+(\d+.\d+)",card.find_all('div','detail__item-option')[1].text)[0]

# %%
div_gems = card.select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)')

# %%
re.findall(r'Камни:\s+([\w\W]+)',div_gems[0].text.strip())[0]

# %%
 
data.loc[row,'gold'] = re.findall(r"(Золото\s+\d+)",str(card))[0]
data.loc[row,'weight'] = float(re.findall(r"(?:Вес:\n)\s+(\d+.\d+)",
                                          card.find_all('div','detail__item-option')[1].text)[0])
#data.loc[row,'weight'] = float(re.findall(r"(?:Вес:\n)\s+(\d+.\d+)",str(card))[1])
div_gems = card.select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)')
#data.loc[row,'gems'] = re.search(r'Камни:\s+([\w\W]+)', str(div_gems[0].text.strip()))[1]
data.loc[row,'gems'] = re.findall(r'Камни:\s+([\w\W]+)',div_gems[0].text.strip())[0]

# %%
data

# %%
#change 151121
data.loc[row,'art'] = card.select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > div.title-line > meta:nth-child(1)')

# %%
data.loc[row,'price'] = float(''.join(re.findall(r'\d+', card.find('div',"detail__item-price-new").text)))

# %%
data.loc[row,'gold'] = re.findall(r"(Золото\s+\d+)",str(card))[0]

# %%
data.loc[row,'weight'] = float(re.findall(r"(?:Вес:</span>\n)\s+(\d+.\d+)",str(card))[0])

# %%
#div_gems = card.select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)')
#data.loc[row,'gems'] = re.search(r'Камни:\s+([\w\W]+)', str(div_gems[0].text.strip()))[1]
div_gems = re.findall(r'<div class="detail__item-option"><span>Камни:</span>([\w\W]+?)\s*</div>',str(card))

data.loc[row,'gems'] = div_gems[0]

# %%
#old_2021
for i in range(0,len(links)):
    try:
        urlcard = domain +links[i]
        card = mysoup(urlcard)
        row = len(data)
        data.loc[row,'url'] = urlcard
        data.loc[row,'h1'] = card.find("h1").text.strip()
        data.loc[row,'art'] = card.select('body > div.grid > div > div > div.shops__breadcrumbs.catalog_breadcrumbs > div > div:nth-child(4) > span > span')
        data.loc[row,'price'] = float(''.join(re.findall(r'\d+', card.find('div',"detail__item-price-new").text)))
        data.loc[row,'gold'] = re.findall(r"(Золото\s+\d+)",str(card))[0]
        data.loc[row,'weight'] = float(re.findall(r"(?:Вес:</span>\n)\s+(\d+.\d+)",str(card))[0])
        div_gems = card.select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)')
        data.loc[row,'gems'] = re.search(r'Камни:\s+([\w\W]+)', str(div_gems[0].text.strip()))[1]
    except (AttributeError,TypeError) as e:
        print('error',e)
    except IndexError:
        print('indexerror len of = ' , len(card.find_all('div','detail__item-option')) )
    print(i, urlcard)

# %%
#14-04-2022
for i in range(0,len(links)):
    try:
        urlcard = domain +links[i]
        card = mysoup(urlcard)
        row = len(data)
        data.loc[row,'url'] = urlcard
        data.loc[row,'h1'] = card.find("h1").text.strip()
        data.loc[row,'art'] = card.select('body > div.grid > div > div > div.shops__breadcrumbs.catalog_breadcrumbs > div > div:nth-child(4) > span > span')
        data.loc[row,'price'] = float(''.join(re.findall(r'\d+', card.find('div',"detail__item-price-new").text)))
        data.loc[row,'gold'] = re.findall(r"(Золото\s+\d+)",str(card))[0]
        data.loc[row,'weight'] = float(re.findall(r"(?:Вес:</span>\n)\s+(\d+.\d+)",str(card))[0])
        div_gems = card.select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)')
        data.loc[row,'gems'] = re.search(r'Камни:\s+([\w\W]+)', str(div_gems[0].text.strip()))[1]
    except (AttributeError,TypeError) as e:
        print('error',e)
    except IndexError:
        print('indexerror len of = ' , len(card.find_all('div','detail__item-option')) )
    print(i, urlcard)

# %%
data

# %%
import os

# %%
folders = os.listdir()
[q for q in (enumerate(folders))]

# %%
resfolder = folders[14]

# %%
resfolder

# %%
data.to_excel(resfolder+'/'+'mius140422_0-4431.xlsx')

# %%
urlcard

# %%
linkspd = pd.DataFrame(links)

# %%
linkspd.rename(columns={0:'short'}, inplace=True)

# %%
linkspd['path'] = domain +linkspd['short']

# %%
linkspd.to_excel('links5500_16112021.xlsx')

# %%
re.findall(r"(?:Вес:</span>\n)\s+(\d+.\d+)",str(card))

# %%
card

# %%
card = mysoup(urlcard)
row = len(data)
data.loc[row,'h1'] = card.find("h1").text.strip()
data.loc[row,'art'] = card.select('body > div.grid > div > div > div.shops__breadcrumbs.catalog_breadcrumbs > div > div:nth-child(4) > span > span')

data.loc[row,'price'] = float(''.join(re.findall(r'\d+', card.find('div',"detail__item-price-new").text)))
              

#quotes_inner = card.find_all('div', "detail__item-option")
#quotes_inner

data.loc[row,'gold'] = re.findall(r"(Золото\s+\d+)",str(quotes_inner[0]))[0]

data.loc[row,'weight'] = float(re.findall(r"(?:Вес:</span>\n)\s+(\d+.\d+)",str(card))[0])

div_gems = card.select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)')

data.loc[row,'gems'] = re.search(r'Камни:\s+([\w\W]+)', str(div_gems[0].text.strip()))[1]

# %%
patt_muis = r"""(?ix) (?P<N>\d*)\s+(?:Брилл\w+)(?P<Form>[\w\W])[^,]"""

# %%
re.findall(patt_muis,div_gems[0].text.strip() )

# %%
response = requests.get(urls)

# %%
soup = BeautifulSoup(response.text, 'lxml')
quotes = soup.find_all('div', class_="product")

# %%
domain = 'https://miuz.ru'

# %%
link_to_product = domain+quotes[1].find("a").get("href")

# %%
response_inner = requests.get(link_to_product)

# %%
soup_inner = BeautifulSoup(response_inner.text, 'lxml')

# %%
quotes_inner = soup_inner.find_all('div', "detail__item-option")
quotes_inner

# %%
str(quotes_inner[2].find('span',"href"))

# %%
select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)')

# %%
body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)

# %%
div class="detail__item-option"

# %%
BeautifulSoup(response_inner.text, 'lxml')

# %%
quotes[1].prettify()

# %%
name = str(quotes[2].find('div',"product__name_catalog_list"))
name = name.replace('<div class="product__name_catalog_list">\n','').replace('</div>','').strip()
name

# %%
pricenew = str(quotes[2].find('span',"product__price-new"))
pricenew.replace('<span class="product__price-new">','').replace( '<span class="rub"></span>\n</span>','').strip()

# %%
quotes0[3].find('span', 'link__text')

# %%
type(quotes0[3])

# %%
quotes[1].find('span',"href")

# %%
quotes[1].find('div',"product__name_catalog_list")

# %%
quotes[1]

# %%
for i in range(len(quotes)):
    print('---\n', i, quotes[i].find()) )

# %%
quotes0[1]

# %%
if len(quotes) != 0:
    for i in range(len(quotes)):
        name = str(quotes[i].find('span', 'link__text'))
        name = name.replace('<span class="link__text">', '')
        name = name.replace('</span>', '')
        
        url = str(quotes[i].find('a', 'link link_font_large margin_bottom_10 link-holder'))
        url = url.replace('<a class="link link_font_large margin_bottom_10 link-holder" href="', 'https://dobro.mail.ru')
        url = url.split('"')[0]
        
        city = str(quotes[i].find('div', 'p-fund__city margin_bottom_5'))
        city = city.replace('<div class="p-fund__city margin_bottom_5">', '')
        city = city.replace('</div>', '')
        
        responses = requests.get(url)
        soups = BeautifulSoup(responses.text, 'lxml')
        
        site = soups.find_all('div', class_='p-fund-detail__info-row')
        if str(site[0].find('a', 'link')) == None:
            site = str(site[0].find('a', 'link'))
            site = site.replace('<span class="link__text">', '')
            site = site.replace('</span>', '')
        else:
            site = str(site[1].find('a', 'link'))
            site = site.replace('<span class="link__text">', '')
            site = site.split('"')[3]
        
        print(name + '\n' + city + '\n' + url + '\n' + site + '\n')
else:
    print('Нет')
