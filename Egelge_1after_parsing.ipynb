# %%
#21-04-2022 copy from for_parsing_func.ipynb for egelge
#15-04-2022 muiz parcing2
#v17.11.21 c func_rpdiamonds
#разложение таблицы эксель с ювелиркой в таблицу с бриллиантами по ключу 1С7 и подстановка прейскуранта
import numpy as np
import pandas as pd
import re
import os

# %%
from rusprice.dictdiamonds import dcol_dia, dcla_dia, dpo_dia, dogr_dia_discount

# %%
import rusprice.func_rpdiamonds_xlsx as func_rpdiamonds

# %%
func_rpdiamonds.__doc__
# Out:
# "\nparametrs = {'ШТУК':'ШТУК','ОГРАНКА':'ОГРАНКА', 'КАРАТ':'КАРАТ', 'ПО': 'ПО', 'Ц':'Ц', 'Д':'Д'}\nrusian price of diamond v14-10-21 \ndef rpdiamonds({'id':1,'ОГРАНКА':['Кр-57А'], 'Ц':[3], 'Д':['7а'], 'ПО': 'A','ШТУК':[1],'КАРАТ':0.35})\n"

# %%
dcol_dia.__doc__
# Out:
# "dict() -> new empty dictionary\ndict(mapping) -> new dictionary initialized from a mapping object's\n    (key, value) pairs\ndict(iterable) -> new dictionary initialized as if via:\n    d = {}\n    for k, v in iterable:\n        d[k] = v\ndict(**kwargs) -> new dictionary initialized with the name=value pairs\n    in the keyword argument list.  For example:  dict(one=1, two=2)"

# %%
dogr_dia_discount
# Out:
# {'Baguette': 'Бп-25',
#  'Briolete': 'И-57',
#  'Cinnia': 'И-57',
#  'Emerald': 'И-57',
#  'Heart': 'Сердце',
#  'KP 17': 'Кр-17',
#  'KP 57': 'Кр-57',
#  'KP-17': 'Кр-17',
#  'KP-57': 'Кр-57',
#  'KP17': 'Кр-17',
#  'KP57': 'Кр-57',
#  'Marquise': 'М-55',
#  'NXG': 'И-57',
#  'Oval': 'Овал',
#  'PTG': 'И-57',
#  'Pear': 'Г-56',
#  'Princess': 'Принц',
#  'R-17': 'Кр-17',
#  'R-57': 'Кр-57',
#  'R17': 'Кр-17',
#  'R57': 'Кр-57',
#  'Radiant': 'Радиант',
#  'Round': 'Кр-57',
#  'Round-17': 'Кр-17',
#  'Round-33': 'Бп-25',
#  'Sheld': 'Радиант',
#  'TRG': 'И-57',
#  'Triangle': 'Бп-25',
#  'Trilliant': 'Бп-25',
#  'Troida': 'Бп-25',
#  'Антик': 'М-55',
#  'Ашер': 'И-57',
#  'БП': 'Бп-25',
#  'БП25': 'Бп-25',
#  'БТ': 'Бп-25',
#  'Багет': 'Бп-25',
#  'Багет-25': 'Бп-25',
#  'БагетНТО': 'Бп-25',
#  'Бп': 'Бп-25',
#  'Бп-25': 'Бп-25',
#  'Бп-33': 'Бп-25',
#  'Брилл': 'Бп-25',
#  'Бриолетт': 'И-57',
#  'Бт-25': 'Бп-25',
#  'Г': 'Г-56',
#  'Г-52': 'Г-56',
#  'Г-53': 'Г-56',
#  'Г-54': 'Г-56',
#  'Г-55': 'Г-56',
#  'Г-56': 'Г-56',
#  'Г56': 'Г-56',
#  'Гр': 'Г-56',
#  'Груша': 'Г-56',
#  'Груша-56': 'Г-56',
#  'ГрушаНТО': 'Г-56',
#  'Звезда Давида': 'И-57',
#  'И': 'И-57',
#  'И-57': 'И-57',
#  'И-61': 'И-57',
#  'И-65': 'И-57',
#  'И57': 'И-57',
#  'Изумруд': 'И-57',
#  'Изумруд-65': 'И-57',
#  'ИзумрудНТО': 'И-57',
#  'К-25': 'Кв-25',
#  'КР': 'Кр-57',
#  'КР 17': 'Кр-17',
#  'КР 57': 'Кр-57',
#  'КР-17': 'Кр-17',
#  'КР-57': 'Кр-57',
#  'КР17': 'Кр-17',
#  'КР57': 'Кр-57',
#  'КУШЕН': 'Сердце',
#  'Кайт': 'Бп-25',
#  'Кв-25': 'Бп-25',
#  'Кв-61': 'Бп-25',
#  'Кр 17': 'Кр-17',
#  'Кр 57': 'Кр-57',
#  'Кр-137': 'Тускул',
#  'Кр-17': 'Кр-17',
#  'Кр-33': 'Бп-25',
#  'Кр-41': 'Тускул',
#  'Кр-44': 'Кр-44',
#  'Кр-49': 'Тускул',
#  'Кр-57': 'Кр-57',
#  'Кр-63': 'Тускул',
#  'Кр-65': 'Тускул',
#  'Кр-73': 'Тускул',
#  'Кр-73а': 'Кр-57',
#  'Кр-81': 'Тускул',
#  'Кр-87': 'Кр-57',
#  'Кр-89': 'Тускул',
#  'Кр17': 'Кр-17',
#  'Кр33': 'Бп-25',
#  'Кр57': 'Кр-57',
#  'КрМ-65': 'Тускул',
#  'Круглая-17': 'Кр-17',
#  'Круглая-57': 'Кр-57',
#  'Круглая-89': 'Тускул',
#  'Кушен': 'Сердце',
#  'Кушон': 'Сердце',
#  'Кушон-57': 'Сердце',
#  'Кушэн': 'Сердце',
#  'М-49': 'М-55',
#  'М-53': 'М-55',
#  'М-55': 'М-55',
#  'М55': 'М-55',
#  'Маркиз': 'М-55',
#  'Маркиз-55': 'М-55',
#  'Мичил': 'Мичил',
#  'Мод.Г': 'Г-56',
#  'Мод.И': 'И-57',
#  'Мод.М': 'М-55',
#  'Мод.Ов': 'Овал',
#  'Мод.П': 'Принц',
#  'Мод.Ра': 'Радиант',
#  'Мод.Се': 'Сердце',
#  'Мод.Т': 'Бп-25',
#  'Мод.У': 'Сердце',
#  'Ов': 'Овал',
#  'Ов-57': 'Овал',
#  'Овал': 'Овал',
#  'Овал ': 'Овал',
#  'Овал-57': 'Овал',
#  'Овал-61': 'Овал',
#  'ОвалНТО': 'Овал',
#  'Огн. Роза': 'М-55',
#  'П': 'Принц',
#  'П-57': 'Принц',
#  'П-65': 'Принц',
#  'П-73': 'Принц',
#  'П65': 'Принц',
#  'ПР': 'Принц',
#  'ПР57': 'Принц',
#  'ПР65': 'Принц',
#  'ПР75': 'Принц',
#  'Подсолнух': 'Г-56',
#  'Подушка': 'Сердце',
#  'Поллуны': 'Овал',
#  'Пр': 'Принц',
#  'Принц': 'Принц',
#  'Принц.': 'Принц',
#  'Принцесса': 'Принц',
#  'Принцесса-49': 'Принц',
#  'Принцесса-57': 'Принц',
#  'ПринцессаНТО': 'Принц',
#  'Ра': 'Радиант',
#  'Рад': 'Радиант',
#  'Радиант': 'Радиант',
#  'Радиант-57': 'Радиант',
#  'Радиант-кв': 'Радиант',
#  'РадиантНТО': 'Радиант',
#  'Роза': 'М-55',
#  'Ромб': 'Бп-25',
#  'Сердце': 'Сердце',
#  'Сердце-57': 'Сердце',
#  'Т-19': 'Бп-25',
#  'Тимур': 'Тимур',
#  'Тр': 'Бп-25',
#  'Тр-40': 'Бп-25',
#  'Тр-47': 'Бп-25',
#  'Тр-48': 'Бп-25',
#  'Тр-52': 'Бп-25',
#  'Трап-27': 'Бп-25',
#  'Трапеция': 'Бп-25',
#  'Треуг.': 'Бп-25',
#  'ТреугНТО': 'Бп-25',
#  'Треугольник': 'Бп-25',
#  'Триллиант': 'Бп-25',
#  'ТриллиантНТО': 'Бп-25',
#  'Тройда': 'Бп-25',
#  'Тускул': 'Тускул',
#  'У': 'Сердце',
#  'У-57': 'Сердце',
#  'У57': 'Сердце',
#  'Угловатый': 'Сердце',
#  'Фантазия': 'Радиант',
#  'Циния': 'И-57',
#  'Цинния': 'М-55',
#  'Ш57': 'Кр-57',
#  'Щит': 'Радиант',
#  'кр 17': 'Кр-17',
#  'кр 57': 'Кр-57',
#  'кр-17': 'Кр-17',
#  'кр-57': 'Кр-57',
#  'кр17': 'Кр-17',
#  'кр57': 'Кр-57',
#  'кушон': 'Сердце',
#  'пр': 'Принц',
#  'принц': 'Принц'}

# %% [markdown]
# # Чтение файла и подготовка jewellery

# %%
folders = os.listdir(path='jewels/')
[nf for nf in enumerate(folders)]
# Out:
# [(0, '.DS_Store'),
#  (1, 'AnaliticRep031221 - Jupyter Notebook.html'),
#  (2, 'AnaliticRep031221 - Jupyter Notebook_files'),
#  (3, 'AnaliticRep061221-KDM1C8 - Jupyter Notebook.html'),
#  (4, 'AnaliticRep061221-KDM1C8 - Jupyter Notebook_files'),
#  (5, 'egelge'),
#  (6, 'kdm'),
#  (7, 'kdm_1c8'),
#  (8, 'miuz'),
#  (9, 'muiz04-2022')]

# %%
#выбор папки
#sourcepath = 'jewels/antipina2/'
sourcepath = 'jewels/'+folders[5]+'/'
sourcepath
# Out:
# 'jewels/egelge/'

# %%
files = os.listdir(path=sourcepath)
[f for f in enumerate(files)]
# Out:
# [(0, 'эгэлгеЭг_14520-04-2022.xlsx'), (1, 'Ювелирные украшения.html')]

# %%
filename = files[0]

# %%
filenamep = filename.split('.')[0]

# %%
print(filenamep)
# Out:
# эгэлгеЭг_14520-04-2022

# %%
raw = pd.read_excel(sourcepath+filename)

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     145 non-null    int64
#  1   Unnamed: 1                     145 non-null    object
#  2   h1                             145 non-null    object
#  3   art                            145 non-null    object
#  4   price                          145 non-null    int64
#  5   disc_price                     145 non-null    int64
#  6   action                         145 non-null    object
#  7   describe                       145 non-null    object
#  8   Бренд                          145 non-null    object
#  9   Страна производства            145 non-null    object
#  10  Материал                       145 non-null    object
#  11  Вставка                        122 non-null    object
#  12  Средний вес                    145 non-null    float64
#  13  url                            145 non-null    object
#  14  цена за грамм рублей, без НДС  145 non-null    float64
#  15  цена за грамм рублей, с НДС    145 non-null    float64
# dtypes: float64(3), int64(3), object(10)
# memory usage: 18.2+ KB

# %%
raw

# %%
#for all
jewellery = raw

# %%
jewellery['checklog'] = ''
#jewellery['filname'] = filename

# %%
jewellery.rename(columns={'Unnamed: 0':'index_row'}, inplace=True)

# %%
jewellery.rename(columns={'Вставка':'gems'}, inplace=True)

# %%
jewellery.loc[jewellery.gems.isna()]#.to_excel(sourcepath+'_failed_from'+filenamep+'.xlsx')
# Out:
#      index_row   Unnamed: 1                         h1  \
# 17          18  без вставок             Золотое кольцо
# 53          54  без вставок             Золотое кольцо
# 55          56  без вставок             Золотое кольцо
# 75          76  без вставок        Золотые серьги Чоху
# 80          81  без вставок        Золотые серьги Чоху
# 83          84  без вставок        Золотые серьги Чоху
# 84          85  без вставок             Золотые серьги
# 86          87  без вставок        Золотые серьги Чоху
# 104        105  без вставок             Золотые серьги
# 106        107  без вставок             Золотые серьги
# 108        109  без вставок             Золотые серьги
# 109        110  без вставок             Золотые серьги
# 120        121  без вставок  Золотая подвеска Харысхал
# 126        127  без вставок  Золотая подвеска Харысхал
# 127        128  без вставок  Золотая подвеска Харысхал
# 130        131  без вставок  Золотая подвеска Харысхал
# 131        132  без вставок  Золотая подвеска Харысхал
# 132        133  без вставок  Золотая подвеска Харысхал
# 133        134  без вставок  Золотая подвеска Харысхал
# 134        135  без вставок  Золотая подвеска Харысхал
# 135        136  без вставок  Золотая подвеска Харысхал
# 136        137  без вставок           Золотая подвеска
# 137        138  без вставок  Золотая подвеска Харысхал
#
#                             art  price  disc_price                   action  \
# 17      Артикул: я06516-10-1000  25352       17746  Акция: SPRING sale -30%
# 53      Артикул: я06763-10-1000  44411       31087  Акция: SPRING sale -30%
# 55      Артикул: я06514-10-1000  46299       32409  Акция: SPRING sale -30%
# 75      Артикул: я02593-10-1000  21486       15040  Акция: SPRING sale -30%
# 80      Артикул: я02630-10-1000  37129       25990  Акция: SPRING sale -30%
# 83      Артикул: я02589-10-1000  40095       28067  Акция: SPRING sale -30%
# 84             Артикул: 08-1892  40283       28198  Акция: SPRING sale -30%
# 86      Артикул: я02634-10-1000  47917       33542  Акция: SPRING sale -30%
# 104     Артикул: я01618-10-1000  73242       51269  Акция: SPRING sale -30%
# 106     Артикул: я01628-10-1000  85225       59658  Акция: SPRING sale -30%
# 108     Артикул: я01629-10-1000  86294       60406  Акция: SPRING sale -30%
# 109     Артикул: я01635-10-1000  87293       61105  Акция: SPRING sale -30%
# 120            Артикул: 09-0901   6573        4601  Акция: SPRING sale -30%
# 126            Артикул: 09-0891  12301        8611  Акция: SPRING sale -30%
# 127  Артикул: я-0152-10-0000-31  13845        9691  Акция: SPRING sale -30%
# 130  Артикул: я-0150-10-0000-31  15024       10517  Акция: SPRING sale -30%
# 131  Артикул: я-0148-10-0000-31  15400       10780  Акция: SPRING sale -30%
# 132  Артикул: я-0149-10-0000-31  15494       10845  Акция: SPRING sale -30%
# 133  Артикул: я-0151-10-0000-31  15494       10845  Акция: SPRING sale -30%
# 134  Артикул: я-0154-10-0000-31  15494       10845  Акция: SPRING sale -30%
# 135  Артикул: я-0155-10-0000-31  15681       10977  Акция: SPRING sale -30%
# 136     Артикул: п07890-10-1000  15822       11076  Акция: SPRING sale -30%
# 137            Артикул: 09-0890  16151       11306  Акция: SPRING sale -30%
#
#                                                                                                                                                                                                     describe  \
# 17                                                                                      Кольцо из коллекции "Якутские узоры". Изготовлено из красного золота 585 пробы, без вставок. Вес изделия 2,4 грамма.
# 53                                                                                      Кольцо из коллекции "Якутские узоры". Изготовлено из красного золота 585 пробы, без вставок. Вес изделия 4,3 грамма.
# 55                                                                                       Кольцо из коллекции "Якутские узоры". Изготовлено из красного золота 585 пробы, без вставок. Вес изделия 4,8 грамм.
# 75                                                                                 Серьги чоху из коллекции "Якутские узоры". Изготовлены из красного золота 585 пробы, без вставок. Вес изделия 2,3 грамма.
# 80                                                                                 Серьги чоху из коллекции "Якутские узоры". Изготовлены из красного золота 585 пробы, без вставок. Вес изделия 4,7 грамма.
# 83                                                                                 Серьги чоху из коллекции "Якутские узоры". Изготовлены из красного золота 585 пробы, без вставок. Вес изделия 4,4 грамма.
# 84                                                                              Серьги из коллекции "Якутские узоры". Изготовлены из красного золота 585 пробы, без вставок. Средний вес изделия 4,4 грамма.
# 86                                                                                    Серьги чоху из коллекции "Якутские узоры". Изготовлены из красного золота 585 пробы, без вставок. Вес изделия 5 грамм.
# 104                                                                 Серьги из коллекции "Якутские узоры". Изготовлены из красного золота 585 пробы, с английским замком, без вставок. Вес изделия 7,5 грамм.
# 106                                                                 Серьги из коллекции "Якутские узоры". Изготовлены из красного золота 585 пробы, с английским замком, без вставок. Вес изделия 9,9 грамм.
# 108                                                                Серьги из коллекции "Якутские узоры". Изготовлены из красного золота 585 пробы, с английским замком, без вставок. Вес изделия 9,3 грамма.
# 109                                                                Серьги из коллекции "Якутские узоры". Изготовлены из красного золота 585 пробы, с английским замком, без вставок. Вес изделия 9,4 грамма.
# 120                                                      Подвеска из коллекции "Якутские узоры" с харысхалом Долуьуон хатыыта - оберег для ребёнка. Изготовлена из красного золота 585 пробы. Вес 0,7 грамм.
# 126                                     Подвеска из коллекции "Якутские узоры" с харысхалом Ус Кут - символом триединства природы и человека. Изготовлена из красного золота 585 пробы. Вес изделия 1 грамм.
# 127             Подвеска из коллекции "Якутские узоры" с харысхалом "Долуьуон хатыыта"  (Шип шиповника) - оберег для ребенка. Изготовлена из красного золота 585 пробы, без вставок. Вес изделия 1,5 грамма.
# 130                      Подвеска из коллекции "Якутские узоры" с харысхалом Кыптыый (Ножницы) - оберег для девушки, женщины. Изготовлена из красного золота 585 пробы, без вставок. Вес изделия 1,5 грамма.
# 131        Подвеска из коллекции "Якутские узоры" с харысхалом Саhыл Тумса (Лисий нос) - талисман на богатство, деловую удачу. Изготовлена из красного золота 585 пробы, без вставок. Вес изделия 1,5 грамм.
# 132                           Подвеска из коллекции "Якутские узоры" с харысхалом Ох (Стрела) - оберег для мальчика, мужчины. Изготовлена из красного золота 585 пробы, без вставок. Вес изделия 1,55 грамм.
# 133           Подвеска из коллекции "Якутские узоры" с харысхалом Лыах (Бабочка) - талисман благих желаний, оберег от сглаза. Изготовлена из красного золота 585 пробы, без вставок. Вес изделия 1,5 грамма.
# 134       Подвеска из коллекции "Якутские узоры" с харысхалом Дьиэ кэргэн (Семья) - талисман семейного счастья, защита семьи. Изготовлена из красного золота 585 пробы, без вставок. Вес изделия 1,5 грамма.
# 135  Подвеска из коллекции "Якутские узоры" с харысхалом Сопко толкуй (Верное решение) - защищает от принятия неверных решений, притягивает удачу. Изготовлена из красного золота 585 пробы, без вставок....
# 136                                                                                           Подвеска из коллекции "Европейская классика". Изготовлена из красного золота 585 пробы. Вес изделия 1.7 грамм.
# 137                                  Подвеска из коллекции "Якутские узоры" с харысхалом Ус Кут - символом триединства природы и человека. Изготовлена из красного золота 585 пробы. Вес изделия 1,2 грамма.
#
#       Бренд Страна производства                  Материал gems  Средний вес  \
# 17   ЭГЭЛГЭ              Россия  красное золото 585 пробы  NaN         2.40
# 53   ЭГЭЛГЭ              Россия  красное золото 585 пробы  NaN         4.30
# 55   ЭГЭЛГЭ              Россия  красное золото 585 пробы  NaN         4.80
# 75   ЭГЭЛГЭ              Россия  красное золото 585 пробы  NaN         2.30
# 80   ЭГЭЛГЭ              Россия  красное золото 585 пробы  NaN         4.70
# 83   ЭГЭЛГЭ              Россия  красное золото 585 пробы  NaN         4.40
# 84   ЭГЭЛГЭ              Россия  красное золото 585 пробы  NaN         4.40
# 86   ЭГЭЛГЭ              Россия  красное золото 585 пробы  NaN         5.00
# 104  ЭГЭЛГЭ              Россия  красное золото 585 пробы  NaN         7.50
# 106  ЭГЭЛГЭ              Россия  красное золото 585 пробы  NaN         9.90
# 108  ЭГЭЛГЭ              Россия  красное золото 585 пробы  NaN         9.30
# 109  ЭГЭЛГЭ              Россия  красное золото 585 пробы  NaN         9.40
# 120  ЭГЭЛГЭ              Россия  красное золото 585 пробы  NaN         0.70
# 126  ЭГЭЛГЭ              Россия  красное золото 585 пробы  NaN         1.00
# 127  ЭГЭЛГЭ              Россия  красное золото 585 пробы  NaN         1.50
# 130  ЭГЭЛГЭ              Россия  красное золото 585 пробы  NaN         1.50
# 131  ЭГЭЛГЭ              Россия  красное золото 585 пробы  NaN         1.50
# 132  ЭГЭЛГЭ              Россия  красное золото 585 пробы  NaN         1.55
# 133  ЭГЭЛГЭ              Россия  красное золото 585 пробы  NaN         1.50
# 134  ЭГЭЛГЭ              Россия  красное золото 585 пробы  NaN         1.50
# 135  ЭГЭЛГЭ              Россия  красное золото 585 пробы  NaN         1.50
# 136  ЭГЭЛГЭ              Россия  красное золото 585 пробы  NaN         1.70
# 137  ЭГЭЛГЭ              Россия  красное золото 585 пробы  NaN         1.20
#
#                                                             url  \
# 17                https://egelge.com/catalog/zolotoe-kolco-218/
# 53                https://egelge.com/catalog/zolotoe-kolco-831/
# 55                https://egelge.com/catalog/zolotoe-kolco-421/
# 75                https://egelge.com/catalog/zolotye-sergi-430/
# 80          https://egelge.com/catalog/zolotye-sergi-chohu-871/
# 83                https://egelge.com/catalog/zolotye-sergi-429/
# 84                https://egelge.com/catalog/zolotye-sergi-396/
# 86          https://egelge.com/catalog/zolotye-sergi-chohu-874/
# 104               https://egelge.com/catalog/zolotye-sergi-431/
# 106               https://egelge.com/catalog/zolotye-sergi-432/
# 108               https://egelge.com/catalog/zolotye-sergi-433/
# 109               https://egelge.com/catalog/zolotye-sergi-434/
# 120  https://egelge.com/catalog/zolotaya-podveska-haryshal-400/
# 126  https://egelge.com/catalog/zolotaya-podveska-haryshal-398/
# 127  https://egelge.com/catalog/zolotaya-podveska-haryshal-561/
# 130  https://egelge.com/catalog/zolotaya-podveska-haryshal-559/
# 131  https://egelge.com/catalog/zolotaya-podveska-haryshal-557/
# 132  https://egelge.com/catalog/zolotaya-podveska-haryshal-558/
# 133  https://egelge.com/catalog/zolotaya-podveska-haryshal-560/
# 134  https://egelge.com/catalog/zolotaya-podveska-haryshal-563/
# 135  https://egelge.com/catalog/zolotaya-podveska-haryshal-564/
# 136           https://egelge.com/catalog/zolotaya-podveska-861/
# 137           https://egelge.com/catalog/zolotaya-podveska-397/
#
#      цена за грамм рублей, без НДС  цена за грамм рублей, с НДС checklog
# 17                     7394.166667                  6161.805556
# 53                     7229.534884                  6024.612403
# 55                     6751.875000                  5626.562500
# 75                     6539.130435                  5449.275362
# 80                     5529.787234                  4608.156028
# 83                     6378.863636                  5315.719697
# 84                     6408.636364                  5340.530303
# 86                     6708.400000                  5590.333333
# 104                    6835.866667                  5696.555556
# 106                    6026.060606                  5021.717172
# 108                    6495.268817                  5412.724014
# 109                    6500.531915                  5417.109929
# 120                    6572.857143                  5477.380952
# 126                    8611.000000                  7175.833333
# 127                    6460.666667                  5383.888889
# 130                    7011.333333                  5842.777778
# 131                    7186.666667                  5988.888889
# 132                    6996.774194                  5830.645161
# 133                    7230.000000                  6025.000000
# 134                    7230.000000                  6025.000000
# 135                    7318.000000                  6098.333333
# 136                    6515.294118                  5429.411765
# 137                    9421.666667                  7851.388889

# %%
#jewellery = jewellery.loc[~jewellery.gems.isna()].copy()

# %%
#jewellery.info()

# %% [markdown]
# # Выделение наполнение vstavki

# %%
pd.options.display.max_colwidth = 200

# %%
jewellery['vstavki_list1'] = jewellery.gems.apply(lambda x: re.split(r",", x) if  type(x) == type('x') else x)

# %%
jew = jewellery[~jewellery['vstavki_list1'].isna()].copy()

# %%
jewellery[~jewellery['vstavki_list1'].isna()]
# Out:
#      index_row     Unnamed: 1                                        h1  \
# 0            1  с бриллиантом             Золотое кольцо с бриллиантами
# 1            2  с бриллиантом             Золотое кольцо с бриллиантами
# 2            3  с бриллиантом              Золотое кольцо с бриллиантом
# 3            4  с бриллиантом              Золотое кольцо с бриллиантом
# 4            5  с бриллиантом              Золотое кольцо с бриллиантом
# ..         ...            ...                                       ...
# 140        141  с бриллиантом           Золотая подвеска с Бриллиантами
# 141        142  с бриллиантом           Золотая подвеска с Бриллиантами
# 142        143          с ПДК              Золотая подвеска с Фианитами
# 143        144  с бриллиантом           Золотая подвеска с Бриллиантами
# 144        145  с бриллиантом  Золотая подвеска Харысхал с бриллиантами
#
#                          art  price  disc_price                    action  \
# 0    Артикул: п06110-10-2010  21486        8594  Акция: Diamond sale -60%
# 1    Артикул: п06110-10-2010  21486        8594  Акция: Diamond sale -60%
# 2    Артикул: п06095-10-2010  24572        9829  Акция: Diamond sale -60%
# 3    Артикул: п06095-11-2010  25645       10258  Акция: Diamond sale -60%
# 4    Артикул: п06069-10-2010  28128       11251  Акция: Diamond sale -60%
# ..                       ...    ...         ...                       ...
# 140  Артикул: п07892-10-2010  31443       12577  Акция: Diamond sale -60%
# 141  Артикул: п07893-10-2010  39488       15795  Акция: Diamond sale -60%
# 142  Артикул: п07888-10-3010  29088       20362   Акция: SPRING sale -30%
# 143  Артикул: п07889-10-2010  54360       21744  Акция: Diamond sale -60%
# 144  Артикул: я07636-10-2010  56834       22734  Акция: Diamond sale -60%
#
#                                                                                                                                                                                                     describe  \
# 0    Кольцо из коллекции "Европейская классика". Изготовлено из красного золота 585 пробы. Вставки - 3 Бриллианта круглой огранки 57 граней, общим весом 0.03 карат, группа цвета - 3, группа чистоты - 6...
# 1    Кольцо из коллекции "Европейская классика". Изготовлено из красного золота 585 пробы. Вставки - 3 Бриллианта круглой огранки 57 граней, общим весом 0.03 карат, группа цвета - 3, группа чистоты - 6...
# 2    Кольцо из коллекции "Европейская классика". Изготовлено из красного золота 585 пробы. Вставка - 1 Бриллиант круглой огранки 57 граней, вес 0.02 карат, группа цвета - 3, группа чистоты - 6, качеств...
# 3    Кольцо из коллекции "Европейская классика". Изготовлено из белого золота 585 пробы. Вставка - 1 Бриллиант круглой огранки 57 граней, вес 0,02 карат, группа цвета - 4, группа чистоты - 5, качество ...
# 4    Кольцо из коллекции "Европейская классика". Изготовлено из красного золота 585 пробы. Вставка - 1 Бриллиант круглой огранки 57 граней, вес 0.04 карат, группа цвета - 3, группа чистоты - 6, качеств...
# ..                                                                                                                                                                                                       ...
# 140  Подвеска из коллекции "Европейская классика". Изготовлена из красного золота 585 пробы. Вставки - 3 Бриллианта круглой огранки 57 граней, общим весом 0.24 карат, группа цвета - 3, группа чистоты -...
# 141  Подвеска из коллекции "Европейская классика". Изготовлена из красного золота 585 пробы. Вставки - 19 Бриллиантов круглой огранки 57 граней, общим весом 0.1 карат, группа цвета - 2, группа чистоты ...
# 142                                       Подвеска из коллекции "Европейская классика". Изготовлена из красного золота 585 пробы. Вставки - 10 бесцветных Фианитов в огранке маркиз. Вес изделия 2.5 грамма.
# 143  Подвеска из коллекции "Европейская классика". Изготовлена из красного золота 585 пробы. Вставки - 16 Бриллиантов круглой огранки 57 граней, общий вес 0,11 карат, группа цвета - 4, группа чистоты -...
# 144  Подвеска из коллекции "Якутские узоры" с харысхалом Ус Кут - символом триединства природы и человека. Изготовлена из красного золота 585 пробы. Вставки -  3 Бриллианта круглой огранки 57 граней, о...
#
#       Бренд Страна производства                  Материал  \
# 0    ЭГЭЛГЭ              Россия  красное золото 585 пробы
# 1    ЭГЭЛГЭ              Россия  красное золото 585 пробы
# 2    ЭГЭЛГЭ              Россия  красное золото 585 пробы
# 3    ЭГЭЛГЭ              Россия    белое золото 585 пробы
# 4    ЭГЭЛГЭ              Россия  красное золото 585 пробы
# ..      ...                 ...                       ...
# 140  ЭГЭЛГЭ              Россия  красное золото 585 пробы
# 141  ЭГЭЛГЭ              Россия  красное золото 585 пробы
# 142  ЭГЭЛГЭ              Россия  красное золото 585 пробы
# 143  ЭГЭЛГЭ              Россия  красное золото 585 пробы
# 144  ЭГЭЛГЭ              Россия  красное золото 585 пробы
#
#                                                                           gems  \
# 0    1 Бр Кр 57 0,013Ct 3/6А ,1 Бр Кр 57 0,005Ct 3/6А ,1 Бр Кр 57 0,009Ct 3/6А
# 1    1 Бр Кр 57 0,013Ct 3/6А ,1 Бр Кр 57 0,005Ct 3/6А ,1 Бр Кр 57 0,009Ct 3/6А
# 2                                                      1 Бр Кр 57 0,020Ct 3/6А
# 3                                                      1 Бр Кр 57 0,018Ct 4/5А
# 4                                                      1 Бр Кр 57 0,042Ct 3/6А
# ..                                                                         ...
# 140                                                    3 Бр Кр 57 0,024Ct 3/6А
# 141                          1 Бр Кр 57 0,031Ct 4/5А ,18 Бр Кр 17 0,072Ct 2/3А
# 142                                           5 фиан кр 1.0, 5 фиан марк 3*1.5
# 143                          4 Бр Кр 17 0,018Ct 2/3А ,12 Бр Кр 57 0,094Ct 4/5А
# 144                                                    3 Бр Кр 57 0,086Ct 3/6А
#
#      Средний вес  \
# 0            1.1
# 1            1.1
# 2            1.2
# 3            1.2
# 4            1.4
# ..           ...
# 140          1.6
# 141          1.8
# 142          2.5
# 143          2.0
# 144          2.9
#
#                                                                            url  \
# 0                 https://egelge.com/catalog/zolotoe-kolco-s-brilliantami-716/
# 1                 https://egelge.com/catalog/zolotoe-kolco-s-brilliantami-716/
# 2                  https://egelge.com/catalog/zolotoe-kolco-s-brilliantom-541/
# 3                  https://egelge.com/catalog/zolotoe-kolco-s-brilliantom-773/
# 4                  https://egelge.com/catalog/zolotoe-kolco-s-brilliantom-523/
# ..                                                                         ...
# 140           https://egelge.com/catalog/zolotaya-podveska-s-brilliantami-862/
# 141           https://egelge.com/catalog/zolotaya-podveska-s-brilliantami-863/
# 142              https://egelge.com/catalog/zolotaya-podveska-s-fianitami-859/
# 143           https://egelge.com/catalog/zolotaya-podveska-s-brilliantami-860/
# 144  https://egelge.com/catalog/zolotaya-podveska-haryshal-s-brilliantami-452/
#
#      цена за грамм рублей, без НДС  цена за грамм рублей, с НДС checklog  \
# 0                      7812.727273                  6510.606061
# 1                      7812.727273                  6510.606061
# 2                      8190.833333                  6825.694444
# 3                      8548.333333                  7123.611111
# 4                      8036.428571                  6697.023810
# ..                             ...                          ...      ...
# 140                    7860.625000                  6550.520833
# 141                    8775.000000                  7312.500000
# 142                    8144.800000                  6787.333333
# 143                   10872.000000                  9060.000000
# 144                    7839.310345                  6532.758621
#
#                                                                         vstavki_list1
# 0    [1 Бр Кр 57 0, 013Ct 3/6А , 1 Бр Кр 57 0, 005Ct 3/6А , 1 Бр Кр 57 0, 009Ct 3/6А]
# 1    [1 Бр Кр 57 0, 013Ct 3/6А , 1 Бр Кр 57 0, 005Ct 3/6А , 1 Бр Кр 57 0, 009Ct 3/6А]
# 2                                                          [1 Бр Кр 57 0, 020Ct 3/6А]
# 3                                                          [1 Бр Кр 57 0, 018Ct 4/5А]
# 4                                                          [1 Бр Кр 57 0, 042Ct 3/6А]
# ..                                                                                ...
# 140                                                        [3 Бр Кр 57 0, 024Ct 3/6А]
# 141                            [1 Бр Кр 57 0, 031Ct 4/5А , 18 Бр Кр 17 0, 072Ct 2/3А]
# 142                                               [5 фиан кр 1.0,  5 фиан марк 3*1.5]
# 143                            [4 Бр Кр 17 0, 018Ct 2/3А , 12 Бр Кр 57 0, 094Ct 4/5А]
# 144                                                        [3 Бр Кр 57 0, 086Ct 3/6А]
#
# [122 rows x 18 columns]

# %% [markdown]
# ## Удаление изделий с небриллиантами

# %%
#jewellery.vstavki_list1=
jew.vstavki_list1.apply(lambda l: list(filter(lambda x: 0 if x == '' else 1,l)))
# Out:
# 0      [1 Бр Кр 57 0, 013Ct 3/6А , 1 Бр Кр 57 0, 005Ct 3/6А , 1 Бр Кр 57 0, 009Ct 3/6А]
# 1      [1 Бр Кр 57 0, 013Ct 3/6А , 1 Бр Кр 57 0, 005Ct 3/6А , 1 Бр Кр 57 0, 009Ct 3/6А]
# 2                                                            [1 Бр Кр 57 0, 020Ct 3/6А]
# 3                                                            [1 Бр Кр 57 0, 018Ct 4/5А]
# 4                                                            [1 Бр Кр 57 0, 042Ct 3/6А]
#                                              ...
# 140                                                          [3 Бр Кр 57 0, 024Ct 3/6А]
# 141                              [1 Бр Кр 57 0, 031Ct 4/5А , 18 Бр Кр 17 0, 072Ct 2/3А]
# 142                                                 [5 фиан кр 1.0,  5 фиан марк 3*1.5]
# 143                              [4 Бр Кр 17 0, 018Ct 2/3А , 12 Бр Кр 57 0, 094Ct 4/5А]
# 144                                                          [3 Бр Кр 57 0, 086Ct 3/6А]
# Name: vstavki_list1, Length: 122, dtype: object

# %%
jew.vstavki_list1.apply(lambda l: [x.__contains__('Бр') for x in l])#ist(filter(lambda x: 0 if x == '' else 1,l)))
# Out:
# 0      [True, False, True, False, True, False]
# 1      [True, False, True, False, True, False]
# 2                                [True, False]
# 3                                [True, False]
# 4                                [True, False]
#                         ...
# 140                              [True, False]
# 141                 [True, False, True, False]
# 142                             [False, False]
# 143                 [True, False, True, False]
# 144                              [True, False]
# Name: vstavki_list1, Length: 122, dtype: object

# %%
'[3 Бр Кр 57 0, 086Ct 3/6А]'.__contains__('Бр')
# Out:
# True

# %%
l =  [1 Бр Кр 57 0, 031Ct 4/5А , 18 Бр Кр 17 0, 072Ct 2/3А]
[1 if x.__contains__('Бр') else 0 for x in l]
# Out:
#   File "<ipython-input-49-35c8a158f4a5>", line 1
#     l =  [1 Бр Кр 57 0, 031Ct 4/5А , 18 Бр Кр 17 0, 072Ct 2/3А]
#              ^
# SyntaxError: invalid syntax

# %%
#wow = 
jew.vstavki_list1.apply(lambda l: all([1 if x.__contains__('Бр') else 0 for x in l]))
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 140    False
# 141    False
# 142    False
# 143    False
# 144    False
# Name: vstavki_list1, Length: 122, dtype: bool

# %%
jewellery.loc[wow].info()

# %%
#Записали изделия с небриллиантами
jewellery[~wow].to_excel(sourcepath+'_failed_containsnodiamonds_'+filenamep+'.xlsx')

# %%
'1  Бриллиант огранки "Круглая" граней - 57, тип огранки A, цвет 3, чистота 6, 0.06 карат'.__contains__('Б')

# %%
jewellery = jewellery.loc[wow].copy()

# %%
jewellery

# %%
vstavki = jewellery.copy()

# %%
vstavki.info()

# %% [markdown]
# ## Разделение explode

# %%
vstavki = vstavki.explode('vstavki_list1')

# %%
vstavki.head(50)

# %%
vstavki['vstavki_list2'] = vstavki.vstavki_list1.apply(lambda x: x.split(','))

# %%
pattern_miuz0 = r"""(?ix)(?P<n>\d{1,4})\s+(?P<gem>\w+)\s+огранки\s+"
                    (?P<form>[\W\w]+)"[\s\w]*(?:граней)?\s?-?\s?(?P<graney>\d*)?"""

# %%
re.findall(pattern_miuz0,'6 Бриллиантов огранки "Круглая" граней - 17, тип огранки A, цвет 3, чистота 4, 0.02 карат')

# %%
vstavki['n_gem_ogr_ngra'] = vstavki.vstavki_list2.apply(lambda x: re.findall(pattern_miuz0,x[0]))

# %%
vstavki['ШТУК'] = vstavki.n_gem_ogr_ngra.apply(lambda x: x[0][0] if len(x) != 0 else 0)

# %%
vstavki['gem'] = vstavki.n_gem_ogr_ngra.apply(lambda x: x[0][1] if len(x) != 0 else '')

# %%
vstavki['ОГРАНКА'] = vstavki.n_gem_ogr_ngra.apply(lambda x: (x[0][2]+'-'+ x[0][3]).strip('-') if len(x) != 0 else '')

# %%
vstavki['ПО'] = vstavki.vstavki_list1.apply(lambda x: re.findall(r"""тип огранки\s+(.)""" , x)[0]
                                            if re.findall(r"""тип огранки\s+(.)""" , x) else "")

# %%
vstavki['Ц'] = vstavki.vstavki_list1.apply(lambda x: re.findall(r"""цвет\s+(\d[-.]?\d?\d?)""", x)[0]
                                           if re.findall(r"""цвет\s+(\d[-.]?\d?\d?)""" , x) else "")

# %%
vstavki['Д'] = vstavki.vstavki_list1.apply(lambda x: re.findall(r"""чистота\s+(\d[-.]?\d?\d?\s?\w?)""", x)[0].strip()
                                           if re.findall(r"""чистота\s+(\d[-.]?\d?\d?\s?\w?)""" , x) else "")

# %%
vstavki['КАРАТ'] = vstavki.vstavki_list1.apply(lambda x: float(re.findall(r"""(\d\d?.\d\d?\d?)\s+карат""" , x)[0]) if re.findall(r"""(\d\d?.\d\d?\d?)\s+карат""" , x) else 0)

# %%
re.findall(r"""(\d\d?.\d\d?\d?)\s+карат""" ,'162  Бриллианта огранки "Круглая" граней - 17, тип огранки A, цвет 3, чистота 4, 0.5 карат;')

# %%
#TODO выпали несколько строк из порядка  Бриллиант круглой огранки - 57 граней, тип огранки A, цвет 4, чистота 7, 0.013 карат
#                              против 18 Бриллиантов огранки "Круглая" граней - 57, тип огранки A, цвет 3, чистота 7, 0.1 карат;12
# их мало поэтому пока выкидываем
len(vstavki.loc[ ~vstavki.gem.str.contains('Брилл')])

# %% [markdown]
# ### Using pattern 1

# %%
pattern_miuz1 = r"""(?ix)(?P<n>\d{1,4})\s+(?P<gem>\w+)\s+огранки\s+"
                    (?P<form>[\W\w]+)"[\s\w]*(?:граней)?\s?-?\s?(?P<graney>\d*)?"""

# %%
['62  Бриллианта', ' Круглая огранка', ' тип огранки A', ' цвет 3', ' чистота 4', ' 0.268 карат']
['26  Бриллиантов', ' Круглая огранка', ' тип огранки A', ' цвет 3', ' чистота 4', ' 0.077 карат']
['18  Бриллиантов', ' Круглая огранка', ' тип огранки A', ' цвет 4', ' чистота 4', ' 0.082 карат']
['76  Бриллиантов', ' Круглая огранка', ' тип огранки A', ' цвет 3', ' чистота 4', ' 0.206 карат']
['106  Бриллиантов', ' Круглая огранка', ' тип огранки A', ' цвет 4', ' чистота 4', ' 0.341 карат']
['28  Бриллиантов', ' Круглая огранка', ' тип огранки A', ' цвет 3', ' чистота 4', ' 0.09 карат']

# %%
int(re.findall(r'''(\d{1,4})\s+\Брилл''',['62  Бриллианта', ' Круглая огранка', ' тип огранки A', ' цвет 3', ' чистота 4', ' 0.268 карат'][])[0])

# %%
re.findall(r'''\s+(Круг\w+)\s+''',['62  Бриллианта', ' Круглая огранка', ' тип огранки A', ' цвет 3', ' чистота 4', ' 0.268 карат'][1])[0]

# %%
re.findall(r'''\d+\s+(Брилл\w+)''',['62  Бриллианта', ' Круглая огранка', ' тип огранки A', ' цвет 3', ' чистота 4', ' 0.268 карат'][0])[0]

# %%
vstavki

# %%
vstavki.loc[vstavki.ШТУК == 0,'gem'] = vstavki.loc[vstavki.ШТУК == 0,'vstavki_list1'].apply(
    lambda x: re.findall(r'''\d+\s+(Брилл\w+)''',x)[0])

# %%
vstavki.loc[vstavki.ШТУК == 0,'ОГРАНКА'] = vstavki.loc[vstavki.ШТУК == 0,'vstavki_list1'].apply(
    lambda x: re.findall(r'''\s+(Круг\w+)\s+''',x)[0]  if re.findall(r'''\s+(Круг\w+)\s+''',x) else "")

# %%
vstavki.loc[vstavki.ШТУК == 0,'ШТУК'] = vstavki.loc[vstavki.ШТУК == 0,'vstavki_list1'].apply(
    lambda x: int(re.findall(r'''(\d{1,4})\s+\Брилл''',x)[0]))

# %%
vstavki.loc[vstavki.ШТУК == 0]

# %% [markdown]
# ### Сохраняем промитоги

# %%
sourcepath

# %%
filenamep

# %%
vstavki.to_excel(sourcepath+'_vstsvki_forManual_2_'+filenamep+'.xlsx')

# %% [markdown]
# ## Чистка от пустых и неполных данных по вставкам

# %%
#
jewellery

# %%
diaminds

# %%
vstavki

# %%
#DROPING процедура выбрасывания по индексу с записью в файл по времени выброса 
def dropping(drop_index):
    import datetime
    drop_index = drop_index.unique()
    print(vstavki.loc[drop_index])
    if input("y") == "y":
        datestr = datetime.datetime.now().strftime('%Y-%m-%d-%H-%M')
        vstavki.loc[drop_index].to_excel(sourcepath+'_droping_'+datestr+filenamep+'.xlsx')
        jewellery.drop(index=drop_index, inplace=True)
        vstavki.drop(index=drop_index, inplace=True)
        print('dropped OK file ',sourcepath+'_droping_'+datestr+filenamep+'.xlsx')

# %%
#
drop_index =vstavki.loc[ ~vstavki.gem.str.contains('Брилл')].index#.to_excel(sourcepath+'_failed_re_'+filenamep+'.xlsx')
vstavki.loc[drop_index]

# %%
vstavki.info()

# %%
vstavki.ШТУК = vstavki.ШТУК.astype('int')

# %%
#diaminds = vstavki

# %% [markdown]
# ### Проверка 0  по длине строки вставки и количества распознанных строк + пропуск брилл

# %%
vstavki.ШТУК.sort_values().unique()

# %%
vstavki[vstavki.ШТУК >= 100].sort_values(by="ШТУК")

# %%
vstavki.ПО.unique()

# %%
vstavki.loc[(vstavki.ПО == 'V') |( vstavki.ПО == '') ]

# %%
drop_index = vstavki.loc[(vstavki.ПО == 'V') |( vstavki.ПО == '') ].index
dropping(drop_index)
#drop_index.unique()

# %%
vstavki.ОГРАНКА.unique()

# %%
#diaminds[diaminds.ОГРАНКА == 'Роза']

# %%
#drop_index = diaminds.loc[diaminds.ОГРАНКА == 'Роза'].index
#diaminds.loc[drop_index]

# %%
#dropping(diaminds.loc[diaminds.ОГРАНКА == 'Роза'].index)

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
print(diaminds.loc[diaminds.КАРАТ > -10000,'КАРАТ'].sort_values().unique())

# %%
vstavki.Ц.unique()

# %%
dropping(vstavki.loc[vstavki.Ц ==''].index)

# %%
 re.findall(r"""чистота\s+(\d[-.]?\d?\d?\s?\w?)"""  , '1 Бриллиант огранки "Груша" граней - 56, тип огранки A, цвет 8.1, чистота 7, 0.71 карат')[0].strip()

# %%
vstavki.Д.unique()

# %%
drop_index = vstavki.loc[vstavki.КАРАТ == 1].index
vstavki.loc[drop_index]

# %%
#vstavki.loc[vstavki.КАРАТ == 0,'КАРАТ'] = 1.0

# %%
#dropping(diaminds.loc[diaminds.КАРАТ == 0].index)

# %%
vstavki.Ц.apply(lambda x: x in dcol_dia).unique()

# %%
vstavki.Д.apply(lambda x: x in dcla_dia).unique()

# %%
#vstavki_d.Д.apply(lambda x: x in dcla_dia)
vstavki.loc[~vstavki.Д.apply(lambda x: x in dcla_dia)]

# %%
vstavki.ПО.apply(lambda x: x in dpo_dia).unique()

# %%
#diaminds.loc[~(diaminds.ПО.apply(lambda x: x in dpo_dia))]

# %%
vstavki.ОГРАНКА.apply(lambda x: x in dogr_dia_discount).unique()

# %%
vstavki.loc[~vstavki.ОГРАНКА.apply(lambda x: x in dogr_dia_discount),'ОГРАНКА'].unique()

# %%
dogr_dia_discount

# %%
vstavki.loc[vstavki.ОГРАНКА == '','ОГРАНКА'] = "Кр-57"

# %%
vstavki.loc[vstavki.ОГРАНКА =='Круглая','ОГРАНКА'] = "Кр-57"

# %%
vstavki.loc[vstavki.ОГРАНКА =='Маркиз','ОГРАНКА'] = 'М-55'

# %%
vstavki.loc[vstavki.ОГРАНКА =='Роза','ОГРАНКА'] = 'Огн. Роза'

# %% [markdown]
# ### Проверки 2

# %%
diaminds['СРКАРАТ'] = diaminds.КАРАТ/diaminds.ШТУК

# %%
vstavki['СРКАРАТ']

# %%
#vstavki_d.loc[vstavki_d.СРКАРАТ > 0.3000,'СРКАРАТ'].sort_values().unique()

# %%
diaminds.СРКАРАТ.sort_values().unique()

# %%
diaminds.loc[diaminds.СРКАРАТ > 1.5]

# %%
pd.read_excel?

# %% [markdown]
# ### Сохранение

# %%
diaminds.to_excel(sourcepath+'_diamonds_'+filenamep+'.xlsx')

# %%
diaminds = pd.read_excel(sourcepath+'_diamonds_'+filenamep+'.xlsx')
diaminds.drop(columns='Unnamed: 0', inplace= True)

# %%
diaminds

# %% [markdown]
# ### Прейскурант

# %%
res = func_rpdiamonds.rpdiamonds(diaminds)

# %%
diamonds = res

# %% [markdown]
# ## Проверка сработки прейскуранта

# %%
#saveerrlog(res,'id7c','МС00148933' )

# %%
res#.drop(index = res.index, inplace = True)

# %%
res.to_excel(sourcepath +'_брилл_в_строку_'+ filenamep+'.xlsx')

# %%
res.columns

# %%
resfinish = res[['index_row','ШТУК', 'КАРАТ','prcost']].groupby(['index_row']).agg({'ШТУК':"sum",'КАРАТ':"sum",'prcost':"sum",}).reset_index()

# %%
#resfinish.loc[resfinish.index_row == 216]

# %%
#res.loc[res.index_row == 216, 'prcost']

# %%
jewelleryfinish = pd.merge(jewellery,resfinish ,how='left',right_on='index_row',left_on='index_row')

# %%
jewelleryfinish

# %%
#jewelleryfinish.to_excel('res/jewdpr_'+filenamep+'.xlsx')
jewelleryfinish.to_excel(sourcepath + '_брилл_суммированы_'+filenamep+'.xlsx')

# %%
q = [(1,2,'j')]
q1 = (0,2,'j')

# %%
q.append(q1)

# %%
q

# %%
pd.merge(jewellery,resfinsh[['id7c','ШТУК', 'КАРАТ','prcost']],how='left',right_on='id7c',left_on='id7c')#.to_excel('res/jewdpr_'+filenamep+'.xlsx')

# %%
summallres = jewelleryfinish[['filname', 'Кол', "Вес", "Закуп", "Розн",'ШТУК', 'КАРАТ','prcost']].groupby(by = 'filname').sum().reset_index()

# %%
summallres['партия'] = sourcepath

# %%
summallres

# %%
summallres.to_excel(sourcepath + '_свод_после_прейскуранта_'+filenamep+'.xlsx')

# %%
summallres

# %% [markdown]
# filname    03-10-203.xls03-10-206а.xls03-10-256а.xls06-34...
# Кол                                                    27521
# Вес                                                121058.21
# Закуп                                           179497903.46
# Розн                                            453427001.68
# dtype: object

# %%
pd.options.display.float_format = '{:.2f}'.format
pd.options.display.max_colwidth = 100

# %%
pd.DataFrame.explode?
