# %%
from bs4 import BeautifulSoup
import requests
from requests import Request, Session
import pandas as pd

# %%
import re

# %%
def mysoup(urls):
    response = requests.get(urls)
    return BeautifulSoup(response.text, 'lxml')

# %%
def getlinks(urls):
    quotes = mysoup(urls).find_all('div', class_="product")
    res = [q.find("a").get("href") for q in quotes]
    print(len(res), 'links is ready ' , res[0], '...', res[-1])
    return res

# %%
def get_info_from_card(urls):
    card = mysoup(urls)
    return card.select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)')

# %%
i=2
f'page={i}/'
# Out:
# 'page=2/'

# %%
links = []

# %%
#def main():

urls = f'https://miuz.ru/catalog/rings/filter/stones_main-is-brilliant/'
domain = f'https://miuz.ru'
for i in range(49,200):
    pages = f'page={i}/'
    links += getlinks(urls+pages)
# Out:
# 50 links is ready  /catalog/rings/R4150-D-LRP33119E/ ... /catalog/rings/R97-CR3404-HE/
# 50 links is ready  /catalog/rings/R97-CR2396-R17/ ... /catalog/rings/R77-R46120-EM-R17/
# 50 links is ready  /catalog/rings/R77-R46119-SA-R17/ ... /catalog/rings/R755-55168R004-R17/
# 50 links is ready  /catalog/rings/R755-52575R001-R17/ ... /catalog/rings/R4150-D-R4550EM/
# 50 links is ready  /catalog/rings/R4150-D-R4476EM/ ... /catalog/rings/R4150-D-LRP35496S/
# 50 links is ready  /catalog/rings/R4150-D-LRP35182S/ ... /catalog/rings/R4150-D-LRP31830/
# 50 links is ready  /catalog/rings/R4150-D-LRP33085S/ ... /catalog/rings/R4150-D-LRL106047ER1/
# 50 links is ready  /catalog/rings/R4150-D-LRG82424S/ ... /catalog/rings/R4150-D-LRAB2356S/
# 50 links is ready  /catalog/rings/R4150-D-LRAB3740E/ ... /catalog/rings/R4150-D-6107S/
# 50 links is ready  /catalog/rings/R4150-D-LR30081-1S/ ... /catalog/rings/R4150-D-4271E/
# 50 links is ready  /catalog/rings/R4150-D-46519PD/ ... /catalog/rings/R4150-D-1982825EMR17/
# 50 links is ready  /catalog/rings/R4150-D-1982805SAR17/ ... /catalog/rings/R4150-D-15810ER17/
# 50 links is ready  /catalog/rings/R4144-R2500-DIA/ ... /catalog/rings/R2017-R313268SAP-R17/
# 50 links is ready  /catalog/rings/R2017-R313274EMR-R17/ ... /catalog/rings/R01-WED-00154-R/
# 50 links is ready  /catalog/rings/R01-WED-00139-W/ ... /catalog/rings/R01-34685/
# 50 links is ready  /catalog/rings/R01-34826/ ... /catalog/rings/R77-BL-R38252-BD-R17/
# 50 links is ready  /catalog/rings/R123-10959RAM4RT-R17/ ... /catalog/rings/R2022-SA2629R/
# 50 links is ready  /catalog/rings/R01-SOL31-020-G2/ ... /catalog/rings/R755-70643R001-R17/
# 50 links is ready  /catalog/rings/R2018-RR01009ADI-R17/ ... /catalog/rings/R4150-D-51053EM/
# 50 links is ready  /catalog/rings/R4150-D-47015R/ ... /catalog/rings/R4150-D-LR30075-1MIX/
# 50 links is ready  /catalog/rings/R4150-D-47745R17/ ... /catalog/rings/R01-33697-AM/
# 50 links is ready  /catalog/rings/R2017-R312640DIA-R17/ ... /catalog/rings/R2506-RG022648-R17/
# 50 links is ready  /catalog/rings/R4150-D-47586R17/ ... /catalog/rings/R4150-D-LR11402R/
# 50 links is ready  /catalog/rings/R4150-D-LR4278RU/ ... /catalog/rings/R4150-D-LRT1563/
# 50 links is ready  /catalog/rings/R4150-D-46518E/ ... /catalog/rings/R4150-D-198798S/
# 50 links is ready  /catalog/rings/R4150-D-1981284BRBD/ ... /catalog/rings/R755-54157R001/
# 50 links is ready  /catalog/rings/R755-67095R001/ ... /catalog/rings/R01-9-33186-66/
# 50 links is ready  /catalog/rings/R01-34877-RO/ ... /catalog/rings/R755-54793R002-R17/
# 50 links is ready  /catalog/rings/R4211-RG2627WDI1/ ... /catalog/rings/R01-ROYAL202-W-300/
# 50 links is ready  /catalog/rings/R01-100-35518/ ... /catalog/rings/R2017-R312796SAP/
# 50 links is ready  /catalog/rings/R108-185233AQQUD/ ... /catalog/rings/R755-69017R001-R17/
# 50 links is ready  /catalog/rings/R77-R59460-SACP/ ... /catalog/rings/R01-35265-150-SA/
# 50 links is ready  /catalog/rings/R2022-SR0011-CU7.5-A/ ... /catalog/rings/R4211-RG2142WDI/
# 50 links is ready  /catalog/rings/R2022-SR0011-CU7.5-A/ ... /catalog/rings/R4211-RG2142WDI/
# 50 links is ready  /catalog/rings/R2022-SR0011-CU7.5-A/ ... /catalog/rings/R4211-RG2142WDI/
# 50 links is ready  /catalog/rings/R2022-SR0011-CU7.5-A/ ... /catalog/rings/R4211-RG2142WDI/
# 50 links is ready  /catalog/rings/R2022-SR0011-CU7.5-A/ ... /catalog/rings/R4211-RG2142WDI/
# 50 links is ready  /catalog/rings/R2022-SR0011-CU7.5-A/ ... /catalog/rings/R4211-RG2142WDI/
# 50 links is ready  /catalog/rings/R2022-SR0011-CU7.5-A/ ... /catalog/rings/R4211-RG2142WDI/
# 50 links is ready  /catalog/rings/R2022-SR0011-CU7.5-A/ ... /catalog/rings/R4211-RG2142WDI/
# 50 links is ready  /catalog/rings/R2022-SR0011-CU7.5-A/ ... /catalog/rings/R4211-RG2142WDI/
# 50 links is ready  /catalog/rings/R2022-SR0011-CU7.5-A/ ... /catalog/rings/R4211-RG2142WDI/
# 50 links is ready  /catalog/rings/R2022-SR0011-CU7.5-A/ ... /catalog/rings/R4211-RG2142WDI/
# 50 links is ready  /catalog/rings/R2022-SR0011-CU7.5-A/ ... /catalog/rings/R4211-RG2142WDI/
# 50 links is ready  /catalog/rings/R2022-SR0011-CU7.5-A/ ... /catalog/rings/R4211-RG2142WDI/
# 50 links is ready  /catalog/rings/R2022-SR0011-CU7.5-A/ ... /catalog/rings/R4211-RG2142WDI/
# 50 links is ready  /catalog/rings/R2022-SR0011-CU7.5-A/ ... /catalog/rings/R4211-RG2142WDI/
# 50 links is ready  /catalog/rings/R2022-SR0011-CU7.5-A/ ... /catalog/rings/R4211-RG2142WDI/
# 50 links is ready  /catalog/rings/R2022-SR0011-CU7.5-A/ ... /catalog/rings/R4211-RG2142WDI/
# 50 links is ready  /catalog/rings/R2022-SR0011-CU7.5-A/ ... /catalog/rings/R4211-RG2142WDI/
# 50 links is ready  /catalog/rings/R2022-SR0011-CU7.5-A/ ... /catalog/rings/R4211-RG2142WDI/
# 50 links is ready  /catalog/rings/R2022-SR0011-CU7.5-A/ ... /catalog/rings/R4211-RG2142WDI/
# 50 links is ready  /catalog/rings/R2022-SR0011-CU7.5-A/ ... /catalog/rings/R4211-RG2142WDI/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-76-9c941be86970> in <module>
#       5 for i in range(49,200):
#       6     pages = f'page={i}/'
# ----> 7     links += getlinks(urls+pages)
#       8
#
# <ipython-input-4-c962f812728c> in getlinks(urls)
#       1 def getlinks(urls):
# ----> 2     quotes = mysoup(urls).find_all('div', class_="product")
#       3     res = [q.find("a").get("href") for q in quotes]
#       4     print(len(res), 'links is ready ' , res[0], '...', res[-1])
#       5     return res
#
# <ipython-input-3-457c2edd76e4> in mysoup(urls)
#       1 def mysoup(urls):
# ----> 2     response = requests.get(urls)
#       3     return BeautifulSoup(response.text, 'lxml')
#       4
#
# C:\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# C:\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# C:\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# C:\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     675             # Redirect resolving generator.
#     676             gen = self.resolve_redirects(r, request, **kwargs)
# --> 677             history = [resp for resp in gen]
#     678         else:
#     679             history = []
#
# C:\anaconda3\lib\site-packages\requests\sessions.py in <listcomp>(.0)
#     675             # Redirect resolving generator.
#     676             gen = self.resolve_redirects(r, request, **kwargs)
# --> 677             history = [resp for resp in gen]
#     678         else:
#     679             history = []
#
# C:\anaconda3\lib\site-packages\requests\sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     235             else:
#     236
# --> 237                 resp = self.send(
#     238                     req,
#     239                     stream=stream,
#
# C:\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# C:\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# C:\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# C:\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# C:\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# C:\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# C:\anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# C:\anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# C:\anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# C:\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# C:\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# C:\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
len(links)
# Out:
# 5499

# %%
#drop duplicates subset keep
links = list(set(links))

# %%
i
# Out:
# 131

# %%
#del after

# %%
jlook = mysoup('https://miuz.ru/catalog/rings/R2022-MSR501/')

# %%
jgems = jlook.select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)')

# %%
type(jgems)
# Out:
# bs4.element.ResultSet

# %%
jlook.find_all('div','detail__item-option')[2].text
# Out:
# 'Камни:\n                    28  Бриллиантов огранки "Круглая" граней - 57, тип огранки A, цвет 3, чистота 6, 0.21 карат;4  Бриллианта огранки "Круглая" граней - 57, тип огранки A, цвет 3, чистота 6, 0.023 карат;12  Бриллиантов огранки "Круглая" граней - 57, тип огранки A, цвет 3, чистота 6, 0.105 карат;12  Бриллиантов огранки "Круглая" граней - 57, тип огранки A, цвет 3, чистота 6, 0.114 карат;4  Бриллианта огранки "Круглая" граней - 57, тип огранки A, цвет 3, чистота 6, 0.084 карат;2  Бриллианта огранки "Багет" граней - 25, тип огранки A, цвет 3, чистота 5, 0.068 карат;2  Бриллианта огранки "Багет" граней - 25, тип огранки A, цвет 3, чистота 5, 0.067 карат;3  Бриллианта огранки "Багет" граней - 25, тип огранки A, цвет 3, чистота 5, 0.325 карат; '

# %%
<div class="detail__item-option"><span>Камни:</span>
                    28  Бриллиантов огранки "Круглая" граней - 57, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/cutForm/'); event.stopPropagation();">тип огранки</span> A, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/razmer-tsvet-ves/'); event.stopPropagation();">цвет</span> 3, <span class="href" onclick="event.preventDefault(); window.open('/guide/quality/chistota-brillianta/'); event.stopPropagation();">чистота</span> 6, 0.21 карат;<br>4  Бриллианта огранки "Круглая" граней - 57, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/cutForm/'); event.stopPropagation();">тип огранки</span> A, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/razmer-tsvet-ves/'); event.stopPropagation();">цвет</span> 3, <span class="href" onclick="event.preventDefault(); window.open('/guide/quality/chistota-brillianta/'); event.stopPropagation();">чистота</span> 6, 0.023 карат;<br>12  Бриллиантов огранки "Круглая" граней - 57, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/cutForm/'); event.stopPropagation();">тип огранки</span> A, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/razmer-tsvet-ves/'); event.stopPropagation();">цвет</span> 3, <span class="href" onclick="event.preventDefault(); window.open('/guide/quality/chistota-brillianta/'); event.stopPropagation();">чистота</span> 6, 0.105 карат;<br>12  Бриллиантов огранки "Круглая" граней - 57, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/cutForm/'); event.stopPropagation();">тип огранки</span> A, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/razmer-tsvet-ves/'); event.stopPropagation();">цвет</span> 3, <span class="href" onclick="event.preventDefault(); window.open('/guide/quality/chistota-brillianta/'); event.stopPropagation();">чистота</span> 6, 0.114 карат;<br>4  Бриллианта огранки "Круглая" граней - 57, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/cutForm/'); event.stopPropagation();">тип огранки</span> A, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/razmer-tsvet-ves/'); event.stopPropagation();">цвет</span> 3, <span class="href" onclick="event.preventDefault(); window.open('/guide/quality/chistota-brillianta/'); event.stopPropagation();">чистота</span> 6, 0.084 карат;<br>2  Бриллианта огранки "Багет" граней - 25, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/cutForm/'); event.stopPropagation();">тип огранки</span> A, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/razmer-tsvet-ves/'); event.stopPropagation();">цвет</span> 3, <span class="href" onclick="event.preventDefault(); window.open('/guide/quality/chistota-brillianta/'); event.stopPropagation();">чистота</span> 5, 0.068 карат;<br>2  Бриллианта огранки "Багет" граней - 25, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/cutForm/'); event.stopPropagation();">тип огранки</span> A, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/razmer-tsvet-ves/'); event.stopPropagation();">цвет</span> 3, <span class="href" onclick="event.preventDefault(); window.open('/guide/quality/chistota-brillianta/'); event.stopPropagation();">чистота</span> 5, 0.067 карат;<br>3  Бриллианта огранки "Багет" граней - 25, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/cutForm/'); event.stopPropagation();">тип огранки</span> A, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/razmer-tsvet-ves/'); event.stopPropagation();">цвет</span> 3, <span class="href" onclick="event.preventDefault(); window.open('/guide/quality/chistota-brillianta/'); event.stopPropagation();">чистота</span> 5, 0.325 карат;<br>                </div>

# %%
re.findall(r'<div class="detail__item-option"><span>Камни:</span>[\w\W]+?\s*</div>',str(jlook))[0]
# Out:
# '<div class="detail__item-option"><span>Камни:</span>\n                    28  Бриллиантов огранки "Круглая" граней - 57, <span class="href" onclick="event.preventDefault(); window.open(\'/guide/stones/dragotsennye-kamni/brilliant/cutForm/\'); event.stopPropagation();">тип огранки</span> A, <span class="href" onclick="event.preventDefault(); window.open(\'/guide/stones/dragotsennye-kamni/brilliant/razmer-tsvet-ves/\'); event.stopPropagation();">цвет</span> 3, <span class="href" onclick="event.preventDefault(); window.open(\'/guide/quality/chistota-brillianta/\'); event.stopPropagation();">чистота</span> 6, 0.21 карат;<br/>4  Бриллианта огранки "Круглая" граней - 57, <span class="href" onclick="event.preventDefault(); window.open(\'/guide/stones/dragotsennye-kamni/brilliant/cutForm/\'); event.stopPropagation();">тип огранки</span> A, <span class="href" onclick="event.preventDefault(); window.open(\'/guide/stones/dragotsennye-kamni/brilliant/razmer-tsvet-ves/\'); event.stopPropagation();">цвет</span> 3, <span class="href" onclick="event.preventDefault(); window.open(\'/guide/quality/chistota-brillianta/\'); event.stopPropagation();">чистота</span> 6, 0.023 карат;<br/>12  Бриллиантов огранки "Круглая" граней - 57, <span class="href" onclick="event.preventDefault(); window.open(\'/guide/stones/dragotsennye-kamni/brilliant/cutForm/\'); event.stopPropagation();">тип огранки</span> A, <span class="href" onclick="event.preventDefault(); window.open(\'/guide/stones/dragotsennye-kamni/brilliant/razmer-tsvet-ves/\'); event.stopPropagation();">цвет</span> 3, <span class="href" onclick="event.preventDefault(); window.open(\'/guide/quality/chistota-brillianta/\'); event.stopPropagation();">чистота</span> 6, 0.105 карат;<br/>12  Бриллиантов огранки "Круглая" граней - 57, <span class="href" onclick="event.preventDefault(); window.open(\'/guide/stones/dragotsennye-kamni/brilliant/cutForm/\'); event.stopPropagation();">тип огранки</span> A, <span class="href" onclick="event.preventDefault(); window.open(\'/guide/stones/dragotsennye-kamni/brilliant/razmer-tsvet-ves/\'); event.stopPropagation();">цвет</span> 3, <span class="href" onclick="event.preventDefault(); window.open(\'/guide/quality/chistota-brillianta/\'); event.stopPropagation();">чистота</span> 6, 0.114 карат;<br/>4  Бриллианта огранки "Круглая" граней - 57, <span class="href" onclick="event.preventDefault(); window.open(\'/guide/stones/dragotsennye-kamni/brilliant/cutForm/\'); event.stopPropagation();">тип огранки</span> A, <span class="href" onclick="event.preventDefault(); window.open(\'/guide/stones/dragotsennye-kamni/brilliant/razmer-tsvet-ves/\'); event.stopPropagation();">цвет</span> 3, <span class="href" onclick="event.preventDefault(); window.open(\'/guide/quality/chistota-brillianta/\'); event.stopPropagation();">чистота</span> 6, 0.084 карат;<br/>2  Бриллианта огранки "Багет" граней - 25, <span class="href" onclick="event.preventDefault(); window.open(\'/guide/stones/dragotsennye-kamni/brilliant/cutForm/\'); event.stopPropagation();">тип огранки</span> A, <span class="href" onclick="event.preventDefault(); window.open(\'/guide/stones/dragotsennye-kamni/brilliant/razmer-tsvet-ves/\'); event.stopPropagation();">цвет</span> 3, <span class="href" onclick="event.preventDefault(); window.open(\'/guide/quality/chistota-brillianta/\'); event.stopPropagation();">чистота</span> 5, 0.068 карат;<br/>2  Бриллианта огранки "Багет" граней - 25, <span class="href" onclick="event.preventDefault(); window.open(\'/guide/stones/dragotsennye-kamni/brilliant/cutForm/\'); event.stopPropagation();">тип огранки</span> A, <span class="href" onclick="event.preventDefault(); window.open(\'/guide/stones/dragotsennye-kamni/brilliant/razmer-tsvet-ves/\'); event.stopPropagation();">цвет</span> 3, <span class="href" onclick="event.preventDefault(); window.open(\'/guide/quality/chistota-brillianta/\'); event.stopPropagation();">чистота</span> 5, 0.067 карат;<br/>3  Бриллианта огранки "Багет" граней - 25, <sp ...

# %%
re.search(r'Камни:\s+([\w\W]+)', str(div_gems[0].text.strip()))[1]

# %%
jgems[0].text
# Out:
# 'Камни:\n                    28  Бриллиантов огранки "Круглая" граней - 57, тип огранки A, цвет 3, чистота 6, 0.21 карат;4  Бриллианта огранки "Круглая" граней - 57, тип огранки A, цвет 3, чистота 6, 0.023 карат;12  Бриллиантов огранки "Круглая" граней - 57, тип огранки A, цвет 3, чистота 6, 0.105 карат;12  Бриллиантов огранки "Круглая" граней - 57, тип огранки A, цвет 3, чистота 6, 0.114 карат;4  Бриллианта огранки "Круглая" граней - 57, тип огранки A, цвет 3, чистота 6, 0.084 карат;2  Бриллианта огранки "Багет" граней - 25, тип огранки A, цвет 3, чистота 5, 0.068 карат;2  Бриллианта огранки "Багет" граней - 25, тип огранки A, цвет 3, чистота 5, 0.067 карат;3  Бриллианта огранки "Багет" граней - 25, тип огранки A, цвет 3, чистота 5, 0.325 карат; '

# %%
data = pd.DataFrame(columns=['h1','art','price','gold','weight','gems','url'])

# %%
 pd.options.display.max_colwidth = 200

# %%
urlcard = domain +links[0]
urlcard
# Out:
# 'https://miuz.ru/catalog/rings/R01-SOL59-025-G3/'

# %%
data

# %%
#отладка ручной прогон

# %%
urlcard = 'https://miuz.ru/catalog/rings/R01-ALR52-090-G1/'

# %%
card = mysoup(urlcard)

# %%
card
# Out:
# <!DOCTYPE html>
# <html lang="ru">
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# product: http://ogp.me/ns/product#">
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="no-referrer-when-downgrade" name="referrer"/>
# <meta content="_qgYWIuV2xT0oumXLChfyILXpWboP-DV-NzpKDk2EOs" name="google-site-verification"/>
# <meta content="Предлагаем купить Кольцо c бриллиантом, артикул R01-ALR52-090-G1, Золото 585,  – цены в каталоге интернет-магазина Московский ювелирный завод, телефон: 8 (800) 100-19-20." name="description"/>
# <meta content="product" property="og:type"/>
# <meta content="https://miuz.ru/catalog/rings/R01-ALR52-090-G1/" property="og:url"/>
# <meta content="Кольцо c бриллиантом Артикул R01-ALR52-090-G1" property="og:title"/>
# <meta content="Предлагаем купить Кольцо c бриллиантом, артикул R01-ALR52-090-G1, Золото 585,  – цены в каталоге интернет-магазина Московский ювелирный завод, телефон: 8 (800) 100-19-20." property="og:description"/>
# <meta content="https://miuz.ru/upload/resize_cache/iblock/af1/580_580_0/R01_ALR52_090_G1.jpg" property="og:image"/>
# <meta content="510" property="og:image:width"/>
# <meta content="228" property="og:image:height"/>
# <meta content="1051194.00" property="product:original_price:amount"/>
# <meta content="RUB" property="product:original_price:currency"/>
# <meta content="instock" property="product:availability"/>
# <base href="https://miuz.ru/"/>
# <meta content="telephone=no" name="format-detection"/>
# <!--<script src="/miuz/theme/js/libs/zoom/jquery.elevateZoom-3.0.8.min.js"></script>-->
# <script async="" src="https://api-maps.yandex.ru/2.1/?lang=ru_RU"></script>
# <style>
#             @font-face {
#                 font-family: 'pt_sansregular';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/pts55f-webfont.eot');
#                 src: url('/miuz/theme/fonts/pts55f-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/pts55f-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/pts55f-webfont.woff') format('woff'), url('/miuz/theme/fonts/pts55f-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/pts55f-webfont.svg#pt_sansregular') format('svg');
#                 font-weight: normal;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'circe';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/crc15-webfont.eot');
#                 src: url('/miuz/theme/fonts/crc15-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/crc15-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/crc15-webfont.woff') format('woff'), url('/miuz/theme/fonts/crc15-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/crc15-webfont.svg#circe_thinthin') format('svg');
#                 font-weight: 100;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'circe';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/crc25-webfont.eot');
#                 src: url('/miuz/theme/fonts/crc25-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/crc25-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/crc25-webfont.woff') format('woff'), url('/miuz/theme/fonts/crc25-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/crc25-webfont.svg#circeextra_light') format('svg');
#                 font-weight: 200;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'circe';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/crc35-webfont.eot');
#                 src: url('/miuz/theme/fonts/crc35-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/crc35-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/crc35-webfont.woff') format('woff'), url('/miuz/theme/fonts/crc35-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/crc35-webfont.svg#circelight') format('svg');
#                 font-weight: 300;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'circe';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/crc55-webfont.eot');
#                 src: url('/miuz/theme/fonts/crc55-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/crc55-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/crc55-webfont.woff') format('woff'), url('/miuz/theme/fonts/crc55-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/crc55-webfont.svg#circeregular') format('svg');
#                 font-weight: 500;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'circe';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/crc65-webfont.eot');
#                 src: url('/miuz/theme/fonts/crc65-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/crc65-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/crc65-webfont.woff') format('woff'), url('/miuz/theme/fonts/crc65-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/crc65-webfont.svg#circebold') format('svg');
#                 font-weight: 600;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'circe';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/crc75-webfont.eot');
#                 src: url('/miuz/theme/fonts/crc75-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/crc75-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/crc75-webfont.woff') format('woff'), url('/miuz/theme/fonts/crc75-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/crc75-webfont.svg#circeextra_bold') format('svg');
#                 font-weight: 700;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'ABodoniNova';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/a_bodoninova-webfont.eot');
#                 src: url('/miuz/theme/fonts/a_bodoninova-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/a_bodoninova-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/a_bodoninova-webfont.woff') format('woff'), url('/miuz/theme/fonts/a_bodoninova-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/a_bodoninova-webfont.svg#a_bodoninovaregular') format('svg');
#                 font-weight: 400;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'ABodoniNova';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/a_bodoninova_bold-webfont.eot');
#                 src: url('/miuz/theme/fonts/a_bodoninova_bold-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/a_bodoninova_bold-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/a_bodoninova_bold-webfont.woff') format('woff'), url('/miuz/theme/fonts/a_bodoninova_bold-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/a_bodoninova_bold-webfont.svg#a_bodoninovabold') format('svg');
#                 font-weight: 700;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'ABodoniNova';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/a_bodoninova_bolditalic-webfont.eot');
#                 src: url('/miuz/theme/fonts/a_bodoninova_bolditalic-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/a_bodoninova_bolditalic-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/a_bodoninova_bolditalic-webfont.woff') format('woff'), url('/miuz/theme/fonts/a_bodoninova_bolditalic-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/a_bodoninova_bolditalic-webfont.svg#a_bodoninovabolditalic') format('svg');
#                 font-weight: 700;
#                 font-style: italic;
#             }
#             @font-face {
#                 font-family: 'ABodoniNova';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/a_bodoninova_italic-webfont.eot');
#                 src: url('/miuz/theme/fonts/a_bodoninova_italic-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/a_bodoninova_italic-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/a_bodoninova_italic-webfont.woff') format('woff'), url('/miuz/theme/fonts/a_bodoninova_italic-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/a_bodoninova_italic-webfont.svg#a_bodoninovaitalic') format('svg');
#                 font-weight: 400;
#                 font-style: italic;
#             }
#             @font-face {
#                 font-family: 'FuturaPT';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/futuraptbold-webfont.eot');
#                 src: url('/miuz/theme/fonts/futuraptbold-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/futuraptbold-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/futuraptbold-webfont.woff') format('woff'), url('/miuz/theme/fonts/futuraptbold-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/futuraptbold-webfont.svg#futura_ptbold') format('svg');
#                 font-weight: 700;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'FuturaPT';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/futuraptboldoblique-webfont.eot');
#                 src: url('/miuz/theme/fonts/futuraptboldoblique-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/futuraptboldoblique-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/futuraptboldoblique-webfont.woff') format('woff'), url('/miuz/theme/fonts/futuraptboldoblique-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/futuraptboldoblique-webfont.svg#futura_pt_bold_italicregular') format('svg');
#                 font-weight: 700;
#                 font-style: italic;
#             }
#             @font-face {
#                 font-family: 'FuturaPT';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/futuraptbook-webfont.eot');
#                 src: url('/miuz/theme/fonts/futuraptbook-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/futuraptbook-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/futuraptbook-webfont.woff') format('woff'), url('/miuz/theme/fonts/futuraptbook-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/futuraptbook-webfont.svg#futura_ptbook') format('svg');
#                 font-weight: 400;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'FuturaPT';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/futuraptbookoblique-webfont.eot');
#                 src: url('/miuz/theme/fonts/futuraptbookoblique-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/futuraptbookoblique-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/futuraptbookoblique-webfont.woff') format('woff'), url('/miuz/theme/fonts/futuraptbookoblique-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/futuraptbookoblique-webfont.svg#futura_pt_book_italicregular') format('svg');
#                 font-weight: 400;
#                 font-style: italic;
#             }
#             @font-face {
#                 font-family: 'FuturaPT';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/futuraptdemi-webfont.eot');
#                 src: url('/miuz/theme/fonts/futuraptdemi-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/futuraptdemi-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/futuraptdemi-webfont.woff') format('woff'), url('/miuz/theme/fonts/futuraptdemi-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/futuraptdemi-webfont.svg#futura_ptdemi') format('svg');
#                 font-weight: 600;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'FuturaPT';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/futuraptextrabold-webfont.eot');
#                 src: url('/miuz/theme/fonts/futuraptextrabold-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/futuraptextrabold-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/futuraptextrabold-webfont.woff') format('woff'), url('/miuz/theme/fonts/futuraptextrabold-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/futuraptextrabold-webfont.svg#futura_ptextra_bold') format('svg');
#                 font-weight: 900;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'FuturaPT';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/futuraptheavy-webfont.eot');
#                 src: url('/miuz/theme/fonts/futuraptheavy-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/futuraptheavy-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/futuraptheavy-webfont.woff') format('woff'), url('/miuz/theme/fonts/futuraptheavy-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/futuraptheavy-webfont.svg#futura_ptheavy') format('svg');
#                 font-weight: 800;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'FuturaPT';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/futuraptlight-webfont.eot');
#                 src: url('/miuz/theme/fonts/futuraptlight-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/futuraptlight-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/futuraptlight-webfont.woff') format('woff'), url('/miuz/theme/fonts/futuraptlight-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/futuraptlight-webfont.svg#futura_ptlight') format('svg');
#                 font-weight: 300;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'FuturaPT';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/futuraptmedium-webfont.eot');
#                 src: url('/miuz/theme/fonts/futuraptmedium-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/futuraptmedium-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/futuraptmedium-webfont.woff') format('woff'), url('/miuz/theme/fonts/futuraptmedium-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/futuraptmedium-webfont.svg#futura_ptmedium') format('svg');
#                 font-weight: 500;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'PT Serif';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/PTSerif-Regular.eot');
#                 src: url('/miuz/theme/fonts/PTSerif-Regular.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/PTSerif-Regular.woff') format('woff'), url('/miuz/theme/fonts/PTSerif-Regular.ttf') format('truetype'), url('/miuz/theme/fonts/PTSerif-Regular.svg#PTSerif-Regular') format('svg');
#                 font-weight: 400;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'Diploma Script Basic';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/latinotype-diploma-script-basic.eot');
#                 src: url('/miuz/theme/fonts/latinotype-diploma-script-basic.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/latinotype-diploma-script-basic.woff2') format('woff2'), url('/miuz/theme/fonts/latinotype-diploma-script-basic.woff') format('woff'), url('/miuz/theme/fonts/latinotype-diploma-script-basic.ttf') format('truetype'), url('/miuz/theme/fonts/latinotype-diploma-script-basic.svg#DiplomaScript-Basic') format('svg');
#                 font-weight: 400;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'Gabriela Stencil Black';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/latinotype-gabriela-stencil-black.eot');
#                 src: url('/miuz/theme/fonts/latinotype-gabriela-stencil-black.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/latinotype-gabriela-stencil-black.woff2') format('woff2'), url('/miuz/theme/fonts/latinotype-gabriela-stencil-black.woff') format('woff'), url('/miuz/theme/fonts/latinotype-gabriela-stencil-black.ttf') format('truetype'), url('/miuz/theme/fonts/latinotype-gabriela-stencil-black.svg#GabrielaStencil-Black') format('svg');
#                 font-weight: 400;
#                 font-style: normal;
#             }
#         </style>
# <!--[if lt IE 9]>
#         <script src="http://html5shiv.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <title>Кольцо c бриллиантом, артикул R01-ALR52-090-G1, Золото 585,  - купить в интернет-магазине Московский ювелирный завод</title>
# <script async="" src="//static.criteo.net/js/ld/ld.js"></script>
# <script>
#             window.criteo_q = window.criteo_q || [];
#             window.criteo_q.push(
#                 {event:"setAccount", account:34906},
#                 {event:"setSiteType", type:"d"},
#                 {event:"setEmail", email:""}
#             );
#         </script>
# <script>
#             const RTB_HOUSE_UID = "unknown";
#         </script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="/bitrix/cache/css/s1/muz/page_d2e5973148e9adcfd4f259abb66b5563/page_d2e5973148e9adcfd4f259abb66b5563_v1.css?1635844522441" rel="stylesheet" type="text/css"/>
# <link data-template-style="true" href="/bitrix/cache/css/s1/muz/template_a7d7562c40b1c14f30c22935a60706db/template_a7d7562c40b1c14f30c22935a60706db_v1.css?1635844522865508" rel="stylesheet" type="text/css"/>
# <script>if(!window.BX)window.BX={};if(!window.BX.message)window.BX.message=function(mess){if(typeof mess=='object') for(var i in mess) BX.message[i]=mess[i]; return true;};</script>
# <script>(window.BX||top.BX).message({'JS_CORE_LOADING':'Загрузка...','JS_CORE_NO_DATA':'- Нет данных -','JS_CORE_WINDOW_CLOSE':'Закрыть','JS_CORE_WINDOW_EXPAND':'Развернуть','JS_CORE_WINDOW_NARROW':'Свернуть в окно','JS_CORE_WINDOW_SAVE':'Сохранить','JS_CORE_WINDOW_CANCEL':'Отменить','JS_CORE_WINDOW_CONTINUE':'Продолжить','JS_CORE_H':'ч','JS_CORE_M':'м','JS_CORE_S':'с','JSADM_AI_HIDE_EXTRA':'Скрыть лишние','JSADM_AI_ALL_NOTIF':'Показать все','JSADM_AUTH_REQ':'Требуется авторизация!','JS_CORE_WINDOW_AUTH':'Войти','JS_CORE_IMAGE_FULL':'Полный размер'});</script>
# <script src="/bitrix/js/main/core/core.min.js?1592347382249634"></script>
# <script>BX.setJSList(['/bitrix/js/main/core/core_ajax.js','/bitrix/js/main/core/core_promise.js','/bitrix/js/main/polyfill/promise/js/promise.js','/bitrix/js/main/loadext/loadext.js','/bitrix/js/main/loadext/extension.js','/bitrix/js/main/polyfill/promise/js/promise.js','/bitrix/js/main/polyfill/find/js/find.js','/bitrix/js/main/polyfill/includes/js/includes.js','/bitrix/js/main/polyfill/matches/js/matches.js','/bitrix/js/ui/polyfill/closest/js/closest.js','/bitrix/js/main/polyfill/fill/main.polyfill.fill.js','/bitrix/js/main/polyfill/find/js/find.js','/bitrix/js/main/polyfill/matches/js/matches.js','/bitrix/js/main/polyfill/core/dist/polyfill.bundle.js','/bitrix/js/main/core/core.js','/bitrix/js/main/polyfill/intersectionobserver/js/intersectionobserver.js','/bitrix/js/main/lazyload/dist/lazyload.bundle.js','/bitrix/js/main/polyfill/core/dist/polyfill.bundle.js','/bitrix/js/main/parambag/dist/parambag.bundle.js']);
# BX.setCSSList(['/bitrix/js/main/core/css/core.css','/bitrix/js/main/lazyload/dist/lazyload.bundle.css','/bitrix/js/main/parambag/dist/parambag.bundle.css']);</script>
# <script>(window.BX||top.BX).message({'LANGUAGE_ID':'ru','FORMAT_DATE':'DD.MM.YYYY','FORMAT_DATETIME':'DD.MM.YYYY HH:MI:SS','COOKIE_PREFIX':'BITRIX_SM','SERVER_TZ_OFFSET':'10800','SITE_ID':'s1','SITE_DIR':'/','USER_ID':'','SERVER_TIME':'1637028815','USER_TZ_OFFSET':'0','USER_TZ_AUTO':'Y','bitrix_sessid':'f64525c200340f4c34a2493dbc5dd325'});</script>
# <script>BX.setJSList(['/local/components/aero/catalog/templates/aero/miuz/catalog.section/catalogElement/script.js','/local/js/miuz/rtb/dist/rtb.js','/miuz/theme/js/libs/bitrix.js','/miuz/theme/js/libs/jquery-3.3.1.min.js','/miuz/theme/js/libs/jquery-2.1.1.min.js','/miuz/theme/js/libs/zoom/jquery.elevatezoom.min.js','/miuz/theme/js/libs/lazyload.min.js','/local/templates/muz/js/slick.min.js','/local/templates/muz/js/jquery.inputmask.min.js','/miuz/theme/js/deviceDetect.min.js','/miuz/theme/js/libs/libs.min.js','/miuz/theme/js/components/Application.js','/local/templates/muz/js/flipclock.min.js','/local/templates/muz/js/script.js','/local/templates/muz/js/metric.js','/miuz/theme/js/libs/magnific-popup/magnific-popup.min.js','/local/js/miuz/Soloway/class.js','/bitrix/components/bitrix/search.title/script.js','/local/templates/muz/components/bitrix/search.title/.default/script.js','/miuz/theme/js/components/Utils.js','/miuz/theme/js/components/Loader.js','/miuz/theme/js/components/Size.js','/miuz/theme/js/BView/GlobalView.js','/miuz/theme/js/BView/Header.js','/miuz/theme/js/BView/Shops.js','/miuz/theme/js/BView/Footer.js','/miuz/theme/js/BView/Default.js','/miuz/theme/js/BView/NotFound.js','/miuz/theme/js/BView/StopSending.js','/miuz/theme/js/BView/Home.js','/miuz/theme/js/libs/svg.min.js','/miuz/theme/js/BView/Catalog.js','/miuz/theme/js/BView/Detail.js','/miuz/theme/js/BView/Discount.js','/miuz/theme/js/BView/Text.js','/miuz/theme/js/BView/Certificate.js','/miuz/theme/js/BView/Contacts.js','/miuz/theme/js/BView/News.js','/miuz/theme/js/BView/Thank.js','/miuz/theme/js/BView/RegionShops.js','/miuz/theme/js/BView/Brilliant.js','/miuz/theme/js/BView/Lk.js','/miuz/theme/js/BView/Enter.js','/miuz/theme/js/BView/BrilliantPair.js','/miuz/theme/js/BView/Collection.js','/miuz/theme/js/BView/Connect.js','/miuz/theme/js/BView/Vacancy.js','/miuz/theme/js/BView/VacancyForm.js','/miuz/theme/js/BView/Vacancies.js','/miuz/theme/js/BView/Stones.js','/miuz/theme/js/BView/Care.js','/miuz/theme/js/BView/Search.js','/miuz/theme/js/BView/Emerald.js','/miuz/theme/js/BView/Diamond.js','/miuz/theme/js/BView/Products.js','/miuz/theme/js/BView/Product.js','/miuz/theme/js/BView/Weight.js','/miuz/theme/js/BView/Links.js','/miuz/theme/js/BView/Element.js','/miuz/theme/js/BView/History.js','/miuz/theme/js/BView/Admin.js','/miuz/theme/js/libs/jquery.mCustomScrollbar.concat.min.js','/miuz/theme/js/BView/RegionalContacts.js','/miuz/theme/js/Router.js','/miuz/theme/js/script.js','/local/js/miuz/garderobo/class.js']); </script>
# <script>BX.setCSSList(['/local/components/aero/catalog/templates/aero/miuz/catalog.section/catalogElement/style.css','/local/templates/muz/css/flipclock.css','/miuz/theme/css/swiper.min.css','/miuz/theme/css/chosen.min.css','/miuz/theme/css/bitrix.css','/miuz/theme/js/libs/jquery-ui/jquery-ui.min.css','/miuz/theme/js/libs/fancybox/jquery.fancybox.min.css','/miuz/theme/generator.css','/miuz/theme/template_styles.css','/local/templates/muz/css/landings/slick.css','/miuz/theme/js/libs/magnific-popup/magnific-popup.min.css','/local/templates/muz/components/bitrix/search.title/.default/style.css','/miuz/theme/css/jquery.mCustomScrollbar.min.css','/local/templates/muz/styles.css','/local/templates/muz/template_styles.css']); </script>
# <script>
# 					(function () {
# 						"use strict";
#
# 						var counter = function ()
# 						{
# 							var cookie = (function (name) {
# 								var parts = ("; " + document.cookie).split("; " + name + "=");
# 								if (parts.length == 2) {
# 									try {return JSON.parse(decodeURIComponent(parts.pop().split(";").shift()));}
# 									catch (e) {}
# 								}
# 							})("BITRIX_CONVERSION_CONTEXT_s1");
#
# 							if (cookie && cookie.EXPIRE >= BX.message("SERVER_TIME"))
# 								return;
#
# 							var request = new XMLHttpRequest();
# 							request.open("POST", "/bitrix/tools/conversion/ajax_counter.php", true);
# 							request.setRequestHeader("Content-type", "application/x-www-form-urlencoded");
# 							request.send(
# 								"SITE_ID="+encodeURIComponent("s1")+
# 								"&sessid="+encodeURIComponent(BX.bitrix_sessid())+
# 								"&HTTP_REFERER="+encodeURIComponent(document.referrer)
# 							);
# 						};
#
# 						if (window.frameRequestStart === true)
# 							BX.addCustomEvent("onFrameDataReceived", counter);
# 						else
# 							BX.ready(counter);
# 					})();
# 				</script>
# <link as="font" crossorigin="" href="/miuz/theme/fonts/crc35-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/miuz/theme/fonts/crc65-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/miuz/theme/fonts/futuraptlight-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/miuz/theme/fonts/futuraptdemi-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/miuz/theme/fonts/futuraptbold-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/miuz/theme/fonts/futuraptbook-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="image" href="/miuz/theme/images/logo_msk.svg" rel="preload"/>
# <link as="image" href="/miuz/theme/images/car.svg" rel="preload"/>
# <link as="image" href="/miuz/theme/images/icons/search.svg" rel="preload"/>
# <link as="image" href="/miuz/theme/images/background__counter.svg" rel="preload"/>
# <link as="image" href="/miuz/theme/images/pixel.gif" rel="preload"/>
# <link as="image" href="/miuz/theme/images/box-brilliant.png" rel="preload"/>
# <link as="image" href="/miuz/theme/images/icons/spritesheet.png" rel="preload"/>
# <link as="image" href="/miuz/theme/images/icons/spritesheet_new.png" rel="preload"/>
# <link as="image" href="/miuz/theme/images/icons/ico-help-grey.png" rel="preload"/>
# <link as="image" href="/miuz/theme/images/icons/viber.svg" rel="preload"/>
# <script async="" src="https://www.youtube.com/iframe_api"></script>
# <link href="//google-analytics.com" rel="preconnect"/>
# <link href="//mc.yandex.ru/" rel="preconnect"/>
# <link href="//top-fwz1.mail.ru" rel="preconnect"/>
# <script>window.criteo_q.push({event:"viewItem", item:"R01-ALR52-090-G1"});</script>
# <script>if (typeof(window.fbq) !== "undefined") fbq.push(["track", "ViewContent", {content_type: "product", content_ids:["R01-ALR52-090-G1"]}]);</script>
# <script>
#             dataLayer = [
#                 {"pageType":"ProductPage","City":"","product":{"groupId":3612899,"name":"Кольцо c бриллиантом","price":1051194,"oldPrice":1751990,"pictureUrl":"https://miuz.ru/upload/resize_cache/iblock/af1/200_200_2/R01_ALR52_090_G1.jpg","url":"https://miuz.ru/catalog/rings/R01-ALR52-090-G1/","model":"R01-ALR52-090-G1","vendor":"МЮЗ","params":{"minPrice":1051194,"minOldPrice":1751990,"delivery":false},"isAvailable":true,"categoryPaths":"Кольца/Кольца c бриллиантом/","description":"","typePrefix":"Кольца"}}
#             ];
#         </script>
# <script src="/bitrix/cache/js/s1/muz/template_fadc3e3f5ad71b2793863d9c56f70b04/template_fadc3e3f5ad71b2793863d9c56f70b04_v1.js?16358445221630789"></script>
# <script src="/bitrix/cache/js/s1/muz/page_cb20c4f9247ab90a5cf9f35b420ba12d/page_cb20c4f9247ab90a5cf9f35b420ba12d_v1.js?16358445221790"></script>
# <script>
#             (function (window) {
#                 var BX = window.BX;
#                 if (BX && BX.rtb)
#                 {
#                     BX.rtb("unknown").productPage("R01-ALR52-090-G1");
#                 }
#             })(window);
#         </script>
# <script>var _ba = _ba || []; _ba.push(["aid", "f93e9ffc96fa98b7372d25c0882bdc24"]); _ba.push(["host", "miuz.ru"]); _ba.push(["ad[ct][item]", "..."]);_ba.push(["ad[ct][user_id]", function(){return BX.message("USER_ID") ? BX.message("USER_ID") : 0;}]);_ba.push(["ad[ct][recommendation]", function() {var rcmId = "";var cookieValue = BX.getCookie("BITRIX_SM_RCM_PRODUCT_LOG");var productId = 3612899;var cItems = [];var cItem;if (cookieValue){cItems = cookieValue.split(".");}var i = cItems.length;while (i--){cItem = cItems[i].split("-");if (cItem[0] == productId){rcmId = cItem[1];break;}}return rcmId;}]);_ba.push(["ad[ct][v]", "2"]);(function() {var ba = document.createElement("script"); ba.type = "text/javascript"; ba.async = true;ba.src = (document.location.protocol == "https:" ? "https://" : "http://") + "bitrix.info/ba.js";var s = document.getElementsByTagName("script")[0];s.parentNode.insertBefore(ba, s);})();</script>
# <script>
#             var baseWidth = 1280,
#                 baseSize = 10,
#                 $html = $('html')
#             ;
#             _helper();
#             function _helper() {
#                 //alert($(window).width());
#                 if ($(window).width() <= 840) {
#                     baseWidth = 840;
#                     $html.addClass('mobile');
#                 } else {
#                     baseWidth = 1280;
#                     $html.removeClass('mobile');
#                 }
#                 $html.css({'font-size': Math.min($(window).width(), baseWidth) / baseWidth * baseSize + 'px'});
#             }
#         </script>
# <script>
#             if(typeof dataLayer === 'undefined'){dataLayer = [{}];}
#         </script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                 j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#             })(window,document,'script','dataLayer','GTM-KLWF6Q');</script>
# <!-- End Google Tag Manager -->
# <!-- Global site tag (gtag.js) - Google Marketing Platform -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=DC-10624467"></script>
# <script>
#                 window.dataLayer = window.dataLayer || [];
#                 function gtag(){dataLayer.push(arguments);}
#                 gtag('js', new Date());
#
#                 gtag('config', 'DC-10624467');
#             </script>
# <script>
#                     if (typeof gtag === "function")
#                     {
#                         gtag('event', 'conversion', {
#                             'allow_custom_scripts': true,
#                             'session_id': 'f64525c200340f4c34a2493dbc5dd325',
#                             'send_to': 'DC-10624467/nu4xl0/rsz0t0+per_session'
#                         });
#                     }
#                 </script>
# <!-- Конец тега Global Site Tag. Не удаляйте этот код. -->
# <script>(window.Image ? (new Image()) : document.createElement('img')).src = location.protocol + '//vk.com/rtrg?r=uo84IIIYoi3yi9qoajllOwYhzD9HvGkQaN64N3AdBKA4JQFwtErKNeZxUhsMNd1iqu5gmosY9EBs13tX3z9sxfer7Iyd4xJq7hjFGmzGxMjgmHn0gl*QfSA3/nlWRtbGhcs0xOHl287Juodk0zvroXPtHo/4XEH8rbDIt/g1KjA-&pixel_id=1000038746';</script>
# <meta content="PdzGF9gKngzRb8pU7zHgoeO64I4wqtsFmkMazZ4y0Pg" name="google-site-verification"/>
# <!--Google reCAPTCHA v3 -->
# <script async="async" src="https://api.flocktory.com/v2/loader.js?site_id=2253"></script>
# <script>
#             var MAX_PRICE_FOR_BUY_FORMAT = '600 000';
#
#         </script>
# <!--  Soloway -->
# <script>
#             Soloway.init();
#         </script>
# <script>
#         $(document).ready(function () {
#             var data_prod_id = $("[data-soloway-product-id]"),
#                 prod_id = "";
#
#             if(data_prod_id.length == 1){
#                 prod_id = data_prod_id.data("soloway-product-id");
#             }
#             document.dispatchEvent(new CustomEvent("allPagesSoloway", {
#                 detail:{ user_id: "", offer_id: prod_id }
#             }));
#         });
#     </script> <!--  Soloway -->
# </head>
# <body class="royal-white body">
# <!-- End Google Tag Manager (noscript) -->
# <div data-lazy-retailrocket-markup-block="57bdcde09872e52d20f1e2a6"></div>
# <div data-lazy-retailrocket-markup-block="57bddb6b9872e52d20f1e401"></div>
# <!-- Rating@Mail.ru counter -->
# <script>
#     var _tmr = window._tmr || (window._tmr = []);
#     _tmr.push({id: "3216462", type: "pageView", start: (new Date()).getTime()});
#     (function (d, w, id) {
#         if (d.getElementById(id)) return;
#         var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#         ts.src = "https://top-fwz1.mail.ru/js/code.js";
#         var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#         if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
#     })(document, window, "topmailru-code");
# </script><noscript><div>
# <img alt="Top.Mail.Ru" src="https://top-fwz1.mail.ru/counter?id=3216462;js=na" style="border:0;position:absolute;left:-9999px;"/>
# </div></noscript>
# <!-- //Rating@Mail.ru counter -->
# <!-- Yandex.Metrika counter -->
# <script>
#     (function (d, w, c) {
#         (w[c] = w[c] || []).push(function() {
#             try {
#                 w.yaCounter5911648 = new Ya.Metrika({
#                     id:5911648,
#                     clickmap:true,
#                     trackLinks:true,
#                     accurateTrackBounce:true,
#                     webvisor:true,
#                     ecommerce:"dataLayer"
#                 });
#             } catch(e) { }
#         });
#
#         var n = d.getElementsByTagName("script")[0],
#             s = d.createElement("script"),
#             f = function () { n.parentNode.insertBefore(s, n); };
#         s.type = "text/javascript";
#         s.async = true;
#         s.src = "https://mc.yandex.ru/metrika/watch.js";
#
#         if (w.opera == "[object Opera]") {
#             d.addEventListener("DOMContentLoaded", f, false);
#         } else { f(); }
#     })(document, window, "yandex_metrika_callbacks");
# </script>
# <noscript><div><img alt="" src="https://mc.yandex.ru/watch/5911648" style="position:absolute; left:-9999px;"/></div></noscript>
# <!-- /Yandex.Metrika counter -->
# <script>
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#     ga('create', 'UA-10755722-3', 'auto');
#     ga(function(tracker) {
#         var clientId = tracker.get('clientId'); // получение clientId из Google Analytics
#         document.cookie = "_ga_cid=" + clientId + "; path=/"; // сохранение cookie в _ga_cid
#         ga('set', 'dimension1', clientId); //запись clientId для каждого пользователя
#     });
#     ga('send', 'pageview');
# </script>
# <!--<div class="loader js-loader">
#         <div class="loader_box"></div>
#     </div>-->
# <header class="header js-header">
# <div class="header__holder"></div>
# <div class="header__h" data-header-mob-indent=""></div>
# <div class="header__inner grid__inner js-header-fixed">
# <div class="header__left">
# <div class="href header__menu-btn" data-mob-menu-btn="">
# <div class="header__menu-btn-ico"></div>
# </div>
# <a class="header__tell" data-target="click_phone" href="tel:88001001920">8 (800) 100-19-20</a>
# <div class="header__city">
# <div class="city-select">
# <form action="/ajax/city.php" method="post">
# <select class="city-select__select" data-city-chosen="" name="CITY">
# <option value="Абакан">Абакан</option>
# <option value="Александров">Александров</option>
# <option value="Алматы">Алматы</option>
# <option value="Анапа">Анапа</option>
# <option value="Армавир">Армавир</option>
# <option value="Архангельск">Архангельск</option>
# <option value="Астрахань">Астрахань</option>
# <option value="Балашиха">Балашиха</option>
# <option value="Белгород">Белгород</option>
# <option value="Белебей">Белебей</option>
# <option value="Брянск">Брянск</option>
# <option value="Видное">Видное</option>
# <option value="Владивосток">Владивосток</option>
# <option value="Владикавказ">Владикавказ</option>
# <option value="Владимир">Владимир</option>
# <option value="Волгоград">Волгоград</option>
# <option value="Волгодонск">Волгодонск</option>
# <option value="Вологда">Вологда</option>
# <option value="Воронеж">Воронеж</option>
# <option value="Геленджик">Геленджик</option>
# <option value="Грозный">Грозный</option>
# <option value="Губкинский ЯНАО">Губкинский ЯНАО</option>
# <option value="Дзержинск">Дзержинск</option>
# <option value="Дмитров">Дмитров</option>
# <option value="Дубна">Дубна</option>
# <option value="Ейск">Ейск</option>
# <option value="Екатеринбург">Екатеринбург</option>
# <option value="Ессентуки">Ессентуки</option>
# <option value="Иваново">Иваново</option>
# <option value="Ижевск">Ижевск</option>
# <option value="Иркутск">Иркутск</option>
# <option value="Казань">Казань</option>
# <option value="Калининград">Калининград</option>
# <option value="Калуга">Калуга</option>
# <option value="Кемерово">Кемерово</option>
# <option value="Кинешма">Кинешма</option>
# <option value="Кисловодск">Кисловодск</option>
# <option value="Коломна">Коломна</option>
# <option value="Конаково">Конаково</option>
# <option value="Котельники">Котельники</option>
# <option value="Красногорск">Красногорск</option>
# <option value="Краснодар">Краснодар</option>
# <option value="Красноярск">Красноярск</option>
# <option value="Кропоткин">Кропоткин</option>
# <option value="Курган">Курган</option>
# <option value="Курск">Курск</option>
# <option value="Магнитогорск">Магнитогорск</option>
# <option value="Майкоп">Майкоп</option>
# <option value="Махачкала">Махачкала</option>
# <option value="Минеральные Воды">Минеральные Воды</option>
# <option value="Минск">Минск</option>
# <option value="Можайск">Можайск</option>
# <option value="Москва">Москва</option>
# <option value="Московский">Московский</option>
# <option value="Мурманск">Мурманск</option>
# <option value="Мытищи">Мытищи</option>
# <option value="Набережные Челны">Набережные Челны</option>
# <option value="Нальчик">Нальчик</option>
# <option value="Невинномысск">Невинномысск</option>
# <option value="Нефтеюганск">Нефтеюганск</option>
# <option value="Нижневартовск">Нижневартовск</option>
# <option value="Нижний Новгород">Нижний Новгород</option>
# <option value="Новоивановское">Новоивановское</option>
# <option value="Новокузнецк">Новокузнецк</option>
# <option value="Новороссийск">Новороссийск</option>
# <option value="Новосибирск">Новосибирск</option>
# <option value="Нур-Султан">Нур-Султан</option>
# <option value="Обнинск">Обнинск</option>
# <option value="Одинцово">Одинцово</option>
# <option value="Омск">Омск</option>
# <option value="Орел">Орел</option>
# <option value="Оренбург">Оренбург</option>
# <option value="Орехово-Зуево">Орехово-Зуево</option>
# <option value="Пенза">Пенза</option>
# <option value="Пермь">Пермь</option>
# <option value="Петрозаводск">Петрозаводск</option>
# <option value="Петропавловск-Камчатский">Петропавловск-Камчатский</option>
# <option value="Псков">Псков</option>
# <option value="Пушкино">Пушкино</option>
# <option value="Пятигорск">Пятигорск</option>
# <option value="Реутов">Реутов</option>
# <option value="Ржев">Ржев</option>
# <option value="Ростов-на-Дону">Ростов-на-Дону</option>
# <option value="Рязань">Рязань</option>
# <option value="Самара">Самара</option>
# <option value="Санкт-Петербург">Санкт-Петербург</option>
# <option value="Саратов">Саратов</option>
# <option value="Северодвинск">Северодвинск</option>
# <option value="Серпухов">Серпухов</option>
# <option value="Солнечногорск">Солнечногорск</option>
# <option value="Сочи">Сочи</option>
# <option value="Ставрополь">Ставрополь</option>
# <option value="Сургут">Сургут</option>
# <option value="Тверь">Тверь</option>
# <option value="Тольятти">Тольятти</option>
# <option value="Томск">Томск</option>
# <option value="Троицк">Троицк</option>
# <option value="Тула">Тула</option>
# <option value="Тюмень">Тюмень</option>
# <option value="Улан-Удэ">Улан-Удэ</option>
# <option value="Ульяновск">Ульяновск</option>
# <option value="Уфа">Уфа</option>
# <option value="Хабаровск">Хабаровск</option>
# <option value="Химки">Химки</option>
# <option value="Чебоксары">Чебоксары</option>
# <option value="Челябинск">Челябинск</option>
# <option value="Черкесск">Черкесск</option>
# <option value="Чита">Чита</option>
# <option value="Шахты">Шахты</option>
# <option value="Шымкент">Шымкент</option>
# <option value="Щелково">Щелково</option>
# <option value="Элиста">Элиста</option>
# <option value="Энгельс">Энгельс</option>
# <option value="Ярославль">Ярославль</option>
# <option value="пгт. Алексеевское">пгт. Алексеевское</option>
# </select>
# <div class="need_select_city" data-city="Москва">
# <div class="header__city-popup-arrow"></div>
# <div class="title">Ваш город <b>Москва</b>?</div>
# <div class="button_block">
# <button class="b-btn _red left">Да</button>
# <button class="b-btn _default right">Нет</button>
# </div>
# <div class="clear"></div>
# </div>
# </form>
# </div>
# </div>
# <div class="header__small-phone header__hide-mobile">
#                     Короткий номер:
#                     <span class="header__small-code"><span class="header__star"><span>*</span></span>1920</span>
# <div class="header__delivery-help-wrapper">
# <span class="header__delivery-help" data-phone-i="">i</span>
# <div class="header__delivery-help-message" data-phone-info="">
#                             Для абонентов Билайн, Мегафон, МТС, TELE2, Тинькофф мобайл.
#                         </div>
# </div>
# </div>
# </div>
# <div class="header__right"><a class="header__account b-ico__wrap link-border-solid" href="/auth/">
#                         Вход
#                     </a><a class="header__bascket b-ico__wrap link-border-solid" href="/personal/basket/">Корзина<!--<div class="header__bascket-count">--><!--</div>--></a> <div class="header__delivery">
# <div class="header__delivery-help-wrapper">
# <span class="header__delivery-help" data-delivery-i="">i</span>
# <div class="header__delivery-help-message" data-delivery-info="">
#                             Бесплатная доставка любого изделия.
#                             Заказы стоимостью от 200 тысяч рублей могут быть доставлены на дом после внесения 100% предоплаты безналичным способом или оплачены при получении в магазине.
#                         </div>
# </div>
#
#                     Бесплатная доставка
#                 </div>
# <span class="href header__search-mob" onclick="event.preventDefault();window.location.href='/search/';"></span>
# <a class="header__bascket-mob" href="/personal/basket/"></a>
# </div>
# <a class="header__logo" href="/">
# <!--<img alt="Официальный интернет-магазин производителя ювелирных украшений Московский ювелирный завод"
#      src=""/>-->
# <img alt="Официальный интернет-магазин производителя ювелирных украшений Московский ювелирный завод" src="/miuz/theme/images/logo_feb.png" title="Перейти на главную страницу"/>
# <img alt="Официальный интернет-магазин производителя ювелирных украшений Московский ювелирный завод" src="/miuz/theme/images/miuz_logo-02.svg" title="Перейти на главную страницу"/>
# </a>
# <div class="header__border-mob"></div>
# <div class="header__menu">
# <div class="header__menu-container">
# <div class="header__menu-droplink js-link-menu">
# <a class="header__menu-item _menu" href="/catalog/">
# <span class="title">Украшения</span>
# <span class="ico"></span>
# </a>
# <div class="header__menu-droplist _jewel" data-header-submenu="">
# <div class="header__flex-wrapper">
# <div class="col">
# <a class="col__title _active" data-header-submenu-photo-link-url="http://miuz.ru/catalog/rings/R97-MR17887-SA-PS/" data-header-submenu-photo-url="/upload/resize_cache/iblock/a05/280_280_2/R755_70643R001_R17.jpg" href="/catalog/rings/" title="Кольца">
# <img alt="Кольца" class="ico" src="/upload/uf/98f/koltsa.svg"/>
# <span class="title">Кольца
#                                             <span class="gold ib fix">(7532)</span>
# </span>
# </a>
# <div class="col__item">
# <a href="/catalog/rings/filter/stones_main-is-brilliant/">Кольца с бриллиантами</a>
# </div>
# <div class="col__item">
# <a href="/catalog/rings/filter/offers_metall-is-zoloto/">Золотые кольца</a>
# </div>
# <div class="col__item">
# <a href="/catalog/rings/filter/offers_metall-is-zoloto/offers_metall_color-is-belyy-zoloto/">Кольца из белого золота</a>
# </div>
# <div class="col__item">
# <a href="/catalog/rings/filter/collection-is-pomolvochnye_koltsa/">Помолвочные кольца</a>
# </div>
# <div class="col__item">
# <a href="/catalog/rings/filter/collection-is-obruchalnye_koltsa/">Обручальные кольца</a>
# </div>
# <a class="col__title" data-header-submenu-photo-link-url="http://miuz.ru/catalog/earrings/E97-CR2852E-SA/" data-header-submenu-photo-url="/upload/resize_cache/iblock/55d/280_280_2/E97_CR2852E_SA.jpg" href="/catalog/earrings/" title="Серьги">
# <img alt="Серьги" class="ico" src="/upload/uf/8a9/sergi.svg"/>
# <span class="title">Серьги
#                                             <span class="gold ib fix">(6322)</span>
# </span>
# </a>
# <div class="col__item">
# <a href="/catalog/earrings/filter/stones_main-is-brilliant/">Серьги с бриллиантами</a>
# </div>
# <div class="col__item">
# <a href="/catalog/earrings/filter/stones_main-is-sapfir/">С сапфирами</a>
# </div>
# <div class="col__item">
# <a href="/catalog/earrings/filter/stones_main-is-zhemchug/">С жемчугом</a>
# </div>
# <div class="col__item">
# <a href="/catalog/earrings/filter/offers_metall-is-zoloto/">Золотые серьги</a>
# </div>
# <div class="col__item">
# <a href="/catalog/earrings/filter/offers_metall-is-serebro/">Серебряные серьги</a>
# </div>
# <a class="col__title" data-header-submenu-photo-link-url="http://miuz.ru/catalog/pendants/P01-33583-SA/" data-header-submenu-photo-url="/upload/resize_cache/iblock/c57/280_280_2/p01_33583_sa.jpg" href="/catalog/pendants/" title="Подвески">
# <img alt="Подвески" class="ico" src="/upload/uf/4d0/podveski.svg"/>
# <span class="title">Подвески
#                                             <span class="gold ib fix">(1578)</span>
# </span>
# </a>
# <div class="col__item">
# <a href="/catalog/pendants/filter/stones_main-is-brilliant/">С бриллиантами</a>
# </div>
# <div class="col__item">
# <a href="/catalog/pendants/filter/offers_metall-is-zoloto/offers_metall_color-is-belyy-zoloto/">Из белого золота</a>
# </div>
# <div class="col__item">
# <a href="/catalog/pendants/filter/offers_metall-is-zoloto/">Золотые подвески</a>
# </div>
# <div class="col__item">
# <a href="/catalog/pendants/filter/offers_metall-is-serebro/">Серебряные подвески</a>
# </div>
# </div>
# <div class="col">
# <a class="col__title" data-header-submenu-photo-link-url="http://miuz.ru/catalog/necklace/N17-N00177-RU/" data-header-submenu-photo-url="/upload/resize_cache/iblock/7f7/280_280_2/N77_N49447_EM_R17.jpg" href="/catalog/necklace/" title="Колье">
# <img alt="Колье" class="ico" src="/upload/uf/b41/kole.svg"/>
# <span class="title">Колье
#                                             <span class="gold ib fix">(833)</span>
# </span>
# </a>
# <div class="col__item">
# <a href="/catalog/necklace/filter/stones_main-is-brilliant/">С бриллиантами</a>
# </div>
# <div class="col__item">
# <a href="/catalog/necklace/filter/stones_main-is-zhemchug/">С жемчугом</a>
# </div>
# <div class="col__item">
# <a href="/catalog/necklace/filter/offers_metall-is-zoloto/">Из золота</a>
# </div>
# <div class="col__item">
# <a href="/catalog/necklace/filter/offers_metall-is-serebro/">Из серебра</a>
# </div>
# <a class="col__title" data-header-submenu-photo-link-url="http://miuz.ru/catalog/bracelets/B01-RS-34175-MIX/" data-header-submenu-photo-url="/upload/resize_cache/iblock/09e/280_280_2/V4211_BG0702BRE1.jpg" href="/catalog/bracelets/" title="Браслеты">
# <img alt="Браслеты" class="ico" src="/upload/uf/7b9/braslety.svg"/>
# <span class="title">Браслеты
#                                             <span class="gold ib fix">(755)</span>
# </span>
# </a>
# <div class="col__item">
# <a href="/catalog/bracelets/filter/weaving_type-is-yakornoe/">Якорное</a>
# </div>
# <div class="col__item">
# <a href="/catalog/bracelets/filter/stones_main-is-brilliant/">С бриллиантами</a>
# </div>
# <div class="col__item">
# <a href="/catalog/bracelets/filter/stones_main-is-zhemchug/">С жемчугом</a>
# </div>
# <div class="col__item">
# <a href="/catalog/bracelets/filter/offers_metall-is-zoloto/">Золотые браслеты</a>
# </div>
# <div class="col__item">
# <a href="/catalog/bracelets/filter/offers_metall-is-serebro/">Серебряные браслеты</a>
# </div>
# ...
# </a>
# <a class="footer__bottom-item-social-item" href="http://instagram.com/miuz_ru" target="_blank">
# <svg viewbox="0 0 511 511.9" xmlns="http://www.w3.org/2000/svg"><path d="m510.949219 150.5c-1.199219-27.199219-5.597657-45.898438-11.898438-62.101562-6.5-17.199219-16.5-32.597657-29.601562-45.398438-12.800781-13-28.300781-23.101562-45.300781-29.5-16.296876-6.300781-34.898438-10.699219-62.097657-11.898438-27.402343-1.300781-36.101562-1.601562-105.601562-1.601562s-78.199219.300781-105.5 1.5c-27.199219 1.199219-45.898438 5.601562-62.097657 11.898438-
.21A5.74,5.74,0,0,0,25,10.62Zm0,11.9A3.07,3.07,0,0,1,23.7,24a3.15,3.15,0,0,1-.57.18c-.22-.07-.43-.11-.63-.2a14.25,14.25,0,0,1-5.37-3.63,14.09,14.09,0,0,1-2.06-3.18c-.26-.54-.49-1.1-.71-1.66a1.45,1.45,0,0,1,.42-1.42,3.31,3.31,0,0,1,1.11-.84.71.71,0,0,1,.89.21,11.57,11.57,0,0,1,1.37,1.94.93.93,0,0,1-.26,1.25c-.1.07-.2.16-.3.24a1,1,0,0,0-.22.24.66.66,0,0,0,0,.57,5.16,5.16,0,0,0,2.88,3.22,1.45,1.45,0,0,0,.74.18c.45-.05.6-.55.91-.81a.85.85,0,0,1,1,0c.33.21.66.44,1,.67a11.16,11.16,0,0,1,.92.71A.74.74,0,0,1,25,22.51Zm-2.6-4.77h0a.33.33,0,0,1-.34-.32A3.39,3.39,0,0,0,22,17a1.21,1.21,0,0,0-.44-.7,1.14,1.14,0,0,0-.36-.17c-.16,0-.33,0-.49-.07a.31.31,0,0,1-.25-.35.32.32,0,0,1,.34-.26,1.83,1.83,0,0,1,1.87,1.83.85.85,0,0,1,0,.26.26.26,0,0,1-.23.22Zm-.66-2.79a3.59,3.59,0,0,0-1-.31l-.46-.06a.29.29,0,0,1-.27-.33.29.29,0,0,1,.32-.28,4.14,4.14,0,0,1,1.74.46A3.55,3.55,0,0,1,24,17.17c0,.06,0,.11,0,.17s0,.28,0,.46A1.29,1.29,0,0,1,24,18a.3.3,0,0,1-.57,0,.81.81,0,0,1,0-.26A3.27,3.27,0,0,0,23,16.14,3,3,0,0,0,21.75,14.94Zm3.4,3.83c-.21,0-.31-.18-.32-.37,0-.38,0-.76-.1-1.14a4.77,4.77,0,0,0-3.82-4c-.3-.05-.6-.07-.9-.1s-.44,0-.48-.27a.33.33,0,0,1,.32-.37H20A5.41,5.41,0,0,1,25.3,17c.08.45.11.91.14,1.37A.32.32,0,0,1,25.15,18.78Z"></path>
# </g>
# </g>
# </svg>
# </a>
# </div>
# </div>
# <a class="footer__bottom-item-tell" data-target="click_phone" href="tel:88001001920">8(800)100-19-20</a>
# <div class="footer__bottom-gia" style="padding-top: 15px"><img src="/miuz/theme/images/gia.png"/></div>
# </div>
# </div>
# <div class="footer__bottom-copy">
# 	 Copyright © 2021 Московский ювелирный завод
# </div>
# <br/> </div>
# </div>
# </footer>
# <script async="async" src="https://yastatic.net/share2/share.js"></script>
# <!-- Garderobo AI -->
# <script src="https://widget.garderobo.ai/widget.js"></script>
# <script>
#     $(document).ready(function(){
#         Garderobo.init();
#     });
# </script>
# <!-- Garderobo AI -->
# <!-- {literal} -->
# <script>
#         $(document).ready(function(){
#             setTimeout(function() {
#                 window['liv'+'eTe'+'x'] = true,
#                     window['liv'+'eTe'+'xI'+'D'] = 111693,
#                     window['liveT'+'ex_ob'+'je'+'ct'] = true;
#                 var t = document['crea'+'t'+'eEleme'+'nt']('script');
#                 t.type ='text/javascript';
#                 t.async = true;
#                 t.src = '//cs15.live'+'tex.'+'ru/js/cli'+'en'+'t.js';
#                 var c = document['g'+'etE'+'le'+'mentsByT'+'ag'+'N'+'ame']('script')[0];
#                 if ( c ) c['par'+'en'+'t'+'N'+'ode']['i'+'nser'+'tBe'+'for'+'e'](t, c);
#                 else document['documen'+'t'+'Ele'+'men'+'t']['fi'+'rstCh'+'i'+'ld']['app'+'endCh'+'il'+'d'](t);
#             },5000);
#         });
#     </script>
# <!-- {/literal} -->
# <!-- Retail Rocket -->
# <script>
#     var rrPartnerId = "514ffe4987900a05d43e4664";
#     var rrApi = {};
#     var rrApiOnReady = rrApiOnReady || [];
#     rrApi.addToBasket = rrApi.order = rrApi.categoryView = rrApi.view =
#         rrApi.recomMouseDown = rrApi.recomAddToCart = function () {
#         };
#     (function (d) {
#         var ref = d.getElementsByTagName('script')[0];
#         var apiJs, apiJsId = 'rrApi-jssdk';
#         if (d.getElementById(apiJsId)) return;
#         apiJs = d.createElement('script');
#         apiJs.id = apiJsId;
#         apiJs.async = true;
#         apiJs.src = "//cdn.retailrocket.ru/content/javascript/tracking.js";
#         ref.parentNode.insertBefore(apiJs, ref);
#     }(document));
# </script>
# <!-- Retail Rocket -->
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-KLWF6Q" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!--пиксель продублирован  в файле /certificates/index.php-->
# <!-- Facebook Pixel Code -->
# <script>
#         !function (f, b, e, v, n, t, s) {
#             if (f.fbq) return;
#             n = f.fbq = function () {
#                 n.callMethod ? n.callMethod.apply(n, arguments) : n.queue.push(arguments)
#             };
#             if (!f._fbq) f._fbq = n;
#             n.push = n;
#             n.loaded = !0;
#             n.version = '2.0';
#             n.queue = [];
#             t = b.createElement(e);
#             t.async = !0;
#             t.src = v;
#             s = b.getElementsByTagName(e)[0];
#             s.parentNode.insertBefore(t, s)
#         }(window, document, 'script', 'https://connect.facebook.net/en_US/fbevents.js');
#         fbq('init', '650512918440434');
#         fbq('track', 'PageView');
#     </script>
# <!-- End Facebook Pixel Code -->
# <!-- Facebook Pixel Code -->
# <script>
#         !function (f, b, e, v, n, t, s) {
#             if (f.fbq) return;
#             n = f.fbq = function () {
#                 n.callMethod ?
#                     n.callMethod.apply(n, arguments) : n.queue.push(arguments)
#             };
#             if (!f._fbq) f._fbq = n;
#             n.push = n;
#             n.loaded = !0;
#             n.version = '2.0';
#             n.queue = [];
#             t = b.createElement(e);
#             t.async = !0;
#             t.src = v;
#             s = b.getElementsByTagName(e)[0];
#             s.parentNode.insertBefore(t, s)
#         }(window, document, 'script',
#             'https://connect.facebook.net/en_US/fbevents.js');
#         fbq('init', '681116522342148');
#         fbq('track', 'PageView');
#     </script>
# <noscript><img alt="" height="1" src="https://www.facebook.com/tr?id=681116522342148&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <!-- VK Remarketing -->
# <script>
#         var PIXEL_ID = 'VK-RTRG-38746-4FC1F';
#         var PRICE_LIST_ID = '126981';
#     </script>
# <div id="vk_api_transport"></div>
# <!--<script>
#         window.vkAsyncInit = function() {
#             VK.Retargeting.Init(PIXEL_ID);
#         };
#
#         setTimeout(function() {
#             var el = document.createElement("script");
#             el.type = "text/javascript";
#             el.src = "https://vk.com/js/api/openapi.js?150";
#             el.async = true;
#             document.getElementById("vk_api_transport").appendChild(el);
#         }, 0);
#     </script>-->
# <script>!function(){var t=document.createElement("script");t.type="text/javascript",t.async=!0,t.src="https://vk.com/js/api/openapi.js?169",t.onload=function(){VK.Retargeting.Init("VK-RTRG-943158-afU3I"),VK.Retargeting.Hit()},document.head.appendChild(t)}();</script><noscript><img alt="" src="https://vk.com/rtrg?p=VK-RTRG-943158-afU3I" style="position:fixed; left:-999px;"/></noscript>
# <!--RTBHouse-->
# <script>
#         (function (window) {
#             var BX = window.BX;
#             if (BX && BX.rtb)
#             {
#                 BX.rtb('unknown').page();
#             }
#         })(window);
#     </script>
# </body>
# </html>

# %%
re.findall(r'<div class="detail__item-option"><span>Камни:</span>([\w\W]+?)\s*</div>',str(card))
# Out:
# ['\n<div class="detail__item-option__info">\n                    1  Бриллиант огранки "Круглая" граней - 57, <span class="href" onclick="event.preventDefault(); window.open(\'/guide/stones/dragotsennye-kamni/brilliant/cutForm/\'); event.stopPropagation();">тип огранки</span> A, <span class="href" onclick="event.preventDefault(); window.open(\'/guide/stones/dragotsennye-kamni/brilliant/razmer-tsvet-ves/\'); event.stopPropagation();">цвет</span> 2, <span class="href" onclick="event.preventDefault(); window.open(\'/guide/quality/chistota-brillianta/\'); event.stopPropagation();">чистота</span> 5, 0.9 карат;<br/>']

# %%
row = len(data)

# %%
data.loc[row,'url'] = urlcard

# %%
data.loc[row,'h1'] = card.find("h1").text.strip()

# %%
data.loc[row,'art'] = card.select('body > div.grid > div > div > div.shops__breadcrumbs.catalog_breadcrumbs > div > div:nth-child(4) > span > span')

# %%
data.loc[row,'price'] = float(''.join(re.findall(r'\d+', card.find('div',"detail__item-price-new").text)))

# %%
data.loc[row,'gold'] = re.findall(r"(Золото\s+\d+)",str(card))[0]

# %%
div_gems = card.select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)')

# %%
div_gems = card.find_all('div','detail__item-option')[3]

# %%
card.find_all('div','detail__item-option')[3].text
# Out:
# 'Камни:\n\n                    1  Бриллиант огранки "Круглая" граней - 57, тип огранки A, цвет 2, чистота 5, 0.9 карат; \n'

# %%
len(card.find_all('div','detail__item-option'))
# Out:
# 4

# %%
len(jlook.find_all('div','detail__item-option'))
# Out:
# 6

# %%
jlook.find_all('div','detail__item-option')[].text
# Out:
# '\n\n\n\n\n\nБесплатная доставка курьером\n\n\n\n\n\nПолучите заказ в фирменном магазине MIUZ Diamonds\n\n\n\n\n\nЗаберите заказ в удобном пункте выдачи заказов\n\n\n\n'

# %%
data.loc[row,'gems'] = re.search(r'Камни:\s+([\w\W]+)', str(div_gems.text.strip()))[1]

# %%
data.loc[row,'weight'] = float(re.findall(r"(?:Вес:</span>\n)\s+(\d+.\d+)",str(card))[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-143-8312e9a9d99b> in <module>
# ----> 1 data.loc[row,'weight'] = float(re.findall(r"(?:Вес:</span>\n)\s+(\d+.\d+)",str(card))[0])
#
# IndexError: list index out of range

# %%
 
        data.loc[row,'gold'] = re.findall(r"(Золото\s+\d+)",str(card))[0]
        data.loc[row,'weight'] = float(re.findall(r"(?:Вес:</span>\n)\s+(\d+.\d+)",str(card))[0])
        div_gems = card.select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)')
        data.loc[row,'gems'] = re.search(r'Камни:\s+([\w\W]+)', str(div_gems[0].text.strip()))[1]

# %%
# Out:
#                                                        h1  \
# 0                Кольцо c бриллиантами R755-40094R007-R17
# 1                                                  Кольца
# 2           Кольцо c бриллиантами и жемчугом R01-34212-PR
# 3                                    Кольцо c бриллиантом
# 4                                    Кольцо c бриллиантом
# ...                                                   ...
# 3178                Кольцо c бриллиантом R01-SOL97-005-G2
# 3179   Кольцо c бриллиантами и сапфиром R01-EX-52698-SA-B
# 3180   Кольцо c бриллиантами и сапфиром R4150-D-LRAB2747S
# 3181  Кольцо c бриллиантами и изумрудом R4150-D-LRP35494E
# 3182                     Кольцо c бриллиантами R17-R20465
#
#                                  art      price        gold weight  \
# 0     [[Артикул R755-40094R007-R17]]   153610.0  Золото 585   6.72
# 1                                 []        NaN         NaN    NaN
# 2           [[Артикул R01-34212-PR]]    25596.0  Золото 585   3.81
# 3       [[Артикул R01-ALR52-090-G1]]  1051194.0  Золото 585    NaN
# 4       [[Артикул R01-ALR52-090-G1]]  1051194.0  Золото 585    NaN
# ...                              ...        ...         ...    ...
# 3178    [[Артикул R01-SOL97-005-G2]]    16495.0  Золото 585   1.39
# 3179   [[Артикул R01-EX-52698-SA-B]]   159894.0  Золото 585    4.9
# 3180   [[Артикул R4150-D-LRAB2747S]]    28947.0  Золото 585   2.74
# 3181   [[Артикул R4150-D-LRP35494E]]    24297.0  Золото 585   1.49
# 3182          [[Артикул R17-R20465]]   115300.0  Золото 585   3.67
#
#                                                                                                                                                                                                          gems  \
# 0                   162  Бриллианта огранки "Круглая" граней - 17, тип огранки A, цвет 3, чистота 4, 0.508 карат;7  Бриллиантов огранки "Круглая" граней - 57, тип огранки A, цвет 3, чистота 7, 0.274 карат;
# 1                                                                                                                                                                                                         NaN
# 2                                                                               17  Бриллиантов огранки "Круглая" граней - 17, тип огранки A, цвет 4, чистота 4, 0.05 карат;1  Жемчуг, цвет Белый, 4.1 карат;
# 3                                                                                                                                                                                                         NaN
# 4                                                                                                                    1  Бриллиант огранки "Круглая" граней - 57, тип огранки A, цвет 2, чистота 5, 0.9 карат;
# ...                                                                                                                                                                                                       ...
# 3178                                                                                                                1  Бриллиант огранки "Круглая" граней - 57, тип огранки A, цвет 5, чистота 5, 0.06 карат;
# 3179  32  Бриллианта огранки "Круглая" граней - 17, тип огранки A, цвет 3, чистота 4, 0.13 карат;10  Бриллиантов огранки "Круглая" граней - 57, тип огранки A, цвет 3, чистота 6, 0.15 карат;2  Бриллианта...
# 3180  4  Бриллианта огранки "Круглая" граней - 57, тип огранки A, цвет 3, чистота 6, 0.04 карат;2  Бриллианта огранки "Круглая" граней - 57, тип огранки A, цвет 3, чистота 6, 0.03 карат;1  Сапфир огранк...
# 3181                                                     9  Бриллиантов огранки "Круглая" граней - 57, тип огранки A, цвет 6, чистота 6, 0.04 карат;1  Изумруд огранки "Овал", цвет 3, чистота 3, 0.78 карат;
# 3182  18  Бриллиантов огранки "Круглая" граней - 57, тип огранки A, цвет 3, чистота 7, 0.1 карат;12  Бриллиантов огранки "Маркиз" граней - 55, тип огранки A, цвет 4, чистота 5, 0.52 карат;6  Бриллиантов...
#
#                                                     url
# 0     https://miuz.ru/catalog/rings/R755-40094R007-R17/
# 1        https://miuz.ru/catalog/rings/R4150-D-LRT1283/
# 2           https://miuz.ru/catalog/rings/R01-34212-PR/
# 3       https://miuz.ru/catalog/rings/R01-ALR52-090-G1/
# 4       https://miuz.ru/catalog/rings/R01-ALR52-090-G1/
# ...                                                 ...
# 3178    https://miuz.ru/catalog/rings/R01-SOL97-005-G2/
# 3179   https://miuz.ru/catalog/rings/R01-EX-52698-SA-B/
# 3180   https://miuz.ru/catalog/rings/R4150-D-LRAB2747S/
# 3181   https://miuz.ru/catalog/rings/R4150-D-LRP35494E/
# 3182          https://miuz.ru/catalog/rings/R17-R20465/
#
# [3183 rows x 7 columns]

# %%
#change 151121
data.loc[row,'art'] = card.select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > div.title-line > meta:nth-child(1)')

# %%
data.loc[row,'price'] = float(''.join(re.findall(r'\d+', card.find('div',"detail__item-price-new").text)))

# %%
data.loc[row,'gold'] = re.findall(r"(Золото\s+\d+)",str(card))[0]

# %%
data.loc[row,'weight'] = float(re.findall(r"(?:Вес:</span>\n)\s+(\d+.\d+)",str(card))[0])

# %%
#div_gems = card.select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)')
#data.loc[row,'gems'] = re.search(r'Камни:\s+([\w\W]+)', str(div_gems[0].text.strip()))[1]
div_gems = re.findall(r'<div class="detail__item-option"><span>Камни:</span>([\w\W]+?)\s*</div>',str(card))

data.loc[row,'gems'] = div_gems[0]

# %%
for i in range(0,len(links)):
    try:
        urlcard = domain +links[i]
        card = mysoup(urlcard)
        row = len(data)
        data.loc[row,'url'] = urlcard
        data.loc[row,'h1'] = card.find("h1").text.strip()
        data.loc[row,'art'] = card.select('body > div.grid > div > div > div.shops__breadcrumbs.catalog_breadcrumbs > div > div:nth-child(4) > span > span')
        data.loc[row,'price'] = float(''.join(re.findall(r'\d+', card.find('div',"detail__item-price-new").text)))
        data.loc[row,'gold'] = re.findall(r"(Золото\s+\d+)",str(card))[0]
        data.loc[row,'weight'] = float(re.findall(r"(?:Вес:</span>\n)\s+(\d+.\d+)",str(card))[0])
        div_gems = card.select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)')
        data.loc[row,'gems'] = re.search(r'Камни:\s+([\w\W]+)', str(div_gems[0].text.strip()))[1]
    except (AttributeError,TypeError) as e:
        print('error',e)
    except IndexError:
        print('indexerror len of = ' , len(card.find_all('div','detail__item-option')) )
    print(i, urlcard)
# Out:
# 0 https://miuz.ru/catalog/rings/R755-40094R007-R17/
# error 'NoneType' object has no attribute 'text'
# 1 https://miuz.ru/catalog/rings/R4150-D-LRT1283/
# 2 https://miuz.ru/catalog/rings/R01-34212-PR/
# indexerror len of =  4
# 3 https://miuz.ru/catalog/rings/R01-ALR52-090-G1/
# 4 https://miuz.ru/catalog/rings/R2017-R301401EMR-R17/
# 5 https://miuz.ru/catalog/rings/R2610-1982990AXD-R17/
# error 'NoneType' object has no attribute 'text'
# 6 https://miuz.ru/catalog/rings/R2017-R312791SAP/
# 7 https://miuz.ru/catalog/rings/R2017-R312798EMR/
# 8 https://miuz.ru/catalog/rings/R97-CR3049-EM/
# error 'NoneType' object has no attribute 'text'
# 9 https://miuz.ru/catalog/rings/R77-R53277-BTBLD/
# 10 https://miuz.ru/catalog/rings/R164-SVR008818OO-R17/
# error 'NoneType' object has no attribute 'text'
# 11 https://miuz.ru/catalog/rings/R4145-56579SA/
# 12 https://miuz.ru/catalog/rings/R779-AFI70-1/
# 13 https://miuz.ru/catalog/rings/R01-34569-EM/
# 14 https://miuz.ru/catalog/rings/R01-SOL38-030-G4/
# 15 https://miuz.ru/catalog/rings/R4211-RG4714WSA1/

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-160-69cf099e3556> in <module>
#       2     try:
#       3         urlcard = domain +links[i]
# ----> 4         card = mysoup(urlcard)
#       5         row = len(data)
#       6         data.loc[row,'url'] = urlcard
#
# <ipython-input-3-457c2edd76e4> in mysoup(urls)
#       1 def mysoup(urls):
# ----> 2     response = requests.get(urls)
#       3     return BeautifulSoup(response.text, 'lxml')
#       4
#
# C:\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# C:\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# C:\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# C:\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# C:\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# C:\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# C:\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# C:\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# C:\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# C:\anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# C:\anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# C:\anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# C:\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# C:\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# C:\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
data.to_excel('mius161121_0-3178.xlsx')

# %%
urlcard

# %%
linkspd = pd.DataFrame(links)

# %%
linkspd.rename(columns={0:'short'}, inplace=True)

# %%
linkspd['path'] = domain +linkspd['short']

# %%
linkspd.to_excel('links5500_16112021.xlsx')

# %%
re.findall(r"(?:Вес:</span>\n)\s+(\d+.\d+)",str(card))
# Out:
# []

# %%
card
# Out:
# <!DOCTYPE html>
# <html lang="ru">
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# product: http://ogp.me/ns/product#">
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="no-referrer-when-downgrade" name="referrer"/>
# <meta content="_qgYWIuV2xT0oumXLChfyILXpWboP-DV-NzpKDk2EOs" name="google-site-verification"/>
# <meta content="Предлагаем купить Кольцо c бриллиантами, артикул R755-65784R004, Золото 585,  – цены в каталоге интернет-магазина Московский ювелирный завод, телефон: 8 (800) 100-19-20." name="description"/>
# <meta content="product" property="og:type"/>
# <meta content="https://miuz.ru/catalog/rings/R755-65784R004/" property="og:url"/>
# <meta content="Кольцо c бриллиантами Артикул R755-65784R004" property="og:title"/>
# <meta content="Предлагаем купить Кольцо c бриллиантами, артикул R755-65784R004, Золото 585,  – цены в каталоге интернет-магазина Московский ювелирный завод, телефон: 8 (800) 100-19-20." property="og:description"/>
# <meta content="https://miuz.ru/upload/resize_cache/iblock/2bf/580_580_0/R755_65784R004.jpg" property="og:image"/>
# <meta content="510" property="og:image:width"/>
# <meta content="228" property="og:image:height"/>
# <meta content="818147.40" property="product:original_price:amount"/>
# <meta content="RUB" property="product:original_price:currency"/>
# <meta content="instock" property="product:availability"/>
# <base href="https://miuz.ru/"/>
# <meta content="telephone=no" name="format-detection"/>
# <!--<script src="/miuz/theme/js/libs/zoom/jquery.elevateZoom-3.0.8.min.js"></script>-->
# <script async="" src="https://api-maps.yandex.ru/2.1/?lang=ru_RU"></script>
# <style>
#             @font-face {
#                 font-family: 'pt_sansregular';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/pts55f-webfont.eot');
#                 src: url('/miuz/theme/fonts/pts55f-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/pts55f-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/pts55f-webfont.woff') format('woff'), url('/miuz/theme/fonts/pts55f-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/pts55f-webfont.svg#pt_sansregular') format('svg');
#                 font-weight: normal;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'circe';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/crc15-webfont.eot');
#                 src: url('/miuz/theme/fonts/crc15-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/crc15-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/crc15-webfont.woff') format('woff'), url('/miuz/theme/fonts/crc15-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/crc15-webfont.svg#circe_thinthin') format('svg');
#                 font-weight: 100;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'circe';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/crc25-webfont.eot');
#                 src: url('/miuz/theme/fonts/crc25-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/crc25-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/crc25-webfont.woff') format('woff'), url('/miuz/theme/fonts/crc25-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/crc25-webfont.svg#circeextra_light') format('svg');
#                 font-weight: 200;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'circe';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/crc35-webfont.eot');
#                 src: url('/miuz/theme/fonts/crc35-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/crc35-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/crc35-webfont.woff') format('woff'), url('/miuz/theme/fonts/crc35-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/crc35-webfont.svg#circelight') format('svg');
#                 font-weight: 300;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'circe';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/crc55-webfont.eot');
#                 src: url('/miuz/theme/fonts/crc55-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/crc55-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/crc55-webfont.woff') format('woff'), url('/miuz/theme/fonts/crc55-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/crc55-webfont.svg#circeregular') format('svg');
#                 font-weight: 500;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'circe';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/crc65-webfont.eot');
#                 src: url('/miuz/theme/fonts/crc65-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/crc65-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/crc65-webfont.woff') format('woff'), url('/miuz/theme/fonts/crc65-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/crc65-webfont.svg#circebold') format('svg');
#                 font-weight: 600;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'circe';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/crc75-webfont.eot');
#                 src: url('/miuz/theme/fonts/crc75-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/crc75-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/crc75-webfont.woff') format('woff'), url('/miuz/theme/fonts/crc75-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/crc75-webfont.svg#circeextra_bold') format('svg');
#                 font-weight: 700;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'ABodoniNova';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/a_bodoninova-webfont.eot');
#                 src: url('/miuz/theme/fonts/a_bodoninova-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/a_bodoninova-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/a_bodoninova-webfont.woff') format('woff'), url('/miuz/theme/fonts/a_bodoninova-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/a_bodoninova-webfont.svg#a_bodoninovaregular') format('svg');
#                 font-weight: 400;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'ABodoniNova';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/a_bodoninova_bold-webfont.eot');
#                 src: url('/miuz/theme/fonts/a_bodoninova_bold-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/a_bodoninova_bold-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/a_bodoninova_bold-webfont.woff') format('woff'), url('/miuz/theme/fonts/a_bodoninova_bold-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/a_bodoninova_bold-webfont.svg#a_bodoninovabold') format('svg');
#                 font-weight: 700;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'ABodoniNova';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/a_bodoninova_bolditalic-webfont.eot');
#                 src: url('/miuz/theme/fonts/a_bodoninova_bolditalic-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/a_bodoninova_bolditalic-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/a_bodoninova_bolditalic-webfont.woff') format('woff'), url('/miuz/theme/fonts/a_bodoninova_bolditalic-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/a_bodoninova_bolditalic-webfont.svg#a_bodoninovabolditalic') format('svg');
#                 font-weight: 700;
#                 font-style: italic;
#             }
#             @font-face {
#                 font-family: 'ABodoniNova';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/a_bodoninova_italic-webfont.eot');
#                 src: url('/miuz/theme/fonts/a_bodoninova_italic-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/a_bodoninova_italic-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/a_bodoninova_italic-webfont.woff') format('woff'), url('/miuz/theme/fonts/a_bodoninova_italic-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/a_bodoninova_italic-webfont.svg#a_bodoninovaitalic') format('svg');
#                 font-weight: 400;
#                 font-style: italic;
#             }
#             @font-face {
#                 font-family: 'FuturaPT';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/futuraptbold-webfont.eot');
#                 src: url('/miuz/theme/fonts/futuraptbold-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/futuraptbold-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/futuraptbold-webfont.woff') format('woff'), url('/miuz/theme/fonts/futuraptbold-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/futuraptbold-webfont.svg#futura_ptbold') format('svg');
#                 font-weight: 700;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'FuturaPT';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/futuraptboldoblique-webfont.eot');
#                 src: url('/miuz/theme/fonts/futuraptboldoblique-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/futuraptboldoblique-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/futuraptboldoblique-webfont.woff') format('woff'), url('/miuz/theme/fonts/futuraptboldoblique-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/futuraptboldoblique-webfont.svg#futura_pt_bold_italicregular') format('svg');
#                 font-weight: 700;
#                 font-style: italic;
#             }
#             @font-face {
#                 font-family: 'FuturaPT';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/futuraptbook-webfont.eot');
#                 src: url('/miuz/theme/fonts/futuraptbook-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/futuraptbook-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/futuraptbook-webfont.woff') format('woff'), url('/miuz/theme/fonts/futuraptbook-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/futuraptbook-webfont.svg#futura_ptbook') format('svg');
#                 font-weight: 400;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'FuturaPT';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/futuraptbookoblique-webfont.eot');
#                 src: url('/miuz/theme/fonts/futuraptbookoblique-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/futuraptbookoblique-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/futuraptbookoblique-webfont.woff') format('woff'), url('/miuz/theme/fonts/futuraptbookoblique-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/futuraptbookoblique-webfont.svg#futura_pt_book_italicregular') format('svg');
#                 font-weight: 400;
#                 font-style: italic;
#             }
#             @font-face {
#                 font-family: 'FuturaPT';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/futuraptdemi-webfont.eot');
#                 src: url('/miuz/theme/fonts/futuraptdemi-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/futuraptdemi-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/futuraptdemi-webfont.woff') format('woff'), url('/miuz/theme/fonts/futuraptdemi-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/futuraptdemi-webfont.svg#futura_ptdemi') format('svg');
#                 font-weight: 600;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'FuturaPT';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/futuraptextrabold-webfont.eot');
#                 src: url('/miuz/theme/fonts/futuraptextrabold-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/futuraptextrabold-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/futuraptextrabold-webfont.woff') format('woff'), url('/miuz/theme/fonts/futuraptextrabold-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/futuraptextrabold-webfont.svg#futura_ptextra_bold') format('svg');
#                 font-weight: 900;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'FuturaPT';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/futuraptheavy-webfont.eot');
#                 src: url('/miuz/theme/fonts/futuraptheavy-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/futuraptheavy-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/futuraptheavy-webfont.woff') format('woff'), url('/miuz/theme/fonts/futuraptheavy-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/futuraptheavy-webfont.svg#futura_ptheavy') format('svg');
#                 font-weight: 800;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'FuturaPT';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/futuraptlight-webfont.eot');
#                 src: url('/miuz/theme/fonts/futuraptlight-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/futuraptlight-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/futuraptlight-webfont.woff') format('woff'), url('/miuz/theme/fonts/futuraptlight-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/futuraptlight-webfont.svg#futura_ptlight') format('svg');
#                 font-weight: 300;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'FuturaPT';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/futuraptmedium-webfont.eot');
#                 src: url('/miuz/theme/fonts/futuraptmedium-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/futuraptmedium-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/futuraptmedium-webfont.woff') format('woff'), url('/miuz/theme/fonts/futuraptmedium-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/futuraptmedium-webfont.svg#futura_ptmedium') format('svg');
#                 font-weight: 500;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'PT Serif';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/PTSerif-Regular.eot');
#                 src: url('/miuz/theme/fonts/PTSerif-Regular.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/PTSerif-Regular.woff') format('woff'), url('/miuz/theme/fonts/PTSerif-Regular.ttf') format('truetype'), url('/miuz/theme/fonts/PTSerif-Regular.svg#PTSerif-Regular') format('svg');
#                 font-weight: 400;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'Diploma Script Basic';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/latinotype-diploma-script-basic.eot');
#                 src: url('/miuz/theme/fonts/latinotype-diploma-script-basic.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/latinotype-diploma-script-basic.woff2') format('woff2'), url('/miuz/theme/fonts/latinotype-diploma-script-basic.woff') format('woff'), url('/miuz/theme/fonts/latinotype-diploma-script-basic.ttf') format('truetype'), url('/miuz/theme/fonts/latinotype-diploma-script-basic.svg#DiplomaScript-Basic') format('svg');
#                 font-weight: 400;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'Gabriela Stencil Black';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/latinotype-gabriela-stencil-black.eot');
#                 src: url('/miuz/theme/fonts/latinotype-gabriela-stencil-black.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/latinotype-gabriela-stencil-black.woff2') format('woff2'), url('/miuz/theme/fonts/latinotype-gabriela-stencil-black.woff') format('woff'), url('/miuz/theme/fonts/latinotype-gabriela-stencil-black.ttf') format('truetype'), url('/miuz/theme/fonts/latinotype-gabriela-stencil-black.svg#GabrielaStencil-Black') format('svg');
#                 font-weight: 400;
#                 font-style: normal;
#             }
#         </style>
# <!--[if lt IE 9]>
#         <script src="http://html5shiv.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <title>Кольцо c бриллиантами, артикул R755-65784R004, Золото 585,  - купить в интернет-магазине Московский ювелирный завод</title>
# <script async="" src="//static.criteo.net/js/ld/ld.js"></script>
# <script>
#             window.criteo_q = window.criteo_q || [];
#             window.criteo_q.push(
#                 {event:"setAccount", account:34906},
#                 {event:"setSiteType", type:"d"},
#                 {event:"setEmail", email:""}
#             );
#         </script>
# <script>
#             const RTB_HOUSE_UID = "unknown";
#         </script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="/bitrix/cache/css/s1/muz/page_d2e5973148e9adcfd4f259abb66b5563/page_d2e5973148e9adcfd4f259abb66b5563_v1.css?1635844522441" rel="stylesheet" type="text/css"/>
# <link data-template-style="true" href="/bitrix/cache/css/s1/muz/template_a7d7562c40b1c14f30c22935a60706db/template_a7d7562c40b1c14f30c22935a60706db_v1.css?1635844522865508" rel="stylesheet" type="text/css"/>
# <script>if(!window.BX)window.BX={};if(!window.BX.message)window.BX.message=function(mess){if(typeof mess=='object') for(var i in mess) BX.message[i]=mess[i]; return true;};</script>
# <script>(window.BX||top.BX).message({'JS_CORE_LOADING':'Загрузка...','JS_CORE_NO_DATA':'- Нет данных -','JS_CORE_WINDOW_CLOSE':'Закрыть','JS_CORE_WINDOW_EXPAND':'Развернуть','JS_CORE_WINDOW_NARROW':'Свернуть в окно','JS_CORE_WINDOW_SAVE':'Сохранить','JS_CORE_WINDOW_CANCEL':'Отменить','JS_CORE_WINDOW_CONTINUE':'Продолжить','JS_CORE_H':'ч','JS_CORE_M':'м','JS_CORE_S':'с','JSADM_AI_HIDE_EXTRA':'Скрыть лишние','JSADM_AI_ALL_NOTIF':'Показать все','JSADM_AUTH_REQ':'Требуется авторизация!','JS_CORE_WINDOW_AUTH':'Войти','JS_CORE_IMAGE_FULL':'Полный размер'});</script>
# <script src="/bitrix/js/main/core/core.min.js?1592347382249634"></script>
# <script>BX.setJSList(['/bitrix/js/main/core/core_ajax.js','/bitrix/js/main/core/core_promise.js','/bitrix/js/main/polyfill/promise/js/promise.js','/bitrix/js/main/loadext/loadext.js','/bitrix/js/main/loadext/extension.js','/bitrix/js/main/polyfill/promise/js/promise.js','/bitrix/js/main/polyfill/find/js/find.js','/bitrix/js/main/polyfill/includes/js/includes.js','/bitrix/js/main/polyfill/matches/js/matches.js','/bitrix/js/ui/polyfill/closest/js/closest.js','/bitrix/js/main/polyfill/fill/main.polyfill.fill.js','/bitrix/js/main/polyfill/find/js/find.js','/bitrix/js/main/polyfill/matches/js/matches.js','/bitrix/js/main/polyfill/core/dist/polyfill.bundle.js','/bitrix/js/main/core/core.js','/bitrix/js/main/polyfill/intersectionobserver/js/intersectionobserver.js','/bitrix/js/main/lazyload/dist/lazyload.bundle.js','/bitrix/js/main/polyfill/core/dist/polyfill.bundle.js','/bitrix/js/main/parambag/dist/parambag.bundle.js']);
# BX.setCSSList(['/bitrix/js/main/core/css/core.css','/bitrix/js/main/lazyload/dist/lazyload.bundle.css','/bitrix/js/main/parambag/dist/parambag.bundle.css']);</script>
# <script>(window.BX||top.BX).message({'LANGUAGE_ID':'ru','FORMAT_DATE':'DD.MM.YYYY','FORMAT_DATETIME':'DD.MM.YYYY HH:MI:SS','COOKIE_PREFIX':'BITRIX_SM','SERVER_TZ_OFFSET':'10800','SITE_ID':'s1','SITE_DIR':'/','USER_ID':'','SERVER_TIME':'1636458012','USER_TZ_OFFSET':'0','USER_TZ_AUTO':'Y','bitrix_sessid':'b5a7342f067487ea4e6091677b58db67'});</script>
# <script>BX.setJSList(['/local/components/aero/catalog/templates/aero/miuz/catalog.section/catalogElement/script.js','/local/js/miuz/rtb/dist/rtb.js','/miuz/theme/js/libs/bitrix.js','/miuz/theme/js/libs/jquery-3.3.1.min.js','/miuz/theme/js/libs/jquery-2.1.1.min.js','/miuz/theme/js/libs/zoom/jquery.elevatezoom.min.js','/miuz/theme/js/libs/lazyload.min.js','/local/templates/muz/js/slick.min.js','/local/templates/muz/js/jquery.inputmask.min.js','/miuz/theme/js/deviceDetect.min.js','/miuz/theme/js/libs/libs.min.js','/miuz/theme/js/components/Application.js','/local/templates/muz/js/flipclock.min.js','/local/templates/muz/js/script.js','/local/templates/muz/js/metric.js','/miuz/theme/js/libs/magnific-popup/magnific-popup.min.js','/local/js/miuz/Soloway/class.js','/bitrix/components/bitrix/search.title/script.js','/local/templates/muz/components/bitrix/search.title/.default/script.js','/miuz/theme/js/components/Utils.js','/miuz/theme/js/components/Loader.js','/miuz/theme/js/components/Size.js','/miuz/theme/js/BView/GlobalView.js','/miuz/theme/js/BView/Header.js','/miuz/theme/js/BView/Shops.js','/miuz/theme/js/BView/Footer.js','/miuz/theme/js/BView/Default.js','/miuz/theme/js/BView/NotFound.js','/miuz/theme/js/BView/StopSending.js','/miuz/theme/js/BView/Home.js','/miuz/theme/js/libs/svg.min.js','/miuz/theme/js/BView/Catalog.js','/miuz/theme/js/BView/Detail.js','/miuz/theme/js/BView/Discount.js','/miuz/theme/js/BView/Text.js','/miuz/theme/js/BView/Certificate.js','/miuz/theme/js/BView/Contacts.js','/miuz/theme/js/BView/News.js','/miuz/theme/js/BView/Thank.js','/miuz/theme/js/BView/RegionShops.js','/miuz/theme/js/BView/Brilliant.js','/miuz/theme/js/BView/Lk.js','/miuz/theme/js/BView/Enter.js','/miuz/theme/js/BView/BrilliantPair.js','/miuz/theme/js/BView/Collection.js','/miuz/theme/js/BView/Connect.js','/miuz/theme/js/BView/Vacancy.js','/miuz/theme/js/BView/VacancyForm.js','/miuz/theme/js/BView/Vacancies.js','/miuz/theme/js/BView/Stones.js','/miuz/theme/js/BView/Care.js','/miuz/theme/js/BView/Search.js','/miuz/theme/js/BView/Emerald.js','/miuz/theme/js/BView/Diamond.js','/miuz/theme/js/BView/Products.js','/miuz/theme/js/BView/Product.js','/miuz/theme/js/BView/Weight.js','/miuz/theme/js/BView/Links.js','/miuz/theme/js/BView/Element.js','/miuz/theme/js/BView/History.js','/miuz/theme/js/BView/Admin.js','/miuz/theme/js/libs/jquery.mCustomScrollbar.concat.min.js','/miuz/theme/js/BView/RegionalContacts.js','/miuz/theme/js/Router.js','/miuz/theme/js/script.js','/local/js/miuz/garderobo/class.js']); </script>
# <script>BX.setCSSList(['/local/components/aero/catalog/templates/aero/miuz/catalog.section/catalogElement/style.css','/local/templates/muz/css/flipclock.css','/miuz/theme/css/swiper.min.css','/miuz/theme/css/chosen.min.css','/miuz/theme/css/bitrix.css','/miuz/theme/js/libs/jquery-ui/jquery-ui.min.css','/miuz/theme/js/libs/fancybox/jquery.fancybox.min.css','/miuz/theme/generator.css','/miuz/theme/template_styles.css','/local/templates/muz/css/landings/slick.css','/miuz/theme/js/libs/magnific-popup/magnific-popup.min.css','/local/templates/muz/components/bitrix/search.title/.default/style.css','/miuz/theme/css/jquery.mCustomScrollbar.min.css','/local/templates/muz/styles.css','/local/templates/muz/template_styles.css']); </script>
# <script>
# 					(function () {
# 						"use strict";
#
# 						var counter = function ()
# 						{
# 							var cookie = (function (name) {
# 								var parts = ("; " + document.cookie).split("; " + name + "=");
# 								if (parts.length == 2) {
# 									try {return JSON.parse(decodeURIComponent(parts.pop().split(";").shift()));}
# 									catch (e) {}
# 								}
# 							})("BITRIX_CONVERSION_CONTEXT_s1");
#
# 							if (cookie && cookie.EXPIRE >= BX.message("SERVER_TIME"))
# 								return;
#
# 							var request = new XMLHttpRequest();
# 							request.open("POST", "/bitrix/tools/conversion/ajax_counter.php", true);
# 							request.setRequestHeader("Content-type", "application/x-www-form-urlencoded");
# 							request.send(
# 								"SITE_ID="+encodeURIComponent("s1")+
# 								"&sessid="+encodeURIComponent(BX.bitrix_sessid())+
# 								"&HTTP_REFERER="+encodeURIComponent(document.referrer)
# 							);
# 						};
#
# 						if (window.frameRequestStart === true)
# 							BX.addCustomEvent("onFrameDataReceived", counter);
# 						else
# 							BX.ready(counter);
# 					})();
# 				</script>
# <link as="font" crossorigin="" href="/miuz/theme/fonts/crc35-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/miuz/theme/fonts/crc65-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/miuz/theme/fonts/futuraptlight-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/miuz/theme/fonts/futuraptdemi-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/miuz/theme/fonts/futuraptbold-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/miuz/theme/fonts/futuraptbook-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="image" href="/miuz/theme/images/logo_msk.svg" rel="preload"/>
# <link as="image" href="/miuz/theme/images/car.svg" rel="preload"/>
# <link as="image" href="/miuz/theme/images/icons/search.svg" rel="preload"/>
# <link as="image" href="/miuz/theme/images/background__counter.svg" rel="preload"/>
# <link as="image" href="/miuz/theme/images/pixel.gif" rel="preload"/>
# <link as="image" href="/miuz/theme/images/box-brilliant.png" rel="preload"/>
# <link as="image" href="/miuz/theme/images/icons/spritesheet.png" rel="preload"/>
# <link as="image" href="/miuz/theme/images/icons/spritesheet_new.png" rel="preload"/>
# <link as="image" href="/miuz/theme/images/icons/ico-help-grey.png" rel="preload"/>
# <link as="image" href="/miuz/theme/images/icons/viber.svg" rel="preload"/>
# <script async="" src="https://www.youtube.com/iframe_api"></script>
# <link href="//google-analytics.com" rel="preconnect"/>
# <link href="//mc.yandex.ru/" rel="preconnect"/>
# <link href="//top-fwz1.mail.ru" rel="preconnect"/>
# <script>window.criteo_q.push({event:"viewItem", item:"R755-65784R004"});</script>
# <script>if (typeof(window.fbq) !== "undefined") fbq.push(["track", "ViewContent", {content_type: "product", content_ids:["R755-65784R004"]}]);</script>
# <script>
#             dataLayer = [
#                 {"pageType":"ProductPage","City":"","product":{"groupId":3945501,"name":"Кольцо c бриллиантами","price":818147,"oldPrice":1363579,"pictureUrl":"https://miuz.ru/upload/resize_cache/iblock/2bf/200_200_2/R755_65784R004.jpg","url":"https://miuz.ru/catalog/rings/R755-65784R004/","model":"R755-65784R004","vendor":"МЮЗ","params":{"minPrice":818147,"minOldPrice":1363579,"delivery":false},"isAvailable":true,"categoryPaths":"Кольца/Кольца c бриллиантом/","description":"","typePrefix":"Кольца"}}
#             ];
#         </script>
# <script src="/bitrix/cache/js/s1/muz/template_fadc3e3f5ad71b2793863d9c56f70b04/template_fadc3e3f5ad71b2793863d9c56f70b04_v1.js?16358445221630789"></script>
# <script src="/bitrix/cache/js/s1/muz/page_cb20c4f9247ab90a5cf9f35b420ba12d/page_cb20c4f9247ab90a5cf9f35b420ba12d_v1.js?16358445221790"></script>
# <script>
#             (function (window) {
#                 var BX = window.BX;
#                 if (BX && BX.rtb)
#                 {
#                     BX.rtb("unknown").productPage("R755-65784R004");
#                 }
#             })(window);
#         </script>
# <script>var _ba = _ba || []; _ba.push(["aid", "f93e9ffc96fa98b7372d25c0882bdc24"]); _ba.push(["host", "miuz.ru"]); _ba.push(["ad[ct][item]", "..."]);_ba.push(["ad[ct][user_id]", function(){return BX.message("USER_ID") ? BX.message("USER_ID") : 0;}]);_ba.push(["ad[ct][recommendation]", function() {var rcmId = "";var cookieValue = BX.getCookie("BITRIX_SM_RCM_PRODUCT_LOG");var productId = 3945501;var cItems = [];var cItem;if (cookieValue){cItems = cookieValue.split(".");}var i = cItems.length;while (i--){cItem = cItems[i].split("-");if (cItem[0] == productId){rcmId = cItem[1];break;}}return rcmId;}]);_ba.push(["ad[ct][v]", "2"]);(function() {var ba = document.createElement("script"); ba.type = "text/javascript"; ba.async = true;ba.src = (document.location.protocol == "https:" ? "https://" : "http://") + "bitrix.info/ba.js";var s = document.getElementsByTagName("script")[0];s.parentNode.insertBefore(ba, s);})();</script>
# <script>
#             var baseWidth = 1280,
#                 baseSize = 10,
#                 $html = $('html')
#             ;
#             _helper();
#             function _helper() {
#                 //alert($(window).width());
#                 if ($(window).width() <= 840) {
#                     baseWidth = 840;
#                     $html.addClass('mobile');
#                 } else {
#                     baseWidth = 1280;
#                     $html.removeClass('mobile');
#                 }
#                 $html.css({'font-size': Math.min($(window).width(), baseWidth) / baseWidth * baseSize + 'px'});
#             }
#         </script>
# <script>
#             if(typeof dataLayer === 'undefined'){dataLayer = [{}];}
#         </script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                 j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#             })(window,document,'script','dataLayer','GTM-KLWF6Q');</script>
# <!-- End Google Tag Manager -->
# <!-- Global site tag (gtag.js) - Google Marketing Platform -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=DC-10624467"></script>
# <script>
#                 window.dataLayer = window.dataLayer || [];
#                 function gtag(){dataLayer.push(arguments);}
#                 gtag('js', new Date());
#
#                 gtag('config', 'DC-10624467');
#             </script>
# <script>
#                     if (typeof gtag === "function")
#                     {
#                         gtag('event', 'conversion', {
#                             'allow_custom_scripts': true,
#                             'session_id': 'b5a7342f067487ea4e6091677b58db67',
#                             'send_to': 'DC-10624467/nu4xl0/rsz0t0+per_session'
#                         });
#                     }
#                 </script>
# <!-- Конец тега Global Site Tag. Не удаляйте этот код. -->
# <script>(window.Image ? (new Image()) : document.createElement('img')).src = location.protocol + '//vk.com/rtrg?r=uo84IIIYoi3yi9qoajllOwYhzD9HvGkQaN64N3AdBKA4JQFwtErKNeZxUhsMNd1iqu5gmosY9EBs13tX3z9sxfer7Iyd4xJq7hjFGmzGxMjgmHn0gl*QfSA3/nlWRtbGhcs0xOHl287Juodk0zvroXPtHo/4XEH8rbDIt/g1KjA-&pixel_id=1000038746';</script>
# <meta content="PdzGF9gKngzRb8pU7zHgoeO64I4wqtsFmkMazZ4y0Pg" name="google-site-verification"/>
# <!--Google reCAPTCHA v3 -->
# <script async="async" src="https://api.flocktory.com/v2/loader.js?site_id=2253"></script>
# <script>
#             var MAX_PRICE_FOR_BUY_FORMAT = '600 000';
#
#         </script>
# <!--  Soloway -->
# <script>
#             Soloway.init();
#         </script>
# <script>
#         $(document).ready(function () {
#             var data_prod_id = $("[data-soloway-product-id]"),
#                 prod_id = "";
#
#             if(data_prod_id.length == 1){
#                 prod_id = data_prod_id.data("soloway-product-id");
#             }
#             document.dispatchEvent(new CustomEvent("allPagesSoloway", {
#                 detail:{ user_id: "", offer_id: prod_id }
#             }));
#         });
#     </script> <!--  Soloway -->
# </head>
# <body class="royal-white body">
# <!-- End Google Tag Manager (noscript) -->
# <div data-lazy-retailrocket-markup-block="57bdcde09872e52d20f1e2a6"></div>
# <div data-lazy-retailrocket-markup-block="57bddb6b9872e52d20f1e401"></div>
# <!-- Rating@Mail.ru counter -->
# <script>
#     var _tmr = window._tmr || (window._tmr = []);
#     _tmr.push({id: "3216462", type: "pageView", start: (new Date()).getTime()});
#     (function (d, w, id) {
#         if (d.getElementById(id)) return;
#         var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#         ts.src = "https://top-fwz1.mail.ru/js/code.js";
#         var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#         if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
#     })(document, window, "topmailru-code");
# </script><noscript><div>
# <img alt="Top.Mail.Ru" src="https://top-fwz1.mail.ru/counter?id=3216462;js=na" style="border:0;position:absolute;left:-9999px;"/>
# </div></noscript>
# <!-- //Rating@Mail.ru counter -->
# <!-- Yandex.Metrika counter -->
# <script>
#     (function (d, w, c) {
#         (w[c] = w[c] || []).push(function() {
#             try {
#                 w.yaCounter5911648 = new Ya.Metrika({
#                     id:5911648,
#                     clickmap:true,
#                     trackLinks:true,
#                     accurateTrackBounce:true,
#                     webvisor:true,
#                     ecommerce:"dataLayer"
#                 });
#             } catch(e) { }
#         });
#
#         var n = d.getElementsByTagName("script")[0],
#             s = d.createElement("script"),
#             f = function () { n.parentNode.insertBefore(s, n); };
#         s.type = "text/javascript";
#         s.async = true;
#         s.src = "https://mc.yandex.ru/metrika/watch.js";
#
#         if (w.opera == "[object Opera]") {
#             d.addEventListener("DOMContentLoaded", f, false);
#         } else { f(); }
#     })(document, window, "yandex_metrika_callbacks");
# </script>
# <noscript><div><img alt="" src="https://mc.yandex.ru/watch/5911648" style="position:absolute; left:-9999px;"/></div></noscript>
# <!-- /Yandex.Metrika counter -->
# <script>
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#     ga('create', 'UA-10755722-3', 'auto');
#     ga(function(tracker) {
#         var clientId = tracker.get('clientId'); // получение clientId из Google Analytics
#         document.cookie = "_ga_cid=" + clientId + "; path=/"; // сохранение cookie в _ga_cid
#         ga('set', 'dimension1', clientId); //запись clientId для каждого пользователя
#     });
#     ga('send', 'pageview');
# </script>
# <!--<div class="loader js-loader">
#         <div class="loader_box"></div>
#     </div>-->
# <header class="header js-header">
# <div class="header__holder"></div>
# <div class="header__h" data-header-mob-indent=""></div>
# <div class="header__inner grid__inner js-header-fixed">
# <div class="header__left">
# <div class="href header__menu-btn" data-mob-menu-btn="">
# <div class="header__menu-btn-ico"></div>
# </div>
# <a class="header__tell" data-target="click_phone" href="tel:88001001920">8 (800) 100-19-20</a>
# <div class="header__city">
# <div class="city-select">
# <form action="/ajax/city.php" method="post">
# <select class="city-select__select" data-city-chosen="" name="CITY">
# <option value="Абакан">Абакан</option>
# <option value="Александров">Александров</option>
# <option value="Алматы">Алматы</option>
# <option value="Анапа">Анапа</option>
# <option value="Армавир">Армавир</option>
# <option value="Архангельск">Архангельск</option>
# <option value="Астрахань">Астрахань</option>
# <option value="Балашиха">Балашиха</option>
# <option value="Белгород">Белгород</option>
# <option value="Белебей">Белебей</option>
# <option value="Брянск">Брянск</option>
# <option value="Видное">Видное</option>
# <option value="Владивосток">Владивосток</option>
# <option value="Владикавказ">Владикавказ</option>
# <option value="Владимир">Владимир</option>
# <option value="Волгоград">Волгоград</option>
# <option value="Волгодонск">Волгодонск</option>
# <option value="Вологда">Вологда</option>
# <option value="Воронеж">Воронеж</option>
# <option value="Геленджик">Геленджик</option>
# <option value="Грозный">Грозный</option>
# <option value="Губкинский ЯНАО">Губкинский ЯНАО</option>
# <option value="Дзержинск">Дзержинск</option>
# <option value="Дмитров">Дмитров</option>
# <option value="Дубна">Дубна</option>
# <option value="Ейск">Ейск</option>
# <option value="Екатеринбург">Екатеринбург</option>
# <option value="Ессентуки">Ессентуки</option>
# <option value="Иваново">Иваново</option>
# <option value="Ижевск">Ижевск</option>
# <option value="Иркутск">Иркутск</option>
# <option value="Казань">Казань</option>
# <option value="Калининград">Калининград</option>
# <option value="Калуга">Калуга</option>
# <option value="Кемерово">Кемерово</option>
# <option value="Кинешма">Кинешма</option>
# <option value="Кисловодск">Кисловодск</option>
# <option value="Коломна">Коломна</option>
# <option value="Конаково">Конаково</option>
# <option value="Котельники">Котельники</option>
# <option value="Красногорск">Красногорск</option>
# <option value="Краснодар">Краснодар</option>
# <option value="Красноярск">Красноярск</option>
# <option value="Кропоткин">Кропоткин</option>
# <option value="Курган">Курган</option>
# <option value="Курск">Курск</option>
# <option value="Магнитогорск">Магнитогорск</option>
# <option value="Майкоп">Майкоп</option>
# <option value="Махачкала">Махачкала</option>
# <option value="Минеральные Воды">Минеральные Воды</option>
# <option value="Минск">Минск</option>
# <option value="Можайск">Можайск</option>
# <option value="Москва">Москва</option>
# <option value="Московский">Московский</option>
# <option value="Мурманск">Мурманск</option>
# <option value="Мытищи">Мытищи</option>
# <option value="Набережные Челны">Набережные Челны</option>
# <option value="Нальчик">Нальчик</option>
# <option value="Невинномысск">Невинномысск</option>
# <option value="Нефтеюганск">Нефтеюганск</option>
# <option value="Нижневартовск">Нижневартовск</option>
# <option value="Нижний Новгород">Нижний Новгород</option>
# <option value="Новоивановское">Новоивановское</option>
# <option value="Новокузнецк">Новокузнецк</option>
# <option value="Новороссийск">Новороссийск</option>
# <option value="Новосибирск">Новосибирск</option>
# <option value="Нур-Султан">Нур-Султан</option>
# <option value="Обнинск">Обнинск</option>
# <option value="Одинцово">Одинцово</option>
# <option value="Омск">Омск</option>
# <option value="Орел">Орел</option>
# <option value="Оренбург">Оренбург</option>
# <option value="Орехово-Зуево">Орехово-Зуево</option>
# <option value="Пенза">Пенза</option>
# <option value="Пермь">Пермь</option>
# <option value="Петрозаводск">Петрозаводск</option>
# <option value="Петропавловск-Камчатский">Петропавловск-Камчатский</option>
# <option value="Псков">Псков</option>
# <option value="Пушкино">Пушкино</option>
# <option value="Пятигорск">Пятигорск</option>
# <option value="Реутов">Реутов</option>
# <option value="Ржев">Ржев</option>
# <option value="Ростов-на-Дону">Ростов-на-Дону</option>
# <option value="Рязань">Рязань</option>
# <option value="Самара">Самара</option>
# <option value="Санкт-Петербург">Санкт-Петербург</option>
# <option value="Саратов">Саратов</option>
# <option value="Северодвинск">Северодвинск</option>
# <option value="Серпухов">Серпухов</option>
# <option value="Солнечногорск">Солнечногорск</option>
# <option value="Сочи">Сочи</option>
# <option value="Ставрополь">Ставрополь</option>
# <option value="Сургут">Сургут</option>
# <option value="Тверь">Тверь</option>
# <option value="Тольятти">Тольятти</option>
# <option value="Томск">Томск</option>
# <option value="Троицк">Троицк</option>
# <option value="Тула">Тула</option>
# <option value="Тюмень">Тюмень</option>
# <option value="Улан-Удэ">Улан-Удэ</option>
# <option value="Ульяновск">Ульяновск</option>
# <option value="Уфа">Уфа</option>
# <option value="Хабаровск">Хабаровск</option>
# <option value="Химки">Химки</option>
# <option value="Чебоксары">Чебоксары</option>
# <option value="Челябинск">Челябинск</option>
# <option value="Черкесск">Черкесск</option>
# <option value="Чита">Чита</option>
# <option value="Шахты">Шахты</option>
# <option value="Шымкент">Шымкент</option>
# <option value="Щелково">Щелково</option>
# <option value="Элиста">Элиста</option>
# <option value="Энгельс">Энгельс</option>
# <option value="Ярославль">Ярославль</option>
# <option value="пгт. Алексеевское">пгт. Алексеевское</option>
# </select>
# <div class="need_select_city" data-city="Москва">
# <div class="header__city-popup-arrow"></div>
# <div class="title">Ваш город <b>Москва</b>?</div>
# <div class="button_block">
# <button class="b-btn _red left">Да</button>
# <button class="b-btn _default right">Нет</button>
# </div>
# <div class="clear"></div>
# </div>
# </form>
# </div>
# </div>
# <div class="header__small-phone header__hide-mobile">
#                     Короткий номер:
#                     <span class="header__small-code"><span class="header__star"><span>*</span></span>1920</span>
# <div class="header__delivery-help-wrapper">
# <span class="header__delivery-help" data-phone-i="">i</span>
# <div class="header__delivery-help-message" data-phone-info="">
#                             Для абонентов Билайн, Мегафон, МТС, TELE2, Тинькофф мобайл.
#                         </div>
# </div>
# </div>
# </div>
# <div class="header__right"><a class="header__account b-ico__wrap link-border-solid" href="/auth/">
#                         Вход
#                     </a><a class="header__bascket b-ico__wrap link-border-solid" href="/personal/basket/">Корзина<!--<div class="header__bascket-count">--><!--</div>--></a> <div class="header__delivery">
# <div class="header__delivery-help-wrapper">
# <span class="header__delivery-help" data-delivery-i="">i</span>
# <div class="header__delivery-help-message" data-delivery-info="">
#                             Бесплатная доставка любого изделия.
#                             Заказы стоимостью от 200 тысяч рублей могут быть доставлены на дом после внесения 100% предоплаты безналичным способом или оплачены при получении в магазине.
#                         </div>
# </div>
#
#                     Бесплатная доставка
#                 </div>
# <span class="href header__search-mob" onclick="event.preventDefault();window.location.href='/search/';"></span>
# <a class="header__bascket-mob" href="/personal/basket/"></a>
# </div>
# <a class="header__logo" href="/">
# <!--<img alt="Официальный интернет-магазин производителя ювелирных украшений Московский ювелирный завод"
#      src=""/>-->
# <img alt="Официальный интернет-магазин производителя ювелирных украшений Московский ювелирный завод" src="/miuz/theme/images/logo_feb.png" title="Перейти на главную страницу"/>
# <img alt="Официальный интернет-магазин производителя ювелирных украшений Московский ювелирный завод" src="/miuz/theme/images/miuz_logo-02.svg" title="Перейти на главную страницу"/>
# </a>
# <div class="header__border-mob"></div>
# <div class="header__menu">
# <div class="header__menu-container">
# <div class="header__menu-droplink js-link-menu">
# <a class="header__menu-item _menu" href="/catalog/">
# <span class="title">Украшения</span>
# <span class="ico"></span>
# </a>
# <div class="header__menu-droplist _jewel" data-header-submenu="">
# <div class="header__flex-wrapper">
# <div class="col">
# <a class="col__title _active" data-header-submenu-photo-link-url="http://miuz.ru/catalog/rings/R97-MR17887-SA-PS/" data-header-submenu-photo-url="/upload/resize_cache/iblock/a05/280_280_2/R755_70643R001_R17.jpg" href="/catalog/rings/" title="Кольца">
# <img alt="Кольца" class="ico" src="/upload/uf/98f/koltsa.svg"/>
# <span class="title">Кольца
#                                             <span class="gold ib fix">(6989)</span>
# </span>
# </a>
# <div class="col__item">
# <a href="/catalog/rings/filter/stones_main-is-brilliant/">Кольца с бриллиантами</a>
# </div>
# <div class="col__item">
# <a href="/catalog/rings/filter/offers_metall-is-zoloto/">Золотые кольца</a>
# </div>
# <div class="col__item">
# <a href="/catalog/rings/filter/offers_metall-is-zoloto/offers_metall_color-is-belyy-zoloto/">Кольца из белого золота</a>
# </div>
# <div class="col__item">
# <a href="/catalog/rings/filter/collection-is-pomolvochnye_koltsa/">Помолвочные кольца</a>
# </div>
# <div class="col__item">
# <a href="/catalog/rings/filter/collection-is-obruchalnye_koltsa/">Обручальные кольца</a>
# </div>
# <a class="col__title" data-header-submenu-photo-link-url="http://miuz.ru/catalog/earrings/E97-CR2852E-SA/" data-header-submenu-photo-url="/upload/resize_cache/iblock/55d/280_280_2/E97_CR2852E_SA.jpg" href="/catalog/earrings/" title="Серьги">
# <img alt="Серьги" class="ico" src="/upload/uf/8a9/sergi.svg"/>
# <span class="title">Серьги
#                                             <span class="gold ib fix">(5850)</span>
# </span>
# </a>
# <div class="col__item">
# <a href="/catalog/earrings/filter/stones_main-is-brilliant/">Серьги с бриллиантами</a>
# </div>
# <div class="col__item">
# <a href="/catalog/earrings/filter/stones_main-is-sapfir/">С сапфирами</a>
# </div>
# <div class="col__item">
# <a href="/catalog/earrings/filter/stones_main-is-zhemchug/">С жемчугом</a>
# </div>
# <div class="col__item">
# <a href="/catalog/earrings/filter/offers_metall-is-zoloto/">Золотые серьги</a>
# </div>
# <div class="col__item">
# <a href="/catalog/earrings/filter/offers_metall-is-serebro/">Серебряные серьги</a>
# </div>
# <a class="col__title" data-header-submenu-photo-link-url="http://miuz.ru/catalog/pendants/P01-33583-SA/" data-header-submenu-photo-url="/upload/resize_cache/iblock/c57/280_280_2/p01_33583_sa.jpg" href="/catalog/pendants/" title="Подвески">
# <img alt="Подвески" class="ico" src="/upload/uf/4d0/podveski.svg"/>
# <span class="title">Подвески
#                                             <span class="gold ib fix">(1439)</span>
# </span>
# </a>
# <div class="col__item">
# <a href="/catalog/pendants/filter/stones_main-is-brilliant/">С бриллиантами</a>
# </div>
# <div class="col__item">
# <a href="/catalog/pendants/filter/offers_metall-is-zoloto/offers_metall_color-is-belyy-zoloto/">Из белого золота</a>
# </div>
# <div class="col__item">
# <a href="/catalog/pendants/filter/offers_metall-is-zoloto/">Золотые подвески</a>
# </div>
# <div class="col__item">
# <a href="/catalog/pendants/filter/offers_metall-is-serebro/">Серебряные подвески</a>
# </div>
# </div>
# <div class="col">
# <a class="col__title" data-header-submenu-photo-link-url="http://miuz.ru/catalog/necklace/N17-N00177-RU/" data-header-submenu-photo-url="/upload/resize_cache/iblock/7f7/280_280_2/N77_N49447_EM_R17.jpg" href="/catalog/necklace/" title="Колье">
# <img alt="Колье" class="ico" src="/upload/uf/b41/kole.svg"/>
# <span class="title">Колье
#                                             <span class="gold ib fix">(770)</span>
# </span>
# </a>
# <div class="col__item">
# <a href="/catalog/necklace/filter/stones_main-is-brilliant/">С бриллиантами</a>
# </div>
# <div class="col__item">
# <a href="/catalog/necklace/filter/stones_main-is-zhemchug/">С жемчугом</a>
# </div>
# <div class="col__item">
# <a href="/catalog/necklace/filter/offers_metall-is-zoloto/">Из золота</a>
# </div>
# <div class="col__item">
# <a href="/catalog/necklace/filter/offers_metall-is-serebro/">Из серебра</a>
# </div>
# <a class="col__title" data-header-submenu-photo-link-url="http://miuz.ru/catalog/bracelets/B01-RS-34175-MIX/" data-header-submenu-photo-url="/upload/resize_cache/iblock/09e/280_280_2/V4211_BG0702BRE1.jpg" href="/catalog/bracelets/" title="Браслеты">
# <img alt="Браслеты" class="ico" src="/upload/uf/7b9/braslety.svg"/>
# <span class="title">Браслеты
#                                             <span class="gold ib fix">(731)</span>
# </span>
# </a>
# <div class="col__item">
# <a href="/catalog/bracelets/filter/weaving_type-is-yakornoe/">Якорное</a>
# </div>
# <div class="col__item">
# <a href="/catalog/bracelets/filter/stones_main-is-brilliant/">С бриллиантами</a>
# </div>
# <div class="col__item">
# <a href="/catalog/bracelets/filter/stones_main-is-zhemchug/">С жемчугом</a>
# </div>
# <div class="col__item">
# <a href="/catalog/bracelets/filter/offers_metall-is-zoloto/">Золотые браслеты</a>
# </div>
# <div class="col__item">
# <a href="/catalog/bracelets/filter/offers_metall-is-serebro/">Серебряные браслеты</a>
# </div>
# ...
# </a>
# <a class="footer__bottom-item-social-item" href="http://instagram.com/miuz_ru" target="_blank">
# <svg viewbox="0 0 511 511.9" xmlns="http://www.w3.org/2000/svg"><path d="m510.949219 150.5c-1.199219-27.199219-5.597657-45.898438-11.898438-62.101562-6.5-17.199219-16.5-32.597657-29.601562-45.398438-12.800781-13-28.300781-23.101562-45.300781-29.5-16.296876-6.300781-34.898438-10.699219-62.097657-11.898438-27.402343-1.300781-36.101562-1.601562-105.601562-1.601562s-78.199219.300781-105.5 1.5c-27.199219 1.199219-45.898438 5.601562-62.097657 11.898438-17.203124 6.5-32.601562 16.5-45.402343 29.601562-13 12.800781-23.097657 28.300781-29.5 45.300781-6.300781 16.300781-10.699219 34.898438-11.898438 62.097657-1.300781 27.402343-1.601562 36.101562-1.601562 105.601562s.300781 78.199219 1.5 105.5c1.199219 27.199219 5.601562 45.898438 11.902343 62.101562 6.5 17.199219 16.597657 32.597657 29.597657 45.398438 12.800781 13 28.300781 23.101562 45.300781 29.5 16.300781 6.300781 34.898438 10.699219 62.101562 11.898438 27.296876 1.203124 36 1.5 105.5 1.5
,0,0,0-.22.24.66.66,0,0,0,0,.57,5.16,5.16,0,0,0,2.88,3.22,1.45,1.45,0,0,0,.74.18c.45-.05.6-.55.91-.81a.85.85,0,0,1,1,0c.33.21.66.44,1,.67a11.16,11.16,0,0,1,.92.71A.74.74,0,0,1,25,22.51Zm-2.6-4.77h0a.33.33,0,0,1-.34-.32A3.39,3.39,0,0,0,22,17a1.21,1.21,0,0,0-.44-.7,1.14,1.14,0,0,0-.36-.17c-.16,0-.33,0-.49-.07a.31.31,0,0,1-.25-.35.32.32,0,0,1,.34-.26,1.83,1.83,0,0,1,1.87,1.83.85.85,0,0,1,0,.26.26.26,0,0,1-.23.22Zm-.66-2.79a3.59,3.59,0,0,0-1-.31l-.46-.06a.29.29,0,0,1-.27-.33.29.29,0,0,1,.32-.28,4.14,4.14,0,0,1,1.74.46A3.55,3.55,0,0,1,24,17.17c0,.06,0,.11,0,.17s0,.28,0,.46A1.29,1.29,0,0,1,24,18a.3.3,0,0,1-.57,0,.81.81,0,0,1,0-.26A3.27,3.27,0,0,0,23,16.14,3,3,0,0,0,21.75,14.94Zm3.4,3.83c-.21,0-.31-.18-.32-.37,0-.38,0-.76-.1-1.14a4.77,4.77,0,0,0-3.82-4c-.3-.05-.6-.07-.9-.1s-.44,0-.48-.27a.33.33,0,0,1,.32-.37H20A5.41,5.41,0,0,1,25.3,17c.08.45.11.91.14,1.37A.32.32,0,0,1,25.15,18.78Z"></path>
# </g>
# </g>
# </svg>
# </a>
# </div>
# </div>
# <a class="footer__bottom-item-tell" data-target="click_phone" href="tel:88001001920">8(800)100-19-20</a>
# <div class="footer__bottom-gia" style="padding-top: 15px"><img src="/miuz/theme/images/gia.png"/></div>
# </div>
# </div>
# <div class="footer__bottom-copy">
# 	 Copyright © 2021 Московский ювелирный завод
# </div>
# <br/> </div>
# </div>
# </footer>
# <script async="async" src="https://yastatic.net/share2/share.js"></script>
# <!-- Garderobo AI -->
# <script src="https://widget.garderobo.ai/widget.js"></script>
# <script>
#     $(document).ready(function(){
#         Garderobo.init();
#     });
# </script>
# <!-- Garderobo AI -->
# <!-- {literal} -->
# <script>
#         $(document).ready(function(){
#             setTimeout(function() {
#                 window['liv'+'eTe'+'x'] = true,
#                     window['liv'+'eTe'+'xI'+'D'] = 111693,
#                     window['liveT'+'ex_ob'+'je'+'ct'] = true;
#                 var t = document['crea'+'t'+'eEleme'+'nt']('script');
#                 t.type ='text/javascript';
#                 t.async = true;
#                 t.src = '//cs15.live'+'tex.'+'ru/js/cli'+'en'+'t.js';
#                 var c = document['g'+'etE'+'le'+'mentsByT'+'ag'+'N'+'ame']('script')[0];
#                 if ( c ) c['par'+'en'+'t'+'N'+'ode']['i'+'nser'+'tBe'+'for'+'e'](t, c);
#                 else document['documen'+'t'+'Ele'+'men'+'t']['fi'+'rstCh'+'i'+'ld']['app'+'endCh'+'il'+'d'](t);
#             },5000);
#         });
#     </script>
# <!-- {/literal} -->
# <!-- Retail Rocket -->
# <script>
#     var rrPartnerId = "514ffe4987900a05d43e4664";
#     var rrApi = {};
#     var rrApiOnReady = rrApiOnReady || [];
#     rrApi.addToBasket = rrApi.order = rrApi.categoryView = rrApi.view =
#         rrApi.recomMouseDown = rrApi.recomAddToCart = function () {
#         };
#     (function (d) {
#         var ref = d.getElementsByTagName('script')[0];
#         var apiJs, apiJsId = 'rrApi-jssdk';
#         if (d.getElementById(apiJsId)) return;
#         apiJs = d.createElement('script');
#         apiJs.id = apiJsId;
#         apiJs.async = true;
#         apiJs.src = "//cdn.retailrocket.ru/content/javascript/tracking.js";
#         ref.parentNode.insertBefore(apiJs, ref);
#     }(document));
# </script>
# <!-- Retail Rocket -->
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-KLWF6Q" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!--пиксель продублирован  в файле /certificates/index.php-->
# <!-- Facebook Pixel Code -->
# <script>
#         !function (f, b, e, v, n, t, s) {
#             if (f.fbq) return;
#             n = f.fbq = function () {
#                 n.callMethod ? n.callMethod.apply(n, arguments) : n.queue.push(arguments)
#             };
#             if (!f._fbq) f._fbq = n;
#             n.push = n;
#             n.loaded = !0;
#             n.version = '2.0';
#             n.queue = [];
#             t = b.createElement(e);
#             t.async = !0;
#             t.src = v;
#             s = b.getElementsByTagName(e)[0];
#             s.parentNode.insertBefore(t, s)
#         }(window, document, 'script', 'https://connect.facebook.net/en_US/fbevents.js');
#         fbq('init', '650512918440434');
#         fbq('track', 'PageView');
#     </script>
# <!-- End Facebook Pixel Code -->
# <!-- Facebook Pixel Code -->
# <script>
#         !function (f, b, e, v, n, t, s) {
#             if (f.fbq) return;
#             n = f.fbq = function () {
#                 n.callMethod ?
#                     n.callMethod.apply(n, arguments) : n.queue.push(arguments)
#             };
#             if (!f._fbq) f._fbq = n;
#             n.push = n;
#             n.loaded = !0;
#             n.version = '2.0';
#             n.queue = [];
#             t = b.createElement(e);
#             t.async = !0;
#             t.src = v;
#             s = b.getElementsByTagName(e)[0];
#             s.parentNode.insertBefore(t, s)
#         }(window, document, 'script',
#             'https://connect.facebook.net/en_US/fbevents.js');
#         fbq('init', '681116522342148');
#         fbq('track', 'PageView');
#     </script>
# <noscript><img alt="" height="1" src="https://www.facebook.com/tr?id=681116522342148&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <!-- VK Remarketing -->
# <script>
#         var PIXEL_ID = 'VK-RTRG-38746-4FC1F';
#         var PRICE_LIST_ID = '126981';
#     </script>
# <div id="vk_api_transport"></div>
# <!--<script>
#         window.vkAsyncInit = function() {
#             VK.Retargeting.Init(PIXEL_ID);
#         };
#
#         setTimeout(function() {
#             var el = document.createElement("script");
#             el.type = "text/javascript";
#             el.src = "https://vk.com/js/api/openapi.js?150";
#             el.async = true;
#             document.getElementById("vk_api_transport").appendChild(el);
#         }, 0);
#     </script>-->
# <script>!function(){var t=document.createElement("script");t.type="text/javascript",t.async=!0,t.src="https://vk.com/js/api/openapi.js?169",t.onload=function(){VK.Retargeting.Init("VK-RTRG-943158-afU3I"),VK.Retargeting.Hit()},document.head.appendChild(t)}();</script><noscript><img alt="" src="https://vk.com/rtrg?p=VK-RTRG-943158-afU3I" style="position:fixed; left:-999px;"/></noscript>
# <!--RTBHouse-->
# <script>
#         (function (window) {
#             var BX = window.BX;
#             if (BX && BX.rtb)
#             {
#                 BX.rtb('unknown').page();
#             }
#         })(window);
#     </script>
# </body>
# </html>

# %%
card = mysoup(urlcard)
row = len(data)
data.loc[row,'h1'] = card.find("h1").text.strip()
data.loc[row,'art'] = card.select('body > div.grid > div > div > div.shops__breadcrumbs.catalog_breadcrumbs > div > div:nth-child(4) > span > span')

data.loc[row,'price'] = float(''.join(re.findall(r'\d+', card.find('div',"detail__item-price-new").text)))
              

#quotes_inner = card.find_all('div', "detail__item-option")
#quotes_inner

data.loc[row,'gold'] = re.findall(r"(Золото\s+\d+)",str(quotes_inner[0]))[0]

data.loc[row,'weight'] = float(re.findall(r"(?:Вес:</span>\n)\s+(\d+.\d+)",str(card))[0])

div_gems = card.select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)')

data.loc[row,'gems'] = re.search(r'Камни:\s+([\w\W]+)', str(div_gems[0].text.strip()))[1]

# %%
patt_muis = r"""(?ix) (?P<N>\d*)\s+(?:Брилл\w+)(?P<Form>[\w\W])[^,]"""

# %%
re.findall(patt_muis,div_gems[0].text.strip() )
# Out:
# [('14', ' '), ('1', ' ')]

# %%
response = requests.get(urls)

# %%
soup = BeautifulSoup(response.text, 'lxml')
quotes = soup.find_all('div', class_="product")

# %%
domain = 'https://miuz.ru'

# %%
link_to_product = domain+quotes[1].find("a").get("href")

# %%
response_inner = requests.get(link_to_product)

# %%
soup_inner = BeautifulSoup(response_inner.text, 'lxml')

# %%
quotes_inner = soup_inner.find_all('div', "detail__item-option")
quotes_inner
# Out:
# [<div class="detail__item-option"><span>Металл:</span>
#  <span class="href" onclick="event.preventDefault(); window.location.href='/catalog/filter/offers_metall-is-zoloto/offers_metall_karat-is-585'; event.stopPropagation();">
#                              Золото 585                        </span>
#  </div>,
#  <div class="detail__item-option">
#  <span>Вес:</span>
#                      2.07 г.                </div>,
#  <div class="detail__item-option"><span>Камни:</span>
#                      14  Бриллиантов огранки "Круглая" граней - 57, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/cutForm/'); event.stopPropagation();">тип огранки</span> A, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/razmer-tsvet-ves/'); event.stopPropagation();">цвет</span> 3, <span class="href" onclick="event.preventDefault(); window.open('/guide/quality/chistota-brillianta/'); event.stopPropagation();">чистота</span> 7, 0.09 карат;<br/>1  Бриллиант огранки "Круглая" граней - 57, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/cutForm/'); event.stopPropagation();">тип огранки</span> A, <span class="href" onclick="event.preventDefault(); window.open('/guide/stones/dragotsennye-kamni/brilliant/razmer-tsvet-ves/'); event.stopPropagation();">цвет</span> 3, <span class="href" onclick="event.preventDefault(); window.open('/guide/quality/chistota-brillianta/'); event.stopPropagation();">чистота</span> 7, 0.23 карат;<br/> </div>,
#  <div class="detail__item-option"><span>Описание:</span>Solo 1920 – это эксклюзивная флагманская коллекция, в которой солирует король всех драгоценных камней. Единственный и неповторимый, сияющий и покоряющий сердца, Его Величество Бриллиант</div>,
#  <div class="detail__item-option detail__item-option--collections"><span>Коллекция:</span>
#  <span class="href" onclick="event.preventDefault(); window.open('/catalog/filter/collection-is-solo_1920/'); event.stopPropagation();">Solo 1920</span>
#  <span class="href" onclick="event.preventDefault(); window.open('/catalog/filter/collection-is-pomolvochnye_koltsa/'); event.stopPropagation();">Помолвочные кольца</span>
#  </div>,
#  <div class="detail__item-option">
#  <div class="detail__item-bookings" only-booking="">
#  <div class="detail__item-booking">
#  <div class="detail__item-booking-img">
#  <img alt="" src="/miuz/theme/images/detail/delivery-box.svg"/>
#  </div>
#  <span>Бесплатная доставка курьером</span>
#  </div>
#  <div class="detail__item-booking">
#  <div class="detail__item-booking-img">
#  <img alt="" src="/miuz/theme/images/detail/pushpin.svg"/>
#  </div>
#  <span>Получите заказ в фирменном магазине MIUZ Diamonds</span>
#  </div>
#  <div class="detail__item-booking">
#  <div class="detail__item-booking-img">
#  <img alt="" src="/miuz/theme/images/detail/pushpin.svg"/>
#  </div>
#  <span>Заберите заказ в удобном пункте выдачи заказов</span>
#  </div>
#  <br/>
#  </div>
#  </div>]

# %%
str(quotes_inner[2].find('span',"href"))
# Out:
# '<span class="href" onclick="event.preventDefault(); window.open(\'/guide/stones/dragotsennye-kamni/brilliant/cutForm/\'); event.stopPropagation();">тип огранки</span>'

# %%
select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)')

# %%
body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)

# %%
div class="detail__item-option"

# %%
BeautifulSoup(response_inner.text, 'lxml')
# Out:
# <!DOCTYPE html>
# <html lang="ru">
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# product: http://ogp.me/ns/product#">
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="no-referrer-when-downgrade" name="referrer"/>
# <meta content="_qgYWIuV2xT0oumXLChfyILXpWboP-DV-NzpKDk2EOs" name="google-site-verification"/>
# <meta content="Предлагаем купить Кольцо, артикул R01-WED-00084-MIX, Золото 585,  – цены в каталоге интернет-магазина Московский ювелирный завод, телефон: 8 (800) 100-19-20." name="description"/>
# <meta content="product" property="og:type"/>
# <meta content="https://miuz.ru/catalog/rings/R01-WED-00084-MIX/" property="og:url"/>
# <meta content="Кольцо Артикул R01-WED-00084-MIX" property="og:title"/>
# <meta content="Предлагаем купить Кольцо, артикул R01-WED-00084-MIX, Золото 585,  – цены в каталоге интернет-магазина Московский ювелирный завод, телефон: 8 (800) 100-19-20." property="og:description"/>
# <meta content="https://miuz.ru/upload/resize_cache/iblock/4c3/580_580_0/R01_WED_00084_MIX.jpg" property="og:image"/>
# <meta content="510" property="og:image:width"/>
# <meta content="228" property="og:image:height"/>
# <meta content="13606.60" property="product:original_price:amount"/>
# <meta content="RUB" property="product:original_price:currency"/>
# <meta content="instock" property="product:availability"/>
# <base href="https://miuz.ru/"/>
# <meta content="telephone=no" name="format-detection"/>
# <!--<script src="/miuz/theme/js/libs/zoom/jquery.elevateZoom-3.0.8.min.js"></script>-->
# <script async="" src="https://api-maps.yandex.ru/2.1/?lang=ru_RU"></script>
# <style>
#             @font-face {
#                 font-family: 'pt_sansregular';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/pts55f-webfont.eot');
#                 src: url('/miuz/theme/fonts/pts55f-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/pts55f-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/pts55f-webfont.woff') format('woff'), url('/miuz/theme/fonts/pts55f-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/pts55f-webfont.svg#pt_sansregular') format('svg');
#                 font-weight: normal;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'circe';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/crc15-webfont.eot');
#                 src: url('/miuz/theme/fonts/crc15-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/crc15-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/crc15-webfont.woff') format('woff'), url('/miuz/theme/fonts/crc15-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/crc15-webfont.svg#circe_thinthin') format('svg');
#                 font-weight: 100;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'circe';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/crc25-webfont.eot');
#                 src: url('/miuz/theme/fonts/crc25-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/crc25-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/crc25-webfont.woff') format('woff'), url('/miuz/theme/fonts/crc25-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/crc25-webfont.svg#circeextra_light') format('svg');
#                 font-weight: 200;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'circe';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/crc35-webfont.eot');
#                 src: url('/miuz/theme/fonts/crc35-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/crc35-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/crc35-webfont.woff') format('woff'), url('/miuz/theme/fonts/crc35-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/crc35-webfont.svg#circelight') format('svg');
#                 font-weight: 300;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'circe';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/crc55-webfont.eot');
#                 src: url('/miuz/theme/fonts/crc55-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/crc55-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/crc55-webfont.woff') format('woff'), url('/miuz/theme/fonts/crc55-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/crc55-webfont.svg#circeregular') format('svg');
#                 font-weight: 500;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'circe';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/crc65-webfont.eot');
#                 src: url('/miuz/theme/fonts/crc65-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/crc65-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/crc65-webfont.woff') format('woff'), url('/miuz/theme/fonts/crc65-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/crc65-webfont.svg#circebold') format('svg');
#                 font-weight: 600;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'circe';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/crc75-webfont.eot');
#                 src: url('/miuz/theme/fonts/crc75-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/crc75-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/crc75-webfont.woff') format('woff'), url('/miuz/theme/fonts/crc75-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/crc75-webfont.svg#circeextra_bold') format('svg');
#                 font-weight: 700;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'ABodoniNova';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/a_bodoninova-webfont.eot');
#                 src: url('/miuz/theme/fonts/a_bodoninova-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/a_bodoninova-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/a_bodoninova-webfont.woff') format('woff'), url('/miuz/theme/fonts/a_bodoninova-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/a_bodoninova-webfont.svg#a_bodoninovaregular') format('svg');
#                 font-weight: 400;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'ABodoniNova';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/a_bodoninova_bold-webfont.eot');
#                 src: url('/miuz/theme/fonts/a_bodoninova_bold-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/a_bodoninova_bold-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/a_bodoninova_bold-webfont.woff') format('woff'), url('/miuz/theme/fonts/a_bodoninova_bold-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/a_bodoninova_bold-webfont.svg#a_bodoninovabold') format('svg');
#                 font-weight: 700;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'ABodoniNova';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/a_bodoninova_bolditalic-webfont.eot');
#                 src: url('/miuz/theme/fonts/a_bodoninova_bolditalic-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/a_bodoninova_bolditalic-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/a_bodoninova_bolditalic-webfont.woff') format('woff'), url('/miuz/theme/fonts/a_bodoninova_bolditalic-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/a_bodoninova_bolditalic-webfont.svg#a_bodoninovabolditalic') format('svg');
#                 font-weight: 700;
#                 font-style: italic;
#             }
#             @font-face {
#                 font-family: 'ABodoniNova';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/a_bodoninova_italic-webfont.eot');
#                 src: url('/miuz/theme/fonts/a_bodoninova_italic-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/a_bodoninova_italic-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/a_bodoninova_italic-webfont.woff') format('woff'), url('/miuz/theme/fonts/a_bodoninova_italic-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/a_bodoninova_italic-webfont.svg#a_bodoninovaitalic') format('svg');
#                 font-weight: 400;
#                 font-style: italic;
#             }
#             @font-face {
#                 font-family: 'FuturaPT';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/futuraptbold-webfont.eot');
#                 src: url('/miuz/theme/fonts/futuraptbold-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/futuraptbold-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/futuraptbold-webfont.woff') format('woff'), url('/miuz/theme/fonts/futuraptbold-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/futuraptbold-webfont.svg#futura_ptbold') format('svg');
#                 font-weight: 700;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'FuturaPT';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/futuraptboldoblique-webfont.eot');
#                 src: url('/miuz/theme/fonts/futuraptboldoblique-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/futuraptboldoblique-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/futuraptboldoblique-webfont.woff') format('woff'), url('/miuz/theme/fonts/futuraptboldoblique-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/futuraptboldoblique-webfont.svg#futura_pt_bold_italicregular') format('svg');
#                 font-weight: 700;
#                 font-style: italic;
#             }
#             @font-face {
#                 font-family: 'FuturaPT';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/futuraptbook-webfont.eot');
#                 src: url('/miuz/theme/fonts/futuraptbook-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/futuraptbook-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/futuraptbook-webfont.woff') format('woff'), url('/miuz/theme/fonts/futuraptbook-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/futuraptbook-webfont.svg#futura_ptbook') format('svg');
#                 font-weight: 400;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'FuturaPT';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/futuraptbookoblique-webfont.eot');
#                 src: url('/miuz/theme/fonts/futuraptbookoblique-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/futuraptbookoblique-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/futuraptbookoblique-webfont.woff') format('woff'), url('/miuz/theme/fonts/futuraptbookoblique-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/futuraptbookoblique-webfont.svg#futura_pt_book_italicregular') format('svg');
#                 font-weight: 400;
#                 font-style: italic;
#             }
#             @font-face {
#                 font-family: 'FuturaPT';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/futuraptdemi-webfont.eot');
#                 src: url('/miuz/theme/fonts/futuraptdemi-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/futuraptdemi-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/futuraptdemi-webfont.woff') format('woff'), url('/miuz/theme/fonts/futuraptdemi-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/futuraptdemi-webfont.svg#futura_ptdemi') format('svg');
#                 font-weight: 600;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'FuturaPT';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/futuraptextrabold-webfont.eot');
#                 src: url('/miuz/theme/fonts/futuraptextrabold-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/futuraptextrabold-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/futuraptextrabold-webfont.woff') format('woff'), url('/miuz/theme/fonts/futuraptextrabold-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/futuraptextrabold-webfont.svg#futura_ptextra_bold') format('svg');
#                 font-weight: 900;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'FuturaPT';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/futuraptheavy-webfont.eot');
#                 src: url('/miuz/theme/fonts/futuraptheavy-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/futuraptheavy-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/futuraptheavy-webfont.woff') format('woff'), url('/miuz/theme/fonts/futuraptheavy-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/futuraptheavy-webfont.svg#futura_ptheavy') format('svg');
#                 font-weight: 800;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'FuturaPT';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/futuraptlight-webfont.eot');
#                 src: url('/miuz/theme/fonts/futuraptlight-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/futuraptlight-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/futuraptlight-webfont.woff') format('woff'), url('/miuz/theme/fonts/futuraptlight-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/futuraptlight-webfont.svg#futura_ptlight') format('svg');
#                 font-weight: 300;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'FuturaPT';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/futuraptmedium-webfont.eot');
#                 src: url('/miuz/theme/fonts/futuraptmedium-webfont.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/futuraptmedium-webfont.woff2') format('woff2'), url('/miuz/theme/fonts/futuraptmedium-webfont.woff') format('woff'), url('/miuz/theme/fonts/futuraptmedium-webfont.ttf') format('truetype'), url('/miuz/theme/fonts/futuraptmedium-webfont.svg#futura_ptmedium') format('svg');
#                 font-weight: 500;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'PT Serif';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/PTSerif-Regular.eot');
#                 src: url('/miuz/theme/fonts/PTSerif-Regular.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/PTSerif-Regular.woff') format('woff'), url('/miuz/theme/fonts/PTSerif-Regular.ttf') format('truetype'), url('/miuz/theme/fonts/PTSerif-Regular.svg#PTSerif-Regular') format('svg');
#                 font-weight: 400;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'Diploma Script Basic';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/latinotype-diploma-script-basic.eot');
#                 src: url('/miuz/theme/fonts/latinotype-diploma-script-basic.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/latinotype-diploma-script-basic.woff2') format('woff2'), url('/miuz/theme/fonts/latinotype-diploma-script-basic.woff') format('woff'), url('/miuz/theme/fonts/latinotype-diploma-script-basic.ttf') format('truetype'), url('/miuz/theme/fonts/latinotype-diploma-script-basic.svg#DiplomaScript-Basic') format('svg');
#                 font-weight: 400;
#                 font-style: normal;
#             }
#             @font-face {
#                 font-family: 'Gabriela Stencil Black';
#                 font-display: swap;
#                 src: url('/miuz/theme/fonts/latinotype-gabriela-stencil-black.eot');
#                 src: url('/miuz/theme/fonts/latinotype-gabriela-stencil-black.eot?#iefix') format('embedded-opentype'), url('/miuz/theme/fonts/latinotype-gabriela-stencil-black.woff2') format('woff2'), url('/miuz/theme/fonts/latinotype-gabriela-stencil-black.woff') format('woff'), url('/miuz/theme/fonts/latinotype-gabriela-stencil-black.ttf') format('truetype'), url('/miuz/theme/fonts/latinotype-gabriela-stencil-black.svg#GabrielaStencil-Black') format('svg');
#                 font-weight: 400;
#                 font-style: normal;
#             }
#         </style>
# <!--[if lt IE 9]>
#         <script src="http://html5shiv.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <title>Кольцо, артикул R01-WED-00084-MIX, Золото 585,  - купить в интернет-магазине Московский ювелирный завод</title>
# <script async="" src="//static.criteo.net/js/ld/ld.js"></script>
# <script>
#             window.criteo_q = window.criteo_q || [];
#             window.criteo_q.push(
#                 {event:"setAccount", account:34906},
#                 {event:"setSiteType", type:"d"},
#                 {event:"setEmail", email:""}
#             );
#         </script>
# <script>
#             const RTB_HOUSE_UID = "unknown";
#         </script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="/bitrix/cache/css/s1/muz/page_d2e5973148e9adcfd4f259abb66b5563/page_d2e5973148e9adcfd4f259abb66b5563_v1.css?1635844522441" rel="stylesheet" type="text/css"/>
# <link data-template-style="true" href="/bitrix/cache/css/s1/muz/template_a7d7562c40b1c14f30c22935a60706db/template_a7d7562c40b1c14f30c22935a60706db_v1.css?1635844522865508" rel="stylesheet" type="text/css"/>
# <script>if(!window.BX)window.BX={};if(!window.BX.message)window.BX.message=function(mess){if(typeof mess=='object') for(var i in mess) BX.message[i]=mess[i]; return true;};</script>
# <script>(window.BX||top.BX).message({'JS_CORE_LOADING':'Загрузка...','JS_CORE_NO_DATA':'- Нет данных -','JS_CORE_WINDOW_CLOSE':'Закрыть','JS_CORE_WINDOW_EXPAND':'Развернуть','JS_CORE_WINDOW_NARROW':'Свернуть в окно','JS_CORE_WINDOW_SAVE':'Сохранить','JS_CORE_WINDOW_CANCEL':'Отменить','JS_CORE_WINDOW_CONTINUE':'Продолжить','JS_CORE_H':'ч','JS_CORE_M':'м','JS_CORE_S':'с','JSADM_AI_HIDE_EXTRA':'Скрыть лишние','JSADM_AI_ALL_NOTIF':'Показать все','JSADM_AUTH_REQ':'Требуется авторизация!','JS_CORE_WINDOW_AUTH':'Войти','JS_CORE_IMAGE_FULL':'Полный размер'});</script>
# <script src="/bitrix/js/main/core/core.min.js?1592347382249634"></script>
# <script>BX.setJSList(['/bitrix/js/main/core/core_ajax.js','/bitrix/js/main/core/core_promise.js','/bitrix/js/main/polyfill/promise/js/promise.js','/bitrix/js/main/loadext/loadext.js','/bitrix/js/main/loadext/extension.js','/bitrix/js/main/polyfill/promise/js/promise.js','/bitrix/js/main/polyfill/find/js/find.js','/bitrix/js/main/polyfill/includes/js/includes.js','/bitrix/js/main/polyfill/matches/js/matches.js','/bitrix/js/ui/polyfill/closest/js/closest.js','/bitrix/js/main/polyfill/fill/main.polyfill.fill.js','/bitrix/js/main/polyfill/find/js/find.js','/bitrix/js/main/polyfill/matches/js/matches.js','/bitrix/js/main/polyfill/core/dist/polyfill.bundle.js','/bitrix/js/main/core/core.js','/bitrix/js/main/polyfill/intersectionobserver/js/intersectionobserver.js','/bitrix/js/main/lazyload/dist/lazyload.bundle.js','/bitrix/js/main/polyfill/core/dist/polyfill.bundle.js','/bitrix/js/main/parambag/dist/parambag.bundle.js']);
# BX.setCSSList(['/bitrix/js/main/core/css/core.css','/bitrix/js/main/lazyload/dist/lazyload.bundle.css','/bitrix/js/main/parambag/dist/parambag.bundle.css']);</script>
# <script>(window.BX||top.BX).message({'LANGUAGE_ID':'ru','FORMAT_DATE':'DD.MM.YYYY','FORMAT_DATETIME':'DD.MM.YYYY HH:MI:SS','COOKIE_PREFIX':'BITRIX_SM','SERVER_TZ_OFFSET':'10800','SITE_ID':'s1','SITE_DIR':'/','USER_ID':'','SERVER_TIME':'1636419059','USER_TZ_OFFSET':'0','USER_TZ_AUTO':'Y','bitrix_sessid':'81d9811e431bd757c3800d674f33bfd8'});</script>
# <script>BX.setJSList(['/local/components/aero/catalog/templates/aero/miuz/catalog.section/catalogElement/script.js','/local/js/miuz/rtb/dist/rtb.js','/miuz/theme/js/libs/bitrix.js','/miuz/theme/js/libs/jquery-3.3.1.min.js','/miuz/theme/js/libs/jquery-2.1.1.min.js','/miuz/theme/js/libs/zoom/jquery.elevatezoom.min.js','/miuz/theme/js/libs/lazyload.min.js','/local/templates/muz/js/slick.min.js','/local/templates/muz/js/jquery.inputmask.min.js','/miuz/theme/js/deviceDetect.min.js','/miuz/theme/js/libs/libs.min.js','/miuz/theme/js/components/Application.js','/local/templates/muz/js/flipclock.min.js','/local/templates/muz/js/script.js','/local/templates/muz/js/metric.js','/miuz/theme/js/libs/magnific-popup/magnific-popup.min.js','/local/js/miuz/Soloway/class.js','/bitrix/components/bitrix/search.title/script.js','/local/templates/muz/components/bitrix/search.title/.default/script.js','/miuz/theme/js/components/Utils.js','/miuz/theme/js/components/Loader.js','/miuz/theme/js/components/Size.js','/miuz/theme/js/BView/GlobalView.js','/miuz/theme/js/BView/Header.js','/miuz/theme/js/BView/Shops.js','/miuz/theme/js/BView/Footer.js','/miuz/theme/js/BView/Default.js','/miuz/theme/js/BView/NotFound.js','/miuz/theme/js/BView/StopSending.js','/miuz/theme/js/BView/Home.js','/miuz/theme/js/libs/svg.min.js','/miuz/theme/js/BView/Catalog.js','/miuz/theme/js/BView/Detail.js','/miuz/theme/js/BView/Discount.js','/miuz/theme/js/BView/Text.js','/miuz/theme/js/BView/Certificate.js','/miuz/theme/js/BView/Contacts.js','/miuz/theme/js/BView/News.js','/miuz/theme/js/BView/Thank.js','/miuz/theme/js/BView/RegionShops.js','/miuz/theme/js/BView/Brilliant.js','/miuz/theme/js/BView/Lk.js','/miuz/theme/js/BView/Enter.js','/miuz/theme/js/BView/BrilliantPair.js','/miuz/theme/js/BView/Collection.js','/miuz/theme/js/BView/Connect.js','/miuz/theme/js/BView/Vacancy.js','/miuz/theme/js/BView/VacancyForm.js','/miuz/theme/js/BView/Vacancies.js','/miuz/theme/js/BView/Stones.js','/miuz/theme/js/BView/Care.js','/miuz/theme/js/BView/Search.js','/miuz/theme/js/BView/Emerald.js','/miuz/theme/js/BView/Diamond.js','/miuz/theme/js/BView/Products.js','/miuz/theme/js/BView/Product.js','/miuz/theme/js/BView/Weight.js','/miuz/theme/js/BView/Links.js','/miuz/theme/js/BView/Element.js','/miuz/theme/js/BView/History.js','/miuz/theme/js/BView/Admin.js','/miuz/theme/js/libs/jquery.mCustomScrollbar.concat.min.js','/miuz/theme/js/BView/RegionalContacts.js','/miuz/theme/js/Router.js','/miuz/theme/js/script.js','/local/js/miuz/garderobo/class.js']); </script>
# <script>BX.setCSSList(['/local/components/aero/catalog/templates/aero/miuz/catalog.section/catalogElement/style.css','/local/templates/muz/css/flipclock.css','/miuz/theme/css/swiper.min.css','/miuz/theme/css/chosen.min.css','/miuz/theme/css/bitrix.css','/miuz/theme/js/libs/jquery-ui/jquery-ui.min.css','/miuz/theme/js/libs/fancybox/jquery.fancybox.min.css','/miuz/theme/generator.css','/miuz/theme/template_styles.css','/local/templates/muz/css/landings/slick.css','/miuz/theme/js/libs/magnific-popup/magnific-popup.min.css','/local/templates/muz/components/bitrix/search.title/.default/style.css','/miuz/theme/css/jquery.mCustomScrollbar.min.css','/local/templates/muz/styles.css','/local/templates/muz/template_styles.css']); </script>
# <script>
# 					(function () {
# 						"use strict";
#
# 						var counter = function ()
# 						{
# 							var cookie = (function (name) {
# 								var parts = ("; " + document.cookie).split("; " + name + "=");
# 								if (parts.length == 2) {
# 									try {return JSON.parse(decodeURIComponent(parts.pop().split(";").shift()));}
# 									catch (e) {}
# 								}
# 							})("BITRIX_CONVERSION_CONTEXT_s1");
#
# 							if (cookie && cookie.EXPIRE >= BX.message("SERVER_TIME"))
# 								return;
#
# 							var request = new XMLHttpRequest();
# 							request.open("POST", "/bitrix/tools/conversion/ajax_counter.php", true);
# 							request.setRequestHeader("Content-type", "application/x-www-form-urlencoded");
# 							request.send(
# 								"SITE_ID="+encodeURIComponent("s1")+
# 								"&sessid="+encodeURIComponent(BX.bitrix_sessid())+
# 								"&HTTP_REFERER="+encodeURIComponent(document.referrer)
# 							);
# 						};
#
# 						if (window.frameRequestStart === true)
# 							BX.addCustomEvent("onFrameDataReceived", counter);
# 						else
# 							BX.ready(counter);
# 					})();
# 				</script>
# <link as="font" crossorigin="" href="/miuz/theme/fonts/crc35-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/miuz/theme/fonts/crc65-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/miuz/theme/fonts/futuraptlight-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/miuz/theme/fonts/futuraptdemi-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/miuz/theme/fonts/futuraptbold-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/miuz/theme/fonts/futuraptbook-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="image" href="/miuz/theme/images/logo_msk.svg" rel="preload"/>
# <link as="image" href="/miuz/theme/images/car.svg" rel="preload"/>
# <link as="image" href="/miuz/theme/images/icons/search.svg" rel="preload"/>
# <link as="image" href="/miuz/theme/images/background__counter.svg" rel="preload"/>
# <link as="image" href="/miuz/theme/images/pixel.gif" rel="preload"/>
# <link as="image" href="/miuz/theme/images/box-brilliant.png" rel="preload"/>
# <link as="image" href="/miuz/theme/images/icons/spritesheet.png" rel="preload"/>
# <link as="image" href="/miuz/theme/images/icons/spritesheet_new.png" rel="preload"/>
# <link as="image" href="/miuz/theme/images/icons/ico-help-grey.png" rel="preload"/>
# <link as="image" href="/miuz/theme/images/icons/viber.svg" rel="preload"/>
# <script async="" src="https://www.youtube.com/iframe_api"></script>
# <link href="//google-analytics.com" rel="preconnect"/>
# <link href="//mc.yandex.ru/" rel="preconnect"/>
# <link href="//top-fwz1.mail.ru" rel="preconnect"/>
# <script>window.criteo_q.push({event:"viewItem", item:"R01-WED-00084-MIX"});</script>
# <script>if (typeof(window.fbq) !== "undefined") fbq.push(["track", "ViewContent", {content_type: "product", content_ids:["R01-WED-00084-MIX"]}]);</script>
# <link href="https://miuz.ru/catalog/rings/R01-WED-00084-MIX/" rel="canonical"/>
# <script>
#             dataLayer = [
#                 {"pageType":"ProductPage","City":"","product":{"groupId":3953109,"name":"Кольцо","price":13606,"oldPrice":19438,"pictureUrl":"https://miuz.ru/upload/resize_cache/iblock/4c3/400_400_2/R01_WED_00084_MIX.jpg","url":"https://miuz.ru/catalog/rings/R01-WED-00084-MIX/","model":"R01-WED-00084-MIX","vendor":"МЮЗ","params":{"minPrice":13606,"minOldPrice":19438,"delivery":true},"isAvailable":true,"categoryPaths":"Кольца/ Кольца без камней/","description":"","typePrefix":"Кольца","modifications":{"72779523":{"vendor":"МЮЗ","isAvailable":true,"price":15565,"oldPrice":22237,"size":"15.5","color":"Микс","params":{"коллекция":"Infinite love ,Обручальные кольца,Свадебное предложение","металл":"Золото","проба":"585","камень":"","вес":"2.78"}},"72799798":{"vendor":"МЮЗ","isAvailable":true,"price":15789,"oldPrice":22557,"size":"15.5","color":"Микс","params":{"коллекция":"Infinite love ,Обручальные кольца,Свадебное предложение","металл":"Золото","проба":"585","камень":"","вес":"2.82"}},"72866609":{"vendor":"МЮЗ","isAvailable":true,"price":15229,"oldPrice":21757,"size":"15.5","color":"Микс","params":{"коллекция":"Infinite love ,Обручальные кольца,Свадебное предложение","металл":"Золото","проба":"585","камень":"","вес":"2.72"}},"72740939":{"vendor":"МЮЗ","isAvailable":true,"price":15565,"oldPrice":22237,"size":"15.5","color":"Микс","params":{"коллекция":"Infinite love ,Обручальные кольца,Свадебное предложение","металл":"Золото","проба":"585","камень":"","вес":"2.78"}},"72799795":{"vendor":"МЮЗ","isAvailable":true,"price":16013,"oldPrice":22877,"size":"15.5","color":"Микс","params":{"коллекция":"Infinite love ,Обручальные кольца,Свадебное предложение","металл":"Золото","проба":"585","камень":"","вес":"2.86"}},"72785969":{"vendor":"МЮЗ","isAvailable":true,"price":15285,"oldPrice":21837,"size":"15.5","color":"Микс","params":{"коллекция":"Infinite love ,Обручальные кольца,Свадебное предложение","металл":"Золото","проба":"585","камень":"","вес":"2.73"}},"72778639":{"vendor":"МЮЗ","isAvailable":true,"price":16237,"oldPrice":23197,"size":"15.5","color":"Микс","params":{"коллекция":"Infinite love ,Обручальные кольца,Свадебное предложение","металл":"Золото","проба":"585","камень":"","вес":"2.9"}},"72788416":{"vendor":"МЮЗ","isAvailable":true,"price":15285,"oldPrice":21837,"size":"15.5","color":"Микс","params":{"коллекция":"Infinite love ,Обручальные кольца,Свадебное предложение","металл":"Золото","проба":"585","камень":"","вес":"2.73"}},"72778635":{"vendor":"МЮЗ","isAvailable":true,"price":17245,"oldPrice":24637,"size":"15.5","color":"Микс","params":{"коллекция":"Infinite love ,Обручальные кольца,Свадебное предложение","металл":"Золото","проба":"585","камень":"","вес":"3.08"}},"72866605":{"vendor":"МЮЗ","isAvailable":true,"price":14053,"oldPrice":20077,"size":"15.5","color":"Микс","params":{"коллекция":"Infinite love ,Обручальные кольца,Свадебное предложение","металл":"Золото","проба":"585","камень":"","вес":"2.51"}},"72634705":{"vendor":"МЮЗ","isAvailable":true,"price":14837,"oldPrice":21197,"size":"15.5","color":"Микс","params":{"коллекция":"Infinite love ,Обручальные кольца,Свадебное предложение","металл":"Золото","проба":"585","камень":"","вес":"2.65"}},"72861925":{"vendor":"МЮЗ","isAvailable":true,"price":15509,"oldPrice":22157,"size":"15.5","color":"Микс","params":{"коллекция":"Infinite love ,Обручальные кольца,Свадебное предложение","металл":"Золото","проба":"585","камень":"","вес":"2.77"}},"72861927":{"vendor":"МЮЗ","isAvailable":true,"price":15509,"oldPrice":22157,"size":"15.5","color":"Микс","params":{"коллекция":"Infinite love ,Обручальные кольца,Свадебное предложение","металл":"Золото","проба":"585","камень":"","вес":"2.77"}},"72632855":{"vendor":"МЮЗ","isAvailable":true,"price":15565,"oldPrice":22237,"size":"15.5","color":"Микс","params":{"коллекция":"Infinite love ,Обручальные кольца,Свадебное предложение","металл":"Золото","проба":"585","камень":"","вес":"2.78"}},"72779528":{"vendor":"МЮЗ","isAvailable":true,"price":15677,"oldP ...
#             ];
#         </script>
# <script src="/bitrix/cache/js/s1/muz/template_fadc3e3f5ad71b2793863d9c56f70b04/template_fadc3e3f5ad71b2793863d9c56f70b04_v1.js?16358445221630789"></script>
# <script src="/bitrix/cache/js/s1/muz/page_cb20c4f9247ab90a5cf9f35b420ba12d/page_cb20c4f9247ab90a5cf9f35b420ba12d_v1.js?16358445221790"></script>
# <script>
#             (function (window) {
#                 var BX = window.BX;
#                 if (BX && BX.rtb)
#                 {
#                     BX.rtb("unknown").productPage("R01-WED-00084-MIX");
#                 }
#             })(window);
#         </script>
# <script>var _ba = _ba || []; _ba.push(["aid", "f93e9ffc96fa98b7372d25c0882bdc24"]); _ba.push(["host", "miuz.ru"]); _ba.push(["ad[ct][item]", ""]);_ba.push(["ad[ct][user_id]", function(){return BX.message("USER_ID") ? BX.message("USER_ID") : 0;}]);_ba.push(["ad[ct][recommendation]", function() {var rcmId = "";var cookieValue = BX.getCookie("BITRIX_SM_RCM_PRODUCT_LOG");var productId = 3953109;var cItems = [];var cItem;if (cookieValue){cItems = cookieValue.split(".");}var i = cItems.length;while (i--){cItem = cItems[i].split("-");if (cItem[0] == productId){rcmId = cItem[1];break;}}return rcmId;}]);_ba.push(["ad[ct][v]", "2"]);(function() {var ba = document.createElement("script"); ba.type = "text/javascript"; ba.async = true;ba.src = (document.location.protocol == "https:" ? "https://" : "http://") + "bitrix.info/ba.js";var s = document.getElementsByTagName("script")[0];s.parentNode.insertBefore(ba, s);})();</script>
# <script>
#             var baseWidth = 1280,
#                 baseSize = 10,
#                 $html = $('html')
#             ;
#             _helper();
#             function _helper() {
#                 //alert($(window).width());
#                 if ($(window).width() <= 840) {
#                     baseWidth = 840;
#                     $html.addClass('mobile');
#                 } else {
#                     baseWidth = 1280;
#                     $html.removeClass('mobile');
#                 }
#                 $html.css({'font-size': Math.min($(window).width(), baseWidth) / baseWidth * baseSize + 'px'});
#             }
#         </script>
# <script>
#             if(typeof dataLayer === 'undefined'){dataLayer = [{}];}
#         </script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                 j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#             })(window,document,'script','dataLayer','GTM-KLWF6Q');</script>
# <!-- End Google Tag Manager -->
# <!-- Global site tag (gtag.js) - Google Marketing Platform -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=DC-10624467"></script>
# <script>
#                 window.dataLayer = window.dataLayer || [];
#                 function gtag(){dataLayer.push(arguments);}
#                 gtag('js', new Date());
#
#                 gtag('config', 'DC-10624467');
#             </script>
# <script>
#                     if (typeof gtag === "function")
#                     {
#                         gtag('event', 'conversion', {
#                             'allow_custom_scripts': true,
#                             'session_id': '81d9811e431bd757c3800d674f33bfd8',
#                             'send_to': 'DC-10624467/nu4xl0/rsz0t0+per_session'
#                         });
#                     }
#                 </script>
# <!-- Конец тега Global Site Tag. Не удаляйте этот код. -->
# <script>(window.Image ? (new Image()) : document.createElement('img')).src = location.protocol + '//vk.com/rtrg?r=uo84IIIYoi3yi9qoajllOwYhzD9HvGkQaN64N3AdBKA4JQFwtErKNeZxUhsMNd1iqu5gmosY9EBs13tX3z9sxfer7Iyd4xJq7hjFGmzGxMjgmHn0gl*QfSA3/nlWRtbGhcs0xOHl287Juodk0zvroXPtHo/4XEH8rbDIt/g1KjA-&pixel_id=1000038746';</script>
# <meta content="PdzGF9gKngzRb8pU7zHgoeO64I4wqtsFmkMazZ4y0Pg" name="google-site-verification"/>
# <!--Google reCAPTCHA v3 -->
# <script async="async" src="https://api.flocktory.com/v2/loader.js?site_id=2253"></script>
# <script>
#             var MAX_PRICE_FOR_BUY_FORMAT = '600 000';
#
#         </script>
# <!--  Soloway -->
# <script>
#             Soloway.init();
#         </script>
# <script>
#         $(document).ready(function () {
#             var data_prod_id = $("[data-soloway-product-id]"),
#                 prod_id = "";
#
#             if(data_prod_id.length == 1){
#                 prod_id = data_prod_id.data("soloway-product-id");
#             }
#             document.dispatchEvent(new CustomEvent("allPagesSoloway", {
#                 detail:{ user_id: "", offer_id: prod_id }
#             }));
#         });
#     </script> <!--  Soloway -->
# </head>
# <body class="body">
# <!-- End Google Tag Manager (noscript) -->
# <div data-lazy-retailrocket-markup-block="57bdcde09872e52d20f1e2a6"></div>
# <div data-lazy-retailrocket-markup-block="57bddb6b9872e52d20f1e401"></div>
# <!-- Rating@Mail.ru counter -->
# <script>
#     var _tmr = window._tmr || (window._tmr = []);
#     _tmr.push({id: "3216462", type: "pageView", start: (new Date()).getTime()});
#     (function (d, w, id) {
#         if (d.getElementById(id)) return;
#         var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#         ts.src = "https://top-fwz1.mail.ru/js/code.js";
#         var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#         if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
#     })(document, window, "topmailru-code");
# </script><noscript><div>
# <img alt="Top.Mail.Ru" src="https://top-fwz1.mail.ru/counter?id=3216462;js=na" style="border:0;position:absolute;left:-9999px;"/>
# </div></noscript>
# <!-- //Rating@Mail.ru counter -->
# <!-- Yandex.Metrika counter -->
# <script>
#     (function (d, w, c) {
#         (w[c] = w[c] || []).push(function() {
#             try {
#                 w.yaCounter5911648 = new Ya.Metrika({
#                     id:5911648,
#                     clickmap:true,
#                     trackLinks:true,
#                     accurateTrackBounce:true,
#                     webvisor:true,
#                     ecommerce:"dataLayer"
#                 });
#             } catch(e) { }
#         });
#
#         var n = d.getElementsByTagName("script")[0],
#             s = d.createElement("script"),
#             f = function () { n.parentNode.insertBefore(s, n); };
#         s.type = "text/javascript";
#         s.async = true;
#         s.src = "https://mc.yandex.ru/metrika/watch.js";
#
#         if (w.opera == "[object Opera]") {
#             d.addEventListener("DOMContentLoaded", f, false);
#         } else { f(); }
#     })(document, window, "yandex_metrika_callbacks");
# </script>
# <noscript><div><img alt="" src="https://mc.yandex.ru/watch/5911648" style="position:absolute; left:-9999px;"/></div></noscript>
# <!-- /Yandex.Metrika counter -->
# <script>
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#     ga('create', 'UA-10755722-3', 'auto');
#     ga(function(tracker) {
#         var clientId = tracker.get('clientId'); // получение clientId из Google Analytics
#         document.cookie = "_ga_cid=" + clientId + "; path=/"; // сохранение cookie в _ga_cid
#         ga('set', 'dimension1', clientId); //запись clientId для каждого пользователя
#     });
#     ga('send', 'pageview');
# </script>
# <!--<div class="loader js-loader">
#         <div class="loader_box"></div>
#     </div>-->
# <header class="header js-header">
# <div class="header__holder"></div>
# <div class="header__h" data-header-mob-indent=""></div>
# <div class="header__inner grid__inner js-header-fixed">
# <div class="header__left">
# <div class="href header__menu-btn" data-mob-menu-btn="">
# <div class="header__menu-btn-ico"></div>
# </div>
# <a class="header__tell" data-target="click_phone" href="tel:88001001920">8 (800) 100-19-20</a>
# <div class="header__city">
# <div class="city-select">
# <form action="/ajax/city.php" method="post">
# <select class="city-select__select" data-city-chosen="" name="CITY">
# <option value="Абакан">Абакан</option>
# <option value="Александров">Александров</option>
# <option value="Алматы">Алматы</option>
# <option value="Анапа">Анапа</option>
# <option value="Армавир">Армавир</option>
# <option value="Архангельск">Архангельск</option>
# <option value="Астрахань">Астрахань</option>
# <option value="Балашиха">Балашиха</option>
# <option value="Белгород">Белгород</option>
# <option value="Белебей">Белебей</option>
# <option value="Брянск">Брянск</option>
# <option value="Видное">Видное</option>
# <option value="Владивосток">Владивосток</option>
# <option value="Владикавказ">Владикавказ</option>
# <option value="Владимир">Владимир</option>
# <option value="Волгоград">Волгоград</option>
# <option value="Волгодонск">Волгодонск</option>
# <option value="Вологда">Вологда</option>
# <option value="Воронеж">Воронеж</option>
# <option value="Геленджик">Геленджик</option>
# <option value="Грозный">Грозный</option>
# <option value="Губкинский ЯНАО">Губкинский ЯНАО</option>
# <option value="Дзержинск">Дзержинск</option>
# <option value="Дмитров">Дмитров</option>
# <option value="Дубна">Дубна</option>
# <option value="Ейск">Ейск</option>
# <option value="Екатеринбург">Екатеринбург</option>
# <option value="Ессентуки">Ессентуки</option>
# <option value="Иваново">Иваново</option>
# <option value="Ижевск">Ижевск</option>
# <option value="Иркутск">Иркутск</option>
# <option value="Казань">Казань</option>
# <option value="Калининград">Калининград</option>
# <option value="Калуга">Калуга</option>
# <option value="Кемерово">Кемерово</option>
# <option value="Кинешма">Кинешма</option>
# <option value="Кисловодск">Кисловодск</option>
# <option value="Коломна">Коломна</option>
# <option value="Конаково">Конаково</option>
# <option value="Котельники">Котельники</option>
# <option value="Красногорск">Красногорск</option>
# <option value="Краснодар">Краснодар</option>
# <option value="Красноярск">Красноярск</option>
# <option value="Кропоткин">Кропоткин</option>
# <option value="Курган">Курган</option>
# <option value="Курск">Курск</option>
# <option value="Магнитогорск">Магнитогорск</option>
# <option value="Майкоп">Майкоп</option>
# <option value="Махачкала">Махачкала</option>
# <option value="Минеральные Воды">Минеральные Воды</option>
# <option value="Минск">Минск</option>
# <option value="Можайск">Можайск</option>
# <option value="Москва">Москва</option>
# <option value="Московский">Московский</option>
# <option value="Мурманск">Мурманск</option>
# <option value="Мытищи">Мытищи</option>
# <option value="Набережные Челны">Набережные Челны</option>
# <option value="Нальчик">Нальчик</option>
# <option value="Невинномысск">Невинномысск</option>
# <option value="Нефтеюганск">Нефтеюганск</option>
# <option value="Нижневартовск">Нижневартовск</option>
# <option value="Нижний Новгород">Нижний Новгород</option>
# <option value="Новоивановское">Новоивановское</option>
# <option value="Новокузнецк">Новокузнецк</option>
# <option value="Новороссийск">Новороссийск</option>
# <option value="Новосибирск">Новосибирск</option>
# <option value="Нур-Султан">Нур-Султан</option>
# <option value="Обнинск">Обнинск</option>
# <option value="Одинцово">Одинцово</option>
# <option value="Омск">Омск</option>
# <option value="Орел">Орел</option>
# <option value="Оренбург">Оренбург</option>
# <option value="Орехово-Зуево">Орехово-Зуево</option>
# <option value="Пенза">Пенза</option>
# <option value="Пермь">Пермь</option>
# <option value="Петрозаводск">Петрозаводск</option>
# <option value="Петропавловск-Камчатский">Петропавловск-Камчатский</option>
# <option value="Псков">Псков</option>
# <option value="Пушкино">Пушкино</option>
# <option value="Пятигорск">Пятигорск</option>
# <option value="Реутов">Реутов</option>
# <option value="Ржев">Ржев</option>
# <option value="Ростов-на-Дону">Ростов-на-Дону</option>
# <option value="Рязань">Рязань</option>
# <option value="Самара">Самара</option>
# <option value="Санкт-Петербург">Санкт-Петербург</option>
# <option value="Саратов">Саратов</option>
# <option value="Северодвинск">Северодвинск</option>
# <option value="Серпухов">Серпухов</option>
# <option value="Солнечногорск">Солнечногорск</option>
# <option value="Сочи">Сочи</option>
# <option value="Ставрополь">Ставрополь</option>
# <option value="Сургут">Сургут</option>
# <option value="Тверь">Тверь</option>
# <option value="Тольятти">Тольятти</option>
# <option value="Томск">Томск</option>
# <option value="Троицк">Троицк</option>
# <option value="Тула">Тула</option>
# <option value="Тюмень">Тюмень</option>
# <option value="Улан-Удэ">Улан-Удэ</option>
# <option value="Ульяновск">Ульяновск</option>
# <option value="Уфа">Уфа</option>
# <option value="Хабаровск">Хабаровск</option>
# <option value="Химки">Химки</option>
# <option value="Чебоксары">Чебоксары</option>
# <option value="Челябинск">Челябинск</option>
# <option value="Черкесск">Черкесск</option>
# <option value="Чита">Чита</option>
# <option value="Шахты">Шахты</option>
# <option value="Шымкент">Шымкент</option>
# <option value="Щелково">Щелково</option>
# <option value="Элиста">Элиста</option>
# <option value="Энгельс">Энгельс</option>
# <option value="Ярославль">Ярославль</option>
# <option value="пгт. Алексеевское">пгт. Алексеевское</option>
# </select>
# <div class="need_select_city" data-city="Москва">
# <div class="header__city-popup-arrow"></div>
# <div class="title">Ваш город <b>Москва</b>?</div>
# <div class="button_block">
# <button class="b-btn _red left">Да</button>
# <button class="b-btn _default right">Нет</button>
# </div>
# <div class="clear"></div>
# </div>
# </form>
# </div>
# </div>
# <div class="header__small-phone header__hide-mobile">
#                     Короткий номер:
#                     <span class="header__small-code"><span class="header__star"><span>*</span></span>1920</span>
# <div class="header__delivery-help-wrapper">
# <span class="header__delivery-help" data-phone-i="">i</span>
# <div class="header__delivery-help-message" data-phone-info="">
#                             Для абонентов Билайн, Мегафон, МТС, TELE2, Тинькофф мобайл.
#                         </div>
# </div>
# </div>
# </div>
# <div class="header__right"><a class="header__account b-ico__wrap link-border-solid" href="/auth/">
#                         Вход
#                     </a><a class="header__bascket b-ico__wrap link-border-solid" href="/personal/basket/">Корзина<!--<div class="header__bascket-count">--><!--</div>--></a> <div class="header__delivery">
# <div class="header__delivery-help-wrapper">
# <span class="header__delivery-help" data-delivery-i="">i</span>
# <div class="header__delivery-help-message" data-delivery-info="">
#                             Бесплатная доставка любого изделия.
#                             Заказы стоимостью от 200 тысяч рублей могут быть доставлены на дом после внесения 100% предоплаты безналичным способом или оплачены при получении в магазине.
#                         </div>
# </div>
#
#                     Бесплатная доставка
#                 </div>
# <span class="href header__search-mob" onclick="event.preventDefault();window.location.href='/search/';"></span>
# <a class="header__bascket-mob" href="/personal/basket/"></a>
# </div>
# <a class="header__logo" href="/">
# <!--<img alt="Официальный интернет-магазин производителя ювелирных украшений Московский ювелирный завод"
#      src=""/>-->
# <img alt="Официальный интернет-магазин производителя ювелирных украшений Московский ювелирный зав
,0,1,.34-.26,1.83,1.83,0,0,1,1.87,1.83.85.85,0,0,1,0,.26.26.26,0,0,1-.23.22Zm-.66-2.79a3.59,3.59,0,0,0-1-.31l-.46-.06a.29.29,0,0,1-.27-.33.29.29,0,0,1,.32-.28,4.14,4.14,0,0,1,1.74.46A3.55,3.55,0,0,1,24,17.17c0,.06,0,.11,0,.17s0,.28,0,.46A1.29,1.29,0,0,1,24,18a.3.3,0,0,1-.57,0,.81.81,0,0,1,0-.26A3.27,3.27,0,0,0,23,16.14,3,3,0,0,0,21.75,14.94Zm3.4,3.83c-.21,0-.31-.18-.32-.37,0-.38,0-.76-.1-1.14a4.77,4.77,0,0,0-3.82-4c-.3-.05-.6-.07-.9-.1s-.44,0-.48-.27a.33.33,0,0,1,.32-.37H20A5.41,5.41,0,0,1,25.3,17c.08.45.11.91.14,1.37A.32.32,0,0,1,25.15,18.78Z"></path>
# </g>
# </g>
# </svg>
# </a>
# </div>
# </div>
# <a class="footer__bottom-item-tell" data-target="click_phone" href="tel:88001001920">8(800)100-19-20</a>
# <div class="footer__bottom-gia" style="padding-top: 15px"><img src="/miuz/theme/images/gia.png"/></div>
# </div>
# </div>
# <div class="footer__bottom-copy">
# 	 Copyright © 2021 Московский ювелирный завод
# </div>
# <br/> </div>
# </div>
# </footer>
# <script async="async" src="https://yastatic.net/share2/share.js"></script>
# <!-- Garderobo AI -->
# <script src="https://widget.garderobo.ai/widget.js"></script>
# <script>
#     $(document).ready(function(){
#         Garderobo.init();
#     });
# </script>
# <!-- Garderobo AI -->
# <!-- {literal} -->
# <script>
#         $(document).ready(function(){
#             setTimeout(function() {
#                 window['liv'+'eTe'+'x'] = true,
#                     window['liv'+'eTe'+'xI'+'D'] = 111693,
#                     window['liveT'+'ex_ob'+'je'+'ct'] = true;
#                 var t = document['crea'+'t'+'eEleme'+'nt']('script');
#                 t.type ='text/javascript';
#                 t.async = true;
#                 t.src = '//cs15.live'+'tex.'+'ru/js/cli'+'en'+'t.js';
#                 var c = document['g'+'etE'+'le'+'mentsByT'+'ag'+'N'+'ame']('script')[0];
#                 if ( c ) c['par'+'en'+'t'+'N'+'ode']['i'+'nser'+'tBe'+'for'+'e'](t, c);
#                 else document['documen'+'t'+'Ele'+'men'+'t']['fi'+'rstCh'+'i'+'ld']['app'+'endCh'+'il'+'d'](t);
#             },5000);
#         });
#     </script>
# <!-- {/literal} -->
# <!-- Retail Rocket -->
# <script>
#     var rrPartnerId = "514ffe4987900a05d43e4664";
#     var rrApi = {};
#     var rrApiOnReady = rrApiOnReady || [];
#     rrApi.addToBasket = rrApi.order = rrApi.categoryView = rrApi.view =
#         rrApi.recomMouseDown = rrApi.recomAddToCart = function () {
#         };
#     (function (d) {
#         var ref = d.getElementsByTagName('script')[0];
#         var apiJs, apiJsId = 'rrApi-jssdk';
#         if (d.getElementById(apiJsId)) return;
#         apiJs = d.createElement('script');
#         apiJs.id = apiJsId;
#         apiJs.async = true;
#         apiJs.src = "//cdn.retailrocket.ru/content/javascript/tracking.js";
#         ref.parentNode.insertBefore(apiJs, ref);
#     }(document));
# </script>
# <!-- Retail Rocket -->
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-KLWF6Q" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!--пиксель продублирован  в файле /certificates/index.php-->
# <!-- Facebook Pixel Code -->
# <script>
#         !function (f, b, e, v, n, t, s) {
#             if (f.fbq) return;
#             n = f.fbq = function () {
#                 n.callMethod ? n.callMethod.apply(n, arguments) : n.queue.push(arguments)
#             };
#             if (!f._fbq) f._fbq = n;
#             n.push = n;
#             n.loaded = !0;
#             n.version = '2.0';
#             n.queue = [];
#             t = b.createElement(e);
#             t.async = !0;
#             t.src = v;
#             s = b.getElementsByTagName(e)[0];
#             s.parentNode.insertBefore(t, s)
#         }(window, document, 'script', 'https://connect.facebook.net/en_US/fbevents.js');
#         fbq('init', '650512918440434');
#         fbq('track', 'PageView');
#     </script>
# <!-- End Facebook Pixel Code -->
# <!-- Facebook Pixel Code -->
# <script>
#         !function (f, b, e, v, n, t, s) {
#             if (f.fbq) return;
#             n = f.fbq = function () {
#                 n.callMethod ?
#                     n.callMethod.apply(n, arguments) : n.queue.push(arguments)
#             };
#             if (!f._fbq) f._fbq = n;
#             n.push = n;
#             n.loaded = !0;
#             n.version = '2.0';
#             n.queue = [];
#             t = b.createElement(e);
#             t.async = !0;
#             t.src = v;
#             s = b.getElementsByTagName(e)[0];
#             s.parentNode.insertBefore(t, s)
#         }(window, document, 'script',
#             'https://connect.facebook.net/en_US/fbevents.js');
#         fbq('init', '681116522342148');
#         fbq('track', 'PageView');
#     </script>
# <noscript><img alt="" height="1" src="https://www.facebook.com/tr?id=681116522342148&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <!-- VK Remarketing -->
# <script>
#         var PIXEL_ID = 'VK-RTRG-38746-4FC1F';
#         var PRICE_LIST_ID = '126981';
#     </script>
# <div id="vk_api_transport"></div>
# <!--<script>
#         window.vkAsyncInit = function() {
#             VK.Retargeting.Init(PIXEL_ID);
#         };
#
#         setTimeout(function() {
#             var el = document.createElement("script");
#             el.type = "text/javascript";
#             el.src = "https://vk.com/js/api/openapi.js?150";
#             el.async = true;
#             document.getElementById("vk_api_transport").appendChild(el);
#         }, 0);
#     </script>-->
# <script>!function(){var t=document.createElement("script");t.type="text/javascript",t.async=!0,t.src="https://vk.com/js/api/openapi.js?169",t.onload=function(){VK.Retargeting.Init("VK-RTRG-943158-afU3I"),VK.Retargeting.Hit()},document.head.appendChild(t)}();</script><noscript><img alt="" src="https://vk.com/rtrg?p=VK-RTRG-943158-afU3I" style="position:fixed; left:-999px;"/></noscript>
# <!--RTBHouse-->
# <script>
#         (function (window) {
#             var BX = window.BX;
#             if (BX && BX.rtb)
#             {
#                 BX.rtb('unknown').page();
#             }
#         })(window);
#     </script>
# </body>
# </html>

# %%
quotes[1].prettify()
# Out:
# '<div class="product">\n <a data-href="/catalog/rings/R01-WED-00147-RW/" href="/catalog/rings/R01-WED-00147-RW/" onclick="" title="Кольцо c бриллиантом">\n </a>\n <div class="product__discount">\n  NEW\n </div>\n <div class="product__inner">\n  <div class="product__img js-lazyload" data-src="/upload/resize_cache/iblock/9fc/242_254_2a1fde8d5e7dcaa11be442336c9d37f5e/R01_WED_00147_RW.jpg" data-time="1000">\n  </div>\n  <div class="product__price">\n   <div class="product__price-discount">\n    40%\n   </div>\n   <div class="product__price-old">\n    55 990\n   </div>\n   <div class="product__price-new">\n    <sup>\n     от\n    </sup>\n    <span class="product__price-val">\n     33 594\n    </span>\n    <span class="rub">\n    </span>\n   </div>\n   <div class="product__sizes product__sizes_cart">\n    <div class="product__sizes-price product__sizes-price_credit" data-target="credit_item">\n     <span class="href href-additionally">\n      в кредит от\n     </span>\n     <span class="product__price-new">\n      3 359\n      <span class="rub">\n      </span>\n     </span>\n    </div>\n   </div>\n  </div>\n </div>\n <div class="product__overlay">\n  <div class="product__info">\n   <div class="product__name_catalog_list">\n    Кольцо c бриллиантом\n   </div>\n   <span>\n    Цвет металла:\n   </span>\n   <span class="product__colors">\n    <span class="href" onclick="event.preventDefault();window.location.href=\'/catalog/rings/R01-WED-00147-RW/?PROPERTY_METALL_COLOR=1458749192_19\';BX &amp;&amp; BX.rtb ? BX.rtb(\'unknown\').sizeProduct(\'Красно-Белый\') : \'\'">\n     <span class="ico-mix" style="background-image: url(\'/upload/uf/c64/c64f49f0d7cf3bc7319fdf8dd9aa6220.jpg\');">\n     </span>\n    </span>\n   </span>\n   <span>\n    Размеры в наличии:\n   </span>\n   <span class="product__sizes">\n    <span class="href" onclick="event.preventDefault();window.location.href=\'/catalog/rings/R01-WED-00147-RW/?PROPERTY_ITEM_SIZE=1470930096_8\'; BX &amp;&amp; BX.rtb ? BX.rtb(\'unknown\').sizeProduct(\'15.5\') : \'\'">\n     15.5\n    </span>\n    <span class="href" onclick="event.preventDefault();window.location.href=\'/catalog/rings/R01-WED-00147-RW/?PROPERTY_ITEM_SIZE=1470930096_7\'; BX &amp;&amp; BX.rtb ? BX.rtb(\'unknown\').sizeProduct(\'16\') : \'\'">\n     16\n    </span>\n    <span class="href" onclick="event.preventDefault();window.location.href=\'/catalog/rings/R01-WED-00147-RW/?PROPERTY_ITEM_SIZE=1470930096_5\'; BX &amp;&amp; BX.rtb ? BX.rtb(\'unknown\').sizeProduct(\'16.5\') : \'\'">\n     16.5\n    </span>\n    <span class="href" onclick="event.preventDefault();window.location.href=\'/catalog/rings/R01-WED-00147-RW/?PROPERTY_ITEM_SIZE=1470930096_1\'; BX &amp;&amp; BX.rtb ? BX.rtb(\'unknown\').sizeProduct(\'17\') : \'\'">\n     17\n    </span>\n    <span class="href" onclick="event.preventDefault();window.location.href=\'/catalog/rings/R01-WED-00147-RW/?PROPERTY_ITEM_SIZE=1470930096_4\'; BX &amp;&amp; BX.rtb ? BX.rtb(\'unknown\').sizeProduct(\'17.5\') : \'\'">\n     17.5\n    </span>\n   </span>\n   <br/>\n   <div class="product__sizes">\n    <div class="product__sizes-icon">\n    </div>\n    <div class="product__sizes-price" data-target="credit_listing">\n     <span class="href" onclick="event.preventDefault();window.location.href=\'/credit/\';">\n      в кредит от\n     </span>\n     <span class="product__price-new">\n      3 527\n      <span class="rub">\n      </span>\n     </span>\n    </div>\n   </div>\n  </div>\n </div>\n</div>\n'

# %%
name = str(quotes[2].find('div',"product__name_catalog_list"))
name = name.replace('<div class="product__name_catalog_list">\n','').replace('</div>','').strip()
name
# Out:
# 'Кольцо c бриллиантами и сапфиром'

# %%
pricenew = str(quotes[2].find('span',"product__price-new"))
pricenew.replace('<span class="product__price-new">','').replace( '<span class="rub"></span>\n</span>','').strip()
# Out:
# '19 149'

# %%
quotes0[3].find('span', 'link__text')
# Out:
# <span class="link__text">Фонд медицинских решений "Не напрасно"</span>

# %%
type(quotes0[3])
# Out:
# bs4.element.Tag

# %%
quotes[1].find('span',"href")
# Out:
# <span class="href href-additionally">в кредит от</span>

# %%
quotes[1].find('div',"product__name_catalog_list")
# Out:
# <div class="product__name_catalog_list">
#                             Кольцо                        </div>

# %%
quotes[1]
# Out:
# <div class="product">
# <a data-href="/catalog/rings/R01-WED-00084-MIX/" href="/catalog/rings/R01-WED-00084-MIX/" onclick="" title="Кольцо"></a>
# <div class="product__inner">
# <div class="product__img js-lazyload" data-src="/upload/resize_cache/iblock/4c3/242_254_2a1fde8d5e7dcaa11be442336c9d37f5e/R01_WED_00084_MIX.jpg" data-time="1000"></div>
# <div class="product__price">
# <div class="product__price-discount">30%</div>
# <div class="product__price-old">20 077</div>
# <div class="product__price-new">
# <sup>от</sup><span class="product__price-val">14 054</span><span class="rub"></span>
# </div>
# <div class="product__sizes product__sizes_cart">
# <div class="product__sizes-price product__sizes-price_credit" data-target="credit_item">
# <span class="href href-additionally">в кредит от</span>
# <span class="product__price-new">1 405                                        <span class="rub"></span>
# </span>
# </div>
# </div>
# </div>
# </div>
# <div class="product__overlay">
# <div class="product__info">
# <div class="product__name_catalog_list">
#                             Кольцо                        </div>
# <span>Цвет металла:</span>
# <span class="product__colors">
# <span class="href" onclick="event.preventDefault();window.location.href='/catalog/rings/R01-WED-00084-MIX/?PROPERTY_METALL_COLOR=1458749192_3';BX &amp;&amp; BX.rtb ? BX.rtb('unknown').sizeProduct('Микс') : ''">
# <span class="ico-mix" style="background-image: url('/upload/uf/8be/8bed98e53a9eb8a5f45c1dd80d141014.png');"></span>
# </span>
# </span>
# <span>Размеры в наличии:</span>
# <span class="product__sizes">
# <span class="href" onclick="event.preventDefault();window.location.href='/catalog/rings/R01-WED-00084-MIX/?PROPERTY_ITEM_SIZE=1470930096_8'; BX &amp;&amp; BX.rtb ? BX.rtb('unknown').sizeProduct('15.5') : ''">15.5</span>
# <span class="href" onclick="event.preventDefault();window.location.href='/catalog/rings/R01-WED-00084-MIX/?PROPERTY_ITEM_SIZE=1470930096_7'; BX &amp;&amp; BX.rtb ? BX.rtb('unknown').sizeProduct('16') : ''">16</span>
# <span class="href" onclick="event.preventDefault();window.location.href='/catalog/rings/R01-WED-00084-MIX/?PROPERTY_ITEM_SIZE=1470930096_5'; BX &amp;&amp; BX.rtb ? BX.rtb('unknown').sizeProduct('16.5') : ''">16.5</span>
# <span class="href" onclick="event.preventDefault();window.location.href='/catalog/rings/R01-WED-00084-MIX/?PROPERTY_ITEM_SIZE=1470930096_1'; BX &amp;&amp; BX.rtb ? BX.rtb('unknown').sizeProduct('17') : ''">17</span>
# <span class="href" onclick="event.preventDefault();window.location.href='/catalog/rings/R01-WED-00084-MIX/?PROPERTY_ITEM_SIZE=1470930096_4'; BX &amp;&amp; BX.rtb ? BX.rtb('unknown').sizeProduct('17.5') : ''">17.5</span>
# <span class="href" onclick="event.preventDefault();window.location.href='/catalog/rings/R01-WED-00084-MIX/?PROPERTY_ITEM_SIZE=1470930096_3'; BX &amp;&amp; BX.rtb ? BX.rtb('unknown').sizeProduct('18') : ''">18</span>
# <span class="href" onclick="event.preventDefault();window.location.href='/catalog/rings/R01-WED-00084-MIX/?PROPERTY_ITEM_SIZE=1470930096_2'; BX &amp;&amp; BX.rtb ? BX.rtb('unknown').sizeProduct('18.5') : ''">18.5</span>
# <span class="href" onclick="event.preventDefault();window.location.href='/catalog/rings/R01-WED-00084-MIX/?PROPERTY_ITEM_SIZE=1470930096_9'; BX &amp;&amp; BX.rtb ? BX.rtb('unknown').sizeProduct('19') : ''">19</span>
# <span class="href" onclick="event.preventDefault();window.location.href='/catalog/rings/R01-WED-00084-MIX/?PROPERTY_ITEM_SIZE=1470930096_10'; BX &amp;&amp; BX.rtb ? BX.rtb('unknown').sizeProduct('19.5') : ''">19.5</span>
# <span class="href" onclick="event.preventDefault();window.location.href='/catalog/rings/R01-WED-00084-MIX/?PROPERTY_ITEM_SIZE=1470929229_12'; BX &amp;&amp; BX.rtb ? BX.rtb('unknown').sizeProduct('20') : ''">20</span>
# <span class="href" onclick="event.preventDefault();window.location.href='/catalog/rings/R01-WED-00084-MIX/?PROPERTY_ITEM_SIZE=1470930096_6'; BX &amp;&amp; BX.rtb ? BX.rtb('unknown').sizeProduct('20.5') : ''">20.5</span>
# <span class="href" onclick="event.preventDefault();window.location.href='/catalog/rings/R01-WED-00084-MIX/?PROPERTY_ITEM_SIZE=1470930096_18'; BX &amp;&amp; BX.rtb ? BX.rtb('unknown').sizeProduct('21') : ''">21</span>
# </span>
# <br/>
# <div class="product__sizes">
# <div class="product__sizes-icon"></div>
# <div class="product__sizes-price" data-target="credit_listing">
# <span class="href" onclick="event.preventDefault();window.location.href='/credit/';">в кредит от</span>
# <span class="product__price-new">1 429                                        <span class="rub"></span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>

# %%
for i in range(len(quotes)):
    print('---\n', i, quotes[i].find()) )
# Out:
# ---
#  0 <class 'bs4.element.Tag'>
# ---
#  1 <class 'bs4.element.Tag'>
# ---
#  2 <class 'bs4.element.Tag'>
# ---
#  3 <class 'bs4.element.Tag'>
# ---
#  4 <class 'bs4.element.Tag'>
# ---
#  5 <class 'bs4.element.Tag'>
# ---
#  6 <class 'bs4.element.Tag'>
# ---
#  7 <class 'bs4.element.Tag'>
# ---
#  8 <class 'bs4.element.Tag'>
# ---
#  9 <class 'bs4.element.Tag'>
# ---
#  10 <class 'bs4.element.Tag'>
# ---
#  11 <class 'bs4.element.Tag'>
# ---
#  12 <class 'bs4.element.Tag'>
# ---
#  13 <class 'bs4.element.Tag'>
# ---
#  14 <class 'bs4.element.Tag'>
# ---
#  15 <class 'bs4.element.Tag'>
# ---
#  16 <class 'bs4.element.Tag'>
# ---
#  17 <class 'bs4.element.Tag'>
# ---
#  18 <class 'bs4.element.Tag'>
# ---
#  19 <class 'bs4.element.Tag'>
# ---
#  20 <class 'bs4.element.Tag'>
# ---
#  21 <class 'bs4.element.Tag'>
# ---
#  22 <class 'bs4.element.Tag'>
# ---
#  23 <class 'bs4.element.Tag'>
# ---
#  24 <class 'bs4.element.Tag'>
# ---
#  25 <class 'bs4.element.Tag'>
# ---
#  26 <class 'bs4.element.Tag'>
# ---
#  27 <class 'bs4.element.Tag'>
# ---
#  28 <class 'bs4.element.Tag'>
# ---
#  29 <class 'bs4.element.Tag'>
# ---
#  30 <class 'bs4.element.Tag'>
# ---
#  31 <class 'bs4.element.Tag'>
# ---
#  32 <class 'bs4.element.Tag'>
# ---
#  33 <class 'bs4.element.Tag'>
# ---
#  34 <class 'bs4.element.Tag'>
# ---
#  35 <class 'bs4.element.Tag'>
# ---
#  36 <class 'bs4.element.Tag'>
# ---
#  37 <class 'bs4.element.Tag'>
# ---
#  38 <class 'bs4.element.Tag'>
# ---
#  39 <class 'bs4.element.Tag'>
# ---
#  40 <class 'bs4.element.Tag'>
# ---
#  41 <class 'bs4.element.Tag'>
# ---
#  42 <class 'bs4.element.Tag'>
# ---
#  43 <class 'bs4.element.Tag'>
# ---
#  44 <class 'bs4.element.Tag'>
# ---
#  45 <class 'bs4.element.Tag'>
# ---
#  46 <class 'bs4.element.Tag'>
# ---
#  47 <class 'bs4.element.Tag'>
# ---
#  48 <class 'bs4.element.Tag'>
# ---
#  49 <class 'bs4.element.Tag'>

# %%
quotes0[1]
# Out:
# <div class="cols__column cols__column_small_percent-100 cols__column_medium_percent-50 cols__column_large_percent-50"><div class="cols__inner"><div class="p-fund margin_bottom_40 margin_right_20"><div class="tbl tbl_width_full"><span class="cell cell_left padding_right_20"><div class="p-fund__image"><span class="photo photo_full"><div class="photo__inner"><span class="photo__pic" style="background-image:url(/media/images/thumbnails/bWMZOGuojhn2nfiGl_6pa53aN8pk4Ewri42QU-ZC_n9q0OGz0_RfBFBE5pxCtJubUa0PPEXausWuCxxfyCtsdbINIlTt8SQXL3kbMjjpaGb732CgK2Q914XtwkzdU8foSE5bL0mWxgUfV1U9u4Hs3ZHBkrx7WYtZwiLwBS3cPvH9i3ncmFe0gmmtkZdUjPd_DjE6pzpiYLvT8qDEB1L-_cjSKfPIMVCMIUh9dsPVwk4KXpTJcFTyPY7W0zcWnRXPybrLhofa_MuleCws5K8GymQrTXW_IMtdE-Jg17IIKXI314d74U0ftyIO4AC0LgFFN-NIE83ym7qKuVT2JnetBw==.png)"></span></div></span></div></span><span class="cell"><div class="p-fund__city margin_bottom_5">Москва</div><a class="link link_font_large margin_bottom_10 link-holder" href="/funds/fond-podderzhki-nauchnyih-issledovanij-v-onkologii-rakfond/" name="clb27912367"><span class="link__text">РакФонд</span></a><div class="cols"><div class="cols__wrapper"></div></div></span></div></div></div></div>

# %%
if len(quotes) != 0:
    for i in range(len(quotes)):
        name = str(quotes[i].find('span', 'link__text'))
        name = name.replace('<span class="link__text">', '')
        name = name.replace('</span>', '')
        
        url = str(quotes[i].find('a', 'link link_font_large margin_bottom_10 link-holder'))
        url = url.replace('<a class="link link_font_large margin_bottom_10 link-holder" href="', 'https://dobro.mail.ru')
        url = url.split('"')[0]
        
        city = str(quotes[i].find('div', 'p-fund__city margin_bottom_5'))
        city = city.replace('<div class="p-fund__city margin_bottom_5">', '')
        city = city.replace('</div>', '')
        
        responses = requests.get(url)
        soups = BeautifulSoup(responses.text, 'lxml')
        
        site = soups.find_all('div', class_='p-fund-detail__info-row')
        if str(site[0].find('a', 'link')) == None:
            site = str(site[0].find('a', 'link'))
            site = site.replace('<span class="link__text">', '')
            site = site.replace('</span>', '')
        else:
            site = str(site[1].find('a', 'link'))
            site = site.replace('<span class="link__text">', '')
            site = site.split('"')[3]
        
        print(name + '\n' + city + '\n' + url + '\n' + site + '\n')
else:
    print('Нет')
# Out:
# БРОО «Святое Белогорье против детского рака»
# Белгород
# https://dobro.mail.ru/funds/broo-svyatoe-belogore-protiv-detskogo-raka/
# http://www.zhiznplus.ru/
#
# РакФонд
# Москва
# https://dobro.mail.ru/funds/fond-podderzhki-nauchnyih-issledovanij-v-onkologii-rakfond/
# https://www.rakfond.org/
#
# Благотворительный фонд «Жизнь»
# Москва
# https://dobro.mail.ru/funds/blagotvoritelnyij-fond-zhizn/
# http://www.deti-life.ru/
#
# Фонд медицинских решений "Не напрасно"
# Санкт-Петербург
# https://dobro.mail.ru/funds/fond-profilaktiki-raka/
# https://nenaprasno.ru/
#
# Челябинское региональное благотворительное движение помощи онкобольным детям «Искорка Фонд»
# Челябинск
# https://dobro.mail.ru/funds/chelyabinskoe-regionalnoe-blagotvoritelnoe-dvizhenie-iskorka-fond/
# https://onco74.ru/
#
# Благотворительный фонд помощи детям с неизлечимыми заболеваниями имени Ани Чижовой
# Чебоксары
# https://dobro.mail.ru/funds/blagotvoritelnyij-fond-pomoschi-detyam-s-neizlechimyimi-zabolevaniyami-imeni-ani-chizhovoj/
# https://fondani.ru
#
# РОО «Экологическая вахта Сахалина»
# Южно-Сахалинск
# https://dobro.mail.ru/funds/fond-ekovakhta/
# https://ecosakh.ru/
#
# Благотворительный фонд помощи женщинам с онкологическими заболеваниями «Дальше»
# Москва
# https://dobro.mail.ru/funds/blagotvoritelnyij-fond-pomoschi-zhenschinam-s-onkologicheskimi-zabolevaniyami-dalshe/
# https://dalshefond.ru/
#
# Фонд социальных программ и поддержки женщин «Александра»
# Москва
# https://dobro.mail.ru/funds/fond-sotsialnyih-programm-i-podderzhki-zhenschin-aleksandra/
# http://fondaleksandra.ru/
#
# Благотворительный фонд «Предание»
# Москва
# https://dobro.mail.ru/funds/blagotvoritelnyij-fond-predanie/
# https://fond.predanie.ru
#
# Благотворительный фонд помощи хосписам «Вера»
# Москва
# https://dobro.mail.ru/funds/blagotvoritelnyij-fond-pomoschi-hospisam-vera/
# http://www.hospicefund.ru/
#
# Благотворительный фонд «Бюро Добрых Дел»
# Астрахань, Кострома, Нижний Новгород, Саратов, Уфа
# https://dobro.mail.ru/funds/blagotvoritelnyij-fond-byuro-dobryih-del/
# http://www.burodd.ru/
#
# Фонд борьбы с инсультом ОРБИ
# Москва
# https://dobro.mail.ru/funds/mezhregionalnyj-fond-pomoshi-rodstvennikam-bolnyh-s-insultom-orbi/
# http://www.orbifond.ru/
#
# Благотворительный фонд помощи тяжелобольным детям «Потерь нет»
# Уфа
# https://dobro.mail.ru/funds/blagotvoritelnyij-fond-pomoschi-tyazhelobolnyim-detyam-poter-net-3/
# http://poter-net.ru/
