# %%
import numpy as np
import pandas as pd
import re
import os

# %%
import matplotlib.pyplot as plt

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
# %matplotlib notebook
#%matplotlib inline

# %%
files = os.listdir('.')
[nf for nf in enumerate(files)]
# Out:
# [(0, '.DS_Store'),
#  (1, '.git'),
#  (2, '.idea'),
#  (3, '.ipynb_checkpoints'),
#  (4, 'env'),
#  (5, 'for_parsing_func.ipynb'),
#  (6, 'jewels'),
#  (7, 'Parsing.html'),
#  (8, 'ParsingMiuz.ipynb'),
#  (9, 'ParsingNKObyAita.ipynb'),
#  (10, 'requiremnts.txt'),
#  (11, 'rusprice'),
#  (12, 'Untitled.ipynb'),
#  (13, 'visio_matplotlib.ipynb')]

# %%
path = files[6]
files1 = os.listdir(path)
[nf for nf in enumerate(files1)]
# Out:
# [(0, '.DS_Store'), (1, 'miuz')]

# %%
path1 = files1[1]
path2 = path+'/'+path1
files2 = os.listdir(path2)
[nf for nf in enumerate(files2)]
# Out:
# [(0, '_diamonds_mius161121_0-3178.xlsx'),
#  (1, '_droping_2021-11-12-18-51mius1-6.xlsx'),
#  (2, '_droping_2021-11-18-09-29mius161121_0-3178.xlsx'),
#  (3, '_droping_2021-11-18-09-34mius161121_0-3178.xlsx'),
#  (4, '_droping_2021-11-18-09-36mius161121_0-3178.xlsx'),
#  (5, '_droping_2021-11-18-09-52mius161121_0-3178.xlsx'),
#  (6, '_droping_2021-11-18-09-55mius161121_0-3178.xlsx'),
#  (7, '_failed_containsnodiamonds_mius1-6.xlsx'),
#  (8, '_failed_frommius1-6.xlsx'),
#  (9, '_брилл_в_строку_mius1-6.xlsx'),
#  (10, '_брилл_в_строку_mius161121_0-3178.xlsx'),
#  (11, '_брилл_суммированы_mius1-6.xlsx'),
#  (12, '_брилл_суммированы_mius161121_0-3178.xlsx'),
#  (13, '_пред_анализом_брилл_суммированы_mius161121_0-3178.xlsx'),
#  (14, 'links5500_16112021.xlsx'),
#  (15, 'mius1-6.xlsx'),
#  (16, 'mius161121_0-3178.xlsx')]

# %%
data = pd.read_excel(path2+'/'+files2[11]).loc[:,['price','weight','prcost']]

# %%
data
# Out:
#       price  weight  prcost
# 0     57745    1.25  108.00
# 1     33594    1.89   20.40
# 2     38094    2.59   10.20
# 3     65940    3.64   71.80
# 4    194994    3.98  336.84
# ..      ...     ...     ...
# 100   14996    1.50    6.30
# 101   95940    2.76  120.00
# 102   55960    3.15   92.15
# 103   38940    1.49   39.60
# 104  131940    3.91  200.25
#
# [105 rows x 3 columns]

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(data.weight,data.prcost,data.price/1000)
ax.set_xlabel('вес изделия, \n грамм')
ax.set_ylabel('прейск ст-ть \n брилл, долл')
ax.set_zlabel('ст-ть изделия,\n тыс.руб')
ax.view_init(0,0)
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">

# %%
ax.plot_surface(data.weight,data.prcost,data.price/1000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-b02fcce9f261> in <module>()
# ----> 1 ax.plot_surface(data.weight,data.prcost,data.price/1000)
#
# ~/anaconda3/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot_surface(self, X, Y, Z, *args, **kwargs)
#    1620
#    1621         if Z.ndim != 2:
# -> 1622             raise ValueError("Argument Z must be 2-dimensional.")
#    1623         # TODO: Support masked arrays
#    1624         X, Y, Z = np.broadcast_arrays(X, Y, Z)
#
# ValueError: Argument Z must be 2-dimensional.

# %%
#fig = plt.figure(figsize=(5,5))

#ax_3d = Axes3D(fig)

# %%
type(ax)
# Out:
# matplotlib.axes._subplots.Axes3DSubplot

# %%
x = np.linspace(0,100,11)

# %%
y = abs(50*np.cos(x))

# %%
y
# Out:
# array([50.        , 41.95357645, 20.40410309,  7.71257249, 33.34690308,
#        48.24830142, 47.62064902, 31.66596015,  5.51936219, 22.40368081,
#        43.11594361])

# %%
type(ax_3d)
# Out:
# NoneType

# %%
f = ax_3d

# %%
# %matplotlib inline

# %%
f = plt.figure(figsize=(7,7))
f.add_axes([0,0,1,1])

# %%
plt.show()

# %%
fig = plt.figure(figsize=(7,4))

# %%
ax_3d = f.add_subplot(projection = '3D')

# %%
plt.show()

# %%
ff = plt.figure()
ff.add_axes([0,0,100,100])

# %%
ff.show()
# Out:
# /Users/mac1/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
